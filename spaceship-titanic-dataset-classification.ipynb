# %% [markdown]
# <a href="https://www.kaggle.com/code/averilkan/spaceship-titanic-dataset-classification?scriptVersionId=221807050" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 💡 About The Competition: Spaceship Titanic
#
# Task:
# The objective of this task is to predict whether a passenger was transported to an alternate dimension aboard the Spaceship Titanic. This binary classification problem requires the model to predict the 'Transported' status (True or False) for each passenger in the test dataset, based on a variety of features provided.
#
# Dataset:
# The dataset for this competition includes information about passengers aboard the fictional spaceship Titanic. Features include demographic data, cabin information, and details about their in-ship expenditures. The target variable is Transported.
#
# Exploration:
# Begin with exploratory data analysis (EDA) to understand the distribution and relationships of features. Utilize visualization techniques to identify patterns and anomalies that could influence the predictive model's performance.
#
# Evaluation:
# Submissions are evaluated on the accuracy of the predictions. A higher accuracy score indicates a more effective model at classifying passengers' transportation status.
#
# Submission Files:
# train.csv - The training dataset, including the target variable Transported.
# test.csv - The test dataset, where predictions are to be made.
# sample_submission.csv - A sample submission file in the correct format.
# Evaluation Metric:
# The competition uses accuracy as the metric for evaluating submissions. This metric assesses the proportion of correctly predicted outcomes to total predictions.

# %% [markdown]
# # 1. Importing libraries

# %% [markdown]
# ## 💡 About The Packages:
#
# - **NumPy** and **Pandas** for data manipulation and analysis.
# - **Matplotlib** and **Seaborn** for data visualization.
# - **Warnings** to manage warning messages.
# - **lazypredict** for quick model comparison.
# - **Scikit-learn**, **XGBoost**, **LightGBM**, **CatBoost**, and other machine learning libraries for model building and evaluation.

# %%
# !pip install lazypredict

import io
import sys
import tensorflow as tf
import tensorflow_decision_forests as tfdf
import xgboost as xgb
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import category_encoders as ce

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score

from IPython.utils.io import capture_output

from hyperopt import hp, fmin, tpe, Trials

from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args

from contextlib import redirect_stdout, redirect_stderr
from IPython.utils.io import capture_output
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.13-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.1.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.4.0)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.2.0)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Downloading lazypredict-0.2.13-py2.py3-none-any.whl (12 kB)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.13
# 2025-02-10 14:11:00.458093: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 14:11:00.458222: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 14:11:00.667044: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # 2. Reading the Datasets
#
# We start by reading the training and test datasets using the Pandas library. The training dataset contains the target variable `Transported`, which indicates whether a passenger was transported to another dimension. We convert this column to an integer type for compatibility with machine learning algorithms.
#
# We then concatenate the train and test datasets for combined preprocessing and feature engineering. This helps to ensure consistency in data processing and avoid data leakage.

# %%
train_data = pd.read_csv("/kaggle/input/spaceship-titanic/train.csv")
train_data['Transported'] = train_data['Transported'].astype(int)
train_data.head()

test_data = pd.read_csv("/kaggle/input/spaceship-titanic/test.csv")
test_data.head()

train_data['Source'] = 'train'
test_data['Source'] = 'test'

df = pd.concat([train_data, test_data], axis=0)

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) involves summarizing and visualizing the main characteristics of the data. This step helps us understand the structure of the dataset, identify patterns, detect anomalies, and check assumptions.
#
# We create a summary function to give an overview of the dataset, including:
# - The number of unique values in each column.
# - The number of missing values in each column.
# - The data types of each column.
#
# This overview helps us identify any issues that need to be addressed during data preprocessing.

# %%
def summary(df):
    print(f"Dataset has {df.shape[1]} features and {df.shape[0]} examples.")
    summary = pd.DataFrame(index=df.columns)
    summary["Unique"] = df.nunique().values
    summary["Missing"] = df.isnull().sum().values
    summary["Duplicated"] = df.duplicated().sum()
    summary["Types"] = df.dtypes
    return summary

summary(df)
# Out:
# Dataset has 15 features and 12970 examples.
#               Unique  Missing  Duplicated    Types
# PassengerId    12970        0           0   object
# HomePlanet         3      288           0   object
# CryoSleep          2      310           0   object
# Cabin           9825      299           0   object
# Destination        3      274           0   object
# Age               80      270           0  float64
# VIP                2      296           0   object
# RoomService     1578      263           0  float64
# FoodCourt       1953      289           0  float64
# ShoppingMall    1367      306           0  float64
# Spa             1679      284           0  float64
# VRDeck          1642      268           0  float64
# Name           12629      294           0   object
# Transported        2     4277           0  float64
# Source             2        0           0   object

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ### 4.1 Extract Group Size from `PassengerId`
#
# A unique Id for each passenger takes the form `gggg_pp` where `gggg` indicates a group the passenger is travelling with and `pp` is their number within the group. People in a group are often family members, but not always. Extracting the group size can help us understand the potential impact of group travel on the likelihood of being transported.

# %%
group = df['PassengerId'].apply(lambda x: x.split('_')[0]).value_counts().to_dict()
df['Group_size'] = df['PassengerId'].apply(lambda x: group[x.split('_')[0]])
df.set_index('PassengerId', inplace=True)

# %% [markdown]
# ### 4.2 Handle Missing Values in `HomePlanet`
#
# The `HomePlanet` column indicates the planet the passenger is from. To fill missing values, we use a random selection based on the distribution of existing values in the column. This helps maintain the original distribution of `HomePlanet` in the dataset.

# %%
v = df['HomePlanet'].value_counts().index
p = df['HomePlanet'].value_counts(normalize=True).values
df.loc[df['HomePlanet'].isna(), 'HomePlanet'] = np.random.choice(v, df['HomePlanet'].isna().sum(), p=p)

# %% [markdown]
# ### 4.3 Handle Missing Values in CryoSleep
#
# The `CryoSleep` column indicates whether the passenger elected to be put into suspended animation for the duration of the voyage. Given that being in CryoSleep is a notable status that would likely be recorded, missing values are assumed to indicate passengers were not in CryoSleep. Thus, we fill missing values with 0 and convert this column to an integer type.

# %%
df['CryoSleep'] = df['CryoSleep'].fillna(0).astype(int)

# %% [markdown]
# ### 4.4 Extract Cabin Components and Handle Missing Values
#
# The `Cabin` column provides information about the passenger's cabin, including the deck, number, and side. We extract these components into separate columns and handle missing values by randomly assigning values based on the distribution of the existing data.

# %%
tmp = df['Cabin'].apply(lambda x: x.split('/') if isinstance(x, str) else ['-1', '-1', '-1']).to_list()
tmp = np.array(tmp)

df['Cabin_deck'] = tmp[:, 0]
df['Cabin_num'] = tmp[:, 1].astype(int)
df['Cabin_side'] = pd.Series(tmp[:, 2]).map({'S': 0, 'P': 1})

df.drop(columns='Cabin', inplace=True)

df.loc[df['Cabin_deck'] == '-1', 'Cabin_deck'] = np.random.choice(['F', 'G'], sum(df['Cabin_deck'] == '-1'), p=[0.5, 0.5])
df.loc[df['Cabin_side'].isna(), 'Cabin_side'] = np.random.choice([0, 1], sum(df['Cabin_side'].isna()), p=[0.5, 0.5])

# %% [markdown]
# ### 4.5 Handle Missing Values in `Destination`
#
# The `Destination` column indicates the destination of the passenger. We fill missing values by randomly assigning values based on the distribution of the existing data. This maintains the original distribution of `Destination` in the dataset.

# %%
v = df['Destination'].value_counts().index
p = df['Destination'].value_counts(normalize=True).values
df.loc[df['Destination'].isna(), 'Destination'] = np.random.choice(v, df['Destination'].isna().sum(), p=p)

# %% [markdown]
# ### 4.6 Handle Missing Values in `Age`
#
# The `Age` column indicates the age of the passenger. To fill missing values, we use a random sample from a normal distribution with the mean and standard deviation of the existing ages. This helps maintain the original distribution of `Age` in the dataset.

# %%
mean_age = df["Age"].mean()
std_age = df["Age"].std()
is_null = df["Age"].isnull().sum()
rand_sample = np.random.uniform(mean_age - std_age, mean_age + std_age, size = is_null)
df.loc[df['Age'].isna(), 'Age'] = rand_sample

# %% [markdown]
# ### 4.7 Handle Missing Values in `VIP`
#
# The `VIP` column indicates whether the passenger paid for special VIP service during the voyage. We fill missing values with `False` (0), assuming that most passengers did not opt for VIP service. We then convert this column to an integer type.

# %%
df['VIP'] = df['VIP'].fillna(0).astype(int)

# %% [markdown]
# ### 4.8 Handle Missing Values in Spending Columns
#
# The columns `RoomService`, `FoodCourt`, `ShoppingMall`, `Spa`, and `VRDeck` represent the amount of money spent by the passenger on various amenities. We fill missing values with the median value of each column. This helps maintain the original distribution of spending in the dataset.

# %%
cols = ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']

for col in cols:
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# ### 4.9 Create Total Spending Feature
#
# We create a new feature `total_spending` by summing the values of the spending columns. This feature represents the total amount of money spent by the passenger on various amenities during the voyage. We then apply a logarithmic transformation to normalize the spending data, making it easier for the model to learn from.

# %%
df['total_spending'] = df['RoomService'] + df['FoodCourt'] + df['ShoppingMall'] + df['Spa'] + df['VRDeck']

for col in cols + ['total_spending']:
    df.loc[df[col]==0, col] = 0.367
    df[col] = np.log(df[col])

# %% [markdown]
# ### 4.10 Drop the Name column as it does not contain valuable information

# %%
df.drop(columns='Name', inplace=True)

# %% [markdown]
# # 5. One-Hot Encoding for Categorical Features
#
# One-hot encoding is a technique to convert categorical variables into numerical format. This step is crucial for machine learning algorithms, as they require numerical input.
#
# We apply one-hot encoding to the categorical features `HomePlanet`, `Destination`, and `Cabin_deck`. This creates new binary columns for each category, allowing the model to understand and use the categorical data effectively.

# %%
categorical_features = ['HomePlanet', 'Destination', 'Cabin_deck']
df = pd.concat([df, pd.get_dummies(df[categorical_features], dtype=int)], axis=1)
df.drop(columns=categorical_features, inplace=True)

# %% [markdown]
# # 6. Splitting Data back to Train and Test Sets
#
# After preprocessing and feature engineering, we split the combined dataset back into the original training and test sets. This ensures that we maintain the original structure of the data, with the training set used to train the model and the test set used to evaluate its performance.
#
# We also separate the target variable `Transported` from the training data, as this is what we aim to predict.

# %%
train_df = df[df['Source'] == 'train'].drop(columns=['Source'])
test_df = df[df['Source'] == 'test'].drop(columns=['Source'])

X = train_df.drop(columns=['Transported'])
y = train_df['Transported']

train_df.head()
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8693 entries, 0001_01 to 9280_02
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CryoSleep                  8693 non-null   int64
#  1   Age                        8693 non-null   float64
#  2   VIP                        8693 non-null   int64
#  3   RoomService                8693 non-null   float64
#  4   FoodCourt                  8693 non-null   float64
#  5   ShoppingMall               8693 non-null   float64
#  6   Spa                        8693 non-null   float64
#  7   VRDeck                     8693 non-null   float64
#  8   Transported                8693 non-null   float64
#  9   Group_size                 8693 non-null   int64
#  10  Cabin_num                  8693 non-null   int64
#  11  Cabin_side                 8693 non-null   float64
#  12  total_spending             8693 non-null   float64
#  13  HomePlanet_Earth           8693 non-null   int64
#  14  HomePlanet_Europa          8693 non-null   int64
#  15  HomePlanet_Mars            8693 non-null   int64
#  16  Destination_55 Cancri e    8693 non-null   int64
#  17  Destination_PSO J318.5-22  8693 non-null   int64
#  18  Destination_TRAPPIST-1e    8693 non-null   int64
#  19  Cabin_deck_A               8693 non-null   int64
#  20  Cabin_deck_B               8693 non-null   int64
#  21  Cabin_deck_C               8693 non-null   int64
#  22  Cabin_deck_D               8693 non-null   int64
#  23  Cabin_deck_E               8693 non-null   int64
#  24  Cabin_deck_F               8693 non-null   int64
#  25  Cabin_deck_G               8693 non-null   int64
#  26  Cabin_deck_T               8693 non-null   int64
# dtypes: float64(9), int64(18)
# memory usage: 1.9+ MB

# %% [markdown]
# # 7. Initial Model Comparison with LazyPredict
#
# We will use the LazyPredict library to quickly compare the performance of different machine learning models. LazyPredict provides an easy-to-use interface to fit multiple models and get a quick overview of their performance.

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

X = train_df.drop('Transported', axis=1)
y = train_df['Transported'].astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 29/29 [00:20<00:00,  1.42it/s]
# [LightGBM] [Info] Number of positive: 3731, number of negative: 3658
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002131 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1963
# [LightGBM] [Info] Number of data points in the train set: 7389, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504940 -> initscore=0.019760
# [LightGBM] [Info] Start training from score 0.019760
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.79               0.79     0.79      0.79
# LGBMClassifier                     0.79               0.79     0.79      0.79
# RandomForestClassifier             0.79               0.79     0.79      0.79
# AdaBoostClassifier                 0.78               0.78     0.78      0.78
# SVC                                0.78               0.78     0.78      0.78
# NuSVC                              0.78               0.78     0.78      0.78
# ExtraTreesClassifier               0.78               0.78     0.78      0.78
# BaggingClassifier                  0.78               0.78     0.78      0.78
# CalibratedClassifierCV             0.77               0.77     0.77      0.77
# LinearSVC                          0.77               0.77     0.77      0.77
# LogisticRegression                 0.77               0.77     0.77      0.77
# RidgeClassifier                    0.77               0.77     0.77      0.77
# RidgeClassifierCV                  0.77               0.77     0.77      0.77
# LinearDiscriminantAnalysis         0.77               0.77     0.77      0.77
# KNeighborsClassifier               0.76               0.76     0.76      0.76
# SGDClassifier                      0.75               0.75     0.75      0.75
# GaussianNB                         0.75               0.75     0.75      0.75
# QuadraticDiscriminantAnalysis      0.74               0.74     0.74      0.74
# NearestCentroid                    0.74               0.74     0.74      0.74
# BernoulliNB                        0.74               0.73     0.73      0.73
# DecisionTreeClassifier             0.73               0.73     0.73      0.73
# LabelSpreading                     0.72               0.72     0.72      0.72
# LabelPropagation                   0.72               0.72     0.72      0.72
# PassiveAggressiveClassifier        0.71               0.71     0.71      0.71
# ExtraTreeClassifier                0.71               0.71     0.71      0.71
# Perceptron                         0.60               0.60     0.60      0.60
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# XGBClassifier                        0.30
# LGBMClassifier                       0.25
# RandomForestClassifier               1.01
# AdaBoostClassifier                   0.39
# SVC                                  2.46
# NuSVC                                3.07
# ExtraTreesClassifier                 0.80
# BaggingClassifier                    0.35
# CalibratedClassifierCV               3.68
# LinearSVC                            0.96
# LogisticRegression                   0.08
# RidgeClassifier                      0.05
# RidgeClassifierCV                    0.08
# LinearDiscriminantAnalysis           0.11
# KNeighborsClassifier                 0.11
# SGDClassifier                        0.18
# GaussianNB                           0.03
# QuadraticDiscriminantAnalysis        0.07
# NearestCentroid                      0.04
# BernoulliNB                          0.03
# DecisionTreeClassifier               0.12
# LabelSpreading                       3.44
# LabelPropagation                     2.62
# PassiveAggressiveClassifier          0.07
# ExtraTreeClassifier                  0.03
# Perceptron                           0.05
# DummyClassifier                      0.03

# %% [markdown]
# # 8. Detailed Modeling with Pipelines and GridSearchCV
#
# For a more detailed evaluation and fine-tuning, we will use several classifiers with pipelines and GridSearchCV. We will use k-fold cross-validation to ensure a robust estimation of model performance.
#
# We will perform the following steps:
#
# 1. Set up the models and pipelines.
# 2. Define the hyperparameter grids for each model.
# 3. Use GridSearchCV with k-fold cross-validation to find the best parameters for each model.
# 4. Evaluate the performance of the best models on the test set.

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import accuracy_score

pipelines = {
    'adaboost': make_pipeline(StandardScaler(), AdaBoostClassifier(random_state=123)),
    'xgboost': make_pipeline(StandardScaler(), XGBClassifier(random_state=123)),
    'catboost': make_pipeline(StandardScaler(), CatBoostClassifier(random_state=123)),
    'gradientboost': make_pipeline(StandardScaler(), GradientBoostingClassifier(random_state=123)),
    'lightgbm': make_pipeline(StandardScaler(), LGBMClassifier(random_state=123)),
    'randomforest': make_pipeline(StandardScaler(), RandomForestClassifier(random_state=123)),
    'logistic': make_pipeline(StandardScaler(), LogisticRegression(random_state=123)),
    'knn': make_pipeline(StandardScaler(), KNeighborsClassifier())
}

grid = {
    'adaboost': {
        'adaboostclassifier__n_estimators': [50, 100, 150],
        'adaboostclassifier__learning_rate': [0.01, 0.05, 0.1]
    },
    'xgboost': {
        'xgbclassifier__n_estimators': [50, 100, 150],
        'xgbclassifier__learning_rate': [0.01, 0.05],
        'xgbclassifier__max_depth': [3, 4],
        'xgbclassifier__gamma': [0.1, 0.2],
        'xgbclassifier__subsample': [0.6, 0.8]
    },
    'catboost': {
        'catboostclassifier__learning_rate': [0.01, 0.05, 0.1, 0.5],
        'catboostclassifier__depth': [2, 3, 4], 
        'catboostclassifier__iterations': [50, 100, 150]
    },
    'gradientboost': {
        'gradientboostingclassifier__n_estimators': [50, 100, 150],
        'gradientboostingclassifier__learning_rate': [0.01, 0.05],
        'gradientboostingclassifier__max_depth': [3, 4],
        'gradientboostingclassifier__subsample': [0.6, 0.8]
    },
    'lightgbm': {
        'lgbmclassifier__n_estimators': [50, 100, 150],
        'lgbmclassifier__learning_rate': [0.01, 0.05],
        'lgbmclassifier__max_depth': [3, 4],
        'lgbmclassifier__subsample': [0.6, 0.8]
    },
    'randomforest': {
        'randomforestclassifier__n_estimators': [50, 100, 150],
        'randomforestclassifier__max_depth': [3, 4, 5],
        'randomforestclassifier__min_samples_split': [2, 3, 4]
    },
    'logistic': {
        'logisticregression__C': [0.01, 0.1, 1, 10]
    },
    'knn': {
        'kneighborsclassifier__n_neighbors': [3, 5, 7],
        'kneighborsclassifier__weights': ['uniform', 'distance'],
        'kneighborsclassifier__metric': ['euclidean', 'manhattan']
    }
}

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

best_estimators = {}
kf = KFold(n_splits=5, shuffle=True, random_state=42)

metrics = []

f = io.StringIO()
e = io.StringIO()

with redirect_stdout(f), redirect_stderr(e):  # suppress outputs
    with capture_output():
        for name, pipeline in pipelines.items():
            grid_search = GridSearchCV(pipeline, grid[name], cv=kf, n_jobs=-1, verbose=0)
            grid_search.fit(X_train, y_train)
            best_estimators[name] = grid_search.best_estimator_
            yhat = grid_search.predict(X_test)
            accuracy = accuracy_score(y_test, yhat)
            precision = precision_score(y_test, yhat)
            recall = recall_score(y_test, yhat)
            metrics.append((name, accuracy, precision, recall))
            print(f'Metrics for {name}: accuracy- {accuracy:.3f}, precision- {precision:.3f}, recall- {recall:.3f}')
            print(f"Best parameters for {name}: {grid_search.best_params_}")
# Out:
# 0:	learn: 0.6903281	total: 56.9ms	remaining: 2.79s
# 1:	learn: 0.6874752	total: 59.3ms	remaining: 1.42s
# 2:	learn: 0.6841248	total: 65.2ms	remaining: 1.02s
# 3:	learn: 0.6814695	total: 67.4ms	remaining: 775ms
# 4:	learn: 0.6788510	total: 81ms	remaining: 729ms
# 5:	learn: 0.6763034	total: 85.6ms	remaining: 628ms
# 6:	learn: 0.6731698	total: 93.8ms	remaining: 576ms
# 7:	learn: 0.6701070	total: 100ms	remaining: 527ms
# 8:	learn: 0.6677289	total: 104ms	remaining: 474ms
# 9:	learn: 0.6654152	total: 109ms	remaining: 434ms
# 10:	learn: 0.6625221	total: 114ms	remaining: 404ms
# 11:	learn: 0.6596901	total: 118ms	remaining: 374ms
# 12:	learn: 0.6574438	total: 125ms	remaining: 356ms
# 13:	learn: 0.6554414	total: 136ms	remaining: 350ms
# 14:	learn: 0.6533529	total: 142ms	remaining: 331ms
# 15:	learn: 0.6514474	total: 144ms	remaining: 306ms
# 16:	learn: 0.6488617	total: 157ms	remaining: 306ms
# 17:	learn: 0.6463147	total: 159ms	remaining: 284ms
# 18:	learn: 0.6444351	total: 162ms	remaining: 264ms
# 19:	learn: 0.6424610	total: 181ms	remaining: 271ms
# 20:	learn: 0.6406849	total: 191ms	remaining: 264ms
# 21:	learn: 0.6387189	total: 199ms	remaining: 253ms
# 22:	learn: 0.6364492	total: 201ms	remaining: 237ms
# 23:	learn: 0.6347546	total: 211ms	remaining: 228ms
# 24:	learn: 0.6329526	total: 213ms	remaining: 213ms
# 25:	learn: 0.6308086	total: 219ms	remaining: 202ms
# 26:	learn: 0.6289903	total: 227ms	remaining: 193ms
# 27:	learn: 0.6271214	total: 235ms	remaining: 184ms
# 28:	learn: 0.6257530	total: 240ms	remaining: 174ms
# 29:	learn: 0.6236985	total: 243ms	remaining: 162ms
# 30:	learn: 0.6216892	total: 245ms	remaining: 150ms
# 31:	learn: 0.6201815	total: 247ms	remaining: 139ms
# 32:	learn: 0.6186390	total: 249ms	remaining: 128ms
# 33:	learn: 0.6168347	total: 251ms	remaining: 118ms
# 34:	learn: 0.6153875	total: 280ms	remaining: 120ms
# 35:	learn: 0.6135496	total: 282ms	remaining: 110ms
# 36:	learn: 0.6121468	total: 285ms	remaining: 100ms
# 37:	learn: 0.6103641	total: 287ms	remaining: 90.6ms
# 38:	learn: 0.6090538	total: 289ms	remaining: 81.6ms
# 39:	learn: 0.6073500	total: 292ms	remaining: 73ms
# 40:	learn: 0.6057425	total: 294ms	remaining: 64.6ms
# 41:	learn: 0.6045116	total: 296ms	remaining: 56.5ms
# 42:	learn: 0.6032323	total: 320ms	remaining: 52.1ms
# 43:	learn: 0.6019030	total: 322ms	remaining: 43.9ms
# 44:	learn: 0.6003416	total: 335ms	remaining: 37.2ms
# 45:	learn: 0.5987940	total: 342ms	remaining: 29.7ms
# 46:	learn: 0.5976662	total: 348ms	remaining: 22.2ms
# 47:	learn: 0.5965863	total: 353ms	remaining: 14.7ms
# 48:	learn: 0.5953395	total: 359ms	remaining: 7.33ms
# 49:	learn: 0.5941821	total: 363ms	remaining: 0us
# 0:	learn: 0.6793591	total: 5.88ms	remaining: 288ms
# 1:	learn: 0.6668726	total: 7.75ms	remaining: 186ms
# 2:	learn: 0.6526340	total: 10.1ms	remaining: 158ms
# 3:	learn: 0.6429826	total: 12ms	remaining: 137ms
# 4:	learn: 0.6312970	total: 13.9ms	remaining: 125ms
# 5:	learn: 0.6233493	total: 15.8ms	remaining: 116ms
# 6:	learn: 0.6142045	total: 17.8ms	remaining: 109ms
# 7:	learn: 0.6075831	total: 20.1ms	remaining: 105ms
# 8:	learn: 0.5997912	total: 22.1ms	remaining: 100ms
# 9:	learn: 0.5938454	total: 24.2ms	remaining: 96.9ms
# 10:	learn: 0.5886488	total: 26.5ms	remaining: 94ms
# 11:	learn: 0.5837135	total: 28.6ms	remaining: 90.5ms
# 12:	learn: 0.5791411	total: 30.7ms	remaining: 87.3ms
# 13:	learn: 0.5749908	total: 32.9ms	remaining: 84.7ms
# 14:	learn: 0.5701952	total: 35.5ms	remaining: 82.8ms
# 15:	learn: 0.5659261	total: 37.4ms	remaining: 79.5ms
# 16:	learn: 0.5620937	total: 39.6ms	remaining: 76.9ms
# 17:	learn: 0.5583878	total: 41.7ms	remaining: 74.2ms
# 18:	learn: 0.5555374	total: 43.7ms	remaining: 71.3ms
# 19:	learn: 0.5518125	total: 45.7ms	remaining: 68.6ms
# 20:	learn: 0.5490613	total: 47.8ms	remaining: 66ms
# 21:	learn: 0.5459359	total: 50ms	remaining: 63.7ms
# 22:	learn: 0.5430728	total: 52.1ms	remaining: 61.2ms
# 23:	learn: 0.5404570	total: 54.2ms	remaining: 58.7ms
# 24:	learn: 0.5376399	total: 56.2ms	remaining: 56.2ms
# 25:	learn: 0.5353556	total: 58.1ms	remaining: 53.6ms
# 26:	learn: 0.5328300	total: 60.1ms	remaining: 51.2ms
# 27:	learn: 0.5304474	total: 62.4ms	remaining: 49ms
# 28:	learn: 0.5282617	total: 64.5ms	remaining: 46.7ms
# 29:	learn: 0.5262316	total: 66.4ms	remaining: 44.3ms
# 30:	learn: 0.5243223	total: 68.8ms	remaining: 42.1ms
# 31:	learn: 0.5226530	total: 70.6ms	remaining: 39.7ms
# 32:	learn: 0.5206252	total: 72.6ms	remaining: 37.4ms
# 33:	learn: 0.5193203	total: 74.7ms	remaining: 35.1ms
# 34:	learn: 0.5176753	total: 76.7ms	remaining: 32.9ms
# 35:	learn: 0.5159641	total: 78.9ms	remaining: 30.7ms
# 36:	learn: 0.5141952	total: 81.2ms	remaining: 28.5ms
# 37:	learn: 0.5129771	total: 83.5ms	remaining: 26.4ms
# 38:	learn: 0.5114021	total: 85.4ms	remaining: 24.1ms
# 39:	learn: 0.5102824	total: 87.6ms	remaining: 21.9ms
# 40:	learn: 0.5085873	total: 89.4ms	remaining: 19.6ms
# 41:	learn: 0.5070741	total: 91.6ms	remaining: 17.5ms
# 42:	learn: 0.5058428	total: 93.8ms	remaining: 15.3ms
# 43:	learn: 0.5043370	total: 95.9ms	remaining: 13.1ms
# 44:	learn: 0.5031628	total: 98ms	remaining: 10.9ms
# 45:	learn: 0.5017317	total: 100ms	remaining: 8.73ms
# 46:	learn: 0.5009861	total: 102ms	remaining: 6.54ms
# 47:	learn: 0.4993805	total: 104ms	remaining: 4.35ms
# 48:	learn: 0.4987578	total: 106ms	remaining: 2.17ms
# 49:	learn: 0.4976045	total: 108ms	remaining: 0us
# 0:	learn: 0.6806626	total: 5.88ms	remaining: 288ms
# 1:	learn: 0.6671428	total: 8.22ms	remaining: 197ms
# 2:	learn: 0.6528141	total: 10.4ms	remaining: 162ms
# 3:	learn: 0.6425367	total: 13.2ms	remaining: 151ms
# 4:	learn: 0.6337882	total: 15.1ms	remaining: 136ms
# 5:	learn: 0.6252850	total: 16.9ms	remaining: 124ms
# 6:	learn: 0.6154553	total: 18.8ms	remaining: 115ms
# 7:	learn: 0.6093833	total: 20.7ms	remaining: 109ms
# 8:	learn: 0.6025517	total: 22.8ms	remaining: 104ms
# 9:	learn: 0.5966354	total: 24.8ms	remaining: 99.2ms
# 10:	learn: 0.5896182	total: 26.9ms	remaining: 95.5ms
# 11:	learn: 0.5835773	total: 29.3ms	remaining: 92.6ms
# 12:	learn: 0.5791513	total: 31.4ms	remaining: 89.4ms
# 13:	learn: 0.5754985	total: 33.3ms	remaining: 85.8ms
# 14:	learn: 0.5715669	total: 35.8ms	remaining: 83.6ms
# 15:	learn: 0.5679783	total: 38ms	remaining: 80.7ms
# 16:	learn: 0.5648821	total: 40ms	remaining: 77.7ms
# 17:	learn: 0.5618713	total: 42ms	remaining: 74.6ms
# 18:	learn: 0.5579766	total: 43.8ms	remaining: 71.5ms
# 19:	learn: 0.5543450	total: 46.3ms	remaining: 69.5ms
# 20:	learn: 0.5513801	total: 48.3ms	remaining: 66.7ms
# 21:	learn: 0.5483482	total: 50.2ms	remaining: 63.9ms
# 22:	learn: 0.5452591	total: 52.3ms	remaining: 61.4ms
# 23:	learn: 0.5426148	total: 54.7ms	remaining: 59.3ms
# 24:	learn: 0.5404368	total: 56.8ms	remaining: 56.8ms
# 25:	learn: 0.5382706	total: 58.7ms	remaining: 54.2ms
# 26:	learn: 0.5355323	total: 60.8ms	remaining: 51.8ms
# 27:	learn: 0.5335906	total: 62.7ms	remaining: 49.2ms
# 28:	learn: 0.5310569	total: 64.6ms	remaining: 46.8ms
# 29:	learn: 0.5297397	total: 66.9ms	remaining: 44.6ms
# 30:	learn: 0.5278556	total: 69.1ms	remaining: 42.3ms
# 31:	learn: 0.5260505	total: 71.3ms	remaining: 40.1ms
# 32:	learn: 0.5243061	total: 73.4ms	remaining: 37.8ms
# 33:	learn: 0.5221201	total: 75.5ms	remaining: 35.5ms
# 34:	learn: 0.5206197	total: 77.3ms	remaining: 33.1ms
# 35:	learn: 0.5191145	total: 79.5ms	remaining: 30.9ms
# 36:	learn: 0.5174539	total: 81.7ms	remaining: 28.7ms
# 37:	learn: 0.5156092	total: 83.7ms	remaining: 26.4ms
# 38:	learn: 0.5142842	total: 85.7ms	remaining: 24.2ms
# 39:	learn: 0.5133691	total: 90.1ms	remaining: 22.5ms
# 40:	learn: 0.5118065	total: 93ms	remaining: 20.4ms
# 41:	learn: 0.5103620	total: 95.3ms	remaining: 18.1ms
# 42:	learn: 0.5086080	total: 97.9ms	remaining: 15.9ms
# 43:	learn: 0.5069128	total: 100ms	remaining: 13.7ms
# 44:	learn: 0.5055264	total: 103ms	remaining: 11.4ms
# 45:	learn: 0.5048011	total: 105ms	remaining: 9.12ms
# 46:	learn: 0.5035915	total: 107ms	remaining: 6.84ms
# 47:	learn: 0.5031341	total: 109ms	remaining: 4.55ms
# 48:	learn: 0.5019799	total: 112ms	remaining: 2.28ms
# 49:	learn: 0.5008500	total: 114ms	remaining: 0us
# 0:	learn: 0.6679460	total: 7.56ms	remaining: 371ms
# 1:	learn: 0.6449716	total: 18.4ms	remaining: 442ms
# 2:	learn: 0.6200961	total: 24.8ms	remaining: 388ms
# 3:	learn: 0.6009442	total: 27ms	remaining: 311ms
# 4:	learn: 0.5865638	total: 29.4ms	remaining: 264ms
# 5:	learn: 0.5761237	total: 31.4ms	remaining: 230ms
# 6:	learn: 0.5673462	total: 34ms	remaining: 209ms
# 7:	learn: 0.5593117	total: 36.4ms	remaining: 191ms
# 0:	learn: 0.6905940	total: 56.9ms	remaining: 2.79s
# 1:	learn: 0.6876580	total: 59.5ms	remaining: 1.43s
# 2:	learn: 0.6842745	total: 66ms	remaining: 1.03s
# 3:	learn: 0.6813526	total: 74.1ms	remaining: 852ms
# 4:	learn: 0.6782669	total: 80.1ms	remaining: 721ms
# 5:	learn: 0.6751580	total: 87.8ms	remaining: 644ms
# 6:	learn: 0.6720388	total: 90.5ms	remaining: 556ms
# 7:	learn: 0.6698434	total: 101ms	remaining: 532ms
# 8:	learn: 0.6673625	total: 105ms	remaining: 477ms
# 9:	learn: 0.6651601	total: 109ms	remaining: 437ms
# 10:	learn: 0.6629650	total: 113ms	remaining: 401ms
# 11:	learn: 0.6602177	total: 115ms	remaining: 364ms
# 12:	learn: 0.6576222	total: 121ms	remaining: 346ms
# 13:	learn: 0.6555911	total: 126ms	remaining: 323ms
# 14:	learn: 0.6535360	total: 134ms	remaining: 312ms
# 15:	learn: 0.6511758	total: 141ms	remaining: 300ms
# 16:	learn: 0.6486904	total: 143ms	remaining: 278ms
# 17:	learn: 0.6467711	total: 145ms	remaining: 258ms
# 18:	learn: 0.6449152	total: 147ms	remaining: 240ms
# 19:	learn: 0.6430943	total: 162ms	remaining: 243ms
# 20:	learn: 0.6411999	total: 164ms	remaining: 226ms
# 21:	learn: 0.6392941	total: 172ms	remaining: 218ms
# 22:	learn: 0.6372232	total: 176ms	remaining: 207ms
# 23:	learn: 0.6350175	total: 183ms	remaining: 199ms
# 24:	learn: 0.6331764	total: 185ms	remaining: 185ms
# 25:	learn: 0.6315833	total: 197ms	remaining: 182ms
# 26:	learn: 0.6294560	total: 199ms	remaining: 170ms
# 27:	learn: 0.6277396	total: 201ms	remaining: 158ms
# 28:	learn: 0.6261572	total: 218ms	remaining: 158ms
# 29:	learn: 0.6245759	total: 220ms	remaining: 147ms
# 30:	learn: 0.6229978	total: 228ms	remaining: 140ms
# 31:	learn: 0.6213732	total: 236ms	remaining: 133ms
# 32:	learn: 0.6195661	total: 245ms	remaining: 126ms
# 33:	learn: 0.6176977	total: 249ms	remaining: 117ms
# 34:	learn: 0.6162838	total: 256ms	remaining: 110ms
# 35:	learn: 0.6148192	total: 264ms	remaining: 103ms
# 36:	learn: 0.6133972	total: 269ms	remaining: 94.4ms
# 37:	learn: 0.6122073	total: 275ms	remaining: 87ms
# 38:	learn: 0.6110421	total: 278ms	remaining: 78.3ms
# 39:	learn: 0.6097059	total: 280ms	remaining: 70ms
# 40:	learn: 0.6083508	total: 282ms	remaining: 62ms
# 41:	learn: 0.6071783	total: 285ms	remaining: 54.2ms
# 42:	learn: 0.6055372	total: 287ms	remaining: 46.8ms
# 43:	learn: 0.6039960	total: 290ms	remaining: 39.5ms
# 44:	learn: 0.6027427	total: 292ms	remaining: 32.4ms
# 45:	learn: 0.6014932	total: 294ms	remaining: 25.6ms
# 46:	learn: 0.6003181	total: 321ms	remaining: 20.5ms
# 47:	learn: 0.5990821	total: 323ms	remaining: 13.5ms
# 48:	learn: 0.5976207	total: 325ms	remaining: 6.64ms
# 49:	learn: 0.5964189	total: 341ms	remaining: 0us
# 0:	learn: 0.6905447	total: 2.83ms	remaining: 139ms
# 1:	learn: 0.6876640	total: 4.85ms	remaining: 116ms
# 2:	learn: 0.6842610	total: 6.7ms	remaining: 105ms
# 3:	learn: 0.6816560	total: 8.8ms	remaining: 101ms
# 4:	learn: 0.6783687	total: 10.7ms	remaining: 96.6ms
# 5:	learn: 0.6751370	total: 13.4ms	remaining: 98ms
# 6:	learn: 0.6727341	total: 19.8ms	remaining: 122ms
# 7:	learn: 0.6702485	total: 24.9ms	remaining: 131ms
# 8:	learn: 0.6676871	total: 29ms	remaining: 132ms
# 9:	learn: 0.6653133	total: 34.5ms	remaining: 138ms
# 10:	learn: 0.6629720	total: 43.1ms	remaining: 153ms
# 11:	learn: 0.6606245	total: 46ms	remaining: 146ms
# 12:	learn: 0.6578118	total: 54.8ms	remaining: 156ms
# 13:	learn: 0.6556809	total: 57.7ms	remaining: 148ms
# 14:	learn: 0.6534606	total: 59.6ms	remaining: 139ms
# 15:	learn: 0.6507481	total: 62.8ms	remaining: 133ms
# 16:	learn: 0.6487207	total: 64.6ms	remaining: 125ms
# 17:	learn: 0.6462215	total: 70.8ms	remaining: 126ms
# 18:	learn: 0.6443458	total: 72.9ms	remaining: 119ms
# 19:	learn: 0.6422859	total: 83.4ms	remaining: 125ms
# 20:	learn: 0.6403067	total: 90ms	remaining: 124ms
# 21:	learn: 0.6379981	total: 95.7ms	remaining: 122ms
# 22:	learn: 0.6361933	total: 101ms	remaining: 118ms
# 23:	learn: 0.6344656	total: 103ms	remaining: 112ms
# 24:	learn: 0.6321786	total: 114ms	remaining: 114ms
# 25:	learn: 0.6300782	total: 121ms	remaining: 112ms
# 26:	learn: 0.6281180	total: 123ms	remaining: 105ms
# 27:	learn: 0.6260584	total: 132ms	remaining: 104ms
# 28:	learn: 0.6240024	total: 134ms	remaining: 97.3ms
# 29:	learn: 0.6220381	total: 137ms	remaining: 91.1ms
# 30:	learn: 0.6204166	total: 138ms	remaining: 84.9ms
# 31:	learn: 0.6184271	total: 141ms	remaining: 79.2ms
# 32:	learn: 0.6169784	total: 143ms	remaining: 73.5ms
# 33:	learn: 0.6154383	total: 145ms	remaining: 68.2ms
# 34:	learn: 0.6139601	total: 147ms	remaining: 63.1ms
# 35:	learn: 0.6124800	total: 149ms	remaining: 58.1ms
# 36:	learn: 0.6111525	total: 152ms	remaining: 53.6ms
# 37:	learn: 0.6098433	total: 155ms	remaining: 48.8ms
# 38:	learn: 0.6084125	total: 157ms	remaining: 44.2ms
# 39:	learn: 0.6070301	total: 160ms	remaining: 40.1ms
# 40:	learn: 0.6057042	total: 162ms	remaining: 35.7ms
# 41:	learn: 0.6044802	total: 164ms	remaining: 31.3ms
# 42:	learn: 0.6028416	total: 167ms	remaining: 27.1ms
# 43:	learn: 0.6012034	total: 169ms	remaining: 23ms
# 44:	learn: 0.6001039	total: 171ms	remaining: 19ms
# 45:	learn: 0.5984972	total: 173ms	remaining: 15.1ms
# 46:	learn: 0.5973928	total: 176ms	remaining: 11.2ms
# 47:	learn: 0.5962920	total: 178ms	remaining: 7.4ms
# 48:	learn: 0.5947855	total: 180ms	remaining: 3.67ms
# 49:	learn: 0.5936200	total: 182ms	remaining: 0us
# 0:	learn: 0.6803842	total: 2.53ms	remaining: 124ms
# 1:	learn: 0.6672450	total: 4.63ms	remaining: 111ms
# 2:	learn: 0.6529233	total: 6.51ms	remaining: 102ms
# 3:	learn: 0.6421968	total: 8.38ms	remaining: 96.4ms
# 4:	learn: 0.6300361	total: 10.4ms	remaining: 93.3ms
# 5:	learn: 0.6214593	total: 12.3ms	remaining: 89.8ms
# 6:	learn: 0.6115278	total: 14.4ms	remaining: 88.2ms
# 7:	learn: 0.6049257	total: 16.5ms	remaining: 86.8ms
# 8:	learn: 0.5986285	total: 18.6ms	remaining: 84.8ms
# 9:	learn: 0.5925541	total: 20.3ms	remaining: 81.2ms
# 10:	learn: 0.5870835	total: 22.8ms	remaining: 80.9ms
# 11:	learn: 0.5821723	total: 24.9ms	remaining: 78.7ms
# 12:	learn: 0.5775409	total: 26.8ms	remaining: 76.3ms
# 13:	learn: 0.5719895	total: 29ms	remaining: 74.7ms
# 14:	learn: 0.5681158	total: 31.2ms	remaining: 72.9ms
# 15:	learn: 0.5643457	total: 33.7ms	remaining: 71.6ms
# 16:	learn: 0.5612251	total: 35.9ms	remaining: 69.7ms
# 17:	learn: 0.5568511	total: 38.1ms	remaining: 67.7ms
# 18:	learn: 0.5528316	total: 41.1ms	remaining: 67.1ms
# 19:	learn: 0.5490742	total: 43.5ms	remaining: 65.3ms
# 20:	learn: 0.5455727	total: 46.1ms	remaining: 63.7ms
# 21:	learn: 0.5426295	total: 49.1ms	remaining: 62.5ms
# 22:	learn: 0.5397674	total: 51.3ms	remaining: 60.2ms
# 23:	learn: 0.5375325	total: 56.2ms	remaining: 60.9ms
# 24:	learn: 0.5355731	total: 58.1ms	remaining: 58.1ms
# 25:	learn: 0.5329521	total: 61.3ms	remaining: 56.6ms
# 26:	learn: 0.5299158	total: 63.9ms	remaining: 54.4ms
# 27:	learn: 0.5277060	total: 68.8ms	remaining: 54.1ms
# 28:	learn: 0.5254082	total: 75.6ms	remaining: 54.8ms
# 29:	learn: 0.5231313	total: 77.7ms	remaining: 51.8ms
# 30:	learn: 0.5212766	total: 84.5ms	remaining: 51.8ms
# 31:	learn: 0.5198428	total: 90.1ms	remaining: 50.7ms
# 32:	learn: 0.5178699	total: 96ms	remaining: 49.5ms
# 33:	learn: 0.5159937	total: 99.1ms	remaining: 46.6ms
# 34:	learn: 0.5143524	total: 103ms	remaining: 44.2ms
# 35:	learn: 0.5126650	total: 105ms	remaining: 40.8ms
# 36:	learn: 0.5115967	total: 111ms	remaining: 39ms
# 37:	learn: 0.5099828	total: 114ms	remaining: 36ms
# 38:	learn: 0.5087267	total: 116ms	remaining: 32.8ms
# 39:	learn: 0.5073175	total: 125ms	remaining: 31.3ms
# 40:	learn: 0.5056793	total: 135ms	remaining: 29.6ms
# 41:	learn: 0.5044052	total: 141ms	remaining: 26.8ms
# 42:	learn: 0.5027754	total: 145ms	remaining: 23.6ms
# 43:	learn: 0.5016792	total: 147ms	remaining: 20ms
# 44:	learn: 0.5004127	total: 153ms	remaining: 17ms
# 45:	learn: 0.4994599	total: 159ms	remaining: 13.8ms
# 46:	learn: 0.4987494	total: 166ms	remaining: 10.6ms
# 47:	learn: 0.4974544	total: 177ms	remaining: 7.39ms
# 48:	learn: 0.4962171	total: 185ms	remaining: 3.78ms
# 49:	learn: 0.4954629	total: 188ms	remaining: 0us
# 0:	learn: 0.6683703	total: 6.82ms	remaining: 334ms
# 1:	learn: 0.6449610	total: 8.82ms	remaining: 212ms
# 2:	learn: 0.6207487	total: 10.8ms	remaining: 170ms
# 3:	learn: 0.6064883	total: 13.1ms	remaining: 151ms
# 4:	learn: 0.5903254	total: 15.3ms	remaining: 138ms
# 5:	learn: 0.5805977	total: 17.7ms	remaining: 130ms
# 6:	learn: 0.5716109	total: 21.9ms	remaining: 135ms
# 7:	learn: 0.5619014	total: 24.2ms	remaining: 127ms
# 8:	learn: 0.5557486	total: 29.4ms	remaining: 134ms
# 0:	learn: 0.6904941	total: 56.9ms	remaining: 2.79s
# 1:	learn: 0.6876073	total: 66.2ms	remaining: 1.59s
# 2:	learn: 0.6842425	total: 68.3ms	remaining: 1.07s
# 3:	learn: 0.6808505	total: 75.3ms	remaining: 866ms
# 4:	learn: 0.6780660	total: 77.4ms	remaining: 697ms
# 5:	learn: 0.6755473	total: 89.7ms	remaining: 658ms
# 6:	learn: 0.6728824	total: 97.5ms	remaining: 599ms
# 7:	learn: 0.6697357	total: 100ms	remaining: 526ms
# 8:	learn: 0.6673156	total: 110ms	remaining: 499ms
# 9:	learn: 0.6650826	total: 114ms	remaining: 458ms
# 10:	learn: 0.6620690	total: 120ms	remaining: 427ms
# 11:	learn: 0.6596848	total: 127ms	remaining: 401ms
# 12:	learn: 0.6573539	total: 129ms	remaining: 368ms
# 13:	learn: 0.6546215	total: 140ms	remaining: 360ms
# 14:	learn: 0.6525860	total: 147ms	remaining: 343ms
# 15:	learn: 0.6506610	total: 150ms	remaining: 318ms
# 16:	learn: 0.6485979	total: 152ms	remaining: 295ms
# 17:	learn: 0.6459699	total: 163ms	remaining: 289ms
# 18:	learn: 0.6441301	total: 165ms	remaining: 270ms
# 19:	learn: 0.6421196	total: 167ms	remaining: 251ms
# 20:	learn: 0.6403390	total: 181ms	remaining: 250ms
# 21:	learn: 0.6383521	total: 188ms	remaining: 239ms
# 22:	learn: 0.6360738	total: 193ms	remaining: 227ms
# 23:	learn: 0.6342418	total: 202ms	remaining: 219ms
# 24:	learn: 0.6319707	total: 210ms	remaining: 210ms
# 25:	learn: 0.6303409	total: 217ms	remaining: 201ms
# 26:	learn: 0.6282612	total: 225ms	remaining: 191ms
# 27:	learn: 0.6263432	total: 234ms	remaining: 184ms
# 28:	learn: 0.6241244	total: 240ms	remaining: 174ms
# 29:	learn: 0.6220559	total: 250ms	remaining: 167ms
# 30:	learn: 0.6199792	total: 253ms	remaining: 155ms
# 31:	learn: 0.6183224	total: 255ms	remaining: 143ms
# 32:	learn: 0.6167925	total: 258ms	remaining: 133ms
# 33:	learn: 0.6153739	total: 260ms	remaining: 122ms
# 34:	learn: 0.6140460	total: 263ms	remaining: 113ms
# 35:	learn: 0.6126872	total: 265ms	remaining: 103ms
# 36:	learn: 0.6112658	total: 285ms	remaining: 100ms
# 37:	learn: 0.6098465	total: 293ms	remaining: 92.5ms
# 38:	learn: 0.6085537	total: 298ms	remaining: 84.2ms
# 39:	learn: 0.6072243	total: 306ms	remaining: 76.6ms
# 40:	learn: 0.6058573	total: 313ms	remaining: 68.8ms
# 41:	learn: 0.6041739	total: 320ms	remaining: 61ms
# 42:	learn: 0.6028852	total: 323ms	remaining: 52.7ms
# 43:	learn: 0.6016033	total: 330ms	remaining: 45ms
# 44:	learn: 0.6001882	total: 343ms	remaining: 38.1ms
# 45:	learn: 0.5988846	total: 345ms	remaining: 30ms
# 46:	learn: 0.5972319	total: 351ms	remaining: 22.4ms
# 47:	learn: 0.5960531	total: 354ms	remaining: 14.7ms
# 48:	learn: 0.5945543	total: 357ms	remaining: 7.28ms
# 49:	learn: 0.5930188	total: 362ms	remaining: 0us
# 0:	learn: 0.6801822	total: 7.14ms	remaining: 350ms
# 1:	learn: 0.6669730	total: 14.8ms	remaining: 356ms
# 2:	learn: 0.6520851	total: 22.4ms	remaining: 351ms
# 3:	learn: 0.6388571	total: 24.7ms	remaining: 284ms
# 4:	learn: 0.6276691	total: 33.9ms	remaining: 305ms
# 5:	learn: 0.6198957	total: 37ms	remaining: 272ms
# 6:	learn: 0.6104084	total: 43.5ms	remaining: 267ms
# 7:	learn: 0.6031797	total: 51.3ms	remaining: 269ms
# 8:	learn: 0.5949579	total: 59.9ms	remaining: 273ms
# 9:	learn: 0.5894753	total: 67.4ms	remaining: 270ms
# 10:	learn: 0.5837578	total: 77.8ms	remaining: 276ms
# 11:	learn: 0.5786481	total: 82.6ms	remaining: 262ms
# 12:	learn: 0.5731985	total: 85.7ms	remaining: 244ms
# 13:	learn: 0.5694054	total: 89.9ms	remaining: 231ms
# 14:	learn: 0.5644154	total: 93.4ms	remaining: 218ms
# 15:	learn: 0.5599917	total: 95.5ms	remaining: 203ms
# 16:	learn: 0.5562564	total: 106ms	remaining: 206ms
# 17:	learn: 0.5531607	total: 112ms	remaining: 199ms
# 18:	learn: 0.5496464	total: 118ms	remaining: 193ms
# 19:	learn: 0.5463863	total: 126ms	remaining: 189ms
# 20:	learn: 0.5430955	total: 129ms	remaining: 178ms
# 21:	learn: 0.5408220	total: 136ms	remaining: 173ms
# 22:	learn: 0.5380967	total: 145ms	remaining: 170ms
# 23:	learn: 0.5360031	total: 147ms	remaining: 159ms
# 24:	learn: 0.5339878	total: 153ms	remaining: 153ms
# 25:	learn: 0.5314920	total: 155ms	remaining: 143ms
# 26:	learn: 0.5294502	total: 160ms	remaining: 137ms
# 27:	learn: 0.5268503	total: 166ms	remaining: 131ms
# 28:	learn: 0.5246170	total: 168ms	remaining: 122ms
# 29:	learn: 0.5227085	total: 175ms	remaining: 116ms
# 30:	learn: 0.5202791	total: 187ms	remaining: 114ms
# 31:	learn: 0.5180009	total: 191ms	remaining: 107ms
# 32:	learn: 0.5159263	total: 193ms	remaining: 99.5ms
# 33:	learn: 0.5141982	total: 195ms	remaining: 91.9ms
# 34:	learn: 0.5129973	total: 198ms	remaining: 85.1ms
# 35:	learn: 0.5114326	total: 200ms	remaining: 78ms
# 36:	learn: 0.5102857	total: 202ms	remaining: 71.1ms
# 37:	learn: 0.5084899	total: 205ms	remaining: 64.7ms
# 38:	learn: 0.5067369	total: 208ms	remaining: 58.6ms
# 39:	learn: 0.5050478	total: 210ms	remaining: 52.4ms
# 40:	learn: 0.5041916	total: 212ms	remaining: 46.5ms
# 41:	learn: 0.5030427	total: 214ms	remaining: 40.8ms
# 42:	learn: 0.5019742	total: 216ms	remaining: 35.2ms
# 43:	learn: 0.5008030	total: 220ms	remaining: 30ms
# 44:	learn: 0.4992328	total: 225ms	remaining: 25ms
# 45:	learn: 0.4979714	total: 229ms	remaining: 20ms
# 46:	learn: 0.4968307	total: 232ms	remaining: 14.8ms
# 47:	learn: 0.4959196	total: 234ms	remaining: 9.74ms
# 48:	learn: 0.4951942	total: 236ms	remaining: 4.82ms
# 49:	learn: 0.4937951	total: 238ms	remaining: 0us
# 0:	learn: 0.6667868	total: 2.1ms	remaining: 103ms
# 1:	learn: 0.6395392	total: 4.61ms	remaining: 111ms
# 2:	learn: 0.6213391	total: 6.71ms	remaining: 105ms
# 3:	learn: 0.6065409	total: 8.58ms	remaining: 98.6ms
# 4:	learn: 0.5941065	total: 11ms	remaining: 99.2ms
# 5:	learn: 0.5841740	total: 13.2ms	remaining: 97.1ms
# 6:	learn: 0.5745219	total: 15.3ms	remaining: 93.8ms
# 7:	learn: 0.5645245	total: 17.4ms	remaining: 91.4ms
# 8:	learn: 0.5553178	total: 19.8ms	remaining: 90.3ms
# 9:	learn: 0.5481639	total: 21.9ms	remaining: 87.8ms
# 10:	learn: 0.5413513	total: 24.1ms	remaining: 85.3ms
# 11:	learn: 0.5350609	total: 26.6ms	remaining: 84.2ms
# 12:	learn: 0.5306461	total: 28.6ms	remaining: 81.4ms
# 13:	learn: 0.5259937	total: 30.6ms	remaining: 78.7ms
# 14:	learn: 0.5223225	total: 32.4ms	remaining: 75.7ms
# 15:	learn: 0.5182887	total: 34.4ms	remaining: 73.2ms
# 16:	learn: 0.5141066	total: 36.7ms	remaining: 71.3ms
# 17:	learn: 0.5106376	total: 38.8ms	remaining: 68.9ms
# 18:	learn: 0.5068236	total: 41.1ms	remaining: 67.1ms
# 19:	learn: 0.5039775	total: 43.1ms	remaining: 64.7ms
# 20:	learn: 0.5010961	total: 45.6ms	remaining: 62.9ms
# 21:	learn: 0.4984782	total: 48ms	remaining: 61ms
# 22:	learn: 0.4960456	total: 50.5ms	remaining: 59.3ms
# 23:	learn: 0.4933179	total: 52.7ms	remaining: 57.1ms
# 24:	learn: 0.4912322	total: 55ms	remaining: 55ms
# 25:	learn: 0.4889668	total: 57.5ms	remaining: 53.1ms
# 26:	learn: 0.4869100	total: 59.9ms	remaining: 51ms
# 27:	learn: 0.4853576	total: 61.7ms	remaining: 48.5ms
# 28:	learn: 0.4837505	total: 63.8ms	remaining: 46.2ms
# 29:	learn: 0.4825846	total: 66ms	remaining: 44ms
# 30:	learn: 0.4813056	total: 67.9ms	remaining: 41.6ms
# 31:	learn: 0.4799018	total: 69.9ms	remaining: 39.3ms
# 32:	learn: 0.4782656	total: 71.8ms	remaining: 37ms
# 33:	learn: 0.4762987	total: 74.3ms	remaining: 35ms
# 34:	learn: 0.4749829	total: 77.7ms	remaining: 33.3ms
# 35:	learn: 0.4729202	total: 81.3ms	remaining: 31.6ms
# 36:	learn: 0.4712524	total: 83.3ms	remaining: 29.3ms
# 37:	learn: 0.4696309	total: 85.6ms	remaining: 27ms
# 38:	learn: 0.4683432	total: 87.8ms	remaining: 24.8ms
# 39:	learn: 0.4671507	total: 89.9ms	remaining: 22.5ms
# 40:	learn: 0.4663169	total: 92ms	remaining: 20.2ms
# 41:	learn: 0.4654315	total: 94.2ms	remaining: 17.9ms
# 42:	learn: 0.4646724	total: 96.3ms	remaining: 15.7ms
# 43:	learn: 0.4637423	total: 99.1ms	remaining: 13.5ms
# 44:	learn: 0.4630843	total: 101ms	remaining: 11.3ms
# 45:	learn: 0.4620074	total: 103ms	remaining: 8.99ms
# 46:	learn: 0.4611332	total: 106ms	remaining: 6.74ms
# 47:	learn: 0.4600352	total: 108ms	remaining: 4.48ms
# 48:	learn: 0.4593306	total: 110ms	remaining: 2.24ms
# 49:	learn: 0.4582506	total: 112ms	remaining: 0us
# 0:	learn: 0.6688877	total: 4ms	remaining: 196ms
# 1:	learn: 0.6446142	total: 14.7ms	remaining: 353ms
# 2:	learn: 0.6261697	total: 23.4ms	remaining: 367ms
# 3:	learn: 0.6120590	total: 26.3ms	remaining: 303ms
# 4:	learn: 0.5952418	total: 32.4ms	remaining: 292ms
# 5:	learn: 0.5852924	total: 34.7ms	remaining: 255ms
# 6:	learn: 0.5774983	total: 44.1ms	remaining: 271ms
# 7:	learn: 0.5672850	total: 53ms	remaining: 278ms
# 8:	learn: 0.5596161	total: 66.4ms	remaining: 303ms
# 0:	learn: 0.6903745	total: 56.9ms	remaining: 2.79s
# 1:	learn: 0.6869712	total: 64.9ms	remaining: 1.56s
# 2:	learn: 0.6835626	total: 67.2ms	remaining: 1.05s
# 3:	learn: 0.6807934	total: 75ms	remaining: 863ms
# 4:	learn: 0.6776537	total: 77.1ms	remaining: 694ms
# 5:	learn: 0.6750208	total: 87.3ms	remaining: 640ms
# 6:	learn: 0.6721307	total: 94.6ms	remaining: 581ms
# 7:	learn: 0.6695239	total: 103ms	remaining: 539ms
# 8:	learn: 0.6665804	total: 110ms	remaining: 500ms
# 9:	learn: 0.6643004	total: 117ms	remaining: 469ms
# 10:	learn: 0.6612298	total: 125ms	remaining: 443ms
# 11:	learn: 0.6587977	total: 132ms	remaining: 417ms
# 12:	learn: 0.6564562	total: 138ms	remaining: 393ms
# 13:	learn: 0.6537452	total: 141ms	remaining: 361ms
# 14:	learn: 0.6514651	total: 148ms	remaining: 344ms
# 15:	learn: 0.6488162	total: 155ms	remaining: 330ms
# 16:	learn: 0.6466231	total: 163ms	remaining: 316ms
# 17:	learn: 0.6445778	total: 169ms	remaining: 301ms
# 18:	learn: 0.6425156	total: 177ms	remaining: 289ms
# 19:	learn: 0.6404573	total: 184ms	remaining: 276ms
# 20:	learn: 0.6384912	total: 191ms	remaining: 264ms
# 21:	learn: 0.6367021	total: 199ms	remaining: 253ms
# 22:	learn: 0.6349706	total: 206ms	remaining: 242ms
# 23:	learn: 0.6332107	total: 209ms	remaining: 226ms
# 24:	learn: 0.6314421	total: 215ms	remaining: 215ms
# 25:	learn: 0.6294408	total: 223ms	remaining: 206ms
# 26:	learn: 0.6276485	total: 231ms	remaining: 197ms
# 27:	learn: 0.6260396	total: 238ms	remaining: 187ms
# 28:	learn: 0.6239066	total: 246ms	remaining: 178ms
# 29:	learn: 0.6221924	total: 252ms	remaining: 168ms
# 30:	learn: 0.6205991	total: 259ms	remaining: 159ms
# 31:	learn: 0.6189964	total: 266ms	remaining: 150ms
# 32:	learn: 0.6174472	total: 273ms	remaining: 141ms
# 33:	learn: 0.6154817	total: 282ms	remaining: 133ms
# 34:	learn: 0.6142168	total: 289ms	remaining: 124ms
# 35:	learn: 0.6127338	total: 296ms	remaining: 115ms
# 36:	learn: 0.6113694	total: 305ms	remaining: 107ms
# 37:	learn: 0.6099630	total: 311ms	remaining: 98.4ms
# 38:	learn: 0.6082633	total: 320ms	remaining: 90.4ms
# 39:	learn: 0.6065005	total: 325ms	remaining: 81.3ms
# 40:	learn: 0.6050917	total: 332ms	remaining: 73ms
# 41:	learn: 0.6037810	total: 341ms	remaining: 65ms
# 42:	learn: 0.6025201	total: 345ms	remaining: 56.2ms
# 43:	learn: 0.6008634	total: 347ms	remaining: 47.3ms
# 44:	learn: 0.5992633	total: 349ms	remaining: 38.8ms
# 45:	learn: 0.5980250	total: 352ms	remaining: 30.6ms
# 46:	learn: 0.5964798	total: 354ms	remaining: 22.6ms
# 47:	learn: 0.5950847	total: 356ms	remaining: 14.8ms
# 48:	learn: 0.5936328	total: 359ms	remaining: 7.32ms
# 49:	learn: 0.5922927	total: 361ms	remaining: 0us
# 0:	learn: 0.6795752	total: 2.54ms	remaining: 124ms
# 1:	learn: 0.6643122	total: 4.76ms	remaining: 114ms
# 2:	learn: 0.6529084	total: 22.2ms	remaining: 349ms
# 3:	learn: 0.6425282	total: 32.1ms	remaining: 369ms
# 4:	learn: 0.6326857	total: 43.8ms	remaining: 394ms
# 5:	learn: 0.6215844	total: 46.3ms	remaining: 339ms
# 6:	learn: 0.6115035	total: 63.5ms	remaining: 390ms
# 7:	learn: 0.6041807	total: 72.3ms	remaining: 379ms
# 8:	learn: 0.5960795	total: 74.4ms	remaining: 339ms
# 9:	learn: 0.5906419	total: 77.8ms	remaining: 311ms
# 10:	learn: 0.5850483	total: 80.1ms	remaining: 284ms
# 11:	learn: 0.5801715	total: 82.1ms	remaining: 260ms
# 12:	learn: 0.5753131	total: 84.5ms	remaining: 240ms
# 13:	learn: 0.5707986	total: 86.8ms	remaining: 223ms
# 14:	learn: 0.5666686	total: 89.2ms	remaining: 208ms
# 15:	learn: 0.5623490	total: 91.3ms	remaining: 194ms
# 16:	learn: 0.5582155	total: 95.1ms	remaining: 185ms
# 17:	learn: 0.5544603	total: 100ms	remaining: 178ms
# 18:	learn: 0.5507030	total: 103ms	remaining: 169ms
# 19:	learn: 0.5475927	total: 106ms	remaining: 159ms
# 20:	learn: 0.5442274	total: 108ms	remaining: 149ms
# 21:	learn: 0.5410764	total: 110ms	remaining: 140ms
# 22:	learn: 0.5385729	total: 114ms	remaining: 134ms
# 23:	learn: 0.5358621	total: 116ms	remaining: 126ms
# 24:	learn: 0.5330789	total: 120ms	remaining: 120ms
# 25:	learn: 0.5305659	total: 122ms	remaining: 113ms
# 26:	learn: 0.5280549	total: 126ms	remaining: 107ms
# 27:	learn: 0.5256249	total: 128ms	remaining: 101ms
# 28:	learn: 0.5233967	total: 131ms	remaining: 94.6ms
# 29:	learn: 0.5216209	total: 133ms	remaining: 88.5ms
# 30:	learn: 0.5198943	total: 135ms	remaining: 82.9ms
# 31:	learn: 0.5177810	total: 138ms	remaining: 77.5ms
# 32:	learn: 0.5158641	total: 141ms	remaining: 72.6ms
# 33:	learn: 0.5142083	total: 148ms	remaining: 69.6ms
# 34:	learn: 0.5127183	total: 150ms	remaining: 64.5ms
# 35:	learn: 0.5110414	total: 153ms	remaining: 59.3ms
# 36:	learn: 0.5093230	total: 158ms	remaining: 55.7ms
# 37:	learn: 0.5083729	total: 161ms	remaining: 50.8ms
# 38:	learn: 0.5072666	total: 169ms	remaining: 47.5ms
# 39:	learn: 0.5053003	total: 172ms	remaining: 42.9ms
# 40:	learn: 0.5039106	total: 178ms	remaining: 39ms
# 41:	learn: 0.5027220	total: 180ms	remaining: 34.3ms
# 42:	learn: 0.5012298	total: 182ms	remaining: 29.6ms
# 43:	learn: 0.4993825	total: 184ms	remaining: 25.1ms
# 44:	learn: 0.4984934	total: 188ms	remaining: 20.9ms
# 45:	learn: 0.4973178	total: 193ms	remaining: 16.8ms
# 46:	learn: 0.4961180	total: 196ms	remaining: 12.5ms
# 47:	learn: 0.4949819	total: 200ms	remaining: 8.33ms
# 48:	learn: 0.4936230	total: 203ms	remaining: 4.15ms
# 49:	learn: 0.4921801	total: 208ms	remaining: 0us
# 0:	learn: 0.6663622	total: 6.13ms	remaining: 300ms
# 1:	learn: 0.6445291	total: 8.36ms	remaining: 201ms
# 2:	learn: 0.6204707	total: 10.5ms	remaining: 165ms
# 3:	learn: 0.6024469	total: 12.5ms	remaining: 144ms
# 4:	learn: 0.5906141	total: 14.6ms	remaining: 131ms
# 5:	learn: 0.5819192	total: 16.6ms	remaining: 122ms
# 6:	learn: 0.5736478	total: 18.8ms	remaining: 116ms
# 7:	learn: 0.5659966	total: 20.8ms	remaining: 109ms
# 8:	learn: 0.5586338	total: 23ms	remaining: 105ms
# 9:	learn: 0.5515531	total: 25ms	remaining: 100ms
# 10:	learn: 0.5462845	total: 27ms	remaining: 95.8ms
# 11:	learn: 0.5406987	total: 29.5ms	remaining: 93.4ms
# 12:	learn: 0.5352386	total: 31.7ms	remaining: 90.4ms
# 13:	learn: 0.5315321	total: 33.7ms	remaining: 86.8ms
# 14:	learn: 0.5264237	total: 43.9ms	remaining: 102ms
# 15:	learn: 0.5231534	total: 47ms	remaining: 99.8ms
# 16:	learn: 0.5203960	total: 49.2ms	remaining: 95.5ms
# 17:	learn: 0.5171415	total: 59.9ms	remaining: 106ms
# 18:	learn: 0.5136288	total: 62.1ms	remaining: 101ms
# 19:	learn: 0.5107496	total: 78.6ms	remaining: 118ms
# 20:	learn: 0.5072427	total: 85ms	remaining: 117ms
# 21:	learn: 0.5040183	total: 90ms	remaining: 115ms
# 22:	learn: 0.5021645	total: 91.8ms	remaining: 108ms
# 23:	learn: 0.5003679	total: 93.7ms	remaining: 101ms
# 24:	learn: 0.4984700	total: 98.1ms	remaining: 98.1ms
# 25:	learn: 0.4958942	total: 107ms	remaining: 98.6ms
# 26:	learn: 0.4940265	total: 113ms	remaining: 96.1ms
# 27:	learn: 0.4927894	total: 124ms	remaining: 97.3ms
# 28:	learn: 0.4901621	total: 130ms	remaining: 94.3ms
# 29:	learn: 0.4876991	total: 133ms	remaining: 88.7ms
# 30:	learn: 0.4852521	total: 136ms	remaining: 83.1ms
# 31:	learn: 0.4831172	total: 139ms	remaining: 77.9ms
# 32:	learn: 0.4818806	total: 141ms	remaining: 72.5ms
# 33:	learn: 0.4805912	total: 143ms	remaining: 67.1ms
# 34:	learn: 0.4793845	total: 145ms	remaining: 62ms
# 35:	learn: 0.4781501	total: 147ms	remaining: 57.1ms
# 36:	learn: 0.4768589	total: 149ms	remaining: 52.3ms
# 37:	learn: 0.4753486	total: 151ms	remaining: 47.7ms
# 38:	learn: 0.4742799	total: 153ms	remaining: 43.2ms
# 39:	learn: 0.4734177	total: 155ms	remaining: 38.7ms
# 40:	learn: 0.4718271	total: 159ms	remaining: 34.9ms
# 41:	learn: 0.4706545	total: 161ms	remaining: 30.7ms
# 42:	learn: 0.4690700	total: 164ms	remaining: 26.8ms
# 43:	learn: 0.4677959	total: 167ms	remaining: 22.7ms
# 44:	learn: 0.4673526	total: 169ms	remaining: 18.8ms
# 45:	learn: 0.4665888	total: 171ms	remaining: 14.9ms
# 46:	learn: 0.4648510	total: 173ms	remaining: 11.1ms
# 47:	learn: 0.4635429	total: 176ms	remaining: 7.31ms
# 48:	learn: 0.4622336	total: 178ms	remaining: 3.64ms
# 49:	learn: 0.4616404	total: 181ms	remaining: 0us
# 0:	learn: 0.5906363	total: 6.81ms	remaining: 333ms
# 1:	learn: 0.5576844	total: 8.86ms	remaining: 213ms
# 2:	learn: 0.5309305	total: 18.9ms	remaining: 297ms
# 3:	learn: 0.5145006	total: 28.5ms	remaining: 328ms
# 4:	learn: 0.5011119	total: 30.9ms	remaining: 278ms
# 5:	learn: 0.4853018	total: 35.4ms	remaining: 259ms
# 6:	learn: 0.4797106	total: 37.4ms	remaining: 230ms
# 7:	learn: 0.4711730	total: 39.7ms	remaining: 208ms
# 8:	learn: 0.4676007	total: 41.6ms	remaining: 190ms
# 8:	learn: 0.5507200	total: 38.6ms	remaining: 176ms
# 9:	learn: 0.5459636	total: 41.1ms	remaining: 165ms
# 10:	learn: 0.5413682	total: 45.7ms	remaining: 162ms
# 11:	learn: 0.5355696	total: 47.6ms	remaining: 151ms
# 12:	learn: 0.5298133	total: 49.6ms	remaining: 141ms
# 13:	learn: 0.5253149	total: 51.6ms	remaining: 133ms
# 14:	learn: 0.5217370	total: 53.7ms	remaining: 125ms
# 15:	learn: 0.5177275	total: 55.5ms	remaining: 118ms
# 16:	learn: 0.5134919	total: 57.5ms	remaining: 112ms
# 17:	learn: 0.5114131	total: 59.6ms	remaining: 106ms
# 18:	learn: 0.5074729	total: 62ms	remaining: 101ms
# 19:	learn: 0.5044294	total: 64.6ms	remaining: 96.9ms
# 20:	learn: 0.5012011	total: 67.4ms	remaining: 93.1ms
# 21:	learn: 0.4987205	total: 69.7ms	remaining: 88.7ms
# 22:	learn: 0.4959444	total: 71.7ms	remaining: 84.2ms
# 23:	learn: 0.4940118	total: 73.7ms	remaining: 79.8ms
# 24:	learn: 0.4923566	total: 76.6ms	remaining: 76.6ms
# 25:	learn: 0.4897029	total: 79.6ms	remaining: 73.5ms
# 26:	learn: 0.4881067	total: 81.9ms	remaining: 69.8ms
# 27:	learn: 0.4867530	total: 83.9ms	remaining: 65.9ms
# 28:	learn: 0.4842155	total: 86.3ms	remaining: 62.5ms
# 29:	learn: 0.4830426	total: 88.3ms	remaining: 58.9ms
# 30:	learn: 0.4807864	total: 90.3ms	remaining: 55.4ms
# 31:	learn: 0.4792071	total: 92.4ms	remaining: 52ms
# 32:	learn: 0.4778927	total: 94.3ms	remaining: 48.6ms
# 33:	learn: 0.4765042	total: 96.5ms	remaining: 45.4ms
# 34:	learn: 0.4742114	total: 98.6ms	remaining: 42.3ms
# 35:	learn: 0.4726429	total: 101ms	remaining: 39.1ms
# 36:	learn: 0.4717670	total: 103ms	remaining: 36.2ms
# 37:	learn: 0.4707984	total: 109ms	remaining: 34.3ms
# 38:	learn: 0.4700753	total: 111ms	remaining: 31.2ms
# 39:	learn: 0.4690262	total: 113ms	remaining: 28.2ms
# 40:	learn: 0.4681452	total: 115ms	remaining: 25.3ms
# 41:	learn: 0.4675123	total: 118ms	remaining: 22.4ms
# 42:	learn: 0.4667566	total: 121ms	remaining: 19.7ms
# 43:	learn: 0.4661010	total: 124ms	remaining: 17ms
# 44:	learn: 0.4655037	total: 127ms	remaining: 14.1ms
# 45:	learn: 0.4644824	total: 129ms	remaining: 11.2ms
# 46:	learn: 0.4633922	total: 131ms	remaining: 8.38ms
# 47:	learn: 0.4627785	total: 133ms	remaining: 5.54ms
# 48:	learn: 0.4614281	total: 135ms	remaining: 2.76ms
# 49:	learn: 0.4605140	total: 138ms	remaining: 0us
# 0:	learn: 0.5923566	total: 2.38ms	remaining: 117ms
# 1:	learn: 0.5419398	total: 13.8ms	remaining: 331ms
# 2:	learn: 0.5187623	total: 15.9ms	remaining: 250ms
# 3:	learn: 0.4981762	total: 30.9ms	remaining: 355ms
# 4:	learn: 0.4876907	total: 33.2ms	remaining: 298ms
# 5:	learn: 0.4789823	total: 35.5ms	remaining: 260ms
# 6:	learn: 0.4710096	total: 40.7ms	remaining: 250ms
# 7:	learn: 0.4670903	total: 43.1ms	remaining: 226ms
# 8:	learn: 0.4622169	total: 45ms	remaining: 205ms
# 9:	learn: 0.4592312	total: 47.1ms	remaining: 188ms
# 10:	learn: 0.4529872	total: 49.9ms	remaining: 177ms
# 11:	learn: 0.4476506	total: 52.1ms	remaining: 165ms
# 12:	learn: 0.4423489	total: 54.3ms	remaining: 155ms
# 13:	learn: 0.4373322	total: 56.3ms	remaining: 145ms
# 14:	learn: 0.4345756	total: 58.8ms	remaining: 137ms
# 15:	learn: 0.4325927	total: 61.4ms	remaining: 130ms
# 16:	learn: 0.4299454	total: 65.5ms	remaining: 127ms
# 17:	learn: 0.4275269	total: 70.6ms	remaining: 126ms
# 18:	learn: 0.4257912	total: 72.7ms	remaining: 119ms
# 19:	learn: 0.4248051	total: 74.6ms	remaining: 112ms
# 20:	learn: 0.4239454	total: 80.8ms	remaining: 112ms
# 21:	learn: 0.4228214	total: 85.9ms	remaining: 109ms
# 22:	learn: 0.4215619	total: 88.3ms	remaining: 104ms
# 23:	learn: 0.4199576	total: 94ms	remaining: 102ms
# 24:	learn: 0.4172274	total: 96ms	remaining: 96ms
# 25:	learn: 0.4154873	total: 110ms	remaining: 101ms
# 26:	learn: 0.4139093	total: 112ms	remaining: 95.5ms
# 27:	learn: 0.4132226	total: 116ms	remaining: 91.5ms
# 28:	learn: 0.4125084	total: 125ms	remaining: 90.5ms
# 29:	learn: 0.4112328	total: 128ms	remaining: 85.6ms
# 30:	learn: 0.4101386	total: 131ms	remaining: 80.2ms
# 31:	learn: 0.4079090	total: 143ms	remaining: 80.2ms
# 32:	learn: 0.4070394	total: 145ms	remaining: 74.7ms
# 33:	learn: 0.4056213	total: 153ms	remaining: 72.1ms
# 34:	learn: 0.4041650	total: 161ms	remaining: 69ms
# 35:	learn: 0.4025507	total: 177ms	remaining: 68.8ms
# 36:	learn: 0.4008748	total: 182ms	remaining: 64.1ms
# 37:	learn: 0.4001311	total: 185ms	remaining: 58.3ms
# 38:	learn: 0.3993714	total: 187ms	remaining: 52.6ms
# 39:	learn: 0.3982012	total: 189ms	remaining: 47.2ms
# 40:	learn: 0.3973199	total: 192ms	remaining: 42.1ms
# 41:	learn: 0.3962343	total: 194ms	remaining: 37ms
# 42:	learn: 0.3954396	total: 196ms	remaining: 31.9ms
# 43:	learn: 0.3946468	total: 198ms	remaining: 27ms
# 44:	learn: 0.3941054	total: 200ms	remaining: 22.3ms
# 45:	learn: 0.3936835	total: 203ms	remaining: 17.6ms
# 46:	learn: 0.3930347	total: 205ms	remaining: 13.1ms
# 47:	learn: 0.3921131	total: 209ms	remaining: 8.73ms
# 48:	learn: 0.3914440	total: 214ms	remaining: 4.36ms
# 49:	learn: 0.3899317	total: 216ms	remaining: 0us
# 0:	learn: 0.5986562	total: 2.41ms	remaining: 118ms
# 1:	learn: 0.5586361	total: 4.3ms	remaining: 103ms
# 2:	learn: 0.5343780	total: 6.56ms	remaining: 103ms
# 3:	learn: 0.5173696	total: 8.93ms	remaining: 103ms
# 4:	learn: 0.5008309	total: 11.8ms	remaining: 106ms
# 5:	learn: 0.4913781	total: 14.1ms	remaining: 104ms
# 6:	learn: 0.4822683	total: 16.5ms	remaining: 101ms
# 7:	learn: 0.4769134	total: 19.5ms	remaining: 102ms
# 8:	learn: 0.4676386	total: 21.8ms	remaining: 99.3ms
# 9:	learn: 0.4619400	total: 24.7ms	remaining: 99ms
# 10:	learn: 0.4596662	total: 27ms	remaining: 95.8ms
# 11:	learn: 0.4562470	total: 29.1ms	remaining: 92.1ms
# 12:	learn: 0.4510900	total: 31.5ms	remaining: 89.6ms
# 13:	learn: 0.4481732	total: 33.8ms	remaining: 86.9ms
# 14:	learn: 0.4457425	total: 36.5ms	remaining: 85.1ms
# 15:	learn: 0.4431906	total: 38.8ms	remaining: 82.6ms
# 16:	learn: 0.4409517	total: 41ms	remaining: 79.7ms
# 17:	learn: 0.4381332	total: 43.1ms	remaining: 76.6ms
# 18:	learn: 0.4367454	total: 45.9ms	remaining: 74.8ms
# 19:	learn: 0.4332416	total: 49.9ms	remaining: 74.9ms
# 20:	learn: 0.4304091	total: 51.6ms	remaining: 71.3ms
# 21:	learn: 0.4271842	total: 54.8ms	remaining: 69.8ms
# 22:	learn: 0.4256902	total: 58ms	remaining: 68.1ms
# 23:	learn: 0.4236098	total: 60.2ms	remaining: 65.3ms
# 24:	learn: 0.4218646	total: 62.1ms	remaining: 62.1ms
# 25:	learn: 0.4194941	total: 64.5ms	remaining: 59.6ms
# 26:	learn: 0.4183157	total: 66.9ms	remaining: 57ms
# 27:	learn: 0.4176064	total: 69ms	remaining: 54.2ms
# 28:	learn: 0.4168139	total: 71ms	remaining: 51.4ms
# 29:	learn: 0.4161702	total: 73.1ms	remaining: 48.7ms
# 30:	learn: 0.4151309	total: 75.4ms	remaining: 46.2ms
# 31:	learn: 0.4139923	total: 77.5ms	remaining: 43.6ms
# 32:	learn: 0.4129133	total: 79.5ms	remaining: 41ms
# 33:	learn: 0.4109974	total: 81.7ms	remaining: 38.4ms
# 34:	learn: 0.4096039	total: 84.1ms	remaining: 36.1ms
# 35:	learn: 0.4078488	total: 87.2ms	remaining: 33.9ms
# 36:	learn: 0.4070966	total: 89.3ms	remaining: 31.4ms
# 37:	learn: 0.4059933	total: 91.2ms	remaining: 28.8ms
# 38:	learn: 0.4053064	total: 93.4ms	remaining: 26.4ms
# 39:	learn: 0.4044459	total: 96ms	remaining: 24ms
# 40:	learn: 0.4037179	total: 97.8ms	remaining: 21.5ms
# 41:	learn: 0.4028060	total: 99.8ms	remaining: 19ms
# 42:	learn: 0.4014133	total: 102ms	remaining: 16.6ms
# 43:	learn: 0.4007875	total: 104ms	remaining: 14.2ms
# 44:	learn: 0.3999031	total: 107ms	remaining: 11.8ms
# 45:	learn: 0.3986090	total: 109ms	remaining: 9.46ms
# 46:	learn: 0.3979201	total: 111ms	remaining: 7.07ms
# 47:	learn: 0.3970919	total: 113ms	remaining: 4.69ms
# 48:	learn: 0.3964948	total: 115ms	remaining: 2.34ms
# 49:	learn: 0.3956036	total: 118ms	remaining: 0us
# 0:	learn: 0.6904941	total: 2.78ms	remaining: 276ms
# 1:	learn: 0.6876073	total: 4.7ms	remaining: 230ms
# 2:	learn: 0.6842425	total: 6.84ms	remaining: 221ms
# 3:	learn: 0.6808505	total: 9.37ms	remaining: 225ms
# 4:	learn: 0.6780660	total: 11.4ms	remaining: 217ms
# 5:	learn: 0.6755473	total: 13.3ms	remaining: 209ms
# 6:	learn: 0.6728824	total: 15.5ms	remaining: 206ms
# 7:	learn: 0.6697357	total: 17.4ms	remaining: 200ms
# 8:	learn: 0.6673156	total: 19.6ms	remaining: 198ms
# 9:	learn: 0.6650826	total: 21.6ms	remaining: 195ms
# 10:	learn: 0.6620690	total: 23.5ms	remaining: 190ms
# 11:	learn: 0.6596848	total: 25.3ms	remaining: 185ms
# 12:	learn: 0.6573539	total: 27.5ms	remaining: 184ms
# 13:	learn: 0.6546215	total: 29.8ms	remaining: 183ms
# 14:	learn: 0.6525860	total: 31.9ms	remaining: 181ms
# 15:	learn: 0.6506610	total: 33.9ms	remaining: 178ms
# 9:	learn: 0.5497209	total: 31.7ms	remaining: 127ms
# 10:	learn: 0.5432733	total: 34.3ms	remaining: 122ms
# 11:	learn: 0.5375724	total: 36.5ms	remaining: 116ms
# 12:	learn: 0.5322758	total: 39.5ms	remaining: 112ms
# 13:	learn: 0.5284433	total: 43.1ms	remaining: 111ms
# 14:	learn: 0.5227403	total: 45.2ms	remaining: 106ms
# 15:	learn: 0.5191775	total: 47.5ms	remaining: 101ms
# 16:	learn: 0.5156603	total: 49.7ms	remaining: 96.5ms
# 17:	learn: 0.5127918	total: 51.7ms	remaining: 91.8ms
# 18:	learn: 0.5095985	total: 53.8ms	remaining: 87.8ms
# 19:	learn: 0.5064803	total: 55.9ms	remaining: 83.9ms
# 20:	learn: 0.5039772	total: 58ms	remaining: 80.1ms
# 21:	learn: 0.5022789	total: 60.5ms	remaining: 77ms
# 22:	learn: 0.4997285	total: 62.7ms	remaining: 73.6ms
# 23:	learn: 0.4974757	total: 64.7ms	remaining: 70.1ms
# 24:	learn: 0.4955311	total: 66.7ms	remaining: 66.7ms
# 25:	learn: 0.4940765	total: 71.8ms	remaining: 66.3ms
# 26:	learn: 0.4926418	total: 74ms	remaining: 63ms
# 27:	learn: 0.4904102	total: 75.8ms	remaining: 59.6ms
# 28:	learn: 0.4879909	total: 78.1ms	remaining: 56.5ms
# 29:	learn: 0.4859489	total: 80.4ms	remaining: 53.6ms
# 30:	learn: 0.4842976	total: 82.8ms	remaining: 50.7ms
# 31:	learn: 0.4828124	total: 87.3ms	remaining: 49.1ms
# 32:	learn: 0.4813358	total: 90.2ms	remaining: 46.5ms
# 33:	learn: 0.4802299	total: 92.2ms	remaining: 43.4ms
# 34:	learn: 0.4786408	total: 94ms	remaining: 40.3ms
# 35:	learn: 0.4777947	total: 96.3ms	remaining: 37.4ms
# 36:	learn: 0.4770200	total: 98.9ms	remaining: 34.8ms
# 37:	learn: 0.4758147	total: 101ms	remaining: 31.9ms
# 38:	learn: 0.4745848	total: 103ms	remaining: 29.1ms
# 39:	learn: 0.4737767	total: 105ms	remaining: 26.3ms
# 40:	learn: 0.4722979	total: 107ms	remaining: 23.5ms
# 41:	learn: 0.4716044	total: 110ms	remaining: 20.9ms
# 42:	learn: 0.4698726	total: 112ms	remaining: 18.2ms
# 43:	learn: 0.4687513	total: 114ms	remaining: 15.6ms
# 44:	learn: 0.4675963	total: 117ms	remaining: 13ms
# 45:	learn: 0.4663022	total: 119ms	remaining: 10.3ms
# 46:	learn: 0.4646412	total: 121ms	remaining: 7.74ms
# 47:	learn: 0.4637380	total: 123ms	remaining: 5.14ms
# 48:	learn: 0.4623734	total: 125ms	remaining: 2.56ms
# 49:	learn: 0.4609191	total: 128ms	remaining: 0us
# 0:	learn: 0.5971439	total: 2.74ms	remaining: 134ms
# 1:	learn: 0.5568703	total: 4.67ms	remaining: 112ms
# 2:	learn: 0.5310296	total: 11.5ms	remaining: 180ms
# 3:	learn: 0.5129484	total: 14.8ms	remaining: 170ms
# 4:	learn: 0.4942108	total: 17.1ms	remaining: 154ms
# 5:	learn: 0.4855354	total: 22.7ms	remaining: 166ms
# 6:	learn: 0.4766440	total: 24.7ms	remaining: 152ms
# 7:	learn: 0.4718463	total: 27.7ms	remaining: 145ms
# 8:	learn: 0.4672217	total: 29.8ms	remaining: 136ms
# 9:	learn: 0.4614487	total: 32ms	remaining: 128ms
# 10:	learn: 0.4571263	total: 36.2ms	remaining: 128ms
# 11:	learn: 0.4532699	total: 39.2ms	remaining: 124ms
# 12:	learn: 0.4479649	total: 41.6ms	remaining: 118ms
# 13:	learn: 0.4459464	total: 43.6ms	remaining: 112ms
# 14:	learn: 0.4437906	total: 45.9ms	remaining: 107ms
# 15:	learn: 0.4411972	total: 48.8ms	remaining: 104ms
# 16:	learn: 0.4387277	total: 51.8ms	remaining: 100ms
# 17:	learn: 0.4361265	total: 54.8ms	remaining: 97.5ms
# 18:	learn: 0.4346555	total: 57.3ms	remaining: 93.4ms
# 19:	learn: 0.4328423	total: 60.3ms	remaining: 90.5ms
# 20:	learn: 0.4315376	total: 69.1ms	remaining: 95.4ms
# 21:	learn: 0.4292038	total: 74.4ms	remaining: 94.7ms
# 22:	learn: 0.4264496	total: 77.8ms	remaining: 91.4ms
# 23:	learn: 0.4249636	total: 80.3ms	remaining: 87ms
# 24:	learn: 0.4239960	total: 82.5ms	remaining: 82.5ms
# 25:	learn: 0.4221064	total: 84.8ms	remaining: 78.3ms
# 26:	learn: 0.4206829	total: 87.6ms	remaining: 74.6ms
# 27:	learn: 0.4186727	total: 89.9ms	remaining: 70.6ms
# 28:	learn: 0.4174766	total: 92.2ms	remaining: 66.7ms
# 29:	learn: 0.4145949	total: 94.4ms	remaining: 62.9ms
# 30:	learn: 0.4130558	total: 96.8ms	remaining: 59.3ms
# 31:	learn: 0.4124327	total: 99.2ms	remaining: 55.8ms
# 32:	learn: 0.4117294	total: 103ms	remaining: 53.2ms
# 33:	learn: 0.4112246	total: 106ms	remaining: 49.9ms
# 34:	learn: 0.4081071	total: 108ms	remaining: 46.4ms
# 35:	learn: 0.4072812	total: 110ms	remaining: 42.7ms
# 36:	learn: 0.4066952	total: 113ms	remaining: 39.5ms
# 37:	learn: 0.4060633	total: 115ms	remaining: 36.3ms
# 38:	learn: 0.4047906	total: 118ms	remaining: 33.4ms
# 39:	learn: 0.4038942	total: 120ms	remaining: 30.1ms
# 40:	learn: 0.4036508	total: 123ms	remaining: 26.9ms
# 41:	learn: 0.4032341	total: 125ms	remaining: 23.8ms
# 42:	learn: 0.4024275	total: 127ms	remaining: 20.7ms
# 43:	learn: 0.4018954	total: 130ms	remaining: 17.7ms
# 44:	learn: 0.4013598	total: 132ms	remaining: 14.7ms
# 45:	learn: 0.3994951	total: 134ms	remaining: 11.7ms
# 46:	learn: 0.3989483	total: 136ms	remaining: 8.7ms
# 47:	learn: 0.3983422	total: 138ms	remaining: 5.76ms
# 48:	learn: 0.3977086	total: 140ms	remaining: 2.86ms
# 49:	learn: 0.3970310	total: 143ms	remaining: 0us
# 0:	learn: 0.6903745	total: 2.27ms	remaining: 225ms
# 1:	learn: 0.6869712	total: 13ms	remaining: 635ms
# 2:	learn: 0.6835626	total: 15.2ms	remaining: 490ms
# 3:	learn: 0.6807934	total: 17.1ms	remaining: 410ms
# 4:	learn: 0.6776537	total: 20.9ms	remaining: 397ms
# 5:	learn: 0.6750208	total: 25.1ms	remaining: 393ms
# 6:	learn: 0.6721307	total: 32ms	remaining: 426ms
# 7:	learn: 0.6695239	total: 34ms	remaining: 391ms
# 8:	learn: 0.6665804	total: 35.8ms	remaining: 362ms
# 9:	learn: 0.6643004	total: 37.9ms	remaining: 341ms
# 10:	learn: 0.6612298	total: 40.2ms	remaining: 325ms
# 11:	learn: 0.6587977	total: 42.2ms	remaining: 310ms
# 12:	learn: 0.6564562	total: 44.2ms	remaining: 296ms
# 13:	learn: 0.6537452	total: 46ms	remaining: 283ms
# 14:	learn: 0.6514651	total: 47.8ms	remaining: 271ms
# 15:	learn: 0.6488162	total: 50ms	remaining: 262ms
# 16:	learn: 0.6466231	total: 52.2ms	remaining: 255ms
# 17:	learn: 0.6445778	total: 54.4ms	remaining: 248ms
# 18:	learn: 0.6425156	total: 56.5ms	remaining: 241ms
# 19:	learn: 0.6404573	total: 58.3ms	remaining: 233ms
# 20:	learn: 0.6384912	total: 60.5ms	remaining: 228ms
# 21:	learn: 0.6367021	total: 62.5ms	remaining: 222ms
# 22:	learn: 0.6349706	total: 64.6ms	remaining: 216ms
# 23:	learn: 0.6332107	total: 66.9ms	remaining: 212ms
# 24:	learn: 0.6314421	total: 68.7ms	remaining: 206ms
# 25:	learn: 0.6294408	total: 70.7ms	remaining: 201ms
# 26:	learn: 0.6276485	total: 72.6ms	remaining: 196ms
# 27:	learn: 0.6260396	total: 74.8ms	remaining: 192ms
# 28:	learn: 0.6239066	total: 76.9ms	remaining: 188ms
# 29:	learn: 0.6221924	total: 81ms	remaining: 189ms
# 30:	learn: 0.6205991	total: 86.2ms	remaining: 192ms
# 31:	learn: 0.6189964	total: 88ms	remaining: 187ms
# 32:	learn: 0.6174472	total: 94.8ms	remaining: 192ms
# 33:	learn: 0.6154817	total: 97ms	remaining: 188ms
# 34:	learn: 0.6142168	total: 99.6ms	remaining: 185ms
# 35:	learn: 0.6127338	total: 103ms	remaining: 183ms
# 36:	learn: 0.6113694	total: 109ms	remaining: 185ms
# 37:	learn: 0.6099630	total: 114ms	remaining: 185ms
# 38:	learn: 0.6082633	total: 119ms	remaining: 185ms
# 39:	learn: 0.6065005	total: 121ms	remaining: 182ms
# 40:	learn: 0.6050917	total: 124ms	remaining: 179ms
# 41:	learn: 0.6037810	total: 131ms	remaining: 180ms
# 42:	learn: 0.6025201	total: 134ms	remaining: 178ms
# 43:	learn: 0.6008634	total: 136ms	remaining: 173ms
# 44:	learn: 0.5992633	total: 138ms	remaining: 169ms
# 45:	learn: 0.5980250	total: 140ms	remaining: 165ms
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2984, number of negative: 2928
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000754 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1956
# [LightGBM] [Info] Number of data points in the train set: 5912, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504736 -> initscore=0.018945
# [LightGBM] [Info] Start training from score 0.018945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2993, number of negative: 2918
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000704 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1954
# [LightGBM] [Info] Number of data points in the train set: 5911, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506344 -> initscore=0.025378
# [LightGBM] [Info] Start training from score 0.025378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
metrics.sort(key=lambda x: x[1], reverse=True)

print("\nSorted model metrics (by accuracy):")
for metric in metrics:
    print(f"Model: {metric[0]}, Accuracy: {metric[1]:.3f}, Precision: {metric[2]:.3f}, Recall: {metric[3]:.3f}")
# Out:
# Sorted model metrics (by accuracy):
# Model: xgboost, Accuracy: 0.798, Precision: 0.781, Recall: 0.822
# Model: gradientboost, Accuracy: 0.794, Precision: 0.778, Recall: 0.819
# Model: catboost, Accuracy: 0.794, Precision: 0.774, Recall: 0.825
# Model: lightgbm, Accuracy: 0.785, Precision: 0.755, Recall: 0.841
# Model: adaboost, Accuracy: 0.770, Precision: 0.762, Recall: 0.779
# Model: logistic, Accuracy: 0.768, Precision: 0.754, Recall: 0.790
# Model: randomforest, Accuracy: 0.764, Precision: 0.781, Recall: 0.728
# Model: knn, Accuracy: 0.756, Precision: 0.760, Recall: 0.743

# %% [markdown]
# # 9. Apply ensemble method on the test set

# %%
from sklearn.ensemble import VotingClassifier

top_models = [name for name, _, _, _ in metrics[:5]]

estimators = [(name, best_estimators[name]) for name in top_models]

ensemble_model = VotingClassifier(estimators=estimators, voting='soft', n_jobs=-1)

ensemble_model.fit(X, y)

test_df = test_df.drop("Transported",axis=1)
test_predictions = ensemble_model.predict(test_df)
test_predictions = test_predictions.astype(bool)
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 4378, number of negative: 4315
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001498 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1972
# [LightGBM] [Info] Number of data points in the train set: 8693, number of used features: 25
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0:	learn: 0.6566056	total: 8.17ms	remaining: 1.22s
# 1:	learn: 0.6304588	total: 14.9ms	remaining: 1.11s
# 2:	learn: 0.6085573	total: 25.2ms	remaining: 1.23s
# 3:	learn: 0.5916652	total: 28.1ms	remaining: 1.02s
# 4:	learn: 0.5757656	total: 47.9ms	remaining: 1.39s
# 5:	learn: 0.5618814	total: 57.1ms	remaining: 1.37s
# 6:	learn: 0.5513093	total: 60ms	remaining: 1.23s
# 7:	learn: 0.5423336	total: 73.7ms	remaining: 1.31s
# 8:	learn: 0.5313647	total: 83.3ms	remaining: 1.3s
# 9:	learn: 0.5249482	total: 89.2ms	remaining: 1.25s
# 10:	learn: 0.5172656	total: 95ms	remaining: 1.2s
# 11:	learn: 0.5121884	total: 103ms	remaining: 1.18s
# 12:	learn: 0.5072577	total: 110ms	remaining: 1.16s
# 13:	learn: 0.5029765	total: 113ms	remaining: 1.09s
# 14:	learn: 0.4986420	total: 130ms	remaining: 1.17s
# 15:	learn: 0.4954829	total: 136ms	remaining: 1.14s
# 16:	learn: 0.4922142	total: 140ms	remaining: 1.09s
# 17:	learn: 0.4878471	total: 152ms	remaining: 1.11s
# 18:	learn: 0.4848771	total: 159ms	remaining: 1.09s
# 19:	learn: 0.4830452	total: 165ms	remaining: 1.07s
# 20:	learn: 0.4808772	total: 168ms	remaining: 1.03s
# 21:	learn: 0.4781931	total: 178ms	remaining: 1.03s
# 22:	learn: 0.4765933	total: 185ms	remaining: 1.02s
# 23:	learn: 0.4747266	total: 194ms	remaining: 1.02s
# 24:	learn: 0.4727630	total: 198ms	remaining: 989ms
# 25:	learn: 0.4710749	total: 201ms	remaining: 956ms
# 26:	learn: 0.4692090	total: 217ms	remaining: 988ms
# 27:	learn: 0.4675298	total: 225ms	remaining: 981ms
# 28:	learn: 0.4663786	total: 229ms	remaining: 954ms
# 29:	learn: 0.4645731	total: 244ms	remaining: 975ms
# 30:	learn: 0.4631743	total: 246ms	remaining: 946ms
# 31:	learn: 0.4620966	total: 262ms	remaining: 967ms
# 32:	learn: 0.4603822	total: 270ms	remaining: 957ms
# 33:	learn: 0.4591505	total: 273ms	remaining: 931ms
# 34:	learn: 0.4572340	total: 276ms	remaining: 907ms
# 35:	learn: 0.4562371	total: 296ms	remaining: 938ms
# 36:	learn: 0.4553572	total: 299ms	remaining: 914ms
# 37:	learn: 0.4534383	total: 302ms	remaining: 891ms
# 38:	learn: 0.4518780	total: 305ms	remaining: 869ms
# 39:	learn: 0.4505709	total: 321ms	remaining: 882ms
# 40:	learn: 0.4495112	total: 329ms	remaining: 874ms
# 41:	learn: 0.4485638	total: 335ms	remaining: 863ms
# 42:	learn: 0.4466879	total: 345ms	remaining: 858ms
# 43:	learn: 0.4453148	total: 351ms	remaining: 845ms
# 44:	learn: 0.4447462	total: 359ms	remaining: 837ms
# 45:	learn: 0.4433401	total: 371ms	remaining: 838ms
# 46:	learn: 0.4428067	total: 380ms	remaining: 833ms
# 47:	learn: 0.4417396	total: 392ms	remaining: 833ms
# 48:	learn: 0.4410713	total: 399ms	remaining: 823ms
# 49:	learn: 0.4403187	total: 402ms	remaining: 804ms
# 50:	learn: 0.4394528	total: 405ms	remaining: 786ms
# 51:	learn: 0.4387482	total: 408ms	remaining: 770ms
# 52:	learn: 0.4380771	total: 411ms	remaining: 753ms
# 53:	learn: 0.4374794	total: 414ms	remaining: 737ms
# 54:	learn: 0.4368794	total: 418ms	remaining: 722ms
# 55:	learn: 0.4361592	total: 421ms	remaining: 707ms
# 56:	learn: 0.4353604	total: 425ms	remaining: 693ms
# 57:	learn: 0.4351328	total: 428ms	remaining: 678ms
# 58:	learn: 0.4344205	total: 431ms	remaining: 664ms
# 59:	learn: 0.4333775	total: 434ms	remaining: 651ms
# 60:	learn: 0.4327361	total: 437ms	remaining: 638ms
# 61:	learn: 0.4324220	total: 441ms	remaining: 625ms
# 62:	learn: 0.4317636	total: 444ms	remaining: 613ms
# 63:	learn: 0.4312393	total: 447ms	remaining: 601ms
# 64:	learn: 0.4308628	total: 450ms	remaining: 589ms
# 65:	learn: 0.4301221	total: 454ms	remaining: 578ms
# 66:	learn: 0.4295708	total: 457ms	remaining: 566ms
# 67:	learn: 0.4293268	total: 460ms	remaining: 555ms
# 68:	learn: 0.4288956	total: 463ms	remaining: 544ms
# 69:	learn: 0.4277759	total: 467ms	remaining: 533ms
# 70:	learn: 0.4269542	total: 470ms	remaining: 523ms
# 71:	learn: 0.4267515	total: 473ms	remaining: 512ms
# 72:	learn: 0.4264449	total: 476ms	remaining: 502ms
# 73:	learn: 0.4258433	total: 479ms	remaining: 492ms
# 74:	learn: 0.4254525	total: 482ms	remaining: 482ms
# 75:	learn: 0.4249134	total: 485ms	remaining: 472ms
# 76:	learn: 0.4246251	total: 488ms	remaining: 463ms
# 77:	learn: 0.4238465	total: 492ms	remaining: 454ms
# 78:	learn: 0.4225102	total: 496ms	remaining: 446ms
# 79:	learn: 0.4216286	total: 500ms	remaining: 437ms
# 80:	learn: 0.4211633	total: 503ms	remaining: 429ms
# 81:	learn: 0.4207059	total: 506ms	remaining: 420ms
# 82:	learn: 0.4202470	total: 509ms	remaining: 411ms
# 83:	learn: 0.4199508	total: 512ms	remaining: 403ms
# 84:	learn: 0.4194894	total: 515ms	remaining: 394ms
# 85:	learn: 0.4192063	total: 519ms	remaining: 386ms
# 86:	learn: 0.4185931	total: 522ms	remaining: 378ms

# %%
submission = pd.DataFrame([test_data['PassengerId'], test_predictions]).T
submission.columns = ['PassengerID', 'Transported']

# %%
submission.head()
# Out:
#   PassengerID Transported
# 0     0013_01        True
# 1     0018_01       False
# 2     0019_01        True
# 3     0021_01        True
# 4     0023_01        True

# %%
submission.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
