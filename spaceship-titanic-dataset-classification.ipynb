# %% [markdown]
# <a href="https://www.kaggle.com/code/averilkan/spaceship-titanic-dataset-classification?scriptVersionId=221813680" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 💡 About The Competition: Spaceship Titanic
#
# Task:
# The objective of this task is to predict whether a passenger was transported to an alternate dimension aboard the Spaceship Titanic. This binary classification problem requires the model to predict the 'Transported' status (True or False) for each passenger in the test dataset, based on a variety of features provided.
#
# Dataset:
# The dataset for this competition includes information about passengers aboard the fictional spaceship Titanic. Features include demographic data, cabin information, and details about their in-ship expenditures. The target variable is Transported.
#
# Exploration:
# Begin with exploratory data analysis (EDA) to understand the distribution and relationships of features. Utilize visualization techniques to identify patterns and anomalies that could influence the predictive model's performance.
#
# Evaluation:
# Submissions are evaluated on the accuracy of the predictions. A higher accuracy score indicates a more effective model at classifying passengers' transportation status.
#
# Submission Files:
# train.csv - The training dataset, including the target variable Transported.
# test.csv - The test dataset, where predictions are to be made.
# sample_submission.csv - A sample submission file in the correct format.
# Evaluation Metric:
# The competition uses accuracy as the metric for evaluating submissions. This metric assesses the proportion of correctly predicted outcomes to total predictions.

# %% [markdown]
# # 1. Importing libraries

# %% [markdown]
# ## 💡 About The Packages:
#
# - **NumPy** and **Pandas** for data manipulation and analysis.
# - **Matplotlib** and **Seaborn** for data visualization.
# - **Warnings** to manage warning messages.
# - **lazypredict** for quick model comparison.
# - **Scikit-learn**, **XGBoost**, **LightGBM**, **CatBoost**, and other machine learning libraries for model building and evaluation.

# %%
# !pip install lazypredict

import io
import sys
import tensorflow as tf
import tensorflow_decision_forests as tfdf
import xgboost as xgb
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import category_encoders as ce

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score

from IPython.utils.io import capture_output

from hyperopt import hp, fmin, tpe, Trials

from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args

from contextlib import redirect_stdout, redirect_stderr
from IPython.utils.io import capture_output
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.13-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.1.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.4.0)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.2.0)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Downloading lazypredict-0.2.13-py2.py3-none-any.whl (12 kB)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.13
# 2025-02-10 14:55:42.922712: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 14:55:42.922826: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 14:55:43.047860: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # 2. Reading the Datasets
#
# We start by reading the training and test datasets using the Pandas library. The training dataset contains the target variable `Transported`, which indicates whether a passenger was transported to another dimension. We convert this column to an integer type for compatibility with machine learning algorithms.
#
# We then concatenate the train and test datasets for combined preprocessing and feature engineering. This helps to ensure consistency in data processing and avoid data leakage.

# %%
train_data = pd.read_csv("/kaggle/input/spaceship-titanic/train.csv")
train_data['Transported'] = train_data['Transported'].astype(int)
train_data.head()

test_data = pd.read_csv("/kaggle/input/spaceship-titanic/test.csv")
test_data.head()

train_data['Source'] = 'train'
test_data['Source'] = 'test'

df = pd.concat([train_data, test_data], axis=0)

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) involves summarizing and visualizing the main characteristics of the data. This step helps us understand the structure of the dataset, identify patterns, detect anomalies, and check assumptions.
#
# We create a summary function to give an overview of the dataset, including:
# - The number of unique values in each column.
# - The number of missing values in each column.
# - The data types of each column.
#
# This overview helps us identify any issues that need to be addressed during data preprocessing.

# %%
def summary(df):
    print(f"Dataset has {df.shape[1]} features and {df.shape[0]} examples.")
    summary = pd.DataFrame(index=df.columns)
    summary["Unique"] = df.nunique().values
    summary["Missing"] = df.isnull().sum().values
    summary["Duplicated"] = df.duplicated().sum()
    summary["Types"] = df.dtypes
    return summary

summary(df)
# Out:
# Dataset has 15 features and 12970 examples.
#               Unique  Missing  Duplicated    Types
# PassengerId    12970        0           0   object
# HomePlanet         3      288           0   object
# CryoSleep          2      310           0   object
# Cabin           9825      299           0   object
# Destination        3      274           0   object
# Age               80      270           0  float64
# VIP                2      296           0   object
# RoomService     1578      263           0  float64
# FoodCourt       1953      289           0  float64
# ShoppingMall    1367      306           0  float64
# Spa             1679      284           0  float64
# VRDeck          1642      268           0  float64
# Name           12629      294           0   object
# Transported        2     4277           0  float64
# Source             2        0           0   object

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ### 4.1 Extract Group Size from `PassengerId`
#
# A unique Id for each passenger takes the form `gggg_pp` where `gggg` indicates a group the passenger is travelling with and `pp` is their number within the group. People in a group are often family members, but not always. Extracting the group size can help us understand the potential impact of group travel on the likelihood of being transported.

# %%
group = df['PassengerId'].apply(lambda x: x.split('_')[0]).value_counts().to_dict()
df['Group_size'] = df['PassengerId'].apply(lambda x: group[x.split('_')[0]])
df.set_index('PassengerId', inplace=True)

# %% [markdown]
# ### 4.2 Handle Missing Values in `HomePlanet`
#
# The `HomePlanet` column indicates the planet the passenger is from. To fill missing values, we use a random selection based on the distribution of existing values in the column. This helps maintain the original distribution of `HomePlanet` in the dataset.

# %%
v = df['HomePlanet'].value_counts().index
p = df['HomePlanet'].value_counts(normalize=True).values
df.loc[df['HomePlanet'].isna(), 'HomePlanet'] = np.random.choice(v, df['HomePlanet'].isna().sum(), p=p)

# %% [markdown]
# ### 4.3 Handle Missing Values in CryoSleep
#
# The `CryoSleep` column indicates whether the passenger elected to be put into suspended animation for the duration of the voyage. Given that being in CryoSleep is a notable status that would likely be recorded, missing values are assumed to indicate passengers were not in CryoSleep. Thus, we fill missing values with 0 and convert this column to an integer type.

# %%
df['CryoSleep'] = df['CryoSleep'].fillna(0).astype(int)

# %% [markdown]
# ### 4.4 Extract Cabin Components and Handle Missing Values
#
# The `Cabin` column provides information about the passenger's cabin, including the deck, number, and side. We extract these components into separate columns and handle missing values by randomly assigning values based on the distribution of the existing data.

# %%
tmp = df['Cabin'].apply(lambda x: x.split('/') if isinstance(x, str) else ['-1', '-1', '-1']).to_list()
tmp = np.array(tmp)

df['Cabin_deck'] = tmp[:, 0]
df['Cabin_num'] = tmp[:, 1].astype(int)
df['Cabin_side'] = pd.Series(tmp[:, 2]).map({'S': 0, 'P': 1})

df.drop(columns='Cabin', inplace=True)

df.loc[df['Cabin_deck'] == '-1', 'Cabin_deck'] = np.random.choice(['F', 'G'], sum(df['Cabin_deck'] == '-1'), p=[0.5, 0.5])
df.loc[df['Cabin_side'].isna(), 'Cabin_side'] = np.random.choice([0, 1], sum(df['Cabin_side'].isna()), p=[0.5, 0.5])

# %% [markdown]
# ### 4.5 Handle Missing Values in `Destination`
#
# The `Destination` column indicates the destination of the passenger. We fill missing values by randomly assigning values based on the distribution of the existing data. This maintains the original distribution of `Destination` in the dataset.

# %%
v = df['Destination'].value_counts().index
p = df['Destination'].value_counts(normalize=True).values
df.loc[df['Destination'].isna(), 'Destination'] = np.random.choice(v, df['Destination'].isna().sum(), p=p)

# %% [markdown]
# ### 4.6 Handle Missing Values in `Age`
#
# The `Age` column indicates the age of the passenger. To fill missing values, we use a random sample from a normal distribution with the mean and standard deviation of the existing ages. This helps maintain the original distribution of `Age` in the dataset.

# %%
mean_age = df["Age"].mean()
std_age = df["Age"].std()
is_null = df["Age"].isnull().sum()
rand_sample = np.random.uniform(mean_age - std_age, mean_age + std_age, size = is_null)
df.loc[df['Age'].isna(), 'Age'] = rand_sample

# %% [markdown]
# ### 4.7 Handle Missing Values in `VIP`
#
# The `VIP` column indicates whether the passenger paid for special VIP service during the voyage. We fill missing values with `False` (0), assuming that most passengers did not opt for VIP service. We then convert this column to an integer type.

# %%
df['VIP'] = df['VIP'].fillna(0).astype(int)

# %% [markdown]
# ### 4.8 Handle Missing Values in Spending Columns
#
# The columns `RoomService`, `FoodCourt`, `ShoppingMall`, `Spa`, and `VRDeck` represent the amount of money spent by the passenger on various amenities. We fill missing values with the median value of each column. This helps maintain the original distribution of spending in the dataset.

# %%
cols = ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']

for col in cols:
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# ### 4.9 Create Total Spending Feature
#
# We create a new feature `total_spending` by summing the values of the spending columns. This feature represents the total amount of money spent by the passenger on various amenities during the voyage. We then apply a logarithmic transformation to normalize the spending data, making it easier for the model to learn from.

# %%
df['total_spending'] = df['RoomService'] + df['FoodCourt'] + df['ShoppingMall'] + df['Spa'] + df['VRDeck']

for col in cols + ['total_spending']:
    df.loc[df[col]==0, col] = 0.367
    df[col] = np.log(df[col])

# %% [markdown]
# ### 4.10 Drop the Name column as it does not contain valuable information

# %%
df.drop(columns='Name', inplace=True)

# %% [markdown]
# # 5. One-Hot Encoding for Categorical Features
#
# One-hot encoding is a technique to convert categorical variables into numerical format. This step is crucial for machine learning algorithms, as they require numerical input.
#
# We apply one-hot encoding to the categorical features `HomePlanet`, `Destination`, and `Cabin_deck`. This creates new binary columns for each category, allowing the model to understand and use the categorical data effectively.

# %%
categorical_features = ['HomePlanet', 'Destination', 'Cabin_deck']
df = pd.concat([df, pd.get_dummies(df[categorical_features], dtype=int)], axis=1)
df.drop(columns=categorical_features, inplace=True)

# %% [markdown]
# # 6. Splitting Data back to Train and Test Sets
#
# After preprocessing and feature engineering, we split the combined dataset back into the original training and test sets. This ensures that we maintain the original structure of the data, with the training set used to train the model and the test set used to evaluate its performance.
#
# We also separate the target variable `Transported` from the training data, as this is what we aim to predict.

# %%
train_df = df[df['Source'] == 'train'].drop(columns=['Source'])
test_df = df[df['Source'] == 'test'].drop(columns=['Source'])

X = train_df.drop(columns=['Transported'])
y = train_df['Transported']

train_df.head()
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8693 entries, 0001_01 to 9280_02
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CryoSleep                  8693 non-null   int64
#  1   Age                        8693 non-null   float64
#  2   VIP                        8693 non-null   int64
#  3   RoomService                8693 non-null   float64
#  4   FoodCourt                  8693 non-null   float64
#  5   ShoppingMall               8693 non-null   float64
#  6   Spa                        8693 non-null   float64
#  7   VRDeck                     8693 non-null   float64
#  8   Transported                8693 non-null   float64
#  9   Group_size                 8693 non-null   int64
#  10  Cabin_num                  8693 non-null   int64
#  11  Cabin_side                 8693 non-null   float64
#  12  total_spending             8693 non-null   float64
#  13  HomePlanet_Earth           8693 non-null   int64
#  14  HomePlanet_Europa          8693 non-null   int64
#  15  HomePlanet_Mars            8693 non-null   int64
#  16  Destination_55 Cancri e    8693 non-null   int64
#  17  Destination_PSO J318.5-22  8693 non-null   int64
#  18  Destination_TRAPPIST-1e    8693 non-null   int64
#  19  Cabin_deck_A               8693 non-null   int64
#  20  Cabin_deck_B               8693 non-null   int64
#  21  Cabin_deck_C               8693 non-null   int64
#  22  Cabin_deck_D               8693 non-null   int64
#  23  Cabin_deck_E               8693 non-null   int64
#  24  Cabin_deck_F               8693 non-null   int64
#  25  Cabin_deck_G               8693 non-null   int64
#  26  Cabin_deck_T               8693 non-null   int64
# dtypes: float64(9), int64(18)
# memory usage: 1.9+ MB

# %% [markdown]
# # 7. Initial Model Comparison with LazyPredict
#
# We will use the LazyPredict library to quickly compare the performance of different machine learning models. LazyPredict provides an easy-to-use interface to fit multiple models and get a quick overview of their performance.

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

X = train_df.drop('Transported', axis=1)
y = train_df['Transported'].astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 29/29 [00:18<00:00,  1.54it/s]
# [LightGBM] [Info] Number of positive: 3731, number of negative: 3658
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001554 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1964
# [LightGBM] [Info] Number of data points in the train set: 7389, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504940 -> initscore=0.019760
# [LightGBM] [Info] Start training from score 0.019760
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.80               0.80     0.80      0.80
# LGBMClassifier                     0.79               0.79     0.79      0.79
# AdaBoostClassifier                 0.79               0.79     0.79      0.79
# XGBClassifier                      0.79               0.79     0.79      0.79
# SVC                                0.78               0.78     0.78      0.78
# BaggingClassifier                  0.78               0.78     0.78      0.78
# ExtraTreesClassifier               0.78               0.78     0.78      0.78
# NuSVC                              0.78               0.78     0.78      0.78
# LogisticRegression                 0.77               0.77     0.77      0.77
# CalibratedClassifierCV             0.77               0.77     0.77      0.77
# LinearSVC                          0.77               0.77     0.77      0.77
# RidgeClassifier                    0.77               0.77     0.77      0.77
# RidgeClassifierCV                  0.77               0.77     0.77      0.77
# LinearDiscriminantAnalysis         0.77               0.77     0.77      0.77
# SGDClassifier                      0.76               0.76     0.76      0.76
# KNeighborsClassifier               0.75               0.75     0.75      0.75
# GaussianNB                         0.75               0.75     0.75      0.75
# QuadraticDiscriminantAnalysis      0.74               0.74     0.74      0.74
# NearestCentroid                    0.74               0.74     0.74      0.74
# DecisionTreeClassifier             0.74               0.74     0.74      0.74
# BernoulliNB                        0.74               0.73     0.73      0.73
# LabelSpreading                     0.73               0.73     0.73      0.73
# LabelPropagation                   0.73               0.73     0.73      0.73
# PassiveAggressiveClassifier        0.72               0.72     0.72      0.72
# ExtraTreeClassifier                0.71               0.71     0.71      0.71
# Perceptron                         0.67               0.67     0.67      0.67
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# RandomForestClassifier               0.99
# LGBMClassifier                       0.21
# AdaBoostClassifier                   0.36
# XGBClassifier                        0.27
# SVC                                  2.30
# BaggingClassifier                    0.33
# ExtraTreesClassifier                 0.70
# NuSVC                                2.83
# LogisticRegression                   0.07
# CalibratedClassifierCV               3.53
# LinearSVC                            0.92
# RidgeClassifier                      0.04
# RidgeClassifierCV                    0.07
# LinearDiscriminantAnalysis           0.08
# SGDClassifier                        0.16
# KNeighborsClassifier                 0.11
# GaussianNB                           0.03
# QuadraticDiscriminantAnalysis        0.07
# NearestCentroid                      0.04
# DecisionTreeClassifier               0.11
# BernoulliNB                          0.03
# LabelSpreading                       3.15
# LabelPropagation                     2.22
# PassiveAggressiveClassifier          0.06
# ExtraTreeClassifier                  0.02
# Perceptron                           0.05
# DummyClassifier                      0.02

# %% [markdown]
# # 8. Detailed Modeling with Pipelines and GridSearchCV
#
# For a more detailed evaluation and fine-tuning, we will use several classifiers with pipelines and GridSearchCV. We will use k-fold cross-validation to ensure a robust estimation of model performance.
#
# We will perform the following steps:
#
# 1. Set up the models and pipelines.
# 2. Define the hyperparameter grids for each model.
# 3. Use GridSearchCV with k-fold cross-validation to find the best parameters for each model.
# 4. Evaluate the performance of the best models on the test set.

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import accuracy_score

pipelines = {
    'adaboost': make_pipeline(StandardScaler(), AdaBoostClassifier(random_state=123)),
    'xgboost': make_pipeline(StandardScaler(), XGBClassifier(random_state=123)),
    'catboost': make_pipeline(StandardScaler(), CatBoostClassifier(random_state=123)),
    'gradientboost': make_pipeline(StandardScaler(), GradientBoostingClassifier(random_state=123)),
    'lightgbm': make_pipeline(StandardScaler(), LGBMClassifier(random_state=123)),
    'randomforest': make_pipeline(StandardScaler(), RandomForestClassifier(random_state=123)),
    'logistic': make_pipeline(StandardScaler(), LogisticRegression(random_state=123)),
    'knn': make_pipeline(StandardScaler(), KNeighborsClassifier())
}

grid = {
    'adaboost': {
        'adaboostclassifier__n_estimators': [50, 100, 150],
        'adaboostclassifier__learning_rate': [0.01, 0.05, 0.1]
    },
    'xgboost': {
        'xgbclassifier__n_estimators': [50, 100, 150],
        'xgbclassifier__learning_rate': [0.01, 0.05],
        'xgbclassifier__max_depth': [3, 4],
        'xgbclassifier__gamma': [0.1, 0.2],
        'xgbclassifier__subsample': [0.6, 0.8]
    },
    'catboost': {
        'catboostclassifier__learning_rate': [0.01, 0.05, 0.1, 0.5],
        'catboostclassifier__depth': [2, 3, 4], 
        'catboostclassifier__iterations': [50, 100, 150]
    },
    'gradientboost': {
        'gradientboostingclassifier__n_estimators': [50, 100, 150],
        'gradientboostingclassifier__learning_rate': [0.01, 0.05],
        'gradientboostingclassifier__max_depth': [3, 4],
        'gradientboostingclassifier__subsample': [0.6, 0.8]
    },
    'lightgbm': {
        'lgbmclassifier__n_estimators': [50, 100, 150],
        'lgbmclassifier__learning_rate': [0.01, 0.05],
        'lgbmclassifier__max_depth': [3, 4],
        'lgbmclassifier__subsample': [0.6, 0.8]
    },
    'randomforest': {
        'randomforestclassifier__n_estimators': [50, 100, 150],
        'randomforestclassifier__max_depth': [3, 4, 5],
        'randomforestclassifier__min_samples_split': [2, 3, 4]
    },
    'logistic': {
        'logisticregression__C': [0.01, 0.1, 1, 10]
    },
    'knn': {
        'kneighborsclassifier__n_neighbors': [3, 5, 7],
        'kneighborsclassifier__weights': ['uniform', 'distance'],
        'kneighborsclassifier__metric': ['euclidean', 'manhattan']
    }
}

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

best_estimators = {}
kf = KFold(n_splits=5, shuffle=True, random_state=42)

metrics = []

f = io.StringIO()
e = io.StringIO()

with redirect_stdout(f), redirect_stderr(e):  # suppress outputs
    with capture_output():
        for name, pipeline in pipelines.items():
            grid_search = GridSearchCV(pipeline, grid[name], cv=kf, n_jobs=-1, verbose=0)
            grid_search.fit(X_train, y_train)
            best_estimators[name] = grid_search.best_estimator_
            yhat = grid_search.predict(X_test)
            accuracy = accuracy_score(y_test, yhat)
            precision = precision_score(y_test, yhat)
            recall = recall_score(y_test, yhat)
            metrics.append((name, accuracy, precision, recall))
            print(f'Metrics for {name}: accuracy- {accuracy:.3f}, precision- {precision:.3f}, recall- {recall:.3f}')
            print(f"Best parameters for {name}: {grid_search.best_params_}")
# Out:
# 0:	learn: 0.6903745	total: 55.4ms	remaining: 2.71s
# 1:	learn: 0.6870762	total: 64.6ms	remaining: 1.55s
# 2:	learn: 0.6836819	total: 67.6ms	remaining: 1.06s
# 3:	learn: 0.6812329	total: 84ms	remaining: 966ms
# 4:	learn: 0.6785225	total: 90.4ms	remaining: 814ms
# 5:	learn: 0.6753495	total: 98.8ms	remaining: 724ms
# 6:	learn: 0.6721890	total: 107ms	remaining: 657ms
# 7:	learn: 0.6695936	total: 115ms	remaining: 601ms
# 8:	learn: 0.6666339	total: 122ms	remaining: 555ms
# 9:	learn: 0.6643509	total: 124ms	remaining: 496ms
# 10:	learn: 0.6619141	total: 132ms	remaining: 470ms
# 11:	learn: 0.6591439	total: 141ms	remaining: 446ms
# 12:	learn: 0.6568031	total: 148ms	remaining: 421ms
# 13:	learn: 0.6540776	total: 151ms	remaining: 388ms
# 14:	learn: 0.6518015	total: 157ms	remaining: 367ms
# 15:	learn: 0.6496000	total: 163ms	remaining: 347ms
# 16:	learn: 0.6469706	total: 172ms	remaining: 333ms
# 17:	learn: 0.6448429	total: 176ms	remaining: 313ms
# 18:	learn: 0.6428344	total: 178ms	remaining: 291ms
# 19:	learn: 0.6407638	total: 182ms	remaining: 273ms
# 20:	learn: 0.6387992	total: 195ms	remaining: 270ms
# 21:	learn: 0.6365022	total: 198ms	remaining: 252ms
# 22:	learn: 0.6346420	total: 200ms	remaining: 234ms
# 23:	learn: 0.6328923	total: 211ms	remaining: 228ms
# 24:	learn: 0.6306319	total: 216ms	remaining: 216ms
# 25:	learn: 0.6288588	total: 218ms	remaining: 201ms
# 26:	learn: 0.6266840	total: 220ms	remaining: 187ms
# 27:	learn: 0.6251385	total: 233ms	remaining: 183ms
# 28:	learn: 0.6235019	total: 238ms	remaining: 172ms
# 29:	learn: 0.6219429	total: 244ms	remaining: 163ms
# 30:	learn: 0.6203757	total: 247ms	remaining: 151ms
# 31:	learn: 0.6184289	total: 249ms	remaining: 140ms
# 32:	learn: 0.6165531	total: 261ms	remaining: 135ms
# 33:	learn: 0.6146406	total: 271ms	remaining: 127ms
# 34:	learn: 0.6131654	total: 274ms	remaining: 118ms
# 35:	learn: 0.6117423	total: 282ms	remaining: 110ms
# 36:	learn: 0.6102391	total: 284ms	remaining: 99.7ms
# 37:	learn: 0.6087757	total: 286ms	remaining: 90.3ms
# 38:	learn: 0.6074592	total: 288ms	remaining: 81.3ms
# 39:	learn: 0.6057350	total: 290ms	remaining: 72.6ms
# 40:	learn: 0.6043339	total: 292ms	remaining: 64.2ms
# 41:	learn: 0.6029764	total: 310ms	remaining: 59ms
# 42:	learn: 0.6016281	total: 316ms	remaining: 51.4ms
# 43:	learn: 0.6004094	total: 321ms	remaining: 43.8ms
# 44:	learn: 0.5991007	total: 327ms	remaining: 36.3ms
# 45:	learn: 0.5979456	total: 333ms	remaining: 28.9ms
# 46:	learn: 0.5966673	total: 340ms	remaining: 21.7ms
# 47:	learn: 0.5954716	total: 342ms	remaining: 14.3ms
# 48:	learn: 0.5938887	total: 349ms	remaining: 7.12ms
# 49:	learn: 0.5927111	total: 351ms	remaining: 0us
# 0:	learn: 0.6905447	total: 4.36ms	remaining: 214ms
# 1:	learn: 0.6876640	total: 11.7ms	remaining: 281ms
# 2:	learn: 0.6842091	total: 23.5ms	remaining: 368ms
# 3:	learn: 0.6809049	total: 29.1ms	remaining: 335ms
# 4:	learn: 0.6777274	total: 34ms	remaining: 306ms
# 5:	learn: 0.6750158	total: 36.1ms	remaining: 264ms
# 6:	learn: 0.6725000	total: 37.9ms	remaining: 233ms
# 7:	learn: 0.6694539	total: 39.8ms	remaining: 209ms
# 8:	learn: 0.6672056	total: 41.8ms	remaining: 190ms
# 9:	learn: 0.6646974	total: 43.6ms	remaining: 175ms
# 10:	learn: 0.6617414	total: 45.4ms	remaining: 161ms
# 11:	learn: 0.6590364	total: 47.2ms	remaining: 149ms
# 12:	learn: 0.6567645	total: 48.9ms	remaining: 139ms
# 13:	learn: 0.6545038	total: 50.8ms	remaining: 131ms
# 14:	learn: 0.6523180	total: 52.8ms	remaining: 123ms
# 15:	learn: 0.6498108	total: 54.8ms	remaining: 116ms
# 16:	learn: 0.6477536	total: 56.8ms	remaining: 110ms
# 17:	learn: 0.6457121	total: 58.8ms	remaining: 105ms
# 18:	learn: 0.6436952	total: 61ms	remaining: 99.5ms
# 19:	learn: 0.6417185	total: 63ms	remaining: 94.4ms
# 20:	learn: 0.6397410	total: 64.7ms	remaining: 89.3ms
# 21:	learn: 0.6372993	total: 66.4ms	remaining: 84.5ms
# 22:	learn: 0.6354389	total: 68.1ms	remaining: 79.9ms
# 23:	learn: 0.6331218	total: 70ms	remaining: 75.9ms
# 24:	learn: 0.6308125	total: 72.1ms	remaining: 72.1ms
# 25:	learn: 0.6292003	total: 74ms	remaining: 68.3ms
# 26:	learn: 0.6275204	total: 75.8ms	remaining: 64.6ms
# 27:	learn: 0.6257275	total: 78ms	remaining: 61.3ms
# 28:	learn: 0.6237475	total: 79.8ms	remaining: 57.8ms
# 29:	learn: 0.6221310	total: 81.8ms	remaining: 54.5ms
# 30:	learn: 0.6205316	total: 83.7ms	remaining: 51.3ms
# 31:	learn: 0.6188957	total: 85.6ms	remaining: 48.1ms
# 32:	learn: 0.6171334	total: 87.4ms	remaining: 45ms
# 33:	learn: 0.6152383	total: 89.3ms	remaining: 42ms
# 34:	learn: 0.6137302	total: 91.1ms	remaining: 39.1ms
# 35:	learn: 0.6122622	total: 92.9ms	remaining: 36.1ms
# 36:	learn: 0.6109726	total: 94.7ms	remaining: 33.3ms
# 37:	learn: 0.6095522	total: 96.6ms	remaining: 30.5ms
# 38:	learn: 0.6078910	total: 98.6ms	remaining: 27.8ms
# 39:	learn: 0.6065253	total: 101ms	remaining: 25.1ms
# 40:	learn: 0.6051383	total: 103ms	remaining: 22.5ms
# 41:	learn: 0.6038240	total: 105ms	remaining: 20ms
# 42:	learn: 0.6025699	total: 107ms	remaining: 17.4ms
# 43:	learn: 0.6009049	total: 109ms	remaining: 14.9ms
# 44:	learn: 0.5992880	total: 114ms	remaining: 12.6ms
# 45:	learn: 0.5976819	total: 116ms	remaining: 10.1ms
# 46:	learn: 0.5964898	total: 121ms	remaining: 7.71ms
# 47:	learn: 0.5953353	total: 127ms	remaining: 5.31ms
# 48:	learn: 0.5941435	total: 137ms	remaining: 2.79ms
# 49:	learn: 0.5930344	total: 139ms	remaining: 0us
# 0:	learn: 0.6806626	total: 4.1ms	remaining: 201ms
# 1:	learn: 0.6672217	total: 8.65ms	remaining: 208ms
# 2:	learn: 0.6530595	total: 13.2ms	remaining: 207ms
# 3:	learn: 0.6404316	total: 14.9ms	remaining: 172ms
# 4:	learn: 0.6298251	total: 26.8ms	remaining: 241ms
# 5:	learn: 0.6211581	total: 28.7ms	remaining: 211ms
# 6:	learn: 0.6123861	total: 30.2ms	remaining: 186ms
# 7:	learn: 0.6057617	total: 31.9ms	remaining: 167ms
# 8:	learn: 0.6000064	total: 33.8ms	remaining: 154ms
# 9:	learn: 0.5940298	total: 36.9ms	remaining: 148ms
# 10:	learn: 0.5888681	total: 38.7ms	remaining: 137ms
# 11:	learn: 0.5838552	total: 41ms	remaining: 130ms
# 12:	learn: 0.5793027	total: 43.3ms	remaining: 123ms
# 13:	learn: 0.5750761	total: 45.5ms	remaining: 117ms
# 14:	learn: 0.5702817	total: 47.5ms	remaining: 111ms
# 15:	learn: 0.5656695	total: 49.2ms	remaining: 105ms
# 16:	learn: 0.5617970	total: 50.8ms	remaining: 98.7ms
# 17:	learn: 0.5582428	total: 52.6ms	remaining: 93.6ms
# 18:	learn: 0.5549208	total: 54.6ms	remaining: 89.1ms
# 19:	learn: 0.5520088	total: 56.4ms	remaining: 84.5ms
# 20:	learn: 0.5494226	total: 58ms	remaining: 80.1ms
# 21:	learn: 0.5469635	total: 59.6ms	remaining: 75.9ms
# 22:	learn: 0.5445852	total: 61.3ms	remaining: 71.9ms
# 23:	learn: 0.5417717	total: 63.2ms	remaining: 68.5ms
# 24:	learn: 0.5391618	total: 65ms	remaining: 65ms
# 25:	learn: 0.5368021	total: 66.7ms	remaining: 61.6ms
# 26:	learn: 0.5346710	total: 68.6ms	remaining: 58.4ms
# 27:	learn: 0.5328217	total: 70.3ms	remaining: 55.2ms
# 28:	learn: 0.5308164	total: 72.3ms	remaining: 52.3ms
# 29:	learn: 0.5285791	total: 74.2ms	remaining: 49.5ms
# 30:	learn: 0.5267920	total: 75.9ms	remaining: 46.5ms
# 31:	learn: 0.5251037	total: 77.5ms	remaining: 43.6ms
# 32:	learn: 0.5234758	total: 79.2ms	remaining: 40.8ms
# 33:	learn: 0.5217196	total: 81.1ms	remaining: 38.2ms
# 34:	learn: 0.5201807	total: 82.9ms	remaining: 35.5ms
# 35:	learn: 0.5188685	total: 85.1ms	remaining: 33.1ms
# 36:	learn: 0.5174203	total: 87.5ms	remaining: 30.7ms
# 37:	learn: 0.5156000	total: 89.1ms	remaining: 28.1ms
# 38:	learn: 0.5137825	total: 91.1ms	remaining: 25.7ms
# 39:	learn: 0.5124757	total: 92.9ms	remaining: 23.2ms
# 40:	learn: 0.5114457	total: 94.8ms	remaining: 20.8ms
# 41:	learn: 0.5098634	total: 96.5ms	remaining: 18.4ms
# 42:	learn: 0.5086312	total: 98.4ms	remaining: 16ms
# 43:	learn: 0.5074074	total: 100ms	remaining: 13.7ms
# 44:	learn: 0.5056877	total: 102ms	remaining: 11.3ms
# 45:	learn: 0.5045934	total: 104ms	remaining: 9.04ms
# 46:	learn: 0.5033661	total: 106ms	remaining: 6.76ms
# 47:	learn: 0.5021903	total: 108ms	remaining: 4.49ms
# 48:	learn: 0.5012268	total: 110ms	remaining: 2.24ms
# 49:	learn: 0.4997274	total: 112ms	remaining: 0us
# 0:	learn: 0.6679460	total: 4.42ms	remaining: 217ms
# 1:	learn: 0.6449716	total: 7.31ms	remaining: 175ms
# 2:	learn: 0.6195913	total: 12ms	remaining: 188ms
# 3:	learn: 0.6067452	total: 13.9ms	remaining: 160ms
# 4:	learn: 0.5941538	total: 20.1ms	remaining: 181ms
# 5:	learn: 0.5844568	total: 21.9ms	remaining: 161ms
# 6:	learn: 0.5752112	total: 23.8ms	remaining: 146ms
# 7:	learn: 0.5644770	total: 26.2ms	remaining: 137ms
# 0:	learn: 0.6903281	total: 55.4ms	remaining: 2.71s
# 1:	learn: 0.6874752	total: 59ms	remaining: 1.42s
# 2:	learn: 0.6841076	total: 60.8ms	remaining: 952ms
# 3:	learn: 0.6814470	total: 70.3ms	remaining: 809ms
# 4:	learn: 0.6783009	total: 75.1ms	remaining: 676ms
# 5:	learn: 0.6751029	total: 78.4ms	remaining: 575ms
# 6:	learn: 0.6719638	total: 80.5ms	remaining: 494ms
# 7:	learn: 0.6694772	total: 82.4ms	remaining: 433ms
# 8:	learn: 0.6666273	total: 84.6ms	remaining: 386ms
# 9:	learn: 0.6637457	total: 102ms	remaining: 407ms
# 10:	learn: 0.6616058	total: 106ms	remaining: 377ms
# 11:	learn: 0.6588072	total: 108ms	remaining: 343ms
# 12:	learn: 0.6561975	total: 116ms	remaining: 332ms
# 13:	learn: 0.6535481	total: 122ms	remaining: 313ms
# 14:	learn: 0.6514503	total: 128ms	remaining: 299ms
# 15:	learn: 0.6493083	total: 130ms	remaining: 277ms
# 16:	learn: 0.6467614	total: 140ms	remaining: 272ms
# 17:	learn: 0.6446337	total: 142ms	remaining: 253ms
# 18:	learn: 0.6421394	total: 150ms	remaining: 245ms
# 19:	learn: 0.6399030	total: 152ms	remaining: 228ms
# 20:	learn: 0.6379468	total: 163ms	remaining: 225ms
# 21:	learn: 0.6360456	total: 165ms	remaining: 210ms
# 22:	learn: 0.6343693	total: 166ms	remaining: 195ms
# 23:	learn: 0.6320925	total: 170ms	remaining: 184ms
# 24:	learn: 0.6302816	total: 186ms	remaining: 186ms
# 25:	learn: 0.6287069	total: 193ms	remaining: 178ms
# 26:	learn: 0.6266386	total: 202ms	remaining: 172ms
# 27:	learn: 0.6246228	total: 204ms	remaining: 160ms
# 28:	learn: 0.6231620	total: 215ms	remaining: 156ms
# 29:	learn: 0.6219284	total: 217ms	remaining: 145ms
# 30:	learn: 0.6198171	total: 219ms	remaining: 135ms
# 31:	learn: 0.6181989	total: 230ms	remaining: 129ms
# 32:	learn: 0.6163378	total: 240ms	remaining: 124ms
# 33:	learn: 0.6148381	total: 244ms	remaining: 115ms
# 34:	learn: 0.6133472	total: 246ms	remaining: 106ms
# 35:	learn: 0.6119734	total: 261ms	remaining: 102ms
# 36:	learn: 0.6102632	total: 265ms	remaining: 93.1ms
# 37:	learn: 0.6088450	total: 267ms	remaining: 84.3ms
# 38:	learn: 0.6072145	total: 276ms	remaining: 77.7ms
# 39:	learn: 0.6054118	total: 285ms	remaining: 71.2ms
# 40:	learn: 0.6041290	total: 287ms	remaining: 63ms
# 41:	learn: 0.6028615	total: 289ms	remaining: 55.1ms
# 42:	learn: 0.6015306	total: 291ms	remaining: 47.4ms
# 43:	learn: 0.6003710	total: 293ms	remaining: 40ms
# 44:	learn: 0.5991786	total: 295ms	remaining: 32.8ms
# 45:	learn: 0.5979402	total: 297ms	remaining: 25.8ms
# 46:	learn: 0.5967462	total: 328ms	remaining: 20.9ms
# 47:	learn: 0.5956158	total: 335ms	remaining: 13.9ms
# 48:	learn: 0.5941927	total: 340ms	remaining: 6.94ms
# 49:	learn: 0.5927802	total: 342ms	remaining: 0us
# 0:	learn: 0.6793591	total: 2.96ms	remaining: 145ms
# 1:	learn: 0.6668726	total: 5.35ms	remaining: 128ms
# 2:	learn: 0.6524740	total: 7.7ms	remaining: 121ms
# 3:	learn: 0.6404867	total: 9.86ms	remaining: 113ms
# 4:	learn: 0.6288609	total: 11.8ms	remaining: 106ms
# 5:	learn: 0.6209121	total: 13.5ms	remaining: 99.2ms
# 6:	learn: 0.6130578	total: 15.6ms	remaining: 95.5ms
# 7:	learn: 0.6036052	total: 17.6ms	remaining: 92.4ms
# 8:	learn: 0.5974972	total: 19.6ms	remaining: 89.5ms
# 9:	learn: 0.5916345	total: 21.4ms	remaining: 85.6ms
# 10:	learn: 0.5846045	total: 23.3ms	remaining: 82.6ms
# 11:	learn: 0.5800713	total: 25.3ms	remaining: 80.1ms
# 12:	learn: 0.5759602	total: 27.3ms	remaining: 77.6ms
# 13:	learn: 0.5706454	total: 29.5ms	remaining: 75.9ms
# 14:	learn: 0.5671209	total: 31.6ms	remaining: 73.7ms
# 15:	learn: 0.5637142	total: 34.5ms	remaining: 73.3ms
# 16:	learn: 0.5606276	total: 36.2ms	remaining: 70.2ms
# 17:	learn: 0.5564073	total: 37.9ms	remaining: 67.4ms
# 18:	learn: 0.5530075	total: 39.7ms	remaining: 64.8ms
# 19:	learn: 0.5492579	total: 42ms	remaining: 63ms
# 20:	learn: 0.5461478	total: 44ms	remaining: 60.8ms
# 21:	learn: 0.5433987	total: 46ms	remaining: 58.6ms
# 22:	learn: 0.5409524	total: 48.1ms	remaining: 56.5ms
# 23:	learn: 0.5386355	total: 49.9ms	remaining: 54.1ms
# 24:	learn: 0.5359918	total: 51.8ms	remaining: 51.8ms
# 25:	learn: 0.5334354	total: 53.8ms	remaining: 49.7ms
# 26:	learn: 0.5312855	total: 56.8ms	remaining: 48.4ms
# 27:	learn: 0.5288799	total: 58.5ms	remaining: 46ms
# 28:	learn: 0.5270760	total: 74.2ms	remaining: 53.7ms
# 29:	learn: 0.5256392	total: 81.4ms	remaining: 54.2ms
# 30:	learn: 0.5234031	total: 87.7ms	remaining: 53.8ms
# 31:	learn: 0.5215535	total: 89.7ms	remaining: 50.5ms
# 32:	learn: 0.5195736	total: 93.4ms	remaining: 48.1ms
# 33:	learn: 0.5181422	total: 95.9ms	remaining: 45.2ms
# 34:	learn: 0.5163957	total: 98.4ms	remaining: 42.2ms
# 35:	learn: 0.5146662	total: 103ms	remaining: 39.9ms
# 36:	learn: 0.5128994	total: 105ms	remaining: 36.9ms
# 37:	learn: 0.5113795	total: 107ms	remaining: 33.8ms
# 38:	learn: 0.5100884	total: 109ms	remaining: 30.8ms
# 39:	learn: 0.5090605	total: 111ms	remaining: 27.8ms
# 40:	learn: 0.5072472	total: 113ms	remaining: 24.9ms
# 41:	learn: 0.5058465	total: 116ms	remaining: 22.1ms
# 42:	learn: 0.5045176	total: 118ms	remaining: 19.2ms
# 43:	learn: 0.5028880	total: 121ms	remaining: 16.4ms
# 44:	learn: 0.5016500	total: 123ms	remaining: 13.7ms
# 45:	learn: 0.5000353	total: 126ms	remaining: 11ms
# 46:	learn: 0.4988869	total: 129ms	remaining: 8.22ms
# 47:	learn: 0.4971901	total: 131ms	remaining: 5.45ms
# 48:	learn: 0.4960908	total: 133ms	remaining: 2.72ms
# 49:	learn: 0.4953660	total: 135ms	remaining: 0us
# 0:	learn: 0.6803842	total: 2.58ms	remaining: 127ms
# 1:	learn: 0.6672450	total: 4.45ms	remaining: 107ms
# 2:	learn: 0.6526915	total: 6.15ms	remaining: 96.3ms
# 3:	learn: 0.6403002	total: 8.31ms	remaining: 95.6ms
# 4:	learn: 0.6305301	total: 10.2ms	remaining: 91.7ms
# 5:	learn: 0.6196965	total: 11.8ms	remaining: 86.5ms
# 6:	learn: 0.6117651	total: 13.5ms	remaining: 83.2ms
# 7:	learn: 0.6029137	total: 15.3ms	remaining: 80.1ms
# 8:	learn: 0.5954874	total: 17.3ms	remaining: 78.9ms
# 9:	learn: 0.5893999	total: 19.1ms	remaining: 76.2ms
# 10:	learn: 0.5827308	total: 20.8ms	remaining: 73.6ms
# 11:	learn: 0.5778755	total: 22.4ms	remaining: 70.8ms
# 12:	learn: 0.5724837	total: 24.2ms	remaining: 68.8ms
# 13:	learn: 0.5675687	total: 26ms	remaining: 66.8ms
# 14:	learn: 0.5636275	total: 27.6ms	remaining: 64.5ms
# 15:	learn: 0.5600972	total: 30.3ms	remaining: 64.5ms
# 16:	learn: 0.5557333	total: 32.1ms	remaining: 62.4ms
# 17:	learn: 0.5519274	total: 34ms	remaining: 60.5ms
# 18:	learn: 0.5483302	total: 37.2ms	remaining: 60.6ms
# 19:	learn: 0.5449911	total: 38.8ms	remaining: 58.2ms
# 20:	learn: 0.5419758	total: 40.5ms	remaining: 56ms
# 21:	learn: 0.5388588	total: 42.3ms	remaining: 53.9ms
# 22:	learn: 0.5365196	total: 44.3ms	remaining: 52ms
# 23:	learn: 0.5340485	total: 46.1ms	remaining: 50ms
# 24:	learn: 0.5316394	total: 50.7ms	remaining: 50.7ms
# 25:	learn: 0.5299098	total: 52.3ms	remaining: 48.3ms
# 26:	learn: 0.5274781	total: 56.5ms	remaining: 48.1ms
# 27:	learn: 0.5253994	total: 61ms	remaining: 48ms
# 28:	learn: 0.5231922	total: 62.8ms	remaining: 45.4ms
# 29:	learn: 0.5217292	total: 64.7ms	remaining: 43.1ms
# 30:	learn: 0.5199367	total: 66.8ms	remaining: 40.9ms
# 31:	learn: 0.5180179	total: 68.7ms	remaining: 38.6ms
# 32:	learn: 0.5163845	total: 70.6ms	remaining: 36.4ms
# 33:	learn: 0.5144009	total: 72.4ms	remaining: 34.1ms
# 34:	learn: 0.5126870	total: 74.3ms	remaining: 31.9ms
# 35:	learn: 0.5107477	total: 76.3ms	remaining: 29.7ms
# 36:	learn: 0.5092220	total: 78.4ms	remaining: 27.5ms
# 37:	learn: 0.5077317	total: 80.4ms	remaining: 25.4ms
# 38:	learn: 0.5061321	total: 82.1ms	remaining: 23.2ms
# 39:	learn: 0.5045654	total: 83.9ms	remaining: 21ms
# 40:	learn: 0.5032211	total: 85.7ms	remaining: 18.8ms
# 41:	learn: 0.5020080	total: 87.5ms	remaining: 16.7ms
# 42:	learn: 0.5004720	total: 89.2ms	remaining: 14.5ms
# 43:	learn: 0.4990545	total: 91.3ms	remaining: 12.5ms
# 44:	learn: 0.4980416	total: 93.2ms	remaining: 10.4ms
# 45:	learn: 0.4967199	total: 95.3ms	remaining: 8.28ms
# 46:	learn: 0.4958221	total: 97.2ms	remaining: 6.2ms
# 47:	learn: 0.4945796	total: 99.5ms	remaining: 4.14ms
# 48:	learn: 0.4934105	total: 101ms	remaining: 2.07ms
# 49:	learn: 0.4919512	total: 104ms	remaining: 0us
# 0:	learn: 0.6688877	total: 6.65ms	remaining: 326ms
# 1:	learn: 0.6448047	total: 9.46ms	remaining: 227ms
# 2:	learn: 0.6223835	total: 11.6ms	remaining: 182ms
# 3:	learn: 0.6076304	total: 14.8ms	remaining: 170ms
# 4:	learn: 0.5963223	total: 18.6ms	remaining: 167ms
# 5:	learn: 0.5858937	total: 20.8ms	remaining: 153ms
# 6:	learn: 0.5773291	total: 23.2ms	remaining: 142ms
# 7:	learn: 0.5692932	total: 26.3ms	remaining: 138ms
# 0:	learn: 0.6904941	total: 55.4ms	remaining: 2.71s
# 1:	learn: 0.6876073	total: 57.3ms	remaining: 1.38s
# 2:	learn: 0.6842234	total: 65.7ms	remaining: 1.03s
# 3:	learn: 0.6808023	total: 68.1ms	remaining: 783ms
# 4:	learn: 0.6782183	total: 80.3ms	remaining: 722ms
# 5:	learn: 0.6749077	total: 87.9ms	remaining: 645ms
# 6:	learn: 0.6726636	total: 91.8ms	remaining: 564ms
# 7:	learn: 0.6703245	total: 98.9ms	remaining: 519ms
# 8:	learn: 0.6672892	total: 105ms	remaining: 481ms
# 9:	learn: 0.6649329	total: 114ms	remaining: 456ms
# 10:	learn: 0.6619208	total: 119ms	remaining: 422ms
# 11:	learn: 0.6596883	total: 125ms	remaining: 397ms
# 12:	learn: 0.6568855	total: 127ms	remaining: 362ms
# 13:	learn: 0.6542910	total: 133ms	remaining: 343ms
# 14:	learn: 0.6520265	total: 140ms	remaining: 327ms
# 15:	learn: 0.6493006	total: 148ms	remaining: 315ms
# 16:	learn: 0.6472281	total: 150ms	remaining: 292ms
# 17:	learn: 0.6446109	total: 156ms	remaining: 278ms
# 18:	learn: 0.6427787	total: 164ms	remaining: 267ms
# 19:	learn: 0.6406588	total: 166ms	remaining: 249ms
# 20:	learn: 0.6386527	total: 174ms	remaining: 240ms
# 21:	learn: 0.6364067	total: 179ms	remaining: 228ms
# 22:	learn: 0.6344642	total: 186ms	remaining: 219ms
# 23:	learn: 0.6325573	total: 188ms	remaining: 204ms
# 24:	learn: 0.6308030	total: 196ms	remaining: 196ms
# 25:	learn: 0.6284955	total: 203ms	remaining: 188ms
# 26:	learn: 0.6267105	total: 205ms	remaining: 175ms
# 27:	learn: 0.6249510	total: 214ms	remaining: 168ms
# 28:	learn: 0.6232122	total: 220ms	remaining: 159ms
# 29:	learn: 0.6215225	total: 226ms	remaining: 151ms
# 30:	learn: 0.6193827	total: 233ms	remaining: 143ms
# 31:	learn: 0.6177969	total: 240ms	remaining: 135ms
# 32:	learn: 0.6163329	total: 247ms	remaining: 127ms
# 33:	learn: 0.6149769	total: 254ms	remaining: 120ms
# 34:	learn: 0.6132122	total: 261ms	remaining: 112ms
# 35:	learn: 0.6117483	total: 270ms	remaining: 105ms
# 36:	learn: 0.6103900	total: 273ms	remaining: 95.8ms
# 37:	learn: 0.6090978	total: 281ms	remaining: 88.8ms
# 38:	learn: 0.6076275	total: 289ms	remaining: 81.6ms
# 39:	learn: 0.6062222	total: 292ms	remaining: 72.9ms
# 40:	learn: 0.6049620	total: 294ms	remaining: 64.5ms
# 41:	learn: 0.6036458	total: 297ms	remaining: 56.5ms
# 42:	learn: 0.6020360	total: 299ms	remaining: 48.6ms
# 43:	learn: 0.6008570	total: 318ms	remaining: 43.3ms
# 44:	learn: 0.5991402	total: 326ms	remaining: 36.2ms
# 45:	learn: 0.5978990	total: 332ms	remaining: 28.9ms
# 46:	learn: 0.5966593	total: 339ms	remaining: 21.6ms
# 47:	learn: 0.5954830	total: 348ms	remaining: 14.5ms
# 48:	learn: 0.5938694	total: 353ms	remaining: 7.2ms
# 49:	learn: 0.5924399	total: 355ms	remaining: 0us
# 0:	learn: 0.6795752	total: 2.37ms	remaining: 116ms
# 1:	learn: 0.6644807	total: 18.7ms	remaining: 448ms
# 2:	learn: 0.6530669	total: 20.7ms	remaining: 324ms
# 3:	learn: 0.6426337	total: 37.5ms	remaining: 431ms
# 4:	learn: 0.6306346	total: 43.2ms	remaining: 388ms
# 5:	learn: 0.6217205	total: 44.8ms	remaining: 329ms
# 6:	learn: 0.6144910	total: 46.4ms	remaining: 285ms
# 7:	learn: 0.6069776	total: 52.4ms	remaining: 275ms
# 8:	learn: 0.5986539	total: 54.3ms	remaining: 247ms
# 9:	learn: 0.5910733	total: 56ms	remaining: 224ms
# 10:	learn: 0.5851693	total: 57.8ms	remaining: 205ms
# 11:	learn: 0.5806016	total: 59.8ms	remaining: 189ms
# 12:	learn: 0.5760253	total: 61.7ms	remaining: 175ms
# 13:	learn: 0.5715902	total: 63.5ms	remaining: 163ms
# 14:	learn: 0.5678627	total: 65.4ms	remaining: 153ms
# 15:	learn: 0.5644236	total: 67.9ms	remaining: 144ms
# 16:	learn: 0.5600305	total: 69.8ms	remaining: 136ms
# 17:	learn: 0.5565399	total: 71.6ms	remaining: 127ms
# 18:	learn: 0.5528154	total: 73.7ms	remaining: 120ms
# 19:	learn: 0.5491993	total: 75.6ms	remaining: 113ms
# 20:	learn: 0.5459944	total: 77.5ms	remaining: 107ms
# 21:	learn: 0.5427130	total: 79.4ms	remaining: 101ms
# 22:	learn: 0.5395871	total: 81.5ms	remaining: 95.6ms
# 23:	learn: 0.5369765	total: 83.5ms	remaining: 90.5ms
# 24:	learn: 0.5343902	total: 85.6ms	remaining: 85.6ms
# 25:	learn: 0.5318468	total: 87.5ms	remaining: 80.8ms
# 26:	learn: 0.5291539	total: 89.7ms	remaining: 76.4ms
# 27:	learn: 0.5272026	total: 91.6ms	remaining: 72ms
# 28:	learn: 0.5247415	total: 93.9ms	remaining: 68ms
# 29:	learn: 0.5222197	total: 95.8ms	remaining: 63.9ms
# 30:	learn: 0.5199857	total: 97.8ms	remaining: 59.9ms
# 31:	learn: 0.5181694	total: 99.7ms	remaining: 56.1ms
# 32:	learn: 0.5163216	total: 102ms	remaining: 52.5ms
# 33:	learn: 0.5142997	total: 104ms	remaining: 49ms
# 34:	learn: 0.5127376	total: 106ms	remaining: 45.5ms
# 35:	learn: 0.5109728	total: 108ms	remaining: 42.1ms
# 36:	learn: 0.5091403	total: 111ms	remaining: 38.8ms
# 37:	learn: 0.5077576	total: 113ms	remaining: 35.6ms
# 38:	learn: 0.5064118	total: 115ms	remaining: 32.4ms
# 39:	learn: 0.5047956	total: 117ms	remaining: 29.2ms
# 40:	learn: 0.5031226	total: 119ms	remaining: 26.1ms
# 41:	learn: 0.5018006	total: 121ms	remaining: 23.1ms
# 42:	learn: 0.5005249	total: 123ms	remaining: 20.1ms
# 43:	learn: 0.4995632	total: 125ms	remaining: 17.1ms
# 44:	learn: 0.4980422	total: 128ms	remaining: 14.2ms
# 45:	learn: 0.4966784	total: 130ms	remaining: 11.3ms
# 46:	learn: 0.4951945	total: 132ms	remaining: 8.4ms
# 47:	learn: 0.4942758	total: 134ms	remaining: 5.57ms
# 48:	learn: 0.4931408	total: 136ms	remaining: 2.78ms
# 49:	learn: 0.4921680	total: 138ms	remaining: 0us
# 0:	learn: 0.6663622	total: 9.56ms	remaining: 469ms
# 1:	learn: 0.6445291	total: 18.5ms	remaining: 445ms
# 2:	learn: 0.6201816	total: 20.6ms	remaining: 322ms
# 3:	learn: 0.6028714	total: 35.1ms	remaining: 403ms
# 4:	learn: 0.5912933	total: 37ms	remaining: 333ms
# 5:	learn: 0.5808250	total: 43.9ms	remaining: 322ms
# 6:	learn: 0.5703552	total: 49ms	remaining: 301ms
# 7:	learn: 0.5617210	total: 56.7ms	remaining: 298ms
# 8:	learn: 0.5543820	total: 60.7ms	remaining: 277ms
# 9:	learn: 0.5494354	total: 62.5ms	remaining: 250ms
# 10:	learn: 0.5416409	total: 71.4ms	remaining: 253ms
# 11:	learn: 0.5356192	total: 73.3ms	remaining: 232ms
# 12:	learn: 0.5308177	total: 75.3ms	remaining: 214ms
# 13:	learn: 0.5259257	total: 77.5ms	remaining: 199ms
# 14:	learn: 0.5214378	total: 79.4ms	remaining: 185ms
# 15:	learn: 0.5178531	total: 81.3ms	remaining: 173ms
# 16:	learn: 0.5141661	total: 83ms	remaining: 161ms
# 17:	learn: 0.5105404	total: 84.9ms	remaining: 151ms
# 18:	learn: 0.5074565	total: 87ms	remaining: 142ms
# 19:	learn: 0.5050732	total: 88.9ms	remaining: 133ms
# 20:	learn: 0.5027660	total: 91ms	remaining: 126ms
# 21:	learn: 0.5003812	total: 94.4ms	remaining: 120ms
# 22:	learn: 0.4983807	total: 100ms	remaining: 117ms
# 23:	learn: 0.4964468	total: 102ms	remaining: 110ms
# 24:	learn: 0.4942702	total: 104ms	remaining: 104ms
# 25:	learn: 0.4917442	total: 107ms	remaining: 98.6ms
# 26:	learn: 0.4901915	total: 110ms	remaining: 93.8ms
# 27:	learn: 0.4888020	total: 114ms	remaining: 89.9ms
# 28:	learn: 0.4871746	total: 118ms	remaining: 85.8ms
# 29:	learn: 0.4848187	total: 124ms	remaining: 83ms
# 30:	learn: 0.4824560	total: 131ms	remaining: 80.5ms
# 31:	learn: 0.4807451	total: 137ms	remaining: 76.8ms
# 32:	learn: 0.4798752	total: 141ms	remaining: 72.4ms
# 33:	learn: 0.4786154	total: 147ms	remaining: 69ms
# 34:	learn: 0.4764446	total: 149ms	remaining: 63.8ms
# 35:	learn: 0.4752601	total: 155ms	remaining: 60.1ms
# 36:	learn: 0.4739754	total: 156ms	remaining: 54.9ms
# 37:	learn: 0.4730193	total: 168ms	remaining: 53.2ms
# 38:	learn: 0.4711155	total: 171ms	remaining: 48.1ms
# 39:	learn: 0.4703853	total: 173ms	remaining: 43.2ms
# 40:	learn: 0.4689032	total: 175ms	remaining: 38.4ms
# 41:	learn: 0.4678383	total: 177ms	remaining: 33.7ms
# 42:	learn: 0.4667155	total: 179ms	remaining: 29.2ms
# 43:	learn: 0.4659994	total: 181ms	remaining: 24.7ms
# 44:	learn: 0.4649697	total: 183ms	remaining: 20.3ms
# 45:	learn: 0.4636862	total: 185ms	remaining: 16.1ms
# 46:	learn: 0.4628690	total: 187ms	remaining: 11.9ms
# 47:	learn: 0.4622012	total: 189ms	remaining: 7.86ms
# 48:	learn: 0.4615854	total: 191ms	remaining: 3.9ms
# 49:	learn: 0.4608944	total: 193ms	remaining: 0us
# 0:	learn: 0.6683703	total: 4.33ms	remaining: 212ms
# 1:	learn: 0.6449610	total: 14.2ms	remaining: 340ms
# 2:	learn: 0.6205881	total: 20.9ms	remaining: 327ms
# 3:	learn: 0.6063422	total: 22.9ms	remaining: 263ms
# 4:	learn: 0.5943685	total: 24.7ms	remaining: 222ms
# 5:	learn: 0.5837114	total: 26.4ms	remaining: 194ms
# 6:	learn: 0.5748706	total: 28.3ms	remaining: 174ms
# 7:	learn: 0.5660403	total: 30.3ms	remaining: 159ms
# 8:	learn: 0.5562016	total: 32.1ms	remaining: 146ms
# 0:	learn: 0.6905940	total: 56.1ms	remaining: 2.75s
# 1:	learn: 0.6876852	total: 59.8ms	remaining: 1.44s
# 2:	learn: 0.6843128	total: 64.5ms	remaining: 1.01s
# 3:	learn: 0.6810326	total: 67ms	remaining: 771ms
# 4:	learn: 0.6778912	total: 76.9ms	remaining: 692ms
# 5:	learn: 0.6752729	total: 79.2ms	remaining: 581ms
# 6:	learn: 0.6722482	total: 81.2ms	remaining: 499ms
# 7:	learn: 0.6693130	total: 83.5ms	remaining: 438ms
# 8:	learn: 0.6671228	total: 85.9ms	remaining: 391ms
# 9:	learn: 0.6647816	total: 105ms	remaining: 420ms
# 10:	learn: 0.6624847	total: 117ms	remaining: 416ms
# 11:	learn: 0.6600484	total: 124ms	remaining: 392ms
# 12:	learn: 0.6577764	total: 126ms	remaining: 359ms
# 13:	learn: 0.6550633	total: 133ms	remaining: 342ms
# 14:	learn: 0.6531692	total: 140ms	remaining: 327ms
# 15:	learn: 0.6507408	total: 142ms	remaining: 302ms
# 16:	learn: 0.6487483	total: 149ms	remaining: 290ms
# 17:	learn: 0.6469277	total: 157ms	remaining: 278ms
# 18:	learn: 0.6449275	total: 163ms	remaining: 266ms
# 19:	learn: 0.6431677	total: 165ms	remaining: 248ms
# 20:	learn: 0.6408165	total: 172ms	remaining: 238ms
# 21:	learn: 0.6385273	total: 180ms	remaining: 229ms
# 22:	learn: 0.6362307	total: 182ms	remaining: 213ms
# 23:	learn: 0.6343589	total: 189ms	remaining: 205ms
# 24:	learn: 0.6326733	total: 196ms	remaining: 196ms
# 25:	learn: 0.6309095	total: 203ms	remaining: 188ms
# 26:	learn: 0.6292819	total: 205ms	remaining: 175ms
# 27:	learn: 0.6275639	total: 215ms	remaining: 169ms
# 28:	learn: 0.6254868	total: 219ms	remaining: 159ms
# 29:	learn: 0.6239101	total: 221ms	remaining: 147ms
# 30:	learn: 0.6223634	total: 223ms	remaining: 137ms
# 31:	learn: 0.6207508	total: 236ms	remaining: 133ms
# 32:	learn: 0.6190271	total: 243ms	remaining: 125ms
# 33:	learn: 0.6171372	total: 251ms	remaining: 118ms
# 34:	learn: 0.6157019	total: 258ms	remaining: 110ms
# 35:	learn: 0.6143729	total: 266ms	remaining: 103ms
# 36:	learn: 0.6130182	total: 269ms	remaining: 94.4ms
# 37:	learn: 0.6116407	total: 276ms	remaining: 87.2ms
# 38:	learn: 0.6098800	total: 284ms	remaining: 80ms
# 39:	learn: 0.6086866	total: 291ms	remaining: 72.7ms
# 40:	learn: 0.6069940	total: 298ms	remaining: 65.5ms
# 41:	learn: 0.6058392	total: 300ms	remaining: 57.2ms
# 42:	learn: 0.6045640	total: 312ms	remaining: 50.8ms
# 43:	learn: 0.6034282	total: 314ms	remaining: 42.9ms
# 44:	learn: 0.6022233	total: 322ms	remaining: 35.8ms
# 45:	learn: 0.6010329	total: 329ms	remaining: 28.6ms
# 46:	learn: 0.5994599	total: 332ms	remaining: 21.2ms
# 47:	learn: 0.5983357	total: 334ms	remaining: 13.9ms
# 48:	learn: 0.5968697	total: 350ms	remaining: 7.14ms
# 49:	learn: 0.5957862	total: 353ms	remaining: 0us
# 0:	learn: 0.6801822	total: 2.17ms	remaining: 106ms
# 1:	learn: 0.6669730	total: 8.58ms	remaining: 206ms
# 2:	learn: 0.6519535	total: 16.3ms	remaining: 256ms
# 3:	learn: 0.6385890	total: 18.1ms	remaining: 208ms
# 4:	learn: 0.6273124	total: 25.6ms	remaining: 230ms
# 5:	learn: 0.6195592	total: 27.7ms	remaining: 203ms
# 6:	learn: 0.6099972	total: 43.1ms	remaining: 265ms
# 7:	learn: 0.6027862	total: 44.9ms	remaining: 236ms
# 8:	learn: 0.5945183	total: 46.9ms	remaining: 214ms
# 9:	learn: 0.5890433	total: 48.8ms	remaining: 195ms
# 10:	learn: 0.5833427	total: 54.5ms	remaining: 193ms
# 11:	learn: 0.5782385	total: 56.3ms	remaining: 178ms
# 12:	learn: 0.5727409	total: 58.4ms	remaining: 166ms
# 13:	learn: 0.5686611	total: 60.4ms	remaining: 155ms
# 14:	learn: 0.5650624	total: 62.4ms	remaining: 146ms
# 15:	learn: 0.5603789	total: 64.8ms	remaining: 138ms
# 16:	learn: 0.5563043	total: 67.3ms	remaining: 131ms
# 17:	learn: 0.5533508	total: 75.7ms	remaining: 135ms
# 18:	learn: 0.5498421	total: 77.9ms	remaining: 127ms
# 19:	learn: 0.5464121	total: 80.2ms	remaining: 120ms
# 20:	learn: 0.5429966	total: 82.7ms	remaining: 114ms
# 21:	learn: 0.5404451	total: 84.5ms	remaining: 108ms
# 22:	learn: 0.5384518	total: 87ms	remaining: 102ms
# 23:	learn: 0.5355890	total: 89.6ms	remaining: 97ms
# 24:	learn: 0.5331972	total: 92.4ms	remaining: 92.4ms
# 25:	learn: 0.5306409	total: 95.7ms	remaining: 88.4ms
# 26:	learn: 0.5283005	total: 98.4ms	remaining: 83.8ms
# 27:	learn: 0.5261341	total: 101ms	remaining: 79ms
# 28:	learn: 0.5239670	total: 102ms	remaining: 74.1ms
# 29:	learn: 0.5221122	total: 104ms	remaining: 69.6ms
# 30:	learn: 0.5195970	total: 106ms	remaining: 65.2ms
# 31:	learn: 0.5176258	total: 109ms	remaining: 61.3ms
# 32:	learn: 0.5155489	total: 113ms	remaining: 58ms
# 33:	learn: 0.5136091	total: 117ms	remaining: 55.2ms
# 34:	learn: 0.5116997	total: 120ms	remaining: 51.4ms
# 35:	learn: 0.5096810	total: 122ms	remaining: 47.4ms
# 36:	learn: 0.5078735	total: 124ms	remaining: 43.5ms
# 37:	learn: 0.5064385	total: 126ms	remaining: 39.8ms
# 38:	learn: 0.5053552	total: 128ms	remaining: 36.1ms
# 39:	learn: 0.5035788	total: 130ms	remaining: 32.6ms
# 40:	learn: 0.5023028	total: 132ms	remaining: 29.1ms
# 41:	learn: 0.5012516	total: 135ms	remaining: 25.6ms
# 42:	learn: 0.5001096	total: 137ms	remaining: 22.3ms
# 43:	learn: 0.4987836	total: 139ms	remaining: 18.9ms
# 44:	learn: 0.4975290	total: 141ms	remaining: 15.7ms
# 45:	learn: 0.4962951	total: 143ms	remaining: 12.4ms
# 46:	learn: 0.4948368	total: 145ms	remaining: 9.25ms
# 47:	learn: 0.4937650	total: 147ms	remaining: 6.12ms
# 48:	learn: 0.4924324	total: 149ms	remaining: 3.04ms
# 49:	learn: 0.4914976	total: 151ms	remaining: 0us
# 0:	learn: 0.6667868	total: 3.42ms	remaining: 168ms
# 1:	learn: 0.6398371	total: 6.31ms	remaining: 151ms
# 2:	learn: 0.6216176	total: 8.49ms	remaining: 133ms
# 3:	learn: 0.6067890	total: 10.5ms	remaining: 120ms
# 4:	learn: 0.5909887	total: 12.9ms	remaining: 117ms
# 5:	learn: 0.5803171	total: 15.4ms	remaining: 113ms
# 6:	learn: 0.5714774	total: 17.1ms	remaining: 105ms
# 7:	learn: 0.5614994	total: 19.3ms	remaining: 101ms
# 8:	learn: 0.5552968	total: 21.9ms	remaining: 99.7ms
# 9:	learn: 0.5485337	total: 25.3ms	remaining: 101ms
# 10:	learn: 0.5425007	total: 28.7ms	remaining: 102ms
# 11:	learn: 0.5382503	total: 31ms	remaining: 98ms
# 12:	learn: 0.5326442	total: 32.9ms	remaining: 93.6ms
# 13:	learn: 0.5270314	total: 36.6ms	remaining: 94ms
# 14:	learn: 0.5225457	total: 38.8ms	remaining: 90.6ms
# 15:	learn: 0.5186948	total: 40.8ms	remaining: 86.8ms
# 16:	learn: 0.5152373	total: 42.7ms	remaining: 82.9ms
# 17:	learn: 0.5107040	total: 44.4ms	remaining: 78.9ms
# 18:	learn: 0.5074610	total: 46.4ms	remaining: 75.7ms
# 19:	learn: 0.5040664	total: 48.5ms	remaining: 72.8ms
# 20:	learn: 0.5013212	total: 50.5ms	remaining: 69.7ms
# 21:	learn: 0.4976103	total: 52.4ms	remaining: 66.7ms
# 22:	learn: 0.4955192	total: 54.4ms	remaining: 63.9ms
# 23:	learn: 0.4937538	total: 56.2ms	remaining: 60.9ms
# 24:	learn: 0.4909728	total: 58.2ms	remaining: 58.2ms
# 25:	learn: 0.4891257	total: 60.3ms	remaining: 55.6ms
# 26:	learn: 0.4863196	total: 62.2ms	remaining: 53ms
# 27:	learn: 0.4843381	total: 68.2ms	remaining: 53.6ms
# 28:	learn: 0.4830736	total: 70.3ms	remaining: 50.9ms
# 29:	learn: 0.4817816	total: 72.2ms	remaining: 48.1ms
# 30:	learn: 0.4795922	total: 79.7ms	remaining: 48.9ms
# 31:	learn: 0.4779410	total: 87.4ms	remaining: 49.2ms
# 32:	learn: 0.4763233	total: 90ms	remaining: 46.3ms
# 33:	learn: 0.4750844	total: 95.4ms	remaining: 44.9ms
# 34:	learn: 0.4739717	total: 97.5ms	remaining: 41.8ms
# 35:	learn: 0.4727796	total: 99.4ms	remaining: 38.7ms
# 36:	learn: 0.4714970	total: 102ms	remaining: 35.9ms
# 37:	learn: 0.4705558	total: 106ms	remaining: 33.5ms
# 38:	learn: 0.4697222	total: 112ms	remaining: 31.6ms
# 39:	learn: 0.4689232	total: 115ms	remaining: 28.6ms
# 40:	learn: 0.4668880	total: 122ms	remaining: 26.7ms
# 41:	learn: 0.4660631	total: 127ms	remaining: 24.1ms
# 42:	learn: 0.4650152	total: 130ms	remaining: 21.1ms
# 43:	learn: 0.4643092	total: 133ms	remaining: 18.1ms
# 44:	learn: 0.4632009	total: 135ms	remaining: 15ms
# 45:	learn: 0.4620418	total: 142ms	remaining: 12.4ms
# 46:	learn: 0.4615022	total: 148ms	remaining: 9.43ms
# 47:	learn: 0.4605563	total: 150ms	remaining: 6.25ms
# 48:	learn: 0.4588802	total: 154ms	remaining: 3.15ms
# 49:	learn: 0.4582404	total: 158ms	remaining: 0us
# 0:	learn: 0.5906363	total: 2.3ms	remaining: 113ms
# 1:	learn: 0.5576844	total: 6.91ms	remaining: 166ms
# 2:	learn: 0.5301510	total: 8.9ms	remaining: 139ms
# 3:	learn: 0.5117976	total: 18.7ms	remaining: 215ms
# 4:	learn: 0.4995545	total: 20.8ms	remaining: 188ms
# 5:	learn: 0.4853680	total: 33ms	remaining: 242ms
# 6:	learn: 0.4745022	total: 35.2ms	remaining: 216ms
# 7:	learn: 0.4690722	total: 43.7ms	remaining: 229ms
# 8:	learn: 0.5584104	total: 27.9ms	remaining: 127ms
# 9:	learn: 0.5512262	total: 30.2ms	remaining: 121ms
# 10:	learn: 0.5460548	total: 41.3ms	remaining: 146ms
# 11:	learn: 0.5405321	total: 46.5ms	remaining: 147ms
# 12:	learn: 0.5348393	total: 48.4ms	remaining: 138ms
# 13:	learn: 0.5308682	total: 52.5ms	remaining: 135ms
# 14:	learn: 0.5265113	total: 54.5ms	remaining: 127ms
# 15:	learn: 0.5231033	total: 56.8ms	remaining: 121ms
# 16:	learn: 0.5196375	total: 58.9ms	remaining: 114ms
# 17:	learn: 0.5164589	total: 60.8ms	remaining: 108ms
# 18:	learn: 0.5124596	total: 63.2ms	remaining: 103ms
# 19:	learn: 0.5089321	total: 65.4ms	remaining: 98.1ms
# 20:	learn: 0.5057870	total: 67.6ms	remaining: 93.3ms
# 21:	learn: 0.5030137	total: 69.7ms	remaining: 88.7ms
# 22:	learn: 0.5010646	total: 73.5ms	remaining: 86.3ms
# 23:	learn: 0.4983924	total: 78.5ms	remaining: 85.1ms
# 24:	learn: 0.4956606	total: 82.4ms	remaining: 82.4ms
# 25:	learn: 0.4937439	total: 84.9ms	remaining: 78.3ms
# 26:	learn: 0.4914279	total: 87.3ms	remaining: 74.3ms
# 27:	learn: 0.4884484	total: 89.9ms	remaining: 70.6ms
# 28:	learn: 0.4864407	total: 93.7ms	remaining: 67.9ms
# 29:	learn: 0.4845406	total: 99.3ms	remaining: 66.2ms
# 30:	learn: 0.4823707	total: 101ms	remaining: 62ms
# 31:	learn: 0.4803949	total: 103ms	remaining: 58ms
# 32:	learn: 0.4782516	total: 108ms	remaining: 55.6ms
# 33:	learn: 0.4768836	total: 111ms	remaining: 52.4ms
# 34:	learn: 0.4756352	total: 114ms	remaining: 48.8ms
# 35:	learn: 0.4744223	total: 120ms	remaining: 46.5ms
# 36:	learn: 0.4735317	total: 126ms	remaining: 44.4ms
# 37:	learn: 0.4719181	total: 129ms	remaining: 40.6ms
# 38:	learn: 0.4701679	total: 131ms	remaining: 36.8ms
# 39:	learn: 0.4687073	total: 133ms	remaining: 33.3ms
# 40:	learn: 0.4677202	total: 135ms	remaining: 29.7ms
# 41:	learn: 0.4670335	total: 137ms	remaining: 26.1ms
# 42:	learn: 0.4660308	total: 140ms	remaining: 22.7ms
# 43:	learn: 0.4650772	total: 142ms	remaining: 19.3ms
# 44:	learn: 0.4640021	total: 145ms	remaining: 16.1ms
# 45:	learn: 0.4630508	total: 147ms	remaining: 12.8ms
# 46:	learn: 0.4623029	total: 150ms	remaining: 9.56ms
# 47:	learn: 0.4610407	total: 152ms	remaining: 6.33ms
# 48:	learn: 0.4603771	total: 154ms	remaining: 3.15ms
# 49:	learn: 0.4596059	total: 156ms	remaining: 0us
# 0:	learn: 0.5923566	total: 2.53ms	remaining: 124ms
# 1:	learn: 0.5431462	total: 4.49ms	remaining: 108ms
# 2:	learn: 0.5183319	total: 6.82ms	remaining: 107ms
# 3:	learn: 0.4998949	total: 9.59ms	remaining: 110ms
# 4:	learn: 0.4886964	total: 11.3ms	remaining: 102ms
# 5:	learn: 0.4788736	total: 13.5ms	remaining: 98.8ms
# 6:	learn: 0.4712469	total: 16ms	remaining: 98.4ms
# 7:	learn: 0.4665989	total: 18.1ms	remaining: 95ms
# 8:	learn: 0.4613135	total: 20.3ms	remaining: 92.4ms
# 9:	learn: 0.4567744	total: 22.3ms	remaining: 89.1ms
# 10:	learn: 0.4519389	total: 24.3ms	remaining: 86ms
# 11:	learn: 0.4491775	total: 26.4ms	remaining: 83.6ms
# 12:	learn: 0.4450818	total: 28.2ms	remaining: 80.3ms
# 13:	learn: 0.4431118	total: 30.2ms	remaining: 77.6ms
# 14:	learn: 0.4401306	total: 32.5ms	remaining: 75.7ms
# 15:	learn: 0.4386180	total: 35ms	remaining: 74.4ms
# 16:	learn: 0.4362345	total: 37.2ms	remaining: 72.2ms
# 17:	learn: 0.4328684	total: 39ms	remaining: 69.2ms
# 18:	learn: 0.4309337	total: 41.1ms	remaining: 67ms
# 19:	learn: 0.4289227	total: 43.2ms	remaining: 64.7ms
# 20:	learn: 0.4264441	total: 45.6ms	remaining: 62.9ms
# 21:	learn: 0.4236816	total: 47.7ms	remaining: 60.7ms
# 22:	learn: 0.4212509	total: 49.9ms	remaining: 58.5ms
# 23:	learn: 0.4187231	total: 52.4ms	remaining: 56.8ms
# 24:	learn: 0.4176335	total: 54.6ms	remaining: 54.6ms
# 25:	learn: 0.4115537	total: 62.1ms	remaining: 57.3ms
# 26:	learn: 0.4103677	total: 67.1ms	remaining: 57.2ms
# 27:	learn: 0.4092110	total: 70ms	remaining: 55ms
# 28:	learn: 0.4078862	total: 71.8ms	remaining: 52ms
# 29:	learn: 0.4065915	total: 73.6ms	remaining: 49.1ms
# 30:	learn: 0.4055999	total: 75.5ms	remaining: 46.2ms
# 31:	learn: 0.4032388	total: 77.5ms	remaining: 43.6ms
# 32:	learn: 0.4022074	total: 79.8ms	remaining: 41.1ms
# 33:	learn: 0.4016910	total: 83.5ms	remaining: 39.3ms
# 34:	learn: 0.4011302	total: 85.9ms	remaining: 36.8ms
# 35:	learn: 0.4004070	total: 87.8ms	remaining: 34.1ms
# 36:	learn: 0.3992337	total: 89.7ms	remaining: 31.5ms
# 37:	learn: 0.3985532	total: 91.7ms	remaining: 29ms
# 38:	learn: 0.3977163	total: 94ms	remaining: 26.5ms
# 39:	learn: 0.3964492	total: 96.1ms	remaining: 24ms
# 40:	learn: 0.3955123	total: 98ms	remaining: 21.5ms
# 41:	learn: 0.3945887	total: 100ms	remaining: 19.1ms
# 42:	learn: 0.3939395	total: 102ms	remaining: 16.6ms
# 43:	learn: 0.3932518	total: 104ms	remaining: 14.2ms
# 44:	learn: 0.3924418	total: 106ms	remaining: 11.8ms
# 45:	learn: 0.3919924	total: 108ms	remaining: 9.41ms
# 46:	learn: 0.3912394	total: 110ms	remaining: 7.02ms
# 47:	learn: 0.3905889	total: 112ms	remaining: 4.67ms
# 48:	learn: 0.3901007	total: 114ms	remaining: 2.32ms
# 49:	learn: 0.3895314	total: 116ms	remaining: 0us
# 0:	learn: 0.6903281	total: 3.19ms	remaining: 316ms
# 1:	learn: 0.6874752	total: 5ms	remaining: 245ms
# 2:	learn: 0.6841076	total: 13.5ms	remaining: 437ms
# 3:	learn: 0.6814470	total: 15.9ms	remaining: 381ms
# 4:	learn: 0.6783009	total: 18.2ms	remaining: 347ms
# 5:	learn: 0.6751029	total: 20.3ms	remaining: 318ms
# 6:	learn: 0.6719638	total: 22.4ms	remaining: 297ms
# 7:	learn: 0.6694772	total: 24.2ms	remaining: 279ms
# 8:	learn: 0.6666273	total: 26.2ms	remaining: 265ms
# 9:	learn: 0.6637457	total: 28.5ms	remaining: 257ms
# 10:	learn: 0.6616058	total: 32.4ms	remaining: 262ms
# 11:	learn: 0.6588072	total: 34.4ms	remaining: 252ms
# 12:	learn: 0.6561975	total: 39.8ms	remaining: 267ms
# 13:	learn: 0.6535481	total: 42.3ms	remaining: 260ms
# 14:	learn: 0.6514503	total: 48.6ms	remaining: 275ms
# 15:	learn: 0.6493083	total: 50.8ms	remaining: 267ms
# 16:	learn: 0.6467614	total: 54.1ms	remaining: 264ms
# 17:	learn: 0.6446337	total: 56.5ms	remaining: 258ms
# 18:	learn: 0.6421394	total: 63ms	remaining: 269ms
# 19:	learn: 0.6399030	total: 64.7ms	remaining: 259ms
# 20:	learn: 0.6379468	total: 66.5ms	remaining: 250ms
# 21:	learn: 0.6360456	total: 72.2ms	remaining: 256ms
# 22:	learn: 0.6343693	total: 74.2ms	remaining: 248ms
# 23:	learn: 0.6320925	total: 76.5ms	remaining: 242ms
# 24:	learn: 0.6302816	total: 79ms	remaining: 237ms
# 25:	learn: 0.6287069	total: 81.5ms	remaining: 232ms
# 26:	learn: 0.6266386	total: 83.2ms	remaining: 225ms
# 27:	learn: 0.6246228	total: 85.1ms	remaining: 219ms
# 28:	learn: 0.6231620	total: 87.2ms	remaining: 214ms
# 29:	learn: 0.6219284	total: 88.9ms	remaining: 208ms
# 30:	learn: 0.6198171	total: 90.9ms	remaining: 202ms
# 31:	learn: 0.6181989	total: 92.8ms	remaining: 197ms
# 32:	learn: 0.6163378	total: 94.7ms	remaining: 192ms
# 33:	learn: 0.6148381	total: 98.2ms	remaining: 191ms
# 34:	learn: 0.6133472	total: 100ms	remaining: 186ms
# 35:	learn: 0.6119734	total: 103ms	remaining: 183ms
# 36:	learn: 0.6102632	total: 105ms	remaining: 179ms
# 37:	learn: 0.6088450	total: 107ms	remaining: 174ms
# 38:	learn: 0.6072145	total: 109ms	remaining: 170ms
# 39:	learn: 0.6054118	total: 111ms	remaining: 166ms
# 40:	learn: 0.6041290	total: 113ms	remaining: 162ms
# 41:	learn: 0.6028615	total: 115ms	remaining: 158ms
# 42:	learn: 0.6015306	total: 117ms	remaining: 155ms
# 43:	learn: 0.6003710	total: 119ms	remaining: 151ms
# 44:	learn: 0.5991786	total: 121ms	remaining: 148ms
# 45:	learn: 0.5979402	total: 123ms	remaining: 144ms
# 46:	learn: 0.5967462	total: 125ms	remaining: 141ms
# 47:	learn: 0.5956158	total: 127ms	remaining: 138ms
# 48:	learn: 0.5941927	total: 130ms	remaining: 135ms
# 49:	learn: 0.5927802	total: 131ms	remaining: 131ms
# 50:	learn: 0.5916636	total: 133ms	remaining: 128ms
# 51:	learn: 0.5905439	total: 135ms	remaining: 125ms
# 52:	learn: 0.5892518	total: 137ms	remaining: 122ms
# 53:	learn: 0.5882517	total: 139ms	remaining: 119ms
# 54:	learn: 0.5873062	total: 141ms	remaining: 116ms
# 55:	learn: 0.5863308	total: 143ms	remaining: 113ms
# 56:	learn: 0.5853621	total: 145ms	remaining: 110ms
# 57:	learn: 0.5843343	total: 150ms	remaining: 109ms
# 58:	learn: 0.5833631	total: 153ms	remaining: 106ms
# 59:	learn: 0.5824576	total: 154ms	remaining: 103ms
# 60:	learn: 0.5815152	total: 157ms	remaining: 100ms
# 61:	learn: 0.5805919	total: 159ms	remaining: 97.4ms
# 62:	learn: 0.5797260	total: 164ms	remaining: 96.2ms
# 63:	learn: 0.5788850	total: 168ms	remaining: 94.3ms
# 64:	learn: 0.5779356	total: 171ms	remaining: 92.3ms
# 65:	learn: 0.5768931	total: 174ms	remaining: 89.5ms
# 8:	learn: 0.5631900	total: 28.5ms	remaining: 130ms
# 9:	learn: 0.5564228	total: 31.6ms	remaining: 127ms
# 10:	learn: 0.5502608	total: 36.7ms	remaining: 130ms
# 11:	learn: 0.5450372	total: 44.4ms	remaining: 140ms
# 12:	learn: 0.5398968	total: 51.3ms	remaining: 146ms
# 13:	learn: 0.5359587	total: 56.2ms	remaining: 144ms
# 14:	learn: 0.5315117	total: 59.5ms	remaining: 139ms
# 15:	learn: 0.5271702	total: 63.7ms	remaining: 135ms
# 16:	learn: 0.5235476	total: 70.2ms	remaining: 136ms
# 17:	learn: 0.5177323	total: 73.4ms	remaining: 130ms
# 18:	learn: 0.5150706	total: 82.7ms	remaining: 135ms
# 19:	learn: 0.5117513	total: 84.6ms	remaining: 127ms
# 20:	learn: 0.5081920	total: 86.9ms	remaining: 120ms
# 21:	learn: 0.5059912	total: 89.4ms	remaining: 114ms
# 22:	learn: 0.5033135	total: 92.6ms	remaining: 109ms
# 23:	learn: 0.5010133	total: 96.6ms	remaining: 105ms
# 24:	learn: 0.4983466	total: 104ms	remaining: 104ms
# 25:	learn: 0.4965104	total: 106ms	remaining: 97.7ms
# 26:	learn: 0.4947411	total: 114ms	remaining: 97.5ms
# 27:	learn: 0.4936721	total: 118ms	remaining: 92.7ms
# 28:	learn: 0.4915289	total: 120ms	remaining: 86.7ms
# 29:	learn: 0.4898027	total: 125ms	remaining: 83.6ms
# 30:	learn: 0.4881954	total: 128ms	remaining: 78.5ms
# 31:	learn: 0.4866922	total: 130ms	remaining: 73ms
# 32:	learn: 0.4850102	total: 132ms	remaining: 68ms
# 33:	learn: 0.4839796	total: 134ms	remaining: 63ms
# 34:	learn: 0.4830202	total: 136ms	remaining: 58.3ms
# 35:	learn: 0.4815244	total: 138ms	remaining: 53.8ms
# 36:	learn: 0.4807170	total: 140ms	remaining: 49.3ms
# 37:	learn: 0.4789652	total: 142ms	remaining: 44.9ms
# 38:	learn: 0.4779963	total: 144ms	remaining: 40.6ms
# 39:	learn: 0.4769421	total: 146ms	remaining: 36.5ms
# 40:	learn: 0.4761508	total: 148ms	remaining: 32.5ms
# 41:	learn: 0.4751800	total: 150ms	remaining: 28.5ms
# 42:	learn: 0.4743999	total: 152ms	remaining: 24.7ms
# 43:	learn: 0.4729867	total: 154ms	remaining: 21ms
# 44:	learn: 0.4721579	total: 156ms	remaining: 17.3ms
# 45:	learn: 0.4712072	total: 158ms	remaining: 13.7ms
# 46:	learn: 0.4699696	total: 160ms	remaining: 10.2ms
# 47:	learn: 0.4689043	total: 162ms	remaining: 6.74ms
# 48:	learn: 0.4677722	total: 164ms	remaining: 3.34ms
# 49:	learn: 0.4670481	total: 167ms	remaining: 0us
# 0:	learn: 0.5971439	total: 1.97ms	remaining: 96.3ms
# 1:	learn: 0.5388685	total: 3.83ms	remaining: 91.8ms
# 2:	learn: 0.5149548	total: 8.79ms	remaining: 138ms
# 3:	learn: 0.4994137	total: 15.5ms	remaining: 178ms
# 4:	learn: 0.4903285	total: 21.3ms	remaining: 192ms
# 5:	learn: 0.4830261	total: 24.1ms	remaining: 177ms
# 6:	learn: 0.4681623	total: 29.4ms	remaining: 180ms
# 7:	learn: 0.4643961	total: 32ms	remaining: 168ms
# 8:	learn: 0.4595318	total: 34.5ms	remaining: 157ms
# 9:	learn: 0.4526691	total: 40.8ms	remaining: 163ms
# 10:	learn: 0.4484956	total: 42.9ms	remaining: 152ms
# 11:	learn: 0.4461702	total: 44.8ms	remaining: 142ms
# 12:	learn: 0.4427657	total: 49.9ms	remaining: 142ms
# 13:	learn: 0.4397250	total: 54ms	remaining: 139ms
# 14:	learn: 0.4387184	total: 56.1ms	remaining: 131ms
# 15:	learn: 0.4365858	total: 57.9ms	remaining: 123ms
# 16:	learn: 0.4330144	total: 60ms	remaining: 117ms
# 17:	learn: 0.4309006	total: 61.8ms	remaining: 110ms
# 18:	learn: 0.4285622	total: 63.9ms	remaining: 104ms
# 19:	learn: 0.4264873	total: 66.6ms	remaining: 99.9ms
# 20:	learn: 0.4252684	total: 68.5ms	remaining: 94.6ms
# 21:	learn: 0.4229662	total: 72.7ms	remaining: 92.6ms
# 22:	learn: 0.4206474	total: 76.6ms	remaining: 89.9ms
# 23:	learn: 0.4191065	total: 81.9ms	remaining: 88.8ms
# 24:	learn: 0.4168387	total: 84ms	remaining: 84ms
# 25:	learn: 0.4162869	total: 93.8ms	remaining: 86.6ms
# 26:	learn: 0.4152780	total: 102ms	remaining: 86.9ms
# 27:	learn: 0.4136163	total: 107ms	remaining: 84.4ms
# 28:	learn: 0.4127009	total: 116ms	remaining: 84.1ms
# 29:	learn: 0.4122049	total: 127ms	remaining: 84.5ms
# 30:	learn: 0.4111886	total: 137ms	remaining: 83.7ms
# 31:	learn: 0.4102772	total: 139ms	remaining: 78.3ms
# 32:	learn: 0.4091393	total: 146ms	remaining: 75.3ms
# 33:	learn: 0.4082274	total: 155ms	remaining: 73ms
# 34:	learn: 0.4073827	total: 163ms	remaining: 70ms
# 35:	learn: 0.4065562	total: 169ms	remaining: 65.6ms
# 36:	learn: 0.4058745	total: 172ms	remaining: 60.4ms
# 37:	learn: 0.4052041	total: 174ms	remaining: 55ms
# 38:	learn: 0.4041855	total: 176ms	remaining: 49.7ms
# 39:	learn: 0.4035431	total: 178ms	remaining: 44.5ms
# 40:	learn: 0.4026453	total: 183ms	remaining: 40.1ms
# 41:	learn: 0.4021458	total: 186ms	remaining: 35.4ms
# 42:	learn: 0.4012168	total: 190ms	remaining: 30.9ms
# 43:	learn: 0.4004955	total: 192ms	remaining: 26.1ms
# 44:	learn: 0.3992227	total: 197ms	remaining: 21.9ms
# 45:	learn: 0.3965633	total: 201ms	remaining: 17.5ms
# 46:	learn: 0.3957254	total: 206ms	remaining: 13.1ms
# 47:	learn: 0.3950576	total: 209ms	remaining: 8.71ms
# 48:	learn: 0.3945400	total: 213ms	remaining: 4.35ms
# 49:	learn: 0.3940864	total: 218ms	remaining: 0us
# 0:	learn: 0.6904941	total: 1.92ms	remaining: 190ms
# 1:	learn: 0.6876073	total: 3.7ms	remaining: 181ms
# 2:	learn: 0.6842234	total: 5.43ms	remaining: 175ms
# 3:	learn: 0.6808023	total: 15.3ms	remaining: 368ms
# 4:	learn: 0.6782183	total: 17.2ms	remaining: 327ms
# 5:	learn: 0.6749077	total: 19.2ms	remaining: 301ms
# 6:	learn: 0.6726636	total: 21ms	remaining: 280ms
# 7:	learn: 0.6703245	total: 23.1ms	remaining: 265ms
# 8:	learn: 0.6672892	total: 24.8ms	remaining: 251ms
# 9:	learn: 0.6649329	total: 27.6ms	remaining: 248ms
# 10:	learn: 0.6619208	total: 29.4ms	remaining: 238ms
# 11:	learn: 0.6596883	total: 31.2ms	remaining: 229ms
# 12:	learn: 0.6568855	total: 33.1ms	remaining: 222ms
# 13:	learn: 0.6542910	total: 34.6ms	remaining: 213ms
# 14:	learn: 0.6520265	total: 36.3ms	remaining: 206ms
# 15:	learn: 0.6493006	total: 38ms	remaining: 199ms
# 16:	learn: 0.6472281	total: 39.6ms	remaining: 193ms
# 17:	learn: 0.6446109	total: 41.4ms	remaining: 189ms
# 18:	learn: 0.6427787	total: 43.8ms	remaining: 187ms
# 19:	learn: 0.6406588	total: 45.8ms	remaining: 183ms
# 20:	learn: 0.6386527	total: 47.9ms	remaining: 180ms
# 21:	learn: 0.6364067	total: 49.6ms	remaining: 176ms
# 22:	learn: 0.6344642	total: 51.3ms	remaining: 172ms
# 23:	learn: 0.6325573	total: 53ms	remaining: 168ms
# 24:	learn: 0.6308030	total: 55ms	remaining: 165ms
# 25:	learn: 0.6284955	total: 56.9ms	remaining: 162ms
# 26:	learn: 0.6267105	total: 58.5ms	remaining: 158ms
# 27:	learn: 0.6249510	total: 60.2ms	remaining: 155ms
# 28:	learn: 0.6232122	total: 62ms	remaining: 152ms
# 29:	learn: 0.6215225	total: 64ms	remaining: 149ms
# 30:	learn: 0.6193827	total: 65.9ms	remaining: 147ms
# 31:	learn: 0.6177969	total: 68ms	remaining: 145ms
# 32:	learn: 0.6163329	total: 69.8ms	remaining: 142ms
# 33:	learn: 0.6149769	total: 71.7ms	remaining: 139ms
# 34:	learn: 0.6132122	total: 73.6ms	remaining: 137ms
# 35:	learn: 0.6117483	total: 75.6ms	remaining: 134ms
# 36:	learn: 0.6103900	total: 77.6ms	remaining: 132ms
# 37:	learn: 0.6090978	total: 79.3ms	remaining: 129ms
# 38:	learn: 0.6076275	total: 81ms	remaining: 127ms
# 39:	learn: 0.6062222	total: 82.8ms	remaining: 124ms
# 40:	learn: 0.6049620	total: 84.8ms	remaining: 122ms
# 41:	learn: 0.6036458	total: 86.8ms	remaining: 120ms
# 42:	learn: 0.6020360	total: 88.8ms	remaining: 118ms
# 43:	learn: 0.6008570	total: 90.8ms	remaining: 116ms
# 44:	learn: 0.5991402	total: 93.1ms	remaining: 114ms
# 45:	learn: 0.5978990	total: 95.4ms	remaining: 112ms
# 46:	learn: 0.5966593	total: 97.3ms	remaining: 110ms
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2993, number of negative: 2918
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005918 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1952
# [LightGBM] [Info] Number of data points in the train set: 5911, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506344 -> initscore=0.025378
# [LightGBM] [Info] Start training from score 0.025378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2999, number of negative: 2912
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002686 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1952
# [LightGBM] [Info] Number of data points in the train set: 5911, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.507359 -> initscore=0.029439
# [LightGBM] [Info] Start training from score 0.029439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2963, number of negative: 2948
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.137903 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1950
# [LightGBM] [Info] Number of data points in the train set: 5911, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501269 -> initscore=0.005075
# [LightGBM] [Info] Start training from score 0.005075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
metrics.sort(key=lambda x: x[1], reverse=True)

print("\nSorted model metrics (by accuracy):")
for metric in metrics:
    print(f"Model: {metric[0]}, Accuracy: {metric[1]:.3f}, Precision: {metric[2]:.3f}, Recall: {metric[3]:.3f}")
# Out:
# Sorted model metrics (by accuracy):
# Model: lightgbm, Accuracy: 0.800, Precision: 0.781, Recall: 0.830
# Model: xgboost, Accuracy: 0.798, Precision: 0.779, Recall: 0.828
# Model: catboost, Accuracy: 0.794, Precision: 0.777, Recall: 0.822
# Model: gradientboost, Accuracy: 0.794, Precision: 0.777, Recall: 0.821
# Model: logistic, Accuracy: 0.770, Precision: 0.756, Recall: 0.793
# Model: adaboost, Accuracy: 0.767, Precision: 0.762, Recall: 0.771
# Model: randomforest, Accuracy: 0.761, Precision: 0.778, Recall: 0.725
# Model: knn, Accuracy: 0.759, Precision: 0.772, Recall: 0.731

# %% [markdown]
# # 9. Apply ensemble method on the test set

# %%
from sklearn.ensemble import VotingClassifier

top_models = [name for name, _, _, _ in metrics[:5]]

estimators = [(name, best_estimators[name]) for name in top_models]

ensemble_model = VotingClassifier(estimators=estimators, voting='soft', n_jobs=-1)

ensemble_model.fit(X, y)

test_df = test_df.drop("Transported",axis=1)
test_predictions = ensemble_model.predict(test_df)
test_predictions = test_predictions.astype(bool)
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0:	learn: 0.6536157	total: 10.4ms	remaining: 1.54s
# 1:	learn: 0.6223751	total: 16.6ms	remaining: 1.23s
# 2:	learn: 0.5954391	total: 32ms	remaining: 1.57s
# 3:	learn: 0.5760006	total: 43.5ms	remaining: 1.59s
# 4:	learn: 0.5598442	total: 47ms	remaining: 1.36s
# 5:	learn: 0.5467100	total: 50.2ms	remaining: 1.21s
# 6:	learn: 0.5353659	total: 77.5ms	remaining: 1.58s
# 7:	learn: 0.5265827	total: 88.4ms	remaining: 1.57s
# 8:	learn: 0.5172674	total: 91.4ms	remaining: 1.43s
# 9:	learn: 0.5096909	total: 106ms	remaining: 1.48s
# 10:	learn: 0.5034137	total: 114ms	remaining: 1.43s
# 11:	learn: 0.4976727	total: 122ms	remaining: 1.4s
# 12:	learn: 0.4914930	total: 125ms	remaining: 1.31s
# 13:	learn: 0.4857328	total: 144ms	remaining: 1.4s
# 14:	learn: 0.4827523	total: 155ms	remaining: 1.39s
# 15:	learn: 0.4776943	total: 166ms	remaining: 1.39s
# 16:	learn: 0.4745776	total: 177ms	remaining: 1.39s
# 17:	learn: 0.4713706	total: 198ms	remaining: 1.45s
# 18:	learn: 0.4684767	total: 204ms	remaining: 1.41s
# 19:	learn: 0.4658006	total: 217ms	remaining: 1.41s
# 20:	learn: 0.4635231	total: 225ms	remaining: 1.38s
# 21:	learn: 0.4611205	total: 233ms	remaining: 1.35s
# 22:	learn: 0.4591896	total: 246ms	remaining: 1.36s
# 23:	learn: 0.4561682	total: 253ms	remaining: 1.33s
# 24:	learn: 0.4534789	total: 261ms	remaining: 1.31s
# 25:	learn: 0.4513064	total: 270ms	remaining: 1.29s
# 26:	learn: 0.4493296	total: 281ms	remaining: 1.28s
# 27:	learn: 0.4476104	total: 289ms	remaining: 1.26s
# 28:	learn: 0.4459067	total: 303ms	remaining: 1.26s
# 29:	learn: 0.4446372	total: 310ms	remaining: 1.24s
# 30:	learn: 0.4431864	total: 317ms	remaining: 1.22s
# 31:	learn: 0.4415313	total: 325ms	remaining: 1.2s
# 32:	learn: 0.4407344	total: 333ms	remaining: 1.18s
# 33:	learn: 0.4395813	total: 342ms	remaining: 1.17s
# 34:	learn: 0.4385681	total: 353ms	remaining: 1.16s
# 35:	learn: 0.4373837	total: 359ms	remaining: 1.14s
# 36:	learn: 0.4359739	total: 373ms	remaining: 1.14s
# 37:	learn: 0.4324793	total: 383ms	remaining: 1.13s
# 38:	learn: 0.4316226	total: 397ms	remaining: 1.13s
# 39:	learn: 0.4307591	total: 411ms	remaining: 1.13s
# 40:	learn: 0.4297102	total: 419ms	remaining: 1.11s
# 41:	learn: 0.4291322	total: 436ms	remaining: 1.12s
# 42:	learn: 0.4284629	total: 450ms	remaining: 1.12s
# 43:	learn: 0.4263280	total: 459ms	remaining: 1.11s
# 44:	learn: 0.4253383	total: 473ms	remaining: 1.1s
# 45:	learn: 0.4249303	total: 481ms	remaining: 1.09s
# 46:	learn: 0.4240009	total: 489ms	remaining: 1.07s
# 47:	learn: 0.4234090	total: 499ms	remaining: 1.06s
# 48:	learn: 0.4226565	total: 508ms	remaining: 1.05s
# 49:	learn: 0.4221089	total: 520ms	remaining: 1.04s
# 50:	learn: 0.4213509	total: 524ms	remaining: 1.02s
# 51:	learn: 0.4204829	total: 528ms	remaining: 995ms
# 52:	learn: 0.4198536	total: 531ms	remaining: 972ms
# 53:	learn: 0.4194739	total: 534ms	remaining: 950ms
# 54:	learn: 0.4190131	total: 538ms	remaining: 930ms
# 55:	learn: 0.4181966	total: 542ms	remaining: 909ms
# 56:	learn: 0.4175333	total: 545ms	remaining: 889ms
# 57:	learn: 0.4165222	total: 548ms	remaining: 869ms
# 58:	learn: 0.4158667	total: 551ms	remaining: 850ms
# 59:	learn: 0.4153231	total: 554ms	remaining: 832ms
# 60:	learn: 0.4147697	total: 557ms	remaining: 813ms
# 61:	learn: 0.4142548	total: 560ms	remaining: 796ms
# 62:	learn: 0.4138522	total: 564ms	remaining: 779ms
# 63:	learn: 0.4134324	total: 567ms	remaining: 762ms
# 64:	learn: 0.4116351	total: 570ms	remaining: 746ms
# 65:	learn: 0.4112761	total: 573ms	remaining: 730ms
# 66:	learn: 0.4108770	total: 576ms	remaining: 714ms
# 67:	learn: 0.4105554	total: 579ms	remaining: 699ms
# 68:	learn: 0.4100546	total: 582ms	remaining: 684ms
# 69:	learn: 0.4097983	total: 585ms	remaining: 669ms
# 70:	learn: 0.4090423	total: 588ms	remaining: 655ms
# 71:	learn: 0.4086830	total: 591ms	remaining: 641ms
# 72:	learn: 0.4083696	total: 594ms	remaining: 627ms
# 73:	learn: 0.4077649	total: 597ms	remaining: 614ms
# 74:	learn: 0.4074485	total: 601ms	remaining: 601ms
# 75:	learn: 0.4071268	total: 604ms	remaining: 588ms
# 76:	learn: 0.4068293	total: 607ms	remaining: 575ms
# 77:	learn: 0.4065283	total: 610ms	remaining: 563ms
# 78:	learn: 0.4061502	total: 613ms	remaining: 551ms
# 79:	learn: 0.4055599	total: 616ms	remaining: 539ms
# 80:	learn: 0.4051574	total: 619ms	remaining: 527ms
# 81:	learn: 0.4040097	total: 622ms	remaining: 516ms
# 82:	learn: 0.4036761	total: 625ms	remaining: 505ms
# 83:	learn: 0.4034253	total: 628ms	remaining: 493ms
# 84:	learn: 0.4030150	total: 631ms	remaining: 483ms
# 85:	learn: 0.4022952	total: 635ms	remaining: 472ms
# 86:	learn: 0.4013607	total: 638ms	remaining: 462ms
# 87:	learn: 0.4011878	total: 642ms	remaining: 452ms
# 88:	learn: 0.4007740	total: 645ms	remaining: 442ms
# 89:	learn: 0.4003071	total: 649ms	remaining: 433ms
# 90:	learn: 0.3996703	total: 652ms	remaining: 423ms
# 91:	learn: 0.3994158	total: 656ms	remaining: 414ms
# 92:	learn: 0.3988404	total: 660ms	remaining: 404ms
# 93:	learn: 0.3984267	total: 663ms	remaining: 395ms
# 94:	learn: 0.3976015	total: 667ms	remaining: 386ms
# 95:	learn: 0.3972576	total: 670ms	remaining: 377ms
# 96:	learn: 0.3969203	total: 674ms	remaining: 368ms
# 97:	learn: 0.3967153	total: 677ms	remaining: 359ms
# 98:	learn: 0.3962286	total: 681ms	remaining: 351ms
# 99:	learn: 0.3959487	total: 684ms	remaining: 342ms
# 100:	learn: 0.3956196	total: 688ms	remaining: 334ms
# 101:	learn: 0.3953022	total: 691ms	remaining: 325ms
# 102:	learn: 0.3943536	total: 694ms	remaining: 317ms
# 103:	learn: 0.3939858	total: 698ms	remaining: 309ms
# 104:	learn: 0.3937711	total: 701ms	remaining: 301ms
# 105:	learn: 0.3934502	total: 705ms	remaining: 293ms
# 106:	learn: 0.3931072	total: 708ms	remaining: 285ms
# 107:	learn: 0.3926931	total: 712ms	remaining: 277ms
# 108:	learn: 0.3922522	total: 715ms	remaining: 269ms
# 109:	learn: 0.3918860	total: 718ms	remaining: 261ms
# 110:	learn: 0.3912979	total: 722ms	remaining: 254ms
# 111:	learn: 0.3909523	total: 725ms	remaining: 246ms
# 112:	learn: 0.3905385	total: 728ms	remaining: 238ms
# 113:	learn: 0.3901084	total: 731ms	remaining: 231ms
# 114:	learn: 0.3898743	total: 734ms	remaining: 224ms
# 115:	learn: 0.3891178	total: 738ms	remaining: 216ms
# 116:	learn: 0.3889100	total: 741ms	remaining: 209ms
# 117:	learn: 0.3884473	total: 744ms	remaining: 202ms
# 118:	learn: 0.3881253	total: 747ms	remaining: 195ms
# 119:	learn: 0.3878214	total: 750ms	remaining: 188ms
# 120:	learn: 0.3874330	total: 754ms	remaining: 181ms
# 121:	learn: 0.3870152	total: 757ms	remaining: 174ms
# 122:	learn: 0.3867788	total: 760ms	remaining: 167ms
# 123:	learn: 0.3864798	total: 763ms	remaining: 160ms
# 124:	learn: 0.3861239	total: 766ms	remaining: 153ms

# %%
submission = pd.DataFrame([test_data['PassengerId'], test_predictions]).T
submission.columns = ['PassengerID', 'Transported']

# %%
submission.head()
# Out:
#   PassengerID Transported
# 0     0013_01        True
# 1     0018_01       False
# 2     0019_01        True
# 3     0021_01        True
# 4     0023_01        True

# %%
submission.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
