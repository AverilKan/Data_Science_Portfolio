# %% [markdown]
# <a href="https://www.kaggle.com/code/averilkan/spaceship-titanic-dataset-classification?scriptVersionId=221821003" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 💡 About The Competition: Spaceship Titanic
#
# Task:
# The objective of this task is to predict whether a passenger was transported to an alternate dimension aboard the Spaceship Titanic. This binary classification problem requires the model to predict the 'Transported' status (True or False) for each passenger in the test dataset, based on a variety of provided features.
#
# Dataset:
# The dataset for this competition includes information about passengers aboard the fictional Spaceship Titanic. Features include demographic details, cabin information, and records of their in-ship expenditures. The target variable is Transported.
#
# Exploration:
# Begin with exploratory data analysis (EDA) to understand the distribution and relationships between features. Utilise visualisation techniques to identify patterns and anomalies that could influence the predictive model’s performance.
#
# Evaluation:
# Submissions are evaluated based on the accuracy of the predictions. A higher accuracy score indicates a more effective model at classifying passengers' transportation status.
#
# Submission Files:
# train.csv – The training dataset, including the target variable Transported.
# test.csv – The test dataset, where predictions are to be made.
# sample_submission.csv – A sample submission file in the correct format.
# Evaluation Metric:
# The competition uses accuracy as the metric for evaluating submissions. This metric assesses the proportion of correctly predicted outcomes relative to total predictions.

# %% [markdown]
# # 1. Importing libraries

# %% [markdown]
# ## 💡 About The Packages:
#
# - **NumPy** and **Pandas** for data manipulation and analysis.
# - **Matplotlib** and **Seaborn** for data visualization.
# - **Warnings** to manage warning messages.
# - **lazypredict** for quick model comparison.
# - **Scikit-learn**, **XGBoost**, **LightGBM**, **CatBoost**, and other machine learning libraries for model building and evaluation.

# %%
# !pip install lazypredict

import io
import sys
import tensorflow as tf
import tensorflow_decision_forests as tfdf
import xgboost as xgb
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import category_encoders as ce

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score

from IPython.utils.io import capture_output

from hyperopt import hp, fmin, tpe, Trials

from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args

from contextlib import redirect_stdout, redirect_stderr
from IPython.utils.io import capture_output
# Out:
# Requirement already satisfied: lazypredict in /opt/conda/lib/python3.10/site-packages (0.2.13)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.1.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.4.0)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.2.0)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)

# %% [markdown]
# # 2. Reading the Datasets
#
# We start by reading the training and test datasets using the Pandas library. The training dataset contains the target variable `Transported`, which indicates whether a passenger was transported to another dimension. We convert this column to an integer type for compatibility with machine learning algorithms.
#
# We then concatenate the train and test datasets for combined preprocessing and feature engineering. This helps to ensure consistency in data processing and avoid data leakage.

# %%
train_data = pd.read_csv("/kaggle/input/spaceship-titanic/train.csv")
train_data['Transported'] = train_data['Transported'].astype(int)
train_data.head()

test_data = pd.read_csv("/kaggle/input/spaceship-titanic/test.csv")
test_data.head()

train_data['Source'] = 'train'
test_data['Source'] = 'test'

df = pd.concat([train_data, test_data], axis=0)

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) involves summarizing and visualizing the main characteristics of the data. This step helps us understand the structure of the dataset, identify patterns, detect anomalies, and check assumptions.
#
# We create a summary function to give an overview of the dataset, including:
# - The number of unique values in each column.
# - The number of missing values in each column.
# - The data types of each column.
#
# This overview helps us identify any issues that need to be addressed during data preprocessing.

# %%
def summary(df):
    print(f"Dataset has {df.shape[1]} features and {df.shape[0]} examples.")
    summary = pd.DataFrame(index=df.columns)
    summary["Unique"] = df.nunique().values
    summary["Missing"] = df.isnull().sum().values
    summary["Duplicated"] = df.duplicated().sum()
    summary["Types"] = df.dtypes
    return summary

summary(df)
# Out:
# Dataset has 15 features and 12970 examples.
#               Unique  Missing  Duplicated    Types
# PassengerId    12970        0           0   object
# HomePlanet         3      288           0   object
# CryoSleep          2      310           0   object
# Cabin           9825      299           0   object
# Destination        3      274           0   object
# Age               80      270           0  float64
# VIP                2      296           0   object
# RoomService     1578      263           0  float64
# FoodCourt       1953      289           0  float64
# ShoppingMall    1367      306           0  float64
# Spa             1679      284           0  float64
# VRDeck          1642      268           0  float64
# Name           12629      294           0   object
# Transported        2     4277           0  float64
# Source             2        0           0   object

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ### 4.1 Extract Group Size from `PassengerId`
#
# A unique Id for each passenger takes the form `gggg_pp` where `gggg` indicates a group the passenger is travelling with and `pp` is their number within the group. People in a group are often family members, but not always. Extracting the group size can help us understand the potential impact of group travel on the likelihood of being transported.

# %%
group = df['PassengerId'].apply(lambda x: x.split('_')[0]).value_counts().to_dict()
df['Group_size'] = df['PassengerId'].apply(lambda x: group[x.split('_')[0]])
df.set_index('PassengerId', inplace=True)

# %% [markdown]
# ### 4.2 Handle Missing Values in `HomePlanet`
#
# The `HomePlanet` column indicates the planet the passenger is from. To fill missing values, we use a random selection based on the distribution of existing values in the column. This helps maintain the original distribution of `HomePlanet` in the dataset.

# %%
v = df['HomePlanet'].value_counts().index
p = df['HomePlanet'].value_counts(normalize=True).values
df.loc[df['HomePlanet'].isna(), 'HomePlanet'] = np.random.choice(v, df['HomePlanet'].isna().sum(), p=p)

# %% [markdown]
# ### 4.3 Handle Missing Values in CryoSleep
#
# The `CryoSleep` column indicates whether the passenger elected to be put into suspended animation for the duration of the voyage. Given that being in CryoSleep is a notable status that would likely be recorded, missing values are assumed to indicate passengers were not in CryoSleep. Thus, we fill missing values with 0 and convert this column to an integer type.

# %%
df['CryoSleep'] = df['CryoSleep'].fillna(0).astype(int)

# %% [markdown]
# ### 4.4 Extract Cabin Components and Handle Missing Values
#
# The `Cabin` column provides information about the passenger's cabin, including the deck, number, and side. We extract these components into separate columns and handle missing values by randomly assigning values based on the distribution of the existing data.

# %%
tmp = df['Cabin'].apply(lambda x: x.split('/') if isinstance(x, str) else ['-1', '-1', '-1']).to_list()
tmp = np.array(tmp)

df['Cabin_deck'] = tmp[:, 0]
df['Cabin_num'] = tmp[:, 1].astype(int)
df['Cabin_side'] = pd.Series(tmp[:, 2]).map({'S': 0, 'P': 1})

df.drop(columns='Cabin', inplace=True)

df.loc[df['Cabin_deck'] == '-1', 'Cabin_deck'] = np.random.choice(['F', 'G'], sum(df['Cabin_deck'] == '-1'), p=[0.5, 0.5])
df.loc[df['Cabin_side'].isna(), 'Cabin_side'] = np.random.choice([0, 1], sum(df['Cabin_side'].isna()), p=[0.5, 0.5])

# %% [markdown]
# ### 4.5 Handle Missing Values in `Destination`
#
# The `Destination` column indicates the destination of the passenger. We fill missing values by randomly assigning values based on the distribution of the existing data. This maintains the original distribution of `Destination` in the dataset.

# %%
v = df['Destination'].value_counts().index
p = df['Destination'].value_counts(normalize=True).values
df.loc[df['Destination'].isna(), 'Destination'] = np.random.choice(v, df['Destination'].isna().sum(), p=p)

# %% [markdown]
# ### 4.6 Handle Missing Values in `Age`
#
# The `Age` column indicates the age of the passenger. To fill missing values, we use a random sample from a normal distribution with the mean and standard deviation of the existing ages. This helps maintain the original distribution of `Age` in the dataset.

# %%
mean_age = df["Age"].mean()
std_age = df["Age"].std()
is_null = df["Age"].isnull().sum()
rand_sample = np.random.uniform(mean_age - std_age, mean_age + std_age, size = is_null)
df.loc[df['Age'].isna(), 'Age'] = rand_sample

# %% [markdown]
# ### 4.7 Handle Missing Values in `VIP`
#
# The `VIP` column indicates whether the passenger paid for special VIP service during the voyage. We fill missing values with `False` (0), assuming that most passengers did not opt for VIP service. We then convert this column to an integer type.

# %%
df['VIP'] = df['VIP'].fillna(0).astype(int)

# %% [markdown]
# ### 4.8 Handle Missing Values in Spending Columns
#
# The columns `RoomService`, `FoodCourt`, `ShoppingMall`, `Spa`, and `VRDeck` represent the amount of money spent by the passenger on various amenities. We fill missing values with the median value of each column. This helps maintain the original distribution of spending in the dataset.

# %%
cols = ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']

for col in cols:
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# ### 4.9 Create Total Spending Feature
#
# We create a new feature `total_spending` by summing the values of the spending columns. This feature represents the total amount of money spent by the passenger on various amenities during the voyage. We then apply a logarithmic transformation to normalize the spending data, making it easier for the model to learn from.

# %%
df['total_spending'] = df['RoomService'] + df['FoodCourt'] + df['ShoppingMall'] + df['Spa'] + df['VRDeck']

for col in cols + ['total_spending']:
    df.loc[df[col]==0, col] = 0.367
    df[col] = np.log(df[col])

# %% [markdown]
# ### 4.10 Drop the Name column as it does not contain valuable information

# %%
df.drop(columns='Name', inplace=True)

# %% [markdown]
# # 5. One-Hot Encoding for Categorical Features
#
# One-hot encoding is a technique to convert categorical variables into numerical format. This step is crucial for machine learning algorithms, as they require numerical input.
#
# We apply one-hot encoding to the categorical features `HomePlanet`, `Destination`, and `Cabin_deck`. This creates new binary columns for each category, allowing the model to understand and use the categorical data effectively.

# %%
categorical_features = ['HomePlanet', 'Destination', 'Cabin_deck']
df = pd.concat([df, pd.get_dummies(df[categorical_features], dtype=int)], axis=1)
df.drop(columns=categorical_features, inplace=True)

# %% [markdown]
# # 6. Splitting Data back to Train and Test Sets
#
# After preprocessing and feature engineering, we split the combined dataset back into the original training and test sets. This ensures that we maintain the original structure of the data, with the training set used to train the model and the test set used to evaluate its performance.
#
# We also separate the target variable `Transported` from the training data, as this is what we aim to predict.

# %%
train_df = df[df['Source'] == 'train'].drop(columns=['Source'])
test_df = df[df['Source'] == 'test'].drop(columns=['Source'])

X = train_df.drop(columns=['Transported'])
y = train_df['Transported']

train_df.head()
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8693 entries, 0001_01 to 9280_02
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CryoSleep                  8693 non-null   int64
#  1   Age                        8693 non-null   float64
#  2   VIP                        8693 non-null   int64
#  3   RoomService                8693 non-null   float64
#  4   FoodCourt                  8693 non-null   float64
#  5   ShoppingMall               8693 non-null   float64
#  6   Spa                        8693 non-null   float64
#  7   VRDeck                     8693 non-null   float64
#  8   Transported                8693 non-null   float64
#  9   Group_size                 8693 non-null   int64
#  10  Cabin_num                  8693 non-null   int64
#  11  Cabin_side                 8693 non-null   float64
#  12  total_spending             8693 non-null   float64
#  13  HomePlanet_Earth           8693 non-null   int64
#  14  HomePlanet_Europa          8693 non-null   int64
#  15  HomePlanet_Mars            8693 non-null   int64
#  16  Destination_55 Cancri e    8693 non-null   int64
#  17  Destination_PSO J318.5-22  8693 non-null   int64
#  18  Destination_TRAPPIST-1e    8693 non-null   int64
#  19  Cabin_deck_A               8693 non-null   int64
#  20  Cabin_deck_B               8693 non-null   int64
#  21  Cabin_deck_C               8693 non-null   int64
#  22  Cabin_deck_D               8693 non-null   int64
#  23  Cabin_deck_E               8693 non-null   int64
#  24  Cabin_deck_F               8693 non-null   int64
#  25  Cabin_deck_G               8693 non-null   int64
#  26  Cabin_deck_T               8693 non-null   int64
# dtypes: float64(9), int64(18)
# memory usage: 1.9+ MB

# %% [markdown]
# # 7. Initial Model Comparison with LazyPredict
#
# We will use the LazyPredict library to quickly compare the performance of different machine learning models. LazyPredict provides an easy-to-use interface to fit multiple models and get a quick overview of their performance.

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

X = train_df.drop('Transported', axis=1)
y = train_df['Transported'].astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 29/29 [00:18<00:00,  1.56it/s]
# [LightGBM] [Info] Number of positive: 3731, number of negative: 3658
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001020 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1963
# [LightGBM] [Info] Number of data points in the train set: 7389, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504940 -> initscore=0.019760
# [LightGBM] [Info] Start training from score 0.019760
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.80               0.80     0.80      0.80
# LGBMClassifier                     0.80               0.80     0.80      0.80
# AdaBoostClassifier                 0.78               0.78     0.78      0.78
# SVC                                0.78               0.78     0.78      0.78
# RandomForestClassifier             0.78               0.78     0.78      0.78
# BaggingClassifier                  0.77               0.77     0.77      0.77
# NuSVC                              0.77               0.77     0.77      0.77
# ExtraTreesClassifier               0.77               0.77     0.77      0.77
# LogisticRegression                 0.77               0.77     0.77      0.77
# LinearSVC                          0.76               0.76     0.76      0.76
# LinearDiscriminantAnalysis         0.76               0.76     0.76      0.76
# RidgeClassifier                    0.76               0.76     0.76      0.76
# RidgeClassifierCV                  0.76               0.76     0.76      0.76
# CalibratedClassifierCV             0.76               0.76     0.76      0.76
# SGDClassifier                      0.76               0.76     0.76      0.76
# QuadraticDiscriminantAnalysis      0.76               0.76     0.76      0.76
# GaussianNB                         0.75               0.75     0.75      0.75
# NearestCentroid                    0.74               0.74     0.74      0.74
# KNeighborsClassifier               0.74               0.74     0.74      0.74
# BernoulliNB                        0.74               0.73     0.73      0.73
# DecisionTreeClassifier             0.72               0.72     0.72      0.72
# LabelPropagation                   0.72               0.72     0.72      0.72
# LabelSpreading                     0.72               0.72     0.72      0.72
# PassiveAggressiveClassifier        0.71               0.71     0.71      0.71
# ExtraTreeClassifier                0.69               0.69     0.69      0.69
# Perceptron                         0.54               0.54     0.54      0.54
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# XGBClassifier                        0.33
# LGBMClassifier                       0.19
# AdaBoostClassifier                   0.35
# SVC                                  2.22
# RandomForestClassifier               0.94
# BaggingClassifier                    0.31
# NuSVC                                2.73
# ExtraTreesClassifier                 0.70
# LogisticRegression                   0.06
# LinearSVC                            0.89
# LinearDiscriminantAnalysis           0.07
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.05
# CalibratedClassifierCV               3.52
# SGDClassifier                        0.14
# QuadraticDiscriminantAnalysis        0.04
# GaussianNB                           0.02
# NearestCentroid                      0.03
# KNeighborsClassifier                 0.20
# BernoulliNB                          0.02
# DecisionTreeClassifier               0.12
# LabelPropagation                     2.34
# LabelSpreading                       3.09
# PassiveAggressiveClassifier          0.04
# ExtraTreeClassifier                  0.02
# Perceptron                           0.04
# DummyClassifier                      0.02

# %% [markdown]
# # 8. Detailed Modeling with Pipelines and GridSearchCV
#
# For a more detailed evaluation and fine-tuning, we will use several classifiers with pipelines and GridSearchCV. We will use k-fold cross-validation to ensure a robust estimation of model performance.
#
# We will perform the following steps:
#
# 1. Set up the models and pipelines.
# 2. Define the hyperparameter grids for each model.
# 3. Use GridSearchCV with k-fold cross-validation to find the best parameters for each model.
# 4. Evaluate the performance of the best models on the test set.

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import accuracy_score

pipelines = {
    'adaboost': make_pipeline(StandardScaler(), AdaBoostClassifier(random_state=123)),
    'xgboost': make_pipeline(StandardScaler(), XGBClassifier(random_state=123)),
    'catboost': make_pipeline(StandardScaler(), CatBoostClassifier(random_state=123)),
    'gradientboost': make_pipeline(StandardScaler(), GradientBoostingClassifier(random_state=123)),
    'lightgbm': make_pipeline(StandardScaler(), LGBMClassifier(random_state=123)),
    'randomforest': make_pipeline(StandardScaler(), RandomForestClassifier(random_state=123)),
    'logistic': make_pipeline(StandardScaler(), LogisticRegression(random_state=123)),
    'knn': make_pipeline(StandardScaler(), KNeighborsClassifier())
}

grid = {
    'adaboost': {
        'adaboostclassifier__n_estimators': [50, 100, 150],
        'adaboostclassifier__learning_rate': [0.01, 0.05, 0.1]
    },
    'xgboost': {
        'xgbclassifier__n_estimators': [50, 100, 150],
        'xgbclassifier__learning_rate': [0.01, 0.05],
        'xgbclassifier__max_depth': [3, 4],
        'xgbclassifier__gamma': [0.1, 0.2],
        'xgbclassifier__subsample': [0.6, 0.8]
    },
    'catboost': {
        'catboostclassifier__learning_rate': [0.01, 0.05, 0.1, 0.5],
        'catboostclassifier__depth': [2, 3, 4], 
        'catboostclassifier__iterations': [50, 100, 150]
    },
    'gradientboost': {
        'gradientboostingclassifier__n_estimators': [50, 100, 150],
        'gradientboostingclassifier__learning_rate': [0.01, 0.05],
        'gradientboostingclassifier__max_depth': [3, 4],
        'gradientboostingclassifier__subsample': [0.6, 0.8]
    },
    'lightgbm': {
        'lgbmclassifier__n_estimators': [50, 100, 150],
        'lgbmclassifier__learning_rate': [0.01, 0.05],
        'lgbmclassifier__max_depth': [3, 4],
        'lgbmclassifier__subsample': [0.6, 0.8]
    },
    'randomforest': {
        'randomforestclassifier__n_estimators': [50, 100, 150],
        'randomforestclassifier__max_depth': [3, 4, 5],
        'randomforestclassifier__min_samples_split': [2, 3, 4]
    },
    'logistic': {
        'logisticregression__C': [0.01, 0.1, 1, 10]
    },
    'knn': {
        'kneighborsclassifier__n_neighbors': [3, 5, 7],
        'kneighborsclassifier__weights': ['uniform', 'distance'],
        'kneighborsclassifier__metric': ['euclidean', 'manhattan']
    }
}

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

best_estimators = {}
kf = KFold(n_splits=5, shuffle=True, random_state=42)

metrics = []

f = io.StringIO()
e = io.StringIO()

with redirect_stdout(f), redirect_stderr(e):  # suppress outputs
    with capture_output():
        for name, pipeline in pipelines.items():
            grid_search = GridSearchCV(pipeline, grid[name], cv=kf, n_jobs=-1, verbose=0)
            grid_search.fit(X_train, y_train)
            best_estimators[name] = grid_search.best_estimator_
            yhat = grid_search.predict(X_test)
            accuracy = accuracy_score(y_test, yhat)
            precision = precision_score(y_test, yhat)
            recall = recall_score(y_test, yhat)
            metrics.append((name, accuracy, precision, recall))
            print(f'Metrics for {name}: accuracy- {accuracy:.3f}, precision- {precision:.3f}, recall- {recall:.3f}')
            print(f"Best parameters for {name}: {grid_search.best_params_}")
# Out:
# 0:	learn: 0.6903281	total: 48.6ms	remaining: 2.38s
# 1:	learn: 0.6874752	total: 50.4ms	remaining: 1.21s
# 2:	learn: 0.6841018	total: 52.6ms	remaining: 824ms
# 3:	learn: 0.6814982	total: 54.3ms	remaining: 625ms
# 4:	learn: 0.6790263	total: 56ms	remaining: 504ms
# 5:	learn: 0.6764366	total: 57.7ms	remaining: 423ms
# 6:	learn: 0.6738535	total: 59.3ms	remaining: 364ms
# 7:	learn: 0.6712752	total: 61.3ms	remaining: 322ms
# 8:	learn: 0.6689907	total: 65.9ms	remaining: 300ms
# 9:	learn: 0.6660273	total: 68.5ms	remaining: 274ms
# 10:	learn: 0.6639255	total: 73.7ms	remaining: 261ms
# 11:	learn: 0.6618374	total: 75.6ms	remaining: 240ms
# 12:	learn: 0.6590761	total: 87.3ms	remaining: 248ms
# 13:	learn: 0.6568146	total: 89.8ms	remaining: 231ms
# 14:	learn: 0.6545329	total: 98.6ms	remaining: 230ms
# 15:	learn: 0.6519334	total: 101ms	remaining: 214ms
# 16:	learn: 0.6498275	total: 102ms	remaining: 199ms
# 17:	learn: 0.6472117	total: 104ms	remaining: 186ms
# 18:	learn: 0.6452746	total: 107ms	remaining: 174ms
# 19:	learn: 0.6433962	total: 129ms	remaining: 194ms
# 20:	learn: 0.6414873	total: 131ms	remaining: 181ms
# 21:	learn: 0.6394993	total: 144ms	remaining: 183ms
# 22:	learn: 0.6373400	total: 146ms	remaining: 172ms
# 23:	learn: 0.6350975	total: 149ms	remaining: 161ms
# 24:	learn: 0.6332334	total: 163ms	remaining: 163ms
# 25:	learn: 0.6316798	total: 169ms	remaining: 156ms
# 26:	learn: 0.6295643	total: 179ms	remaining: 152ms
# 27:	learn: 0.6273452	total: 187ms	remaining: 147ms
# 28:	learn: 0.6258037	total: 193ms	remaining: 140ms
# 29:	learn: 0.6243119	total: 201ms	remaining: 134ms
# 30:	learn: 0.6226507	total: 208ms	remaining: 128ms
# 31:	learn: 0.6211553	total: 211ms	remaining: 119ms
# 32:	learn: 0.6197337	total: 219ms	remaining: 113ms
# 33:	learn: 0.6183038	total: 228ms	remaining: 107ms
# 34:	learn: 0.6168506	total: 236ms	remaining: 101ms
# 35:	learn: 0.6149481	total: 245ms	remaining: 95.4ms
# 36:	learn: 0.6135633	total: 253ms	remaining: 89ms
# 37:	learn: 0.6121901	total: 256ms	remaining: 80.7ms
# 38:	learn: 0.6104650	total: 263ms	remaining: 74.2ms
# 39:	learn: 0.6088316	total: 269ms	remaining: 67.3ms
# 40:	learn: 0.6074989	total: 278ms	remaining: 61ms
# 41:	learn: 0.6061425	total: 281ms	remaining: 53.4ms
# 42:	learn: 0.6042424	total: 291ms	remaining: 47.4ms
# 43:	learn: 0.6030571	total: 300ms	remaining: 40.9ms
# 44:	learn: 0.6018407	total: 306ms	remaining: 34ms
# 45:	learn: 0.6006365	total: 308ms	remaining: 26.8ms
# 46:	learn: 0.5994667	total: 310ms	remaining: 19.8ms
# 47:	learn: 0.5982262	total: 312ms	remaining: 13ms
# 48:	learn: 0.5967006	total: 313ms	remaining: 6.4ms
# 49:	learn: 0.5955927	total: 315ms	remaining: 0us
# 0:	learn: 0.6795752	total: 2ms	remaining: 98.3ms
# 1:	learn: 0.6643983	total: 4.04ms	remaining: 96.9ms
# 2:	learn: 0.6529880	total: 5.99ms	remaining: 93.8ms
# 3:	learn: 0.6425984	total: 10.6ms	remaining: 122ms
# 4:	learn: 0.6334309	total: 12.4ms	remaining: 111ms
# 5:	learn: 0.6245423	total: 15.2ms	remaining: 111ms
# 6:	learn: 0.6141985	total: 17ms	remaining: 104ms
# 7:	learn: 0.6047431	total: 18.8ms	remaining: 98.5ms
# 8:	learn: 0.5977799	total: 20.7ms	remaining: 94.5ms
# 9:	learn: 0.5916712	total: 22.8ms	remaining: 91.2ms
# 10:	learn: 0.5844045	total: 24.9ms	remaining: 88.1ms
# 11:	learn: 0.5794474	total: 26.7ms	remaining: 84.7ms
# 12:	learn: 0.5755509	total: 28.5ms	remaining: 81ms
# 13:	learn: 0.5701693	total: 30.2ms	remaining: 77.6ms
# 14:	learn: 0.5663559	total: 31.9ms	remaining: 74.4ms
# 15:	learn: 0.5616724	total: 33.7ms	remaining: 71.6ms
# 16:	learn: 0.5575542	total: 35.5ms	remaining: 69ms
# 17:	learn: 0.5541831	total: 37.3ms	remaining: 66.3ms
# 18:	learn: 0.5503424	total: 39.4ms	remaining: 64.2ms
# 19:	learn: 0.5468419	total: 41.1ms	remaining: 61.6ms
# 20:	learn: 0.5438398	total: 42.7ms	remaining: 59ms
# 21:	learn: 0.5407801	total: 44.7ms	remaining: 56.9ms
# 22:	learn: 0.5376070	total: 46.8ms	remaining: 54.9ms
# 23:	learn: 0.5349144	total: 48.7ms	remaining: 52.7ms
# 24:	learn: 0.5322576	total: 50.4ms	remaining: 50.4ms
# 25:	learn: 0.5295180	total: 52.4ms	remaining: 48.3ms
# 26:	learn: 0.5272534	total: 54.3ms	remaining: 46.3ms
# 27:	learn: 0.5249313	total: 56.3ms	remaining: 44.2ms
# 28:	learn: 0.5229745	total: 58.3ms	remaining: 42.2ms
# 29:	learn: 0.5202805	total: 60.3ms	remaining: 40.2ms
# 30:	learn: 0.5180876	total: 62.1ms	remaining: 38ms
# 31:	learn: 0.5163222	total: 63.8ms	remaining: 35.9ms
# 32:	learn: 0.5147339	total: 65.6ms	remaining: 33.8ms
# 33:	learn: 0.5130502	total: 67.4ms	remaining: 31.7ms
# 34:	learn: 0.5113630	total: 69ms	remaining: 29.6ms
# 35:	learn: 0.5095136	total: 71.2ms	remaining: 27.7ms
# 36:	learn: 0.5082892	total: 73.1ms	remaining: 25.7ms
# 37:	learn: 0.5069560	total: 75.4ms	remaining: 23.8ms
# 38:	learn: 0.5050249	total: 77.2ms	remaining: 21.8ms
# 39:	learn: 0.5038086	total: 78.9ms	remaining: 19.7ms
# 40:	learn: 0.5021177	total: 81ms	remaining: 17.8ms
# 41:	learn: 0.5008601	total: 82.9ms	remaining: 15.8ms
# 42:	learn: 0.4994729	total: 84.8ms	remaining: 13.8ms
# 43:	learn: 0.4981626	total: 86.8ms	remaining: 11.8ms
# 44:	learn: 0.4973142	total: 88.8ms	remaining: 9.87ms
# 45:	learn: 0.4957056	total: 90.8ms	remaining: 7.9ms
# 46:	learn: 0.4945432	total: 93.1ms	remaining: 5.94ms
# 47:	learn: 0.4932242	total: 95ms	remaining: 3.96ms
# 48:	learn: 0.4919499	total: 96.7ms	remaining: 1.97ms
# 49:	learn: 0.4903742	total: 98.8ms	remaining: 0us
# 0:	learn: 0.6803842	total: 2.28ms	remaining: 112ms
# 1:	learn: 0.6672450	total: 14ms	remaining: 337ms
# 2:	learn: 0.6525256	total: 16.6ms	remaining: 260ms
# 3:	learn: 0.6408921	total: 18.6ms	remaining: 214ms
# 4:	learn: 0.6295284	total: 20.5ms	remaining: 184ms
# 5:	learn: 0.6208305	total: 22.3ms	remaining: 163ms
# 6:	learn: 0.6138202	total: 24.1ms	remaining: 148ms
# 7:	learn: 0.6064709	total: 25.9ms	remaining: 136ms
# 8:	learn: 0.5982842	total: 28ms	remaining: 127ms
# 9:	learn: 0.5922628	total: 30ms	remaining: 120ms
# 10:	learn: 0.5855073	total: 31.8ms	remaining: 113ms
# 11:	learn: 0.5804573	total: 33.8ms	remaining: 107ms
# 12:	learn: 0.5750069	total: 35.6ms	remaining: 101ms
# 13:	learn: 0.5706833	total: 37.5ms	remaining: 96.4ms
# 14:	learn: 0.5669328	total: 39.1ms	remaining: 91.2ms
# 15:	learn: 0.5634504	total: 41ms	remaining: 87.2ms
# 16:	learn: 0.5591911	total: 42.8ms	remaining: 83.1ms
# 17:	learn: 0.5555604	total: 45.9ms	remaining: 81.6ms
# 18:	learn: 0.5524116	total: 47.7ms	remaining: 77.8ms
# 19:	learn: 0.5487158	total: 49.5ms	remaining: 74.2ms
# 20:	learn: 0.5455605	total: 51.2ms	remaining: 70.6ms
# 21:	learn: 0.5426879	total: 53.2ms	remaining: 67.7ms
# 22:	learn: 0.5403703	total: 54.9ms	remaining: 64.5ms
# 23:	learn: 0.5379005	total: 56.9ms	remaining: 61.7ms
# 24:	learn: 0.5354671	total: 58.9ms	remaining: 58.9ms
# 25:	learn: 0.5328540	total: 60.9ms	remaining: 56.3ms
# 26:	learn: 0.5301071	total: 63ms	remaining: 53.7ms
# 27:	learn: 0.5282983	total: 65ms	remaining: 51.1ms
# 28:	learn: 0.5253578	total: 66.9ms	remaining: 48.5ms
# 29:	learn: 0.5234449	total: 68.8ms	remaining: 45.9ms
# 30:	learn: 0.5214935	total: 71.2ms	remaining: 43.6ms
# 31:	learn: 0.5197048	total: 77.9ms	remaining: 43.8ms
# 32:	learn: 0.5177994	total: 82.5ms	remaining: 42.5ms
# 33:	learn: 0.5161811	total: 84.4ms	remaining: 39.7ms
# 34:	learn: 0.5143264	total: 86.5ms	remaining: 37.1ms
# 35:	learn: 0.5125344	total: 90.3ms	remaining: 35.1ms
# 36:	learn: 0.5113069	total: 92.4ms	remaining: 32.5ms
# 37:	learn: 0.5096846	total: 94.5ms	remaining: 29.8ms
# 38:	learn: 0.5083158	total: 96.4ms	remaining: 27.2ms
# 39:	learn: 0.5071905	total: 98.2ms	remaining: 24.6ms
# 40:	learn: 0.5063247	total: 100ms	remaining: 22ms
# 41:	learn: 0.5047260	total: 103ms	remaining: 19.6ms
# 42:	learn: 0.5033858	total: 105ms	remaining: 17.1ms
# 43:	learn: 0.5016194	total: 107ms	remaining: 14.6ms
# 44:	learn: 0.5003947	total: 109ms	remaining: 12.1ms
# 45:	learn: 0.4990961	total: 111ms	remaining: 9.62ms
# 46:	learn: 0.4980024	total: 113ms	remaining: 7.18ms
# 47:	learn: 0.4969987	total: 115ms	remaining: 4.77ms
# 48:	learn: 0.4960830	total: 116ms	remaining: 2.38ms
# 49:	learn: 0.4948896	total: 119ms	remaining: 0us
# 0:	learn: 0.6679460	total: 13.1ms	remaining: 640ms
# 1:	learn: 0.6449716	total: 15.2ms	remaining: 364ms
# 2:	learn: 0.6203597	total: 17.5ms	remaining: 275ms
# 3:	learn: 0.6011678	total: 20ms	remaining: 230ms
# 4:	learn: 0.5886563	total: 22ms	remaining: 198ms
# 5:	learn: 0.5786199	total: 24.3ms	remaining: 178ms
# 6:	learn: 0.5709336	total: 26.1ms	remaining: 160ms
# 7:	learn: 0.5614113	total: 28.3ms	remaining: 149ms
# 0:	learn: 0.6904941	total: 48.7ms	remaining: 2.38s
# 1:	learn: 0.6876073	total: 54.6ms	remaining: 1.31s
# 2:	learn: 0.6842447	total: 60.4ms	remaining: 946ms
# 3:	learn: 0.6808543	total: 62.7ms	remaining: 721ms
# 4:	learn: 0.6780665	total: 67.7ms	remaining: 609ms
# 5:	learn: 0.6755584	total: 73.8ms	remaining: 541ms
# 6:	learn: 0.6729327	total: 75.5ms	remaining: 464ms
# 7:	learn: 0.6698148	total: 82.3ms	remaining: 432ms
# 8:	learn: 0.6667401	total: 83.9ms	remaining: 382ms
# 9:	learn: 0.6637763	total: 90.5ms	remaining: 362ms
# 10:	learn: 0.6614956	total: 92.6ms	remaining: 328ms
# 11:	learn: 0.6591611	total: 100ms	remaining: 317ms
# 12:	learn: 0.6568347	total: 104ms	remaining: 295ms
# 13:	learn: 0.6547369	total: 110ms	remaining: 283ms
# 14:	learn: 0.6527012	total: 114ms	remaining: 266ms
# 15:	learn: 0.6501732	total: 120ms	remaining: 255ms
# 16:	learn: 0.6482098	total: 123ms	remaining: 239ms
# 17:	learn: 0.6456275	total: 128ms	remaining: 228ms
# 18:	learn: 0.6431755	total: 133ms	remaining: 217ms
# 19:	learn: 0.6407141	total: 135ms	remaining: 202ms
# 20:	learn: 0.6388012	total: 137ms	remaining: 189ms
# 21:	learn: 0.6363769	total: 139ms	remaining: 176ms
# 22:	learn: 0.6347796	total: 140ms	remaining: 165ms
# 23:	learn: 0.6329136	total: 142ms	remaining: 154ms
# 24:	learn: 0.6311614	total: 159ms	remaining: 159ms
# 25:	learn: 0.6295000	total: 161ms	remaining: 149ms
# 26:	learn: 0.6272325	total: 163ms	remaining: 139ms
# 27:	learn: 0.6254760	total: 165ms	remaining: 130ms
# 28:	learn: 0.6239389	total: 168ms	remaining: 121ms
# 29:	learn: 0.6221330	total: 170ms	remaining: 113ms
# 30:	learn: 0.6205730	total: 172ms	remaining: 105ms
# 31:	learn: 0.6188964	total: 174ms	remaining: 97.6ms
# 32:	learn: 0.6170879	total: 194ms	remaining: 99.9ms
# 33:	learn: 0.6155587	total: 197ms	remaining: 92.7ms
# 34:	learn: 0.6141383	total: 199ms	remaining: 85.2ms
# 35:	learn: 0.6125698	total: 207ms	remaining: 80.4ms
# 36:	learn: 0.6111676	total: 212ms	remaining: 74.4ms
# 37:	learn: 0.6097774	total: 213ms	remaining: 67.4ms
# 38:	learn: 0.6080549	total: 222ms	remaining: 62.5ms
# 39:	learn: 0.6067516	total: 228ms	remaining: 57.1ms
# 40:	learn: 0.6054634	total: 235ms	remaining: 51.6ms
# 41:	learn: 0.6041475	total: 238ms	remaining: 45.3ms
# 42:	learn: 0.6028961	total: 244ms	remaining: 39.7ms
# 43:	learn: 0.6011205	total: 250ms	remaining: 34.1ms
# 44:	learn: 0.5993455	total: 252ms	remaining: 28ms
# 45:	learn: 0.5980875	total: 255ms	remaining: 22.1ms
# 46:	learn: 0.5964716	total: 267ms	remaining: 17.1ms
# 47:	learn: 0.5954674	total: 269ms	remaining: 11.2ms
# 48:	learn: 0.5943068	total: 271ms	remaining: 5.54ms
# 49:	learn: 0.5932714	total: 285ms	remaining: 0us
# 0:	learn: 0.6905447	total: 2.15ms	remaining: 105ms
# 1:	learn: 0.6876640	total: 3.88ms	remaining: 93.2ms
# 2:	learn: 0.6841672	total: 7.94ms	remaining: 124ms
# 3:	learn: 0.6808783	total: 12ms	remaining: 137ms
# 4:	learn: 0.6777073	total: 15.4ms	remaining: 138ms
# 5:	learn: 0.6750012	total: 17ms	remaining: 125ms
# 6:	learn: 0.6724784	total: 18.9ms	remaining: 116ms
# 7:	learn: 0.6694420	total: 20.9ms	remaining: 110ms
# 8:	learn: 0.6671976	total: 22.9ms	remaining: 104ms
# 9:	learn: 0.6646536	total: 24.6ms	remaining: 98.6ms
# 10:	learn: 0.6623308	total: 26.3ms	remaining: 93.2ms
# 11:	learn: 0.6599204	total: 27.9ms	remaining: 88.2ms
# 12:	learn: 0.6569807	total: 30ms	remaining: 85.5ms
# 13:	learn: 0.6543624	total: 31.9ms	remaining: 81.9ms
# 14:	learn: 0.6521839	total: 33.5ms	remaining: 78.1ms
# 15:	learn: 0.6497216	total: 35.1ms	remaining: 74.6ms
# 16:	learn: 0.6471567	total: 37.1ms	remaining: 72ms
# 17:	learn: 0.6451629	total: 38.7ms	remaining: 68.9ms
# 18:	learn: 0.6427563	total: 40.6ms	remaining: 66.2ms
# 19:	learn: 0.6404001	total: 42.3ms	remaining: 63.5ms
# 20:	learn: 0.6381022	total: 43.9ms	remaining: 60.6ms
# 21:	learn: 0.6361694	total: 45.5ms	remaining: 57.9ms
# 22:	learn: 0.6336992	total: 48.4ms	remaining: 56.8ms
# 23:	learn: 0.6317295	total: 50.4ms	remaining: 54.6ms
# 24:	learn: 0.6295320	total: 52.1ms	remaining: 52.1ms
# 25:	learn: 0.6280230	total: 53.8ms	remaining: 49.6ms
# 26:	learn: 0.6263544	total: 55.5ms	remaining: 47.3ms
# 27:	learn: 0.6246631	total: 57.2ms	remaining: 45ms
# 28:	learn: 0.6231979	total: 59.1ms	remaining: 42.8ms
# 29:	learn: 0.6215256	total: 60.8ms	remaining: 40.6ms
# 30:	learn: 0.6199801	total: 62.6ms	remaining: 38.4ms
# 31:	learn: 0.6183617	total: 64.3ms	remaining: 36.2ms
# 32:	learn: 0.6167656	total: 65.9ms	remaining: 34ms
# 33:	learn: 0.6152979	total: 67.9ms	remaining: 31.9ms
# 34:	learn: 0.6138632	total: 69.8ms	remaining: 29.9ms
# 35:	learn: 0.6123900	total: 71.6ms	remaining: 27.8ms
# 36:	learn: 0.6109131	total: 73.3ms	remaining: 25.8ms
# 37:	learn: 0.6096082	total: 75.2ms	remaining: 23.7ms
# 38:	learn: 0.6082195	total: 77.5ms	remaining: 21.9ms
# 39:	learn: 0.6064189	total: 79.7ms	remaining: 19.9ms
# 40:	learn: 0.6050403	total: 81.7ms	remaining: 17.9ms
# 41:	learn: 0.6037797	total: 83.7ms	remaining: 15.9ms
# 42:	learn: 0.6021285	total: 85.4ms	remaining: 13.9ms
# 43:	learn: 0.6009387	total: 87.1ms	remaining: 11.9ms
# 44:	learn: 0.5996769	total: 88.8ms	remaining: 9.87ms
# 45:	learn: 0.5985534	total: 90.7ms	remaining: 7.89ms
# 46:	learn: 0.5974351	total: 93ms	remaining: 5.93ms
# 47:	learn: 0.5962938	total: 94.9ms	remaining: 3.95ms
# 48:	learn: 0.5951603	total: 96.8ms	remaining: 1.98ms
# 49:	learn: 0.5937044	total: 98.8ms	remaining: 0us
# 0:	learn: 0.6806626	total: 7.49ms	remaining: 367ms
# 1:	learn: 0.6671494	total: 16.1ms	remaining: 387ms
# 2:	learn: 0.6528612	total: 21.2ms	remaining: 332ms
# 3:	learn: 0.6439097	total: 25.7ms	remaining: 296ms
# 4:	learn: 0.6323104	total: 27.4ms	remaining: 247ms
# 5:	learn: 0.6222498	total: 29.3ms	remaining: 215ms
# 6:	learn: 0.6144994	total: 31.1ms	remaining: 191ms
# 7:	learn: 0.6076984	total: 33.5ms	remaining: 176ms
# 8:	learn: 0.6018792	total: 35.8ms	remaining: 163ms
# 9:	learn: 0.5962627	total: 39.2ms	remaining: 157ms
# 10:	learn: 0.5908556	total: 42.1ms	remaining: 149ms
# 11:	learn: 0.5860436	total: 47.5ms	remaining: 150ms
# 12:	learn: 0.5800885	total: 49.7ms	remaining: 141ms
# 13:	learn: 0.5764344	total: 52.1ms	remaining: 134ms
# 14:	learn: 0.5714847	total: 54.2ms	remaining: 126ms
# 15:	learn: 0.5677321	total: 56.4ms	remaining: 120ms
# 16:	learn: 0.5631313	total: 58.6ms	remaining: 114ms
# 17:	learn: 0.5594696	total: 60.5ms	remaining: 107ms
# 18:	learn: 0.5560078	total: 63.3ms	remaining: 103ms
# 19:	learn: 0.5530785	total: 65.2ms	remaining: 97.8ms
# 20:	learn: 0.5499359	total: 67.5ms	remaining: 93.3ms
# 21:	learn: 0.5470288	total: 73ms	remaining: 92.9ms
# 22:	learn: 0.5453547	total: 76.7ms	remaining: 90.1ms
# 23:	learn: 0.5427698	total: 79ms	remaining: 85.6ms
# 24:	learn: 0.5405430	total: 80.6ms	remaining: 80.6ms
# 25:	learn: 0.5383323	total: 82.6ms	remaining: 76.3ms
# 26:	learn: 0.5358117	total: 90ms	remaining: 76.7ms
# 27:	learn: 0.5335797	total: 100ms	remaining: 78.8ms
# 28:	learn: 0.5313519	total: 105ms	remaining: 76.1ms
# 29:	learn: 0.5292706	total: 107ms	remaining: 71.6ms
# 30:	learn: 0.5273960	total: 109ms	remaining: 67.1ms
# 31:	learn: 0.5256316	total: 112ms	remaining: 62.8ms
# 32:	learn: 0.5233435	total: 114ms	remaining: 58.6ms
# 33:	learn: 0.5215860	total: 116ms	remaining: 54.5ms
# 34:	learn: 0.5198922	total: 118ms	remaining: 50.6ms
# 35:	learn: 0.5184159	total: 120ms	remaining: 46.7ms
# 36:	learn: 0.5167239	total: 122ms	remaining: 42.9ms
# 37:	learn: 0.5152462	total: 124ms	remaining: 39.1ms
# 38:	learn: 0.5138579	total: 126ms	remaining: 35.4ms
# 39:	learn: 0.5124464	total: 127ms	remaining: 31.9ms
# 40:	learn: 0.5108161	total: 129ms	remaining: 28.4ms
# 41:	learn: 0.5096224	total: 131ms	remaining: 25ms
# 42:	learn: 0.5084266	total: 133ms	remaining: 21.7ms
# 43:	learn: 0.5072766	total: 135ms	remaining: 18.4ms
# 44:	learn: 0.5061499	total: 137ms	remaining: 15.2ms
# 45:	learn: 0.5048183	total: 139ms	remaining: 12.1ms
# 46:	learn: 0.5035693	total: 141ms	remaining: 8.98ms
# 47:	learn: 0.5023602	total: 143ms	remaining: 5.94ms
# 48:	learn: 0.5011088	total: 145ms	remaining: 2.95ms
# 49:	learn: 0.5001599	total: 147ms	remaining: 0us
# 0:	learn: 0.6688877	total: 7.29ms	remaining: 357ms
# 1:	learn: 0.6446430	total: 13.7ms	remaining: 329ms
# 2:	learn: 0.6262028	total: 23.4ms	remaining: 367ms
# 3:	learn: 0.6071055	total: 27.3ms	remaining: 314ms
# 4:	learn: 0.5957314	total: 29.5ms	remaining: 266ms
# 5:	learn: 0.5848239	total: 35.2ms	remaining: 258ms
# 6:	learn: 0.5759233	total: 39.5ms	remaining: 242ms
# 7:	learn: 0.5683286	total: 41.8ms	remaining: 219ms
# 0:	learn: 0.6903745	total: 48.5ms	remaining: 2.38s
# 1:	learn: 0.6870569	total: 50ms	remaining: 1.2s
# 2:	learn: 0.6836826	total: 52.8ms	remaining: 827ms
# 3:	learn: 0.6803741	total: 55.5ms	remaining: 638ms
# 4:	learn: 0.6775979	total: 57.3ms	remaining: 516ms
# 5:	learn: 0.6751219	total: 58.9ms	remaining: 432ms
# 6:	learn: 0.6720733	total: 60.7ms	remaining: 373ms
# 7:	learn: 0.6696485	total: 62.4ms	remaining: 328ms
# 8:	learn: 0.6671651	total: 64ms	remaining: 291ms
# 9:	learn: 0.6647123	total: 66.7ms	remaining: 267ms
# 10:	learn: 0.6624224	total: 69.4ms	remaining: 246ms
# 11:	learn: 0.6598235	total: 71.8ms	remaining: 227ms
# 12:	learn: 0.6577169	total: 74.9ms	remaining: 213ms
# 13:	learn: 0.6555003	total: 82.1ms	remaining: 211ms
# 14:	learn: 0.6533642	total: 86.9ms	remaining: 203ms
# 15:	learn: 0.6506564	total: 91.3ms	remaining: 194ms
# 16:	learn: 0.6482660	total: 101ms	remaining: 195ms
# 17:	learn: 0.6457772	total: 107ms	remaining: 190ms
# 18:	learn: 0.6434312	total: 109ms	remaining: 178ms
# 19:	learn: 0.6410518	total: 111ms	remaining: 166ms
# 20:	learn: 0.6391406	total: 113ms	remaining: 155ms
# 21:	learn: 0.6371996	total: 135ms	remaining: 172ms
# 22:	learn: 0.6354814	total: 137ms	remaining: 161ms
# 23:	learn: 0.6338606	total: 149ms	remaining: 162ms
# 24:	learn: 0.6321019	total: 151ms	remaining: 151ms
# 25:	learn: 0.6302932	total: 153ms	remaining: 141ms
# 26:	learn: 0.6281577	total: 155ms	remaining: 132ms
# 27:	learn: 0.6264455	total: 183ms	remaining: 144ms
# 28:	learn: 0.6249241	total: 187ms	remaining: 136ms
# 29:	learn: 0.6233620	total: 194ms	remaining: 129ms
# 30:	learn: 0.6217713	total: 197ms	remaining: 120ms
# 31:	learn: 0.6200941	total: 206ms	remaining: 116ms
# 32:	learn: 0.6184335	total: 208ms	remaining: 107ms
# 33:	learn: 0.6168488	total: 210ms	remaining: 98.8ms
# 34:	learn: 0.6153377	total: 212ms	remaining: 90.9ms
# 35:	learn: 0.6139554	total: 230ms	remaining: 89.3ms
# 36:	learn: 0.6124974	total: 236ms	remaining: 83ms
# 37:	learn: 0.6110057	total: 245ms	remaining: 77.4ms
# 38:	learn: 0.6092590	total: 247ms	remaining: 69.6ms
# 39:	learn: 0.6079342	total: 249ms	remaining: 62.2ms
# 40:	learn: 0.6063177	total: 266ms	remaining: 58.5ms
# 41:	learn: 0.6046128	total: 269ms	remaining: 51.2ms
# 42:	learn: 0.6033607	total: 271ms	remaining: 44.1ms
# 43:	learn: 0.6020700	total: 281ms	remaining: 38.4ms
# 44:	learn: 0.6005127	total: 289ms	remaining: 32.1ms
# 45:	learn: 0.5992330	total: 294ms	remaining: 25.6ms
# 46:	learn: 0.5979711	total: 302ms	remaining: 19.3ms
# 47:	learn: 0.5967100	total: 304ms	remaining: 12.7ms
# 48:	learn: 0.5954692	total: 308ms	remaining: 6.28ms
# 49:	learn: 0.5943081	total: 310ms	remaining: 0us
# 0:	learn: 0.6793591	total: 11.9ms	remaining: 584ms
# 1:	learn: 0.6668726	total: 19.7ms	remaining: 473ms
# 2:	learn: 0.6525483	total: 23.2ms	remaining: 364ms
# 3:	learn: 0.6431879	total: 25.4ms	remaining: 292ms
# 4:	learn: 0.6342371	total: 28.7ms	remaining: 258ms
# 5:	learn: 0.6252370	total: 33.1ms	remaining: 243ms
# 6:	learn: 0.6153916	total: 34.9ms	remaining: 214ms
# 7:	learn: 0.6064393	total: 36.6ms	remaining: 192ms
# 8:	learn: 0.5987357	total: 39.2ms	remaining: 179ms
# 9:	learn: 0.5932585	total: 44.8ms	remaining: 179ms
# 10:	learn: 0.5881963	total: 51.4ms	remaining: 182ms
# 11:	learn: 0.5829415	total: 53.4ms	remaining: 169ms
# 12:	learn: 0.5779750	total: 55.5ms	remaining: 158ms
# 13:	learn: 0.5723774	total: 69.1ms	remaining: 178ms
# 14:	learn: 0.5677325	total: 74.5ms	remaining: 174ms
# 15:	learn: 0.5640543	total: 76.5ms	remaining: 163ms
# 16:	learn: 0.5607932	total: 78.4ms	remaining: 152ms
# 17:	learn: 0.5569420	total: 80.2ms	remaining: 143ms
# 18:	learn: 0.5531793	total: 82.2ms	remaining: 134ms
# 19:	learn: 0.5499492	total: 84.1ms	remaining: 126ms
# 20:	learn: 0.5471804	total: 86ms	remaining: 119ms
# 21:	learn: 0.5443720	total: 87.8ms	remaining: 112ms
# 22:	learn: 0.5422212	total: 89.7ms	remaining: 105ms
# 23:	learn: 0.5395466	total: 91.6ms	remaining: 99.3ms
# 24:	learn: 0.5369998	total: 94.3ms	remaining: 94.3ms
# 25:	learn: 0.5344608	total: 96.3ms	remaining: 88.9ms
# 26:	learn: 0.5318645	total: 106ms	remaining: 90.6ms
# 27:	learn: 0.5293586	total: 109ms	remaining: 85.4ms
# 28:	learn: 0.5272734	total: 111ms	remaining: 80.2ms
# 29:	learn: 0.5250068	total: 113ms	remaining: 75.2ms
# 30:	learn: 0.5236463	total: 115ms	remaining: 70.4ms
# 31:	learn: 0.5214300	total: 117ms	remaining: 65.7ms
# 32:	learn: 0.5196734	total: 119ms	remaining: 61.1ms
# 33:	learn: 0.5177337	total: 121ms	remaining: 56.9ms
# 34:	learn: 0.5163705	total: 123ms	remaining: 52.6ms
# 35:	learn: 0.5148065	total: 125ms	remaining: 48.5ms
# 36:	learn: 0.5126381	total: 127ms	remaining: 44.5ms
# 37:	learn: 0.5108922	total: 129ms	remaining: 40.7ms
# 38:	learn: 0.5095556	total: 131ms	remaining: 36.9ms
# 39:	learn: 0.5081392	total: 133ms	remaining: 33.3ms
# 40:	learn: 0.5068518	total: 135ms	remaining: 29.6ms
# 41:	learn: 0.5053395	total: 137ms	remaining: 26.1ms
# 42:	learn: 0.5036357	total: 139ms	remaining: 22.6ms
# 43:	learn: 0.5021050	total: 141ms	remaining: 19.2ms
# 44:	learn: 0.5009224	total: 143ms	remaining: 15.9ms
# 45:	learn: 0.4999782	total: 145ms	remaining: 12.6ms
# 46:	learn: 0.4986346	total: 147ms	remaining: 9.38ms
# 47:	learn: 0.4977976	total: 149ms	remaining: 6.2ms
# 48:	learn: 0.4968891	total: 151ms	remaining: 3.07ms
# 49:	learn: 0.4960818	total: 153ms	remaining: 0us
# 0:	learn: 0.6663622	total: 5.22ms	remaining: 256ms
# 1:	learn: 0.6445291	total: 11.3ms	remaining: 271ms
# 2:	learn: 0.6200842	total: 16.4ms	remaining: 258ms
# 3:	learn: 0.6027937	total: 23.9ms	remaining: 275ms
# 4:	learn: 0.5875251	total: 35ms	remaining: 315ms
# 5:	learn: 0.5781287	total: 50.4ms	remaining: 370ms
# 6:	learn: 0.5688479	total: 52.7ms	remaining: 324ms
# 7:	learn: 0.5618802	total: 55.4ms	remaining: 291ms
# 8:	learn: 0.5534685	total: 57.2ms	remaining: 261ms
# 9:	learn: 0.5481810	total: 59ms	remaining: 236ms
# 10:	learn: 0.5423347	total: 61.1ms	remaining: 217ms
# 11:	learn: 0.5380556	total: 64.5ms	remaining: 204ms
# 12:	learn: 0.5332305	total: 68.2ms	remaining: 194ms
# 13:	learn: 0.5290879	total: 71.6ms	remaining: 184ms
# 14:	learn: 0.5250040	total: 75.7ms	remaining: 177ms
# 15:	learn: 0.5220600	total: 77.7ms	remaining: 165ms
# 16:	learn: 0.5190931	total: 79.5ms	remaining: 154ms
# 17:	learn: 0.5150323	total: 83.2ms	remaining: 148ms
# 18:	learn: 0.5123274	total: 85.5ms	remaining: 140ms
# 19:	learn: 0.5095127	total: 87.7ms	remaining: 132ms
# 20:	learn: 0.5061677	total: 89.8ms	remaining: 124ms
# 21:	learn: 0.5035339	total: 91.7ms	remaining: 117ms
# 22:	learn: 0.5012480	total: 93.5ms	remaining: 110ms
# 23:	learn: 0.4995449	total: 95.3ms	remaining: 103ms
# 24:	learn: 0.4967514	total: 97.2ms	remaining: 97.2ms
# 25:	learn: 0.4942769	total: 99.1ms	remaining: 91.5ms
# 26:	learn: 0.4930397	total: 101ms	remaining: 86.3ms
# 27:	learn: 0.4913766	total: 103ms	remaining: 81ms
# 28:	learn: 0.4900119	total: 105ms	remaining: 76.1ms
# 29:	learn: 0.4873108	total: 111ms	remaining: 74ms
# 30:	learn: 0.4864681	total: 117ms	remaining: 71.6ms
# 31:	learn: 0.4840552	total: 120ms	remaining: 67.4ms
# 32:	learn: 0.4829160	total: 125ms	remaining: 64.5ms
# 33:	learn: 0.4817304	total: 128ms	remaining: 60ms
# 34:	learn: 0.4804059	total: 131ms	remaining: 56ms
# 35:	learn: 0.4795283	total: 133ms	remaining: 51.7ms
# 36:	learn: 0.4776923	total: 135ms	remaining: 47.4ms
# 37:	learn: 0.4765931	total: 137ms	remaining: 43.1ms
# 38:	learn: 0.4755396	total: 138ms	remaining: 39ms
# 39:	learn: 0.4746998	total: 140ms	remaining: 35ms
# 40:	learn: 0.4734465	total: 146ms	remaining: 31.9ms
# 41:	learn: 0.4717426	total: 149ms	remaining: 28.5ms
# 42:	learn: 0.4706341	total: 151ms	remaining: 24.7ms
# 43:	learn: 0.4694829	total: 154ms	remaining: 20.9ms
# 44:	learn: 0.4685272	total: 163ms	remaining: 18.1ms
# 45:	learn: 0.4676549	total: 166ms	remaining: 14.4ms
# 46:	learn: 0.4665070	total: 168ms	remaining: 10.7ms
# 47:	learn: 0.4655998	total: 170ms	remaining: 7.09ms
# 48:	learn: 0.4638276	total: 172ms	remaining: 3.51ms
# 49:	learn: 0.4632445	total: 175ms	remaining: 0us
# 0:	learn: 0.5906363	total: 2.5ms	remaining: 123ms
# 1:	learn: 0.5576844	total: 5.15ms	remaining: 124ms
# 2:	learn: 0.5301346	total: 7.91ms	remaining: 124ms
# 3:	learn: 0.5117132	total: 10.9ms	remaining: 125ms
# 4:	learn: 0.4994236	total: 14.1ms	remaining: 126ms
# 5:	learn: 0.4852254	total: 16ms	remaining: 118ms
# 6:	learn: 0.4743794	total: 17.9ms	remaining: 110ms
# 7:	learn: 0.4688714	total: 19.9ms	remaining: 105ms
# 8:	learn: 0.4650980	total: 21.8ms	remaining: 99.2ms
# 0:	learn: 0.6905940	total: 52.6ms	remaining: 2.58s
# 1:	learn: 0.6876543	total: 54.7ms	remaining: 1.31s
# 2:	learn: 0.6842686	total: 56.9ms	remaining: 891ms
# 3:	learn: 0.6818847	total: 58.9ms	remaining: 678ms
# 4:	learn: 0.6794483	total: 77.3ms	remaining: 696ms
# 5:	learn: 0.6764722	total: 86.5ms	remaining: 634ms
# 6:	learn: 0.6741445	total: 88.4ms	remaining: 543ms
# 7:	learn: 0.6710920	total: 97.4ms	remaining: 511ms
# 8:	learn: 0.6686706	total: 111ms	remaining: 506ms
# 9:	learn: 0.6662506	total: 113ms	remaining: 454ms
# 10:	learn: 0.6633646	total: 121ms	remaining: 429ms
# 11:	learn: 0.6612176	total: 128ms	remaining: 405ms
# 12:	learn: 0.6585363	total: 135ms	remaining: 385ms
# 13:	learn: 0.6563703	total: 142ms	remaining: 364ms
# 14:	learn: 0.6543023	total: 148ms	remaining: 345ms
# 15:	learn: 0.6517629	total: 150ms	remaining: 319ms
# 16:	learn: 0.6497665	total: 158ms	remaining: 306ms
# 17:	learn: 0.6472615	total: 163ms	remaining: 290ms
# 18:	learn: 0.6453037	total: 170ms	remaining: 277ms
# 19:	learn: 0.6429703	total: 177ms	remaining: 265ms
# 20:	learn: 0.6413363	total: 183ms	remaining: 253ms
# 21:	learn: 0.6391141	total: 190ms	remaining: 242ms
# 22:	learn: 0.6374076	total: 194ms	remaining: 227ms
# 23:	learn: 0.6357829	total: 204ms	remaining: 221ms
# 24:	learn: 0.6340367	total: 208ms	remaining: 208ms
# 25:	learn: 0.6318385	total: 213ms	remaining: 197ms
# 26:	learn: 0.6301108	total: 220ms	remaining: 188ms
# 27:	learn: 0.6283556	total: 222ms	remaining: 175ms
# 28:	learn: 0.6267137	total: 229ms	remaining: 166ms
# 29:	learn: 0.6251502	total: 237ms	remaining: 158ms
# 30:	learn: 0.6231805	total: 244ms	remaining: 149ms
# 31:	learn: 0.6215918	total: 246ms	remaining: 138ms
# 32:	learn: 0.6201258	total: 254ms	remaining: 131ms
# 33:	learn: 0.6186604	total: 256ms	remaining: 120ms
# 34:	learn: 0.6172275	total: 266ms	remaining: 114ms
# 35:	learn: 0.6154922	total: 272ms	remaining: 106ms
# 36:	learn: 0.6137002	total: 279ms	remaining: 98.1ms
# 37:	learn: 0.6123918	total: 281ms	remaining: 88.9ms
# 38:	learn: 0.6106233	total: 289ms	remaining: 81.5ms
# 39:	learn: 0.6089757	total: 293ms	remaining: 73.2ms
# 40:	learn: 0.6078061	total: 295ms	remaining: 64.7ms
# 41:	learn: 0.6064613	total: 297ms	remaining: 56.6ms
# 42:	learn: 0.6051285	total: 299ms	remaining: 48.7ms
# 43:	learn: 0.6038586	total: 301ms	remaining: 41.1ms
# 44:	learn: 0.6026714	total: 303ms	remaining: 33.7ms
# 45:	learn: 0.6010875	total: 305ms	remaining: 26.5ms
# 46:	learn: 0.5999022	total: 307ms	remaining: 19.6ms
# 47:	learn: 0.5987434	total: 310ms	remaining: 12.9ms
# 48:	learn: 0.5977176	total: 315ms	remaining: 6.42ms
# 49:	learn: 0.5966506	total: 317ms	remaining: 0us
# 0:	learn: 0.6801822	total: 4.72ms	remaining: 231ms
# 1:	learn: 0.6669730	total: 18.7ms	remaining: 449ms
# 2:	learn: 0.6522254	total: 20.5ms	remaining: 321ms
# 3:	learn: 0.6390048	total: 34ms	remaining: 391ms
# 4:	learn: 0.6291519	total: 35.9ms	remaining: 323ms
# 5:	learn: 0.6207961	total: 51.2ms	remaining: 376ms
# 6:	learn: 0.6132394	total: 52.9ms	remaining: 325ms
# 7:	learn: 0.6059768	total: 62.7ms	remaining: 329ms
# 8:	learn: 0.5972754	total: 72.8ms	remaining: 331ms
# 9:	learn: 0.5917599	total: 74.7ms	remaining: 299ms
# 10:	learn: 0.5843839	total: 85.2ms	remaining: 302ms
# 11:	learn: 0.5783230	total: 94.4ms	remaining: 299ms
# 12:	learn: 0.5740439	total: 96.3ms	remaining: 274ms
# 13:	learn: 0.5687270	total: 98.2ms	remaining: 253ms
# 14:	learn: 0.5650003	total: 100ms	remaining: 233ms
# 15:	learn: 0.5614238	total: 102ms	remaining: 218ms
# 16:	learn: 0.5572550	total: 105ms	remaining: 203ms
# 17:	learn: 0.5539516	total: 107ms	remaining: 190ms
# 18:	learn: 0.5511793	total: 109ms	remaining: 177ms
# 19:	learn: 0.5482633	total: 111ms	remaining: 167ms
# 20:	learn: 0.5449882	total: 113ms	remaining: 157ms
# 21:	learn: 0.5418209	total: 117ms	remaining: 149ms
# 22:	learn: 0.5388097	total: 119ms	remaining: 140ms
# 23:	learn: 0.5362287	total: 122ms	remaining: 132ms
# 24:	learn: 0.5333692	total: 124ms	remaining: 124ms
# 25:	learn: 0.5312172	total: 126ms	remaining: 116ms
# 26:	learn: 0.5289530	total: 128ms	remaining: 109ms
# 27:	learn: 0.5265238	total: 130ms	remaining: 102ms
# 28:	learn: 0.5246572	total: 132ms	remaining: 95.3ms
# 29:	learn: 0.5225603	total: 134ms	remaining: 89.1ms
# 30:	learn: 0.5207371	total: 136ms	remaining: 83.1ms
# 31:	learn: 0.5191437	total: 137ms	remaining: 77.3ms
# 32:	learn: 0.5165958	total: 139ms	remaining: 71.8ms
# 33:	learn: 0.5144709	total: 141ms	remaining: 66.4ms
# 34:	learn: 0.5129015	total: 143ms	remaining: 61.4ms
# 35:	learn: 0.5112710	total: 145ms	remaining: 56.6ms
# 36:	learn: 0.5099070	total: 147ms	remaining: 51.8ms
# 37:	learn: 0.5084544	total: 149ms	remaining: 47.1ms
# 38:	learn: 0.5069695	total: 151ms	remaining: 42.6ms
# 39:	learn: 0.5054315	total: 153ms	remaining: 38.3ms
# 40:	learn: 0.5043376	total: 155ms	remaining: 34.1ms
# 41:	learn: 0.5030295	total: 158ms	remaining: 30ms
# 42:	learn: 0.5016841	total: 159ms	remaining: 26ms
# 43:	learn: 0.4997211	total: 161ms	remaining: 22ms
# 44:	learn: 0.4984699	total: 163ms	remaining: 18.1ms
# 45:	learn: 0.4972803	total: 165ms	remaining: 14.4ms
# 46:	learn: 0.4965764	total: 168ms	remaining: 10.7ms
# 47:	learn: 0.4957114	total: 170ms	remaining: 7.07ms
# 48:	learn: 0.4944381	total: 172ms	remaining: 3.5ms
# 49:	learn: 0.4934656	total: 174ms	remaining: 0us
# 0:	learn: 0.6667868	total: 10.3ms	remaining: 506ms
# 1:	learn: 0.6396882	total: 12ms	remaining: 288ms
# 2:	learn: 0.6214777	total: 24.1ms	remaining: 378ms
# 3:	learn: 0.6066684	total: 25.9ms	remaining: 298ms
# 4:	learn: 0.5934021	total: 28.8ms	remaining: 259ms
# 5:	learn: 0.5792451	total: 32.9ms	remaining: 242ms
# 6:	learn: 0.5704385	total: 34.8ms	remaining: 214ms
# 7:	learn: 0.5625802	total: 36.7ms	remaining: 193ms
# 8:	learn: 0.5545070	total: 38.6ms	remaining: 176ms
# 9:	learn: 0.5488096	total: 40.5ms	remaining: 162ms
# 10:	learn: 0.5420232	total: 42.5ms	remaining: 151ms
# 11:	learn: 0.5360802	total: 44.2ms	remaining: 140ms
# 12:	learn: 0.5323711	total: 45.9ms	remaining: 130ms
# 13:	learn: 0.5276706	total: 48.3ms	remaining: 124ms
# 14:	learn: 0.5237919	total: 50.4ms	remaining: 117ms
# 15:	learn: 0.5194296	total: 52.1ms	remaining: 111ms
# 16:	learn: 0.5153274	total: 57.3ms	remaining: 111ms
# 17:	learn: 0.5119423	total: 60ms	remaining: 107ms
# 18:	learn: 0.5091125	total: 62.3ms	remaining: 102ms
# 19:	learn: 0.5056127	total: 64ms	remaining: 96ms
# 20:	learn: 0.5038421	total: 65.8ms	remaining: 90.8ms
# 21:	learn: 0.5008293	total: 67.9ms	remaining: 86.4ms
# 22:	learn: 0.4982743	total: 69.9ms	remaining: 82.1ms
# 23:	learn: 0.4959439	total: 71.8ms	remaining: 77.8ms
# 24:	learn: 0.4933097	total: 73.7ms	remaining: 73.7ms
# 25:	learn: 0.4911338	total: 75.6ms	remaining: 69.8ms
# 26:	learn: 0.4883671	total: 77.5ms	remaining: 66ms
# 27:	learn: 0.4872609	total: 79.4ms	remaining: 62.4ms
# 28:	learn: 0.4861417	total: 81.3ms	remaining: 58.9ms
# 29:	learn: 0.4847824	total: 83.5ms	remaining: 55.6ms
# 30:	learn: 0.4831379	total: 85.3ms	remaining: 52.3ms
# 31:	learn: 0.4816105	total: 87.1ms	remaining: 49ms
# 32:	learn: 0.4787572	total: 89ms	remaining: 45.8ms
# 33:	learn: 0.4764249	total: 90.9ms	remaining: 42.8ms
# 34:	learn: 0.4752675	total: 92.7ms	remaining: 39.7ms
# 35:	learn: 0.4733361	total: 94.9ms	remaining: 36.9ms
# 36:	learn: 0.4724850	total: 96.8ms	remaining: 34ms
# 37:	learn: 0.4710592	total: 98.6ms	remaining: 31.1ms
# 38:	learn: 0.4698310	total: 101ms	remaining: 28.4ms
# 39:	learn: 0.4687679	total: 103ms	remaining: 25.6ms
# 40:	learn: 0.4674470	total: 105ms	remaining: 23ms
# 41:	learn: 0.4661851	total: 107ms	remaining: 20.4ms
# 42:	learn: 0.4643262	total: 109ms	remaining: 17.7ms
# 43:	learn: 0.4633727	total: 111ms	remaining: 15.1ms
# 44:	learn: 0.4625818	total: 113ms	remaining: 12.6ms
# 45:	learn: 0.4617809	total: 115ms	remaining: 10ms
# 46:	learn: 0.4603582	total: 117ms	remaining: 7.47ms
# 47:	learn: 0.4597689	total: 119ms	remaining: 4.95ms
# 48:	learn: 0.4586328	total: 121ms	remaining: 2.46ms
# 49:	learn: 0.4577234	total: 123ms	remaining: 0us
# 0:	learn: 0.6683703	total: 4.14ms	remaining: 203ms
# 1:	learn: 0.6449610	total: 9.99ms	remaining: 240ms
# 2:	learn: 0.6208674	total: 20.3ms	remaining: 319ms
# 3:	learn: 0.6022037	total: 25.4ms	remaining: 292ms
# 4:	learn: 0.5878310	total: 30.2ms	remaining: 272ms
# 5:	learn: 0.5779502	total: 32.2ms	remaining: 236ms
# 6:	learn: 0.5678227	total: 43.2ms	remaining: 266ms
# 7:	learn: 0.5583550	total: 45.1ms	remaining: 237ms
# 8:	learn: 0.5519405	total: 47ms	remaining: 214ms
# 8:	learn: 0.5529701	total: 30.2ms	remaining: 138ms
# 9:	learn: 0.5457279	total: 33.2ms	remaining: 133ms
# 10:	learn: 0.5396144	total: 35ms	remaining: 124ms
# 11:	learn: 0.5341223	total: 37ms	remaining: 117ms
# 12:	learn: 0.5296654	total: 39.4ms	remaining: 112ms
# 13:	learn: 0.5246919	total: 41.1ms	remaining: 106ms
# 14:	learn: 0.5198704	total: 42.9ms	remaining: 100ms
# 15:	learn: 0.5156399	total: 44.8ms	remaining: 95.1ms
# 16:	learn: 0.5124547	total: 46.7ms	remaining: 90.7ms
# 17:	learn: 0.5091050	total: 49ms	remaining: 87.1ms
# 18:	learn: 0.5064905	total: 52.9ms	remaining: 86.3ms
# 19:	learn: 0.5045488	total: 55.4ms	remaining: 83ms
# 20:	learn: 0.5024217	total: 57.6ms	remaining: 79.6ms
# 21:	learn: 0.4989804	total: 59.6ms	remaining: 75.9ms
# 22:	learn: 0.4963179	total: 61.9ms	remaining: 72.7ms
# 23:	learn: 0.4940324	total: 64ms	remaining: 69.3ms
# 24:	learn: 0.4913546	total: 66.2ms	remaining: 66.2ms
# 25:	learn: 0.4886587	total: 68.5ms	remaining: 63.2ms
# 26:	learn: 0.4866473	total: 70.7ms	remaining: 60.2ms
# 27:	learn: 0.4844242	total: 72.8ms	remaining: 57.2ms
# 28:	learn: 0.4820488	total: 74.8ms	remaining: 54.2ms
# 29:	learn: 0.4800560	total: 76.9ms	remaining: 51.3ms
# 30:	learn: 0.4788712	total: 79.1ms	remaining: 48.5ms
# 31:	learn: 0.4777248	total: 81.1ms	remaining: 45.6ms
# 32:	learn: 0.4764740	total: 83.2ms	remaining: 42.9ms
# 33:	learn: 0.4748006	total: 85.1ms	remaining: 40.1ms
# 34:	learn: 0.4736032	total: 87.4ms	remaining: 37.4ms
# 35:	learn: 0.4720048	total: 89.2ms	remaining: 34.7ms
# 36:	learn: 0.4707740	total: 91.2ms	remaining: 32ms
# 37:	learn: 0.4693218	total: 92.9ms	remaining: 29.3ms
# 38:	learn: 0.4679542	total: 94.6ms	remaining: 26.7ms
# 39:	learn: 0.4673795	total: 96.4ms	remaining: 24.1ms
# 40:	learn: 0.4667608	total: 98.6ms	remaining: 21.6ms
# 41:	learn: 0.4662377	total: 102ms	remaining: 19.4ms
# 42:	learn: 0.4653189	total: 104ms	remaining: 16.9ms
# 43:	learn: 0.4644388	total: 108ms	remaining: 14.8ms
# 44:	learn: 0.4629163	total: 110ms	remaining: 12.3ms
# 45:	learn: 0.4615496	total: 112ms	remaining: 9.77ms
# 46:	learn: 0.4599201	total: 114ms	remaining: 7.29ms
# 47:	learn: 0.4592314	total: 116ms	remaining: 4.85ms
# 48:	learn: 0.4582036	total: 118ms	remaining: 2.41ms
# 49:	learn: 0.4575707	total: 121ms	remaining: 0us
# 0:	learn: 0.5923566	total: 4.22ms	remaining: 207ms
# 1:	learn: 0.5423589	total: 7.42ms	remaining: 178ms
# 2:	learn: 0.5191704	total: 10ms	remaining: 157ms
# 3:	learn: 0.4985660	total: 12.3ms	remaining: 142ms
# 4:	learn: 0.4892176	total: 14.7ms	remaining: 133ms
# 5:	learn: 0.4796797	total: 17.8ms	remaining: 131ms
# 6:	learn: 0.4732948	total: 20.2ms	remaining: 124ms
# 7:	learn: 0.4672366	total: 23.8ms	remaining: 125ms
# 8:	learn: 0.4644275	total: 33.5ms	remaining: 153ms
# 9:	learn: 0.4553219	total: 49.8ms	remaining: 199ms
# 10:	learn: 0.4534045	total: 56.3ms	remaining: 200ms
# 11:	learn: 0.4477947	total: 59.1ms	remaining: 187ms
# 12:	learn: 0.4428400	total: 61.9ms	remaining: 176ms
# 13:	learn: 0.4405194	total: 64.2ms	remaining: 165ms
# 14:	learn: 0.4377310	total: 66.6ms	remaining: 155ms
# 15:	learn: 0.4359989	total: 72.6ms	remaining: 154ms
# 16:	learn: 0.4343784	total: 75.3ms	remaining: 146ms
# 17:	learn: 0.4300710	total: 77.7ms	remaining: 138ms
# 18:	learn: 0.4281318	total: 81.8ms	remaining: 133ms
# 19:	learn: 0.4268984	total: 84.3ms	remaining: 127ms
# 20:	learn: 0.4254111	total: 86.8ms	remaining: 120ms
# 21:	learn: 0.4234914	total: 89ms	remaining: 113ms
# 22:	learn: 0.4217577	total: 91.5ms	remaining: 107ms
# 23:	learn: 0.4196329	total: 94ms	remaining: 102ms
# 24:	learn: 0.4177542	total: 96.3ms	remaining: 96.3ms
# 25:	learn: 0.4164015	total: 98.9ms	remaining: 91.3ms
# 26:	learn: 0.4151251	total: 103ms	remaining: 87.6ms
# 27:	learn: 0.4136508	total: 109ms	remaining: 85.9ms
# 28:	learn: 0.4118365	total: 114ms	remaining: 82.5ms
# 29:	learn: 0.4100354	total: 120ms	remaining: 79.7ms
# 30:	learn: 0.4081679	total: 129ms	remaining: 79ms
# 31:	learn: 0.4068967	total: 137ms	remaining: 76.9ms
# 32:	learn: 0.4061610	total: 141ms	remaining: 72.4ms
# 33:	learn: 0.4049452	total: 142ms	remaining: 67ms
# 34:	learn: 0.4028526	total: 144ms	remaining: 61.8ms
# 35:	learn: 0.4017426	total: 146ms	remaining: 56.8ms
# 36:	learn: 0.4010483	total: 148ms	remaining: 52.1ms
# 37:	learn: 0.4004492	total: 151ms	remaining: 47.6ms
# 38:	learn: 0.3976437	total: 153ms	remaining: 43.1ms
# 39:	learn: 0.3965152	total: 155ms	remaining: 38.7ms
# 40:	learn: 0.3958258	total: 157ms	remaining: 34.5ms
# 41:	learn: 0.3952235	total: 159ms	remaining: 30.3ms
# 42:	learn: 0.3947144	total: 161ms	remaining: 26.2ms
# 43:	learn: 0.3939141	total: 163ms	remaining: 22.2ms
# 44:	learn: 0.3922886	total: 165ms	remaining: 18.3ms
# 45:	learn: 0.3918486	total: 167ms	remaining: 14.5ms
# 46:	learn: 0.3911641	total: 169ms	remaining: 10.8ms
# 47:	learn: 0.3905655	total: 171ms	remaining: 7.11ms
# 48:	learn: 0.3901996	total: 173ms	remaining: 3.54ms
# 49:	learn: 0.3895933	total: 176ms	remaining: 0us
# 0:	learn: 0.6903281	total: 10.4ms	remaining: 1.03s
# 1:	learn: 0.6874752	total: 17ms	remaining: 832ms
# 2:	learn: 0.6841018	total: 22.1ms	remaining: 715ms
# 3:	learn: 0.6814982	total: 24.1ms	remaining: 579ms
# 4:	learn: 0.6790263	total: 25.9ms	remaining: 493ms
# 5:	learn: 0.6764366	total: 28.2ms	remaining: 441ms
# 6:	learn: 0.6738535	total: 30.1ms	remaining: 400ms
# 7:	learn: 0.6712752	total: 31.9ms	remaining: 367ms
# 8:	learn: 0.6689907	total: 33.7ms	remaining: 341ms
# 9:	learn: 0.6660273	total: 35.5ms	remaining: 320ms
# 10:	learn: 0.6639255	total: 37.3ms	remaining: 302ms
# 11:	learn: 0.6618374	total: 39ms	remaining: 286ms
# 12:	learn: 0.6590761	total: 40.9ms	remaining: 273ms
# 13:	learn: 0.6568146	total: 42.6ms	remaining: 262ms
# 14:	learn: 0.6545329	total: 44.3ms	remaining: 251ms
# 15:	learn: 0.6519334	total: 46ms	remaining: 241ms
# 16:	learn: 0.6498275	total: 47.7ms	remaining: 233ms
# 17:	learn: 0.6472117	total: 49.4ms	remaining: 225ms
# 18:	learn: 0.6452746	total: 51.3ms	remaining: 219ms
# 19:	learn: 0.6433962	total: 53.3ms	remaining: 213ms
# 20:	learn: 0.6414873	total: 54.9ms	remaining: 207ms
# 21:	learn: 0.6394993	total: 56.3ms	remaining: 199ms
# 22:	learn: 0.6373400	total: 58.4ms	remaining: 196ms
# 23:	learn: 0.6350975	total: 60.4ms	remaining: 191ms
# 24:	learn: 0.6332334	total: 62.7ms	remaining: 188ms
# 25:	learn: 0.6316798	total: 64.9ms	remaining: 185ms
# 26:	learn: 0.6295643	total: 66.6ms	remaining: 180ms
# 27:	learn: 0.6273452	total: 68.4ms	remaining: 176ms
# 28:	learn: 0.6258037	total: 70.4ms	remaining: 172ms
# 29:	learn: 0.6243119	total: 74.6ms	remaining: 174ms
# 30:	learn: 0.6226507	total: 77.6ms	remaining: 173ms
# 31:	learn: 0.6211553	total: 79.3ms	remaining: 168ms
# 32:	learn: 0.6197337	total: 85.2ms	remaining: 173ms
# 33:	learn: 0.6183038	total: 90.9ms	remaining: 176ms
# 34:	learn: 0.6168506	total: 98.1ms	remaining: 182ms
# 35:	learn: 0.6149481	total: 99.9ms	remaining: 178ms
# 36:	learn: 0.6135633	total: 102ms	remaining: 173ms
# 37:	learn: 0.6121901	total: 103ms	remaining: 169ms
# 38:	learn: 0.6104650	total: 105ms	remaining: 165ms
# 39:	learn: 0.6088316	total: 107ms	remaining: 161ms
# 40:	learn: 0.6074989	total: 110ms	remaining: 159ms
# 41:	learn: 0.6061425	total: 119ms	remaining: 165ms
# 42:	learn: 0.6042424	total: 123ms	remaining: 164ms
# 43:	learn: 0.6030571	total: 125ms	remaining: 160ms
# 44:	learn: 0.6018407	total: 127ms	remaining: 156ms
# 45:	learn: 0.6006365	total: 129ms	remaining: 152ms
# 46:	learn: 0.5994667	total: 131ms	remaining: 148ms
# 47:	learn: 0.5982262	total: 133ms	remaining: 145ms
# 48:	learn: 0.5967006	total: 136ms	remaining: 141ms
# 49:	learn: 0.5955927	total: 137ms	remaining: 137ms
# 50:	learn: 0.5944018	total: 139ms	remaining: 134ms
# 51:	learn: 0.5933530	total: 141ms	remaining: 130ms
# 52:	learn: 0.5923098	total: 143ms	remaining: 127ms
# 53:	learn: 0.5908840	total: 145ms	remaining: 123ms
# 54:	learn: 0.5898852	total: 147ms	remaining: 120ms
# 55:	learn: 0.5885478	total: 149ms	remaining: 117ms
# 56:	learn: 0.5875445	total: 151ms	remaining: 114ms
# 57:	learn: 0.5862146	total: 153ms	remaining: 110ms
# 58:	learn: 0.5848917	total: 155ms	remaining: 107ms
# 59:	learn: 0.5836137	total: 156ms	remaining: 104ms
# 60:	learn: 0.5823961	total: 158ms	remaining: 101ms
# 61:	learn: 0.5814198	total: 160ms	remaining: 98.3ms
# 62:	learn: 0.5804557	total: 162ms	remaining: 95.3ms
# 63:	learn: 0.5797230	total: 164ms	remaining: 92.4ms
# 64:	learn: 0.5786215	total: 166ms	remaining: 89.5ms
# 65:	learn: 0.5776969	total: 168ms	remaining: 86.6ms
# 8:	learn: 0.5599464	total: 44ms	remaining: 201ms
# 9:	learn: 0.5538631	total: 45.9ms	remaining: 183ms
# 10:	learn: 0.5459598	total: 53.5ms	remaining: 190ms
# 11:	learn: 0.5397513	total: 55.3ms	remaining: 175ms
# 12:	learn: 0.5349847	total: 59.8ms	remaining: 170ms
# 13:	learn: 0.5308873	total: 69.2ms	remaining: 178ms
# 14:	learn: 0.5276324	total: 71.4ms	remaining: 167ms
# 15:	learn: 0.5238857	total: 77.9ms	remaining: 166ms
# 16:	learn: 0.5193057	total: 79.8ms	remaining: 155ms
# 17:	learn: 0.5161605	total: 81.7ms	remaining: 145ms
# 18:	learn: 0.5137321	total: 83.6ms	remaining: 136ms
# 19:	learn: 0.5112185	total: 86ms	remaining: 129ms
# 20:	learn: 0.5090875	total: 88.6ms	remaining: 122ms
# 21:	learn: 0.5067908	total: 90.5ms	remaining: 115ms
# 22:	learn: 0.5038755	total: 92.9ms	remaining: 109ms
# 23:	learn: 0.5011289	total: 95.8ms	remaining: 104ms
# 24:	learn: 0.4993250	total: 101ms	remaining: 101ms
# 25:	learn: 0.4971302	total: 109ms	remaining: 101ms
# 26:	learn: 0.4959283	total: 112ms	remaining: 95.6ms
# 27:	learn: 0.4947442	total: 114ms	remaining: 89.5ms
# 28:	learn: 0.4923167	total: 116ms	remaining: 83.9ms
# 29:	learn: 0.4908492	total: 118ms	remaining: 78.5ms
# 30:	learn: 0.4885343	total: 120ms	remaining: 73.4ms
# 31:	learn: 0.4873054	total: 122ms	remaining: 68.8ms
# 32:	learn: 0.4861592	total: 124ms	remaining: 63.9ms
# 33:	learn: 0.4853055	total: 126ms	remaining: 59.2ms
# 34:	learn: 0.4841869	total: 127ms	remaining: 54.6ms
# 35:	learn: 0.4832002	total: 129ms	remaining: 50.2ms
# 36:	learn: 0.4820998	total: 131ms	remaining: 46ms
# 37:	learn: 0.4792172	total: 133ms	remaining: 42ms
# 38:	learn: 0.4775572	total: 135ms	remaining: 38ms
# 39:	learn: 0.4758043	total: 137ms	remaining: 34.2ms
# 40:	learn: 0.4751187	total: 139ms	remaining: 30.5ms
# 41:	learn: 0.4743682	total: 143ms	remaining: 27.1ms
# 42:	learn: 0.4728594	total: 147ms	remaining: 23.9ms
# 43:	learn: 0.4716058	total: 155ms	remaining: 21.1ms
# 44:	learn: 0.4703504	total: 157ms	remaining: 17.4ms
# 45:	learn: 0.4690754	total: 160ms	remaining: 13.9ms
# 46:	learn: 0.4680558	total: 162ms	remaining: 10.3ms
# 47:	learn: 0.4673390	total: 164ms	remaining: 6.85ms
# 48:	learn: 0.4664287	total: 166ms	remaining: 3.4ms
# 49:	learn: 0.4657677	total: 176ms	remaining: 0us
# 0:	learn: 0.5971439	total: 1.9ms	remaining: 93.2ms
# 1:	learn: 0.5568703	total: 7.24ms	remaining: 174ms
# 2:	learn: 0.5310296	total: 9.33ms	remaining: 146ms
# 3:	learn: 0.5131288	total: 11ms	remaining: 126ms
# 4:	learn: 0.4966008	total: 13.3ms	remaining: 120ms
# 5:	learn: 0.4871995	total: 15.4ms	remaining: 113ms
# 6:	learn: 0.4821071	total: 20.9ms	remaining: 128ms
# 7:	learn: 0.4733008	total: 28.2ms	remaining: 148ms
# 8:	learn: 0.4674143	total: 32.8ms	remaining: 149ms
# 9:	learn: 0.4611105	total: 35.8ms	remaining: 143ms
# 10:	learn: 0.4583942	total: 37.9ms	remaining: 134ms
# 11:	learn: 0.4545455	total: 39.7ms	remaining: 126ms
# 12:	learn: 0.4483746	total: 41.6ms	remaining: 118ms
# 13:	learn: 0.4446531	total: 43.7ms	remaining: 112ms
# 14:	learn: 0.4425501	total: 45.7ms	remaining: 107ms
# 15:	learn: 0.4395976	total: 48.3ms	remaining: 103ms
# 16:	learn: 0.4369169	total: 50.2ms	remaining: 97.4ms
# 17:	learn: 0.4353818	total: 52.3ms	remaining: 92.9ms
# 18:	learn: 0.4332727	total: 54.8ms	remaining: 89.4ms
# 19:	learn: 0.4260346	total: 57.2ms	remaining: 85.8ms
# 20:	learn: 0.4244516	total: 59.6ms	remaining: 82.4ms
# 21:	learn: 0.4221159	total: 61.8ms	remaining: 78.7ms
# 22:	learn: 0.4206268	total: 64.2ms	remaining: 75.4ms
# 23:	learn: 0.4187960	total: 67.5ms	remaining: 73.1ms
# 24:	learn: 0.4177031	total: 70.6ms	remaining: 70.6ms
# 25:	learn: 0.4163961	total: 73.5ms	remaining: 67.9ms
# 26:	learn: 0.4148737	total: 78.3ms	remaining: 66.7ms
# 27:	learn: 0.4118088	total: 84.1ms	remaining: 66.1ms
# 28:	learn: 0.4107684	total: 87.6ms	remaining: 63.4ms
# 29:	learn: 0.4102759	total: 89.5ms	remaining: 59.6ms
# 30:	learn: 0.4086185	total: 91.4ms	remaining: 56ms
# 31:	learn: 0.4073839	total: 93.3ms	remaining: 52.5ms
# 32:	learn: 0.4063871	total: 100ms	remaining: 51.6ms
# 33:	learn: 0.4051989	total: 102ms	remaining: 48ms
# 34:	learn: 0.4035363	total: 111ms	remaining: 47.8ms
# 35:	learn: 0.4028243	total: 114ms	remaining: 44.2ms
# 36:	learn: 0.4023414	total: 116ms	remaining: 40.7ms
# 37:	learn: 0.4011231	total: 118ms	remaining: 37.4ms
# 38:	learn: 0.4003433	total: 121ms	remaining: 34ms
# 39:	learn: 0.3996482	total: 123ms	remaining: 30.7ms
# 40:	learn: 0.3987871	total: 125ms	remaining: 27.4ms
# 41:	learn: 0.3979442	total: 127ms	remaining: 24.1ms
# 42:	learn: 0.3970482	total: 129ms	remaining: 20.9ms
# 43:	learn: 0.3962305	total: 131ms	remaining: 17.8ms
# 44:	learn: 0.3955251	total: 133ms	remaining: 14.7ms
# 45:	learn: 0.3945554	total: 135ms	remaining: 11.7ms
# 46:	learn: 0.3906798	total: 137ms	remaining: 8.71ms
# 47:	learn: 0.3903610	total: 138ms	remaining: 5.76ms
# 48:	learn: 0.3898027	total: 140ms	remaining: 2.86ms
# 49:	learn: 0.3890729	total: 142ms	remaining: 0us
# 0:	learn: 0.6903745	total: 2ms	remaining: 199ms
# 1:	learn: 0.6870569	total: 3.9ms	remaining: 191ms
# 2:	learn: 0.6836826	total: 5.74ms	remaining: 186ms
# 3:	learn: 0.6803741	total: 7.52ms	remaining: 181ms
# 4:	learn: 0.6775979	total: 9.7ms	remaining: 184ms
# 5:	learn: 0.6751219	total: 11.6ms	remaining: 181ms
# 6:	learn: 0.6720733	total: 16.9ms	remaining: 224ms
# 7:	learn: 0.6696485	total: 19ms	remaining: 218ms
# 8:	learn: 0.6671651	total: 21.3ms	remaining: 215ms
# 9:	learn: 0.6647123	total: 23.3ms	remaining: 210ms
# 10:	learn: 0.6624224	total: 25.2ms	remaining: 204ms
# 11:	learn: 0.6598235	total: 27.2ms	remaining: 200ms
# 12:	learn: 0.6577169	total: 29ms	remaining: 194ms
# 13:	learn: 0.6555003	total: 30.7ms	remaining: 188ms
# 14:	learn: 0.6533642	total: 32.7ms	remaining: 185ms
# 15:	learn: 0.6506564	total: 34.6ms	remaining: 182ms
# 16:	learn: 0.6482660	total: 36.6ms	remaining: 179ms
# 17:	learn: 0.6457772	total: 38.5ms	remaining: 176ms
# 18:	learn: 0.6434312	total: 40.3ms	remaining: 172ms
# 19:	learn: 0.6410518	total: 42ms	remaining: 168ms
# 20:	learn: 0.6391406	total: 43.7ms	remaining: 164ms
# 21:	learn: 0.6371996	total: 45.6ms	remaining: 162ms
# 22:	learn: 0.6354814	total: 47.3ms	remaining: 158ms
# 23:	learn: 0.6338606	total: 49.8ms	remaining: 158ms
# 24:	learn: 0.6321019	total: 52ms	remaining: 156ms
# 25:	learn: 0.6302932	total: 53.9ms	remaining: 154ms
# 26:	learn: 0.6281577	total: 55.8ms	remaining: 151ms
# 27:	learn: 0.6264455	total: 58.3ms	remaining: 150ms
# 28:	learn: 0.6249241	total: 60ms	remaining: 147ms
# 29:	learn: 0.6233620	total: 61.8ms	remaining: 144ms
# 30:	learn: 0.6217713	total: 63.6ms	remaining: 142ms
# 31:	learn: 0.6200941	total: 65.5ms	remaining: 139ms
# 32:	learn: 0.6184335	total: 67.4ms	remaining: 137ms
# 33:	learn: 0.6168488	total: 69.3ms	remaining: 135ms
# 34:	learn: 0.6153377	total: 71ms	remaining: 132ms
# 35:	learn: 0.6139554	total: 73ms	remaining: 130ms
# 36:	learn: 0.6124974	total: 75.1ms	remaining: 128ms
# 37:	learn: 0.6110057	total: 77.1ms	remaining: 126ms
# 38:	learn: 0.6092590	total: 79.1ms	remaining: 124ms
# 39:	learn: 0.6079342	total: 80.8ms	remaining: 121ms
# 40:	learn: 0.6063177	total: 82.6ms	remaining: 119ms
# 41:	learn: 0.6046128	total: 84.8ms	remaining: 117ms
# 42:	learn: 0.6033607	total: 86.9ms	remaining: 115ms
# 43:	learn: 0.6020700	total: 89.1ms	remaining: 113ms
# 44:	learn: 0.6005127	total: 91.3ms	remaining: 112ms
# 45:	learn: 0.5992330	total: 93.4ms	remaining: 110ms
# ...
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504991 -> initscore=0.019963
# [LightGBM] [Info] Start training from score 0.019963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504736 -> initscore=0.018945
# [LightGBM] [Info] Start training from score 0.018945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2985, number of negative: 2926
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086982 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1955
# [LightGBM] [Info] Number of data points in the train set: 5911, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504991 -> initscore=0.019963
# [LightGBM] [Info] Start training from score 0.019963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2999, number of negative: 2912
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009524 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1948
# [LightGBM] [Info] Number of data points in the train set: 5911, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.507359 -> initscore=0.029439
# [LightGBM] [Info] Start training from score 0.029439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2963, number of negative: 2948
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.101914 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1951
# [LightGBM] [Info] Number of data points in the train set: 5911, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501269 -> initscore=0.005075
# [LightGBM] [Info] Start training from score 0.005075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
metrics.sort(key=lambda x: x[1], reverse=True)

print("\nSorted model metrics (by accuracy):")
for metric in metrics:
    print(f"Model: {metric[0]}, Accuracy: {metric[1]:.3f}, Precision: {metric[2]:.3f}, Recall: {metric[3]:.3f}")
# Out:
# Sorted model metrics (by accuracy):
# Model: xgboost, Accuracy: 0.797, Precision: 0.778, Recall: 0.825
# Model: gradientboost, Accuracy: 0.796, Precision: 0.781, Recall: 0.819
# Model: lightgbm, Accuracy: 0.794, Precision: 0.772, Recall: 0.830
# Model: catboost, Accuracy: 0.793, Precision: 0.770, Recall: 0.832
# Model: logistic, Accuracy: 0.767, Precision: 0.754, Recall: 0.787
# Model: adaboost, Accuracy: 0.764, Precision: 0.757, Recall: 0.771
# Model: randomforest, Accuracy: 0.761, Precision: 0.778, Recall: 0.725
# Model: knn, Accuracy: 0.759, Precision: 0.767, Recall: 0.739

# %% [markdown]
# # 9. Apply ensemble method on the test set

# %%
from sklearn.ensemble import VotingClassifier

top_models = [name for name, _, _, _ in metrics[:5]]

estimators = [(name, best_estimators[name]) for name in top_models]

ensemble_model = VotingClassifier(estimators=estimators, voting='soft', n_jobs=-1)

ensemble_model.fit(X, y)

test_df = test_df.drop("Transported",axis=1)
test_predictions = ensemble_model.predict(test_df)
test_predictions = test_predictions.astype(bool)
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 4378, number of negative: 4315
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001260 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1971
# [LightGBM] [Info] Number of data points in the train set: 8693, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503624 -> initscore=0.014495
# [LightGBM] [Info] Start training from score 0.014495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
submission = pd.DataFrame([test_data['PassengerId'], test_predictions]).T
submission.columns = ['PassengerID', 'Transported']

# %%
submission.head()
# Out:
#   PassengerID Transported
# 0     0013_01        True
# 1     0018_01       False
# 2     0019_01        True
# 3     0021_01        True
# 4     0023_01        True

# %%
submission.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0:	learn: 0.6539093	total: 6.27ms	remaining: 621ms
# 1:	learn: 0.6214871	total: 11.8ms	remaining: 576ms
# 2:	learn: 0.5958182	total: 17.1ms	remaining: 552ms
# 3:	learn: 0.5769927	total: 25.4ms	remaining: 609ms
# 4:	learn: 0.5603127	total: 28.2ms	remaining: 535ms
# 5:	learn: 0.5475352	total: 31.5ms	remaining: 493ms
# 6:	learn: 0.5369115	total: 42.9ms	remaining: 569ms
# 7:	learn: 0.5274569	total: 48.3ms	remaining: 556ms
# 8:	learn: 0.5142584	total: 54.4ms	remaining: 550ms
# 9:	learn: 0.5066246	total: 59.8ms	remaining: 539ms
# 10:	learn: 0.4998977	total: 63.3ms	remaining: 512ms
# 11:	learn: 0.4934856	total: 69.9ms	remaining: 513ms
# 12:	learn: 0.4880724	total: 75.3ms	remaining: 504ms
# 13:	learn: 0.4812216	total: 82.1ms	remaining: 504ms
# 14:	learn: 0.4765130	total: 85.4ms	remaining: 484ms
# 15:	learn: 0.4733106	total: 94.5ms	remaining: 496ms
# 16:	learn: 0.4696841	total: 100ms	remaining: 489ms
# 17:	learn: 0.4675567	total: 108ms	remaining: 493ms
# 18:	learn: 0.4640078	total: 112ms	remaining: 477ms
# 19:	learn: 0.4605127	total: 120ms	remaining: 480ms
# 20:	learn: 0.4573422	total: 123ms	remaining: 464ms
# 21:	learn: 0.4554371	total: 133ms	remaining: 470ms
# 22:	learn: 0.4535480	total: 141ms	remaining: 472ms
# 23:	learn: 0.4520670	total: 150ms	remaining: 475ms
# 24:	learn: 0.4503599	total: 157ms	remaining: 472ms
# 25:	learn: 0.4487258	total: 166ms	remaining: 473ms
# 26:	learn: 0.4478159	total: 175ms	remaining: 473ms
# 27:	learn: 0.4458434	total: 184ms	remaining: 473ms
# 28:	learn: 0.4437229	total: 191ms	remaining: 467ms
# 29:	learn: 0.4421388	total: 201ms	remaining: 469ms
# 30:	learn: 0.4404780	total: 208ms	remaining: 463ms
# 31:	learn: 0.4391877	total: 218ms	remaining: 463ms
# 32:	learn: 0.4377405	total: 229ms	remaining: 465ms
# 33:	learn: 0.4367870	total: 236ms	remaining: 458ms
# 34:	learn: 0.4351329	total: 245ms	remaining: 455ms
# 35:	learn: 0.4335734	total: 249ms	remaining: 442ms
# 36:	learn: 0.4329251	total: 261ms	remaining: 444ms
# 37:	learn: 0.4318411	total: 270ms	remaining: 440ms
# 38:	learn: 0.4307007	total: 278ms	remaining: 435ms
# 39:	learn: 0.4300635	total: 286ms	remaining: 430ms
# 40:	learn: 0.4293413	total: 295ms	remaining: 425ms
# 41:	learn: 0.4286915	total: 303ms	remaining: 418ms
# 42:	learn: 0.4268521	total: 315ms	remaining: 417ms
# 43:	learn: 0.4261193	total: 317ms	remaining: 404ms
# 44:	learn: 0.4252210	total: 335ms	remaining: 409ms
# 45:	learn: 0.4244280	total: 341ms	remaining: 400ms
# 46:	learn: 0.4238561	total: 351ms	remaining: 396ms
# 47:	learn: 0.4233907	total: 355ms	remaining: 384ms
# 48:	learn: 0.4222556	total: 358ms	remaining: 372ms
# 49:	learn: 0.4214716	total: 362ms	remaining: 362ms
# 50:	learn: 0.4206728	total: 365ms	remaining: 350ms
# 51:	learn: 0.4200618	total: 368ms	remaining: 339ms
# 52:	learn: 0.4195279	total: 371ms	remaining: 329ms
# 53:	learn: 0.4188558	total: 374ms	remaining: 319ms
# 54:	learn: 0.4181561	total: 377ms	remaining: 309ms
# 55:	learn: 0.4176112	total: 380ms	remaining: 299ms
# 56:	learn: 0.4170006	total: 383ms	remaining: 289ms
# 57:	learn: 0.4162197	total: 387ms	remaining: 280ms
# 58:	learn: 0.4157412	total: 390ms	remaining: 271ms
# 59:	learn: 0.4154465	total: 393ms	remaining: 262ms
# 60:	learn: 0.4150289	total: 396ms	remaining: 253ms
# 61:	learn: 0.4145466	total: 399ms	remaining: 244ms
# 62:	learn: 0.4141936	total: 402ms	remaining: 236ms
# 63:	learn: 0.4138097	total: 405ms	remaining: 228ms
# 64:	learn: 0.4126678	total: 409ms	remaining: 220ms
# 65:	learn: 0.4124211	total: 412ms	remaining: 212ms
# 66:	learn: 0.4112813	total: 415ms	remaining: 204ms
# 67:	learn: 0.4107206	total: 419ms	remaining: 197ms
# 68:	learn: 0.4102752	total: 422ms	remaining: 189ms
# 69:	learn: 0.4080143	total: 425ms	remaining: 182ms
# 70:	learn: 0.4077221	total: 428ms	remaining: 175ms
# 71:	learn: 0.4072170	total: 431ms	remaining: 168ms
# 72:	learn: 0.4068919	total: 435ms	remaining: 161ms
# 73:	learn: 0.4066256	total: 438ms	remaining: 154ms
# 74:	learn: 0.4061708	total: 442ms	remaining: 147ms
# 75:	learn: 0.4058591	total: 445ms	remaining: 140ms
# 76:	learn: 0.4053893	total: 448ms	remaining: 134ms
# 77:	learn: 0.4051033	total: 451ms	remaining: 127ms
# 78:	learn: 0.4049378	total: 454ms	remaining: 121ms
# 79:	learn: 0.4043489	total: 457ms	remaining: 114ms
# 80:	learn: 0.4038108	total: 460ms	remaining: 108ms
# 81:	learn: 0.4029469	total: 463ms	remaining: 102ms
# 82:	learn: 0.4025630	total: 466ms	remaining: 95.5ms
# 83:	learn: 0.4022403	total: 470ms	remaining: 89.5ms
# 84:	learn: 0.4019019	total: 473ms	remaining: 83.4ms
# 85:	learn: 0.4014932	total: 476ms	remaining: 77.4ms
# 86:	learn: 0.4011446	total: 478ms	remaining: 71.4ms
# 87:	learn: 0.4008075	total: 481ms	remaining: 65.7ms
# 88:	learn: 0.4005229	total: 485ms	remaining: 59.9ms
# 89:	learn: 0.3991470	total: 488ms	remaining: 54.2ms
# 90:	learn: 0.3986101	total: 490ms	remaining: 48.5ms
# 91:	learn: 0.3981379	total: 493ms	remaining: 42.9ms
# 92:	learn: 0.3976644	total: 496ms	remaining: 37.3ms
# 93:	learn: 0.3974171	total: 499ms	remaining: 31.8ms
# 94:	learn: 0.3970588	total: 502ms	remaining: 26.4ms
# 95:	learn: 0.3964772	total: 504ms	remaining: 21ms
# 96:	learn: 0.3960155	total: 507ms	remaining: 15.7ms
# 97:	learn: 0.3957430	total: 510ms	remaining: 10.4ms
# 98:	learn: 0.3952881	total: 513ms	remaining: 5.18ms
# 99:	learn: 0.3950277	total: 516ms	remaining: 0us
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
