# %% [markdown]
# <a href="https://www.kaggle.com/code/averilkan/spaceship-titanic-dataset-classification?scriptVersionId=221806399" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 💡 About The Competition: Spaceship Titanic
#
# Task:
# The objective of this task is to predict whether a passenger was transported to an alternate dimension aboard the Spaceship Titanic. This binary classification problem requires the model to predict the 'Transported' status (True or False) for each passenger in the test dataset, based on a variety of features provided.
#
# Dataset:
# The dataset for this competition includes information about passengers aboard the fictional spaceship Titanic. Features include demographic data, cabin information, and details about their in-ship expenditures. The target variable is Transported.
#
# Exploration:
# Begin with exploratory data analysis (EDA) to understand the distribution and relationships of features. Utilize visualization techniques to identify patterns and anomalies that could influence the predictive model's performance.
#
# Evaluation:
# Submissions are evaluated on the accuracy of the predictions. A higher accuracy score indicates a more effective model at classifying passengers' transportation status.
#
# Submission Files:
# train.csv - The training dataset, including the target variable Transported.
# test.csv - The test dataset, where predictions are to be made.
# sample_submission.csv - A sample submission file in the correct format.
# Evaluation Metric:
# The competition uses accuracy as the metric for evaluating submissions. This metric assesses the proportion of correctly predicted outcomes to total predictions.

# %% [markdown]
# # 1. Importing libraries

# %% [markdown]
# ## 💡 About The Packages:
#
# - **NumPy** and **Pandas** for data manipulation and analysis.
# - **Matplotlib** and **Seaborn** for data visualization.
# - **Warnings** to manage warning messages.
# - **lazypredict** for quick model comparison.
# - **Scikit-learn**, **XGBoost**, **LightGBM**, **CatBoost**, and other machine learning libraries for model building and evaluation.

# %%
# !pip install lazypredict

import io
import sys
import tensorflow as tf
import tensorflow_decision_forests as tfdf
import xgboost as xgb
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import category_encoders as ce

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score

from IPython.utils.io import capture_output

from hyperopt import hp, fmin, tpe, Trials

from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args

from contextlib import redirect_stdout, redirect_stderr
from IPython.utils.io import capture_output
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.13-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.1.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.4.0)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.2.0)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Downloading lazypredict-0.2.13-py2.py3-none-any.whl (12 kB)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.13
# 2025-02-10 14:06:20.416438: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 14:06:20.416565: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 14:06:20.795063: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # 2. Reading the Datasets
#
# We start by reading the training and test datasets using the Pandas library. The training dataset contains the target variable `Transported`, which indicates whether a passenger was transported to another dimension. We convert this column to an integer type for compatibility with machine learning algorithms.
#
# We then concatenate the train and test datasets for combined preprocessing and feature engineering. This helps to ensure consistency in data processing and avoid data leakage.

# %%
train_data = pd.read_csv("/kaggle/input/spaceship-titanic/train.csv")
train_data['Transported'] = train_data['Transported'].astype(int)
train_data.head()

test_data = pd.read_csv("/kaggle/input/spaceship-titanic/test.csv")
test_data.head()

train_data['Source'] = 'train'
test_data['Source'] = 'test'

df = pd.concat([train_data, test_data], axis=0)

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) involves summarizing and visualizing the main characteristics of the data. This step helps us understand the structure of the dataset, identify patterns, detect anomalies, and check assumptions.
#
# We create a summary function to give an overview of the dataset, including:
# - The number of unique values in each column.
# - The number of missing values in each column.
# - The data types of each column.
#
# This overview helps us identify any issues that need to be addressed during data preprocessing.

# %%
def summary(df):
    print(f"Dataset has {df.shape[1]} features and {df.shape[0]} examples.")
    summary = pd.DataFrame(index=df.columns)
    summary["Unique"] = df.nunique().values
    summary["Missing"] = df.isnull().sum().values
    summary["Duplicated"] = df.duplicated().sum()
    summary["Types"] = df.dtypes
    return summary

summary(df)
# Out:
# Dataset has 15 features and 12970 examples.
#               Unique  Missing  Duplicated    Types
# PassengerId    12970        0           0   object
# HomePlanet         3      288           0   object
# CryoSleep          2      310           0   object
# Cabin           9825      299           0   object
# Destination        3      274           0   object
# Age               80      270           0  float64
# VIP                2      296           0   object
# RoomService     1578      263           0  float64
# FoodCourt       1953      289           0  float64
# ShoppingMall    1367      306           0  float64
# Spa             1679      284           0  float64
# VRDeck          1642      268           0  float64
# Name           12629      294           0   object
# Transported        2     4277           0  float64
# Source             2        0           0   object

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ### 4.1 Extract Group Size from `PassengerId`
#
# A unique Id for each passenger takes the form `gggg_pp` where `gggg` indicates a group the passenger is travelling with and `pp` is their number within the group. People in a group are often family members, but not always. Extracting the group size can help us understand the potential impact of group travel on the likelihood of being transported.

# %%
group = df['PassengerId'].apply(lambda x: x.split('_')[0]).value_counts().to_dict()
df['Group_size'] = df['PassengerId'].apply(lambda x: group[x.split('_')[0]])
df.set_index('PassengerId', inplace=True)

# %% [markdown]
# ### 4.2 Handle Missing Values in `HomePlanet`
#
# The `HomePlanet` column indicates the planet the passenger is from. To fill missing values, we use a random selection based on the distribution of existing values in the column. This helps maintain the original distribution of `HomePlanet` in the dataset.

# %%
v = df['HomePlanet'].value_counts().index
p = df['HomePlanet'].value_counts(normalize=True).values
df.loc[df['HomePlanet'].isna(), 'HomePlanet'] = np.random.choice(v, df['HomePlanet'].isna().sum(), p=p)

# %% [markdown]
# ### 4.3 Handle Missing Values in CryoSleep
#
# The `CryoSleep` column indicates whether the passenger elected to be put into suspended animation for the duration of the voyage. Given that being in CryoSleep is a notable status that would likely be recorded, missing values are assumed to indicate passengers were not in CryoSleep. Thus, we fill missing values with 0 and convert this column to an integer type.

# %%
df['CryoSleep'] = df['CryoSleep'].fillna(0).astype(int)

# %% [markdown]
# ### 4.4 Extract Cabin Components and Handle Missing Values
#
# The `Cabin` column provides information about the passenger's cabin, including the deck, number, and side. We extract these components into separate columns and handle missing values by randomly assigning values based on the distribution of the existing data.

# %%
tmp = df['Cabin'].apply(lambda x: x.split('/') if isinstance(x, str) else ['-1', '-1', '-1']).to_list()
tmp = np.array(tmp)

df['Cabin_deck'] = tmp[:, 0]
df['Cabin_num'] = tmp[:, 1].astype(int)
df['Cabin_side'] = pd.Series(tmp[:, 2]).map({'S': 0, 'P': 1})

df.drop(columns='Cabin', inplace=True)

df.loc[df['Cabin_deck'] == '-1', 'Cabin_deck'] = np.random.choice(['F', 'G'], sum(df['Cabin_deck'] == '-1'), p=[0.5, 0.5])
df.loc[df['Cabin_side'].isna(), 'Cabin_side'] = np.random.choice([0, 1], sum(df['Cabin_side'].isna()), p=[0.5, 0.5])

# %% [markdown]
# ### 4.5 Handle Missing Values in `Destination`
#
# The `Destination` column indicates the destination of the passenger. We fill missing values by randomly assigning values based on the distribution of the existing data. This maintains the original distribution of `Destination` in the dataset.

# %%
v = df['Destination'].value_counts().index
p = df['Destination'].value_counts(normalize=True).values
df.loc[df['Destination'].isna(), 'Destination'] = np.random.choice(v, df['Destination'].isna().sum(), p=p)

# %% [markdown]
# ### 4.6 Handle Missing Values in `Age`
#
# The `Age` column indicates the age of the passenger. To fill missing values, we use a random sample from a normal distribution with the mean and standard deviation of the existing ages. This helps maintain the original distribution of `Age` in the dataset.

# %%
mean_age = df["Age"].mean()
std_age = df["Age"].std()
is_null = df["Age"].isnull().sum()
rand_sample = np.random.uniform(mean_age - std_age, mean_age + std_age, size = is_null)
df.loc[df['Age'].isna(), 'Age'] = rand_sample

# %% [markdown]
# ### 4.7 Handle Missing Values in `VIP`
#
# The `VIP` column indicates whether the passenger paid for special VIP service during the voyage. We fill missing values with `False` (0), assuming that most passengers did not opt for VIP service. We then convert this column to an integer type.

# %%
df['VIP'] = df['VIP'].fillna(0).astype(int)

# %% [markdown]
# ### 4.8 Handle Missing Values in Spending Columns
#
# The columns `RoomService`, `FoodCourt`, `ShoppingMall`, `Spa`, and `VRDeck` represent the amount of money spent by the passenger on various amenities. We fill missing values with the median value of each column. This helps maintain the original distribution of spending in the dataset.

# %%
cols = ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']

for col in cols:
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# ### 4.9 Create Total Spending Feature
#
# We create a new feature `total_spending` by summing the values of the spending columns. This feature represents the total amount of money spent by the passenger on various amenities during the voyage. We then apply a logarithmic transformation to normalize the spending data, making it easier for the model to learn from.

# %%
df['total_spending'] = df['RoomService'] + df['FoodCourt'] + df['ShoppingMall'] + df['Spa'] + df['VRDeck']

for col in cols + ['total_spending']:
    df.loc[df[col]==0, col] = 0.367
    df[col] = np.log(df[col])

# %% [markdown]
# ### 4.10 Drop the Name column as it does not contain valuable information

# %%
df.drop(columns='Name', inplace=True)

# %% [markdown]
# # 5. One-Hot Encoding for Categorical Features
#
# One-hot encoding is a technique to convert categorical variables into numerical format. This step is crucial for machine learning algorithms, as they require numerical input.
#
# We apply one-hot encoding to the categorical features `HomePlanet`, `Destination`, and `Cabin_deck`. This creates new binary columns for each category, allowing the model to understand and use the categorical data effectively.

# %%
categorical_features = ['HomePlanet', 'Destination', 'Cabin_deck']
df = pd.concat([df, pd.get_dummies(df[categorical_features], dtype=int)], axis=1)
df.drop(columns=categorical_features, inplace=True)

# %% [markdown]
# # 6. Splitting Data back to Train and Test Sets
#
# After preprocessing and feature engineering, we split the combined dataset back into the original training and test sets. This ensures that we maintain the original structure of the data, with the training set used to train the model and the test set used to evaluate its performance.
#
# We also separate the target variable `Transported` from the training data, as this is what we aim to predict.

# %%
train_df = df[df['Source'] == 'train'].drop(columns=['Source'])
test_df = df[df['Source'] == 'test'].drop(columns=['Source'])

X = train_df.drop(columns=['Transported'])
y = train_df['Transported']

train_df.head()
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8693 entries, 0001_01 to 9280_02
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CryoSleep                  8693 non-null   int64
#  1   Age                        8693 non-null   float64
#  2   VIP                        8693 non-null   int64
#  3   RoomService                8693 non-null   float64
#  4   FoodCourt                  8693 non-null   float64
#  5   ShoppingMall               8693 non-null   float64
#  6   Spa                        8693 non-null   float64
#  7   VRDeck                     8693 non-null   float64
#  8   Transported                8693 non-null   float64
#  9   Group_size                 8693 non-null   int64
#  10  Cabin_num                  8693 non-null   int64
#  11  Cabin_side                 8693 non-null   float64
#  12  total_spending             8693 non-null   float64
#  13  HomePlanet_Earth           8693 non-null   int64
#  14  HomePlanet_Europa          8693 non-null   int64
#  15  HomePlanet_Mars            8693 non-null   int64
#  16  Destination_55 Cancri e    8693 non-null   int64
#  17  Destination_PSO J318.5-22  8693 non-null   int64
#  18  Destination_TRAPPIST-1e    8693 non-null   int64
#  19  Cabin_deck_A               8693 non-null   int64
#  20  Cabin_deck_B               8693 non-null   int64
#  21  Cabin_deck_C               8693 non-null   int64
#  22  Cabin_deck_D               8693 non-null   int64
#  23  Cabin_deck_E               8693 non-null   int64
#  24  Cabin_deck_F               8693 non-null   int64
#  25  Cabin_deck_G               8693 non-null   int64
#  26  Cabin_deck_T               8693 non-null   int64
# dtypes: float64(9), int64(18)
# memory usage: 1.9+ MB

# %% [markdown]
# # 7. Initial Model Comparison with LazyPredict
#
# We will use the LazyPredict library to quickly compare the performance of different machine learning models. LazyPredict provides an easy-to-use interface to fit multiple models and get a quick overview of their performance.

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

X = train_df.drop('Transported', axis=1)
y = train_df['Transported'].astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 29/29 [00:18<00:00,  1.53it/s]
# [LightGBM] [Info] Number of positive: 3731, number of negative: 3658
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005584 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1963
# [LightGBM] [Info] Number of data points in the train set: 7389, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504940 -> initscore=0.019760
# [LightGBM] [Info] Start training from score 0.019760
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.80               0.80     0.80      0.80
# XGBClassifier                      0.79               0.79     0.79      0.79
# SVC                                0.78               0.78     0.78      0.78
# RandomForestClassifier             0.78               0.78     0.78      0.78
# AdaBoostClassifier                 0.78               0.78     0.78      0.78
# NuSVC                              0.77               0.77     0.77      0.77
# ExtraTreesClassifier               0.77               0.77     0.77      0.77
# BaggingClassifier                  0.77               0.77     0.77      0.77
# LogisticRegression                 0.77               0.77     0.77      0.77
# LinearSVC                          0.77               0.77     0.77      0.77
# CalibratedClassifierCV             0.77               0.77     0.77      0.77
# RidgeClassifier                    0.76               0.76     0.76      0.76
# RidgeClassifierCV                  0.76               0.76     0.76      0.76
# LinearDiscriminantAnalysis         0.76               0.76     0.76      0.76
# SGDClassifier                      0.76               0.76     0.76      0.76
# QuadraticDiscriminantAnalysis      0.75               0.75     0.75      0.75
# GaussianNB                         0.75               0.75     0.75      0.75
# DecisionTreeClassifier             0.74               0.74     0.74      0.74
# KNeighborsClassifier               0.74               0.74     0.74      0.74
# NearestCentroid                    0.74               0.74     0.74      0.74
# BernoulliNB                        0.74               0.73     0.73      0.73
# LabelPropagation                   0.72               0.72     0.72      0.72
# LabelSpreading                     0.72               0.72     0.72      0.72
# ExtraTreeClassifier                0.70               0.70     0.70      0.70
# PassiveAggressiveClassifier        0.67               0.67     0.67      0.67
# Perceptron                         0.55               0.55     0.55      0.55
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       0.24
# XGBClassifier                        0.32
# SVC                                  2.27
# RandomForestClassifier               0.96
# AdaBoostClassifier                   0.36
# NuSVC                                2.95
# ExtraTreesClassifier                 0.74
# BaggingClassifier                    0.34
# LogisticRegression                   0.07
# LinearSVC                            0.92
# CalibratedClassifierCV               3.54
# RidgeClassifier                      0.05
# RidgeClassifierCV                    0.05
# LinearDiscriminantAnalysis           0.10
# SGDClassifier                        0.16
# QuadraticDiscriminantAnalysis        0.07
# GaussianNB                           0.03
# DecisionTreeClassifier               0.11
# KNeighborsClassifier                 0.11
# NearestCentroid                      0.03
# BernoulliNB                          0.03
# LabelPropagation                     2.21
# LabelSpreading                       3.13
# ExtraTreeClassifier                  0.02
# PassiveAggressiveClassifier          0.04
# Perceptron                           0.04
# DummyClassifier                      0.02

# %% [markdown]
# # 8. Detailed Modeling with Pipelines and GridSearchCV
#
# For a more detailed evaluation and fine-tuning, we will use several classifiers with pipelines and GridSearchCV. We will use k-fold cross-validation to ensure a robust estimation of model performance.
#
# We will perform the following steps:
#
# 1. Set up the models and pipelines.
# 2. Define the hyperparameter grids for each model.
# 3. Use GridSearchCV with k-fold cross-validation to find the best parameters for each model.
# 4. Evaluate the performance of the best models on the test set.

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import accuracy_score

pipelines = {
    'adaboost': make_pipeline(StandardScaler(), AdaBoostClassifier(random_state=123)),
    'xgboost': make_pipeline(StandardScaler(), XGBClassifier(random_state=123)),
    'catboost': make_pipeline(StandardScaler(), CatBoostClassifier(random_state=123)),
    'gradientboost': make_pipeline(StandardScaler(), GradientBoostingClassifier(random_state=123)),
    'lightgbm': make_pipeline(StandardScaler(), LGBMClassifier(random_state=123)),
    'randomforest': make_pipeline(StandardScaler(), RandomForestClassifier(random_state=123)),
    'logistic': make_pipeline(StandardScaler(), LogisticRegression(random_state=123)),
    'knn': make_pipeline(StandardScaler(), KNeighborsClassifier())
}

grid = {
    'adaboost': {
        'adaboostclassifier__n_estimators': [50, 100, 150],
        'adaboostclassifier__learning_rate': [0.01, 0.05, 0.1]
    },
    'xgboost': {
        'xgbclassifier__n_estimators': [50, 100, 150],
        'xgbclassifier__learning_rate': [0.01, 0.05],
        'xgbclassifier__max_depth': [3, 4],
        'xgbclassifier__gamma': [0.1, 0.2],
        'xgbclassifier__subsample': [0.6, 0.8]
    },
    'catboost': {
        'catboostclassifier__learning_rate': [0.01, 0.05, 0.1, 0.5],
        'catboostclassifier__depth': [2, 3, 4], 
        'catboostclassifier__iterations': [50, 100, 150]
    },
    'gradientboost': {
        'gradientboostingclassifier__n_estimators': [50, 100, 150],
        'gradientboostingclassifier__learning_rate': [0.01, 0.05],
        'gradientboostingclassifier__max_depth': [3, 4],
        'gradientboostingclassifier__subsample': [0.6, 0.8]
    },
    'lightgbm': {
        'lgbmclassifier__n_estimators': [50, 100, 150],
        'lgbmclassifier__learning_rate': [0.01, 0.05],
        'lgbmclassifier__max_depth': [3, 4],
        'lgbmclassifier__subsample': [0.6, 0.8]
    },
    'randomforest': {
        'randomforestclassifier__n_estimators': [50, 100, 150],
        'randomforestclassifier__max_depth': [3, 4, 5],
        'randomforestclassifier__min_samples_split': [2, 3, 4]
    },
    'logistic': {
        'logisticregression__C': [0.01, 0.1, 1, 10]
    },
    'knn': {
        'kneighborsclassifier__n_neighbors': [3, 5, 7],
        'kneighborsclassifier__weights': ['uniform', 'distance'],
        'kneighborsclassifier__metric': ['euclidean', 'manhattan']
    }
}

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

best_estimators = {}
kf = KFold(n_splits=5, shuffle=True, random_state=42)

metrics = []

f = io.StringIO()
e = io.StringIO()

with redirect_stdout(f), redirect_stderr(e):  # suppress outputs
    with capture_output():
        for name, pipeline in pipelines.items():
            grid_search = GridSearchCV(pipeline, grid[name], cv=kf, n_jobs=-1, verbose=0)
            grid_search.fit(X_train, y_train)
            best_estimators[name] = grid_search.best_estimator_
            yhat = grid_search.predict(X_test)
            accuracy = accuracy_score(y_test, yhat)
            precision = precision_score(y_test, yhat)
            recall = recall_score(y_test, yhat)
            metrics.append((name, accuracy, precision, recall))
            print(f'Metrics for {name}: accuracy- {accuracy:.3f}, precision- {precision:.3f}, recall- {recall:.3f}')
            print(f"Best parameters for {name}: {grid_search.best_params_}")
# Out:
# 0:	learn: 0.6905940	total: 59.9ms	remaining: 2.94s
# 1:	learn: 0.6876475	total: 62.1ms	remaining: 1.49s
# 2:	learn: 0.6842125	total: 68.3ms	remaining: 1.07s
# 3:	learn: 0.6809990	total: 76.3ms	remaining: 877ms
# 4:	learn: 0.6783445	total: 78.6ms	remaining: 707ms
# 5:	learn: 0.6759075	total: 87.2ms	remaining: 639ms
# 6:	learn: 0.6727219	total: 94ms	remaining: 578ms
# 7:	learn: 0.6705179	total: 96.9ms	remaining: 509ms
# 8:	learn: 0.6676099	total: 104ms	remaining: 472ms
# 9:	learn: 0.6646919	total: 110ms	remaining: 440ms
# 10:	learn: 0.6624350	total: 117ms	remaining: 415ms
# 11:	learn: 0.6596734	total: 125ms	remaining: 396ms
# 12:	learn: 0.6569783	total: 127ms	remaining: 362ms
# 13:	learn: 0.6550299	total: 133ms	remaining: 343ms
# 14:	learn: 0.6529287	total: 140ms	remaining: 327ms
# 15:	learn: 0.6503793	total: 144ms	remaining: 305ms
# 16:	learn: 0.6483618	total: 150ms	remaining: 291ms
# 17:	learn: 0.6459235	total: 157ms	remaining: 279ms
# 18:	learn: 0.6434593	total: 164ms	remaining: 268ms
# 19:	learn: 0.6412568	total: 172ms	remaining: 258ms
# 20:	learn: 0.6393708	total: 179ms	remaining: 247ms
# 21:	learn: 0.6374817	total: 185ms	remaining: 236ms
# 22:	learn: 0.6358944	total: 188ms	remaining: 221ms
# 23:	learn: 0.6342587	total: 195ms	remaining: 211ms
# 24:	learn: 0.6324462	total: 200ms	remaining: 200ms
# 25:	learn: 0.6306468	total: 209ms	remaining: 192ms
# 26:	learn: 0.6285822	total: 211ms	remaining: 179ms
# 27:	learn: 0.6269544	total: 213ms	remaining: 167ms
# 28:	learn: 0.6249156	total: 226ms	remaining: 164ms
# 29:	learn: 0.6231917	total: 233ms	remaining: 155ms
# 30:	learn: 0.6210200	total: 240ms	remaining: 147ms
# 31:	learn: 0.6194855	total: 242ms	remaining: 136ms
# 32:	learn: 0.6181803	total: 250ms	remaining: 129ms
# 33:	learn: 0.6162660	total: 257ms	remaining: 121ms
# 34:	learn: 0.6149214	total: 266ms	remaining: 114ms
# 35:	learn: 0.6136847	total: 272ms	remaining: 106ms
# 36:	learn: 0.6119682	total: 279ms	remaining: 98ms
# 37:	learn: 0.6106273	total: 286ms	remaining: 90.3ms
# 38:	learn: 0.6093476	total: 289ms	remaining: 81.6ms
# 39:	learn: 0.6077319	total: 291ms	remaining: 72.8ms
# 40:	learn: 0.6061837	total: 293ms	remaining: 64.4ms
# 41:	learn: 0.6049152	total: 296ms	remaining: 56.3ms
# 42:	learn: 0.6036324	total: 298ms	remaining: 48.5ms
# 43:	learn: 0.6024906	total: 301ms	remaining: 41ms
# 44:	learn: 0.6012316	total: 323ms	remaining: 35.9ms
# 45:	learn: 0.6000973	total: 326ms	remaining: 28.3ms
# 46:	learn: 0.5985265	total: 334ms	remaining: 21.3ms
# 47:	learn: 0.5973915	total: 342ms	remaining: 14.3ms
# 48:	learn: 0.5961959	total: 349ms	remaining: 7.12ms
# 49:	learn: 0.5951699	total: 357ms	remaining: 0us
# 0:	learn: 0.6905447	total: 2.4ms	remaining: 118ms
# 1:	learn: 0.6876640	total: 4.14ms	remaining: 99.4ms
# 2:	learn: 0.6841756	total: 6.09ms	remaining: 95.5ms
# 3:	learn: 0.6816777	total: 14.4ms	remaining: 166ms
# 4:	learn: 0.6785618	total: 16.2ms	remaining: 146ms
# 5:	learn: 0.6759786	total: 19.7ms	remaining: 144ms
# 6:	learn: 0.6729775	total: 24ms	remaining: 147ms
# 7:	learn: 0.6698321	total: 26.5ms	remaining: 139ms
# 8:	learn: 0.6675874	total: 29.3ms	remaining: 133ms
# 9:	learn: 0.6650855	total: 31.6ms	remaining: 126ms
# 10:	learn: 0.6627298	total: 33.5ms	remaining: 119ms
# 11:	learn: 0.6603881	total: 35.5ms	remaining: 112ms
# 12:	learn: 0.6581559	total: 37.6ms	remaining: 107ms
# 13:	learn: 0.6559698	total: 39.5ms	remaining: 102ms
# 14:	learn: 0.6537832	total: 41.4ms	remaining: 96.5ms
# 15:	learn: 0.6512485	total: 43.2ms	remaining: 91.8ms
# 16:	learn: 0.6486197	total: 45.2ms	remaining: 87.7ms
# 17:	learn: 0.6466134	total: 46.9ms	remaining: 83.4ms
# 18:	learn: 0.6441437	total: 48.8ms	remaining: 79.6ms
# 19:	learn: 0.6417157	total: 50.6ms	remaining: 75.8ms
# 20:	learn: 0.6397723	total: 52.8ms	remaining: 72.9ms
# 21:	learn: 0.6373695	total: 54.6ms	remaining: 69.5ms
# 22:	learn: 0.6354620	total: 56.1ms	remaining: 65.9ms
# 23:	learn: 0.6332765	total: 58.2ms	remaining: 63.1ms
# 24:	learn: 0.6315148	total: 60.3ms	remaining: 60.3ms
# 25:	learn: 0.6298656	total: 62.1ms	remaining: 57.4ms
# 26:	learn: 0.6276264	total: 64.1ms	remaining: 54.6ms
# 27:	learn: 0.6259873	total: 66ms	remaining: 51.8ms
# 28:	learn: 0.6243806	total: 67.9ms	remaining: 49.2ms
# 29:	learn: 0.6227371	total: 69.8ms	remaining: 46.5ms
# 30:	learn: 0.6211060	total: 71.6ms	remaining: 43.9ms
# 31:	learn: 0.6194585	total: 73.6ms	remaining: 41.4ms
# 32:	learn: 0.6176806	total: 75.7ms	remaining: 39ms
# 33:	learn: 0.6157269	total: 77.6ms	remaining: 36.5ms
# 34:	learn: 0.6138933	total: 79.3ms	remaining: 34ms
# 35:	learn: 0.6121880	total: 81.1ms	remaining: 31.5ms
# 36:	learn: 0.6107256	total: 83.3ms	remaining: 29.3ms
# 37:	learn: 0.6092352	total: 85.7ms	remaining: 27ms
# 38:	learn: 0.6079557	total: 87.6ms	remaining: 24.7ms
# 39:	learn: 0.6066867	total: 89.5ms	remaining: 22.4ms
# 40:	learn: 0.6052912	total: 91.5ms	remaining: 20.1ms
# 41:	learn: 0.6039745	total: 93.8ms	remaining: 17.9ms
# 42:	learn: 0.6027269	total: 95.8ms	remaining: 15.6ms
# 43:	learn: 0.6014913	total: 98.1ms	remaining: 13.4ms
# 44:	learn: 0.5999736	total: 99.9ms	remaining: 11.1ms
# 45:	learn: 0.5987778	total: 102ms	remaining: 8.84ms
# 46:	learn: 0.5975586	total: 103ms	remaining: 6.6ms
# 47:	learn: 0.5964359	total: 106ms	remaining: 4.41ms
# 48:	learn: 0.5953134	total: 108ms	remaining: 2.19ms
# 49:	learn: 0.5938404	total: 109ms	remaining: 0us
# 0:	learn: 0.6806626	total: 4.07ms	remaining: 199ms
# 1:	learn: 0.6670718	total: 6.01ms	remaining: 144ms
# 2:	learn: 0.6523997	total: 7.93ms	remaining: 124ms
# 3:	learn: 0.6426106	total: 15.5ms	remaining: 178ms
# 4:	learn: 0.6337545	total: 18.2ms	remaining: 164ms
# 5:	learn: 0.6255206	total: 21.8ms	remaining: 160ms
# 6:	learn: 0.6177390	total: 24.4ms	remaining: 150ms
# 7:	learn: 0.6083245	total: 26.3ms	remaining: 138ms
# 8:	learn: 0.6005959	total: 28.6ms	remaining: 130ms
# 9:	learn: 0.5952990	total: 30.3ms	remaining: 121ms
# 10:	learn: 0.5901476	total: 32.3ms	remaining: 114ms
# 11:	learn: 0.5851879	total: 34.2ms	remaining: 108ms
# 12:	learn: 0.5805284	total: 36.1ms	remaining: 103ms
# 13:	learn: 0.5760735	total: 38.4ms	remaining: 98.8ms
# 14:	learn: 0.5724913	total: 40.2ms	remaining: 93.9ms
# 15:	learn: 0.5675670	total: 42.1ms	remaining: 89.4ms
# 16:	learn: 0.5633308	total: 43.8ms	remaining: 85.1ms
# 17:	learn: 0.5594952	total: 49.6ms	remaining: 88.2ms
# 18:	learn: 0.5566938	total: 51.5ms	remaining: 84.1ms
# 19:	learn: 0.5529792	total: 53.4ms	remaining: 80.1ms
# 20:	learn: 0.5500345	total: 55.6ms	remaining: 76.8ms
# 21:	learn: 0.5465204	total: 57.6ms	remaining: 73.3ms
# 22:	learn: 0.5434685	total: 59.6ms	remaining: 70ms
# 23:	learn: 0.5409180	total: 63.4ms	remaining: 68.7ms
# 24:	learn: 0.5383505	total: 67.6ms	remaining: 67.6ms
# 25:	learn: 0.5356782	total: 74ms	remaining: 68.3ms
# 26:	learn: 0.5331028	total: 85.6ms	remaining: 72.9ms
# 27:	learn: 0.5312389	total: 90.4ms	remaining: 71ms
# 28:	learn: 0.5293210	total: 96.6ms	remaining: 69.9ms
# 29:	learn: 0.5274986	total: 98.7ms	remaining: 65.8ms
# 30:	learn: 0.5255486	total: 101ms	remaining: 61.7ms
# 31:	learn: 0.5235596	total: 106ms	remaining: 59.5ms
# 32:	learn: 0.5217685	total: 111ms	remaining: 57.4ms
# 33:	learn: 0.5204444	total: 113ms	remaining: 53.4ms
# 34:	learn: 0.5189405	total: 119ms	remaining: 50.9ms
# 35:	learn: 0.5173800	total: 124ms	remaining: 48.2ms
# 36:	learn: 0.5156836	total: 128ms	remaining: 45ms
# 37:	learn: 0.5142384	total: 137ms	remaining: 43.1ms
# 38:	learn: 0.5128341	total: 139ms	remaining: 39.3ms
# 39:	learn: 0.5113113	total: 142ms	remaining: 35.4ms
# 40:	learn: 0.5099702	total: 146ms	remaining: 32ms
# 41:	learn: 0.5089079	total: 155ms	remaining: 29.6ms
# 42:	learn: 0.5074878	total: 161ms	remaining: 26.2ms
# 43:	learn: 0.5058336	total: 167ms	remaining: 22.7ms
# 44:	learn: 0.5043278	total: 174ms	remaining: 19.3ms
# 45:	learn: 0.5033238	total: 181ms	remaining: 15.8ms
# 46:	learn: 0.5024220	total: 186ms	remaining: 11.8ms
# 47:	learn: 0.5015121	total: 190ms	remaining: 7.92ms
# 48:	learn: 0.5006214	total: 199ms	remaining: 4.07ms
# 49:	learn: 0.4991260	total: 201ms	remaining: 0us
# 0:	learn: 0.6679460	total: 1.87ms	remaining: 91.4ms
# 1:	learn: 0.6449716	total: 3.56ms	remaining: 85.3ms
# 2:	learn: 0.6196540	total: 5.43ms	remaining: 85.2ms
# 3:	learn: 0.6068133	total: 7.23ms	remaining: 83.2ms
# 4:	learn: 0.5904349	total: 9.47ms	remaining: 85.2ms
# 5:	learn: 0.5796911	total: 11.2ms	remaining: 82.3ms
# 6:	learn: 0.5706967	total: 13.3ms	remaining: 82ms
# 7:	learn: 0.5614629	total: 15.5ms	remaining: 81.2ms
# 0:	learn: 0.6903281	total: 59.9ms	remaining: 2.94s
# 1:	learn: 0.6874752	total: 62ms	remaining: 1.49s
# 2:	learn: 0.6840554	total: 69.7ms	remaining: 1.09s
# 3:	learn: 0.6808526	total: 71.8ms	remaining: 825ms
# 4:	learn: 0.6784091	total: 79.3ms	remaining: 714ms
# 5:	learn: 0.6759988	total: 87.3ms	remaining: 640ms
# 6:	learn: 0.6727929	total: 94.6ms	remaining: 581ms
# 7:	learn: 0.6705376	total: 98ms	remaining: 515ms
# 8:	learn: 0.6676093	total: 109ms	remaining: 497ms
# 9:	learn: 0.6652232	total: 111ms	remaining: 445ms
# 10:	learn: 0.6623857	total: 119ms	remaining: 422ms
# 11:	learn: 0.6600796	total: 125ms	remaining: 397ms
# 12:	learn: 0.6573513	total: 132ms	remaining: 376ms
# 13:	learn: 0.6551961	total: 134ms	remaining: 345ms
# 14:	learn: 0.6531626	total: 142ms	remaining: 330ms
# 15:	learn: 0.6506733	total: 148ms	remaining: 316ms
# 16:	learn: 0.6485767	total: 156ms	remaining: 302ms
# 17:	learn: 0.6460681	total: 158ms	remaining: 280ms
# 18:	learn: 0.6433833	total: 165ms	remaining: 270ms
# 19:	learn: 0.6415081	total: 168ms	remaining: 251ms
# 20:	learn: 0.6391911	total: 179ms	remaining: 247ms
# 21:	learn: 0.6372921	total: 184ms	remaining: 235ms
# 22:	learn: 0.6349871	total: 192ms	remaining: 225ms
# 23:	learn: 0.6331583	total: 194ms	remaining: 210ms
# 24:	learn: 0.6309110	total: 202ms	remaining: 202ms
# 25:	learn: 0.6290385	total: 209ms	remaining: 193ms
# 26:	learn: 0.6273256	total: 216ms	remaining: 184ms
# 27:	learn: 0.6255558	total: 223ms	remaining: 175ms
# 28:	learn: 0.6238388	total: 230ms	remaining: 166ms
# 29:	learn: 0.6221716	total: 237ms	remaining: 158ms
# 30:	learn: 0.6206146	total: 243ms	remaining: 149ms
# 31:	learn: 0.6189782	total: 245ms	remaining: 138ms
# 32:	learn: 0.6171159	total: 252ms	remaining: 130ms
# 33:	learn: 0.6155618	total: 258ms	remaining: 121ms
# 34:	learn: 0.6140411	total: 266ms	remaining: 114ms
# 35:	learn: 0.6126106	total: 273ms	remaining: 106ms
# 36:	learn: 0.6113244	total: 275ms	remaining: 96.6ms
# 37:	learn: 0.6099310	total: 282ms	remaining: 89ms
# 38:	learn: 0.6081604	total: 289ms	remaining: 81.6ms
# 39:	learn: 0.6068484	total: 296ms	remaining: 74.1ms
# 40:	learn: 0.6055810	total: 299ms	remaining: 65.6ms
# 41:	learn: 0.6042053	total: 306ms	remaining: 58.3ms
# 42:	learn: 0.6028513	total: 313ms	remaining: 51ms
# 43:	learn: 0.6016579	total: 321ms	remaining: 43.8ms
# 44:	learn: 0.6003566	total: 328ms	remaining: 36.5ms
# 45:	learn: 0.5987763	total: 331ms	remaining: 28.8ms
# 46:	learn: 0.5975075	total: 341ms	remaining: 21.8ms
# 47:	learn: 0.5958134	total: 343ms	remaining: 14.3ms
# 48:	learn: 0.5946262	total: 350ms	remaining: 7.14ms
# 49:	learn: 0.5934530	total: 357ms	remaining: 0us
# 0:	learn: 0.6795752	total: 3.88ms	remaining: 190ms
# 1:	learn: 0.6643333	total: 7.5ms	remaining: 180ms
# 2:	learn: 0.6529305	total: 12ms	remaining: 188ms
# 3:	learn: 0.6425342	total: 21.4ms	remaining: 246ms
# 4:	learn: 0.6303716	total: 23.3ms	remaining: 210ms
# 5:	learn: 0.6217346	total: 24.9ms	remaining: 183ms
# 6:	learn: 0.6140578	total: 33.4ms	remaining: 205ms
# 7:	learn: 0.6069646	total: 35.4ms	remaining: 186ms
# 8:	learn: 0.5987857	total: 45.2ms	remaining: 206ms
# 9:	learn: 0.5928846	total: 57.4ms	remaining: 229ms
# 10:	learn: 0.5871391	total: 59.2ms	remaining: 210ms
# 11:	learn: 0.5821958	total: 64.1ms	remaining: 203ms
# 12:	learn: 0.5761435	total: 66.2ms	remaining: 188ms
# 13:	learn: 0.5706493	total: 67.8ms	remaining: 174ms
# 14:	learn: 0.5664852	total: 76.6ms	remaining: 179ms
# 15:	learn: 0.5618725	total: 84.7ms	remaining: 180ms
# 16:	learn: 0.5583183	total: 88.4ms	remaining: 172ms
# 17:	learn: 0.5544652	total: 93ms	remaining: 165ms
# 18:	learn: 0.5513508	total: 96.5ms	remaining: 158ms
# 19:	learn: 0.5479839	total: 98.3ms	remaining: 147ms
# 20:	learn: 0.5443297	total: 101ms	remaining: 139ms
# 21:	learn: 0.5412813	total: 103ms	remaining: 131ms
# 22:	learn: 0.5382091	total: 104ms	remaining: 123ms
# 23:	learn: 0.5357016	total: 107ms	remaining: 115ms
# 24:	learn: 0.5329873	total: 108ms	remaining: 108ms
# 25:	learn: 0.5308249	total: 110ms	remaining: 101ms
# 26:	learn: 0.5284938	total: 112ms	remaining: 95.2ms
# 27:	learn: 0.5263146	total: 113ms	remaining: 89.2ms
# 28:	learn: 0.5238026	total: 116ms	remaining: 83.9ms
# 29:	learn: 0.5222398	total: 118ms	remaining: 78.6ms
# 30:	learn: 0.5204042	total: 120ms	remaining: 73.8ms
# 31:	learn: 0.5190713	total: 124ms	remaining: 69.9ms
# 32:	learn: 0.5171663	total: 126ms	remaining: 64.9ms
# 33:	learn: 0.5154892	total: 128ms	remaining: 60.4ms
# 34:	learn: 0.5140332	total: 131ms	remaining: 56ms
# 35:	learn: 0.5123135	total: 132ms	remaining: 51.5ms
# 36:	learn: 0.5111216	total: 134ms	remaining: 47.2ms
# 37:	learn: 0.5091722	total: 136ms	remaining: 43ms
# 38:	learn: 0.5079305	total: 138ms	remaining: 38.9ms
# 39:	learn: 0.5063686	total: 140ms	remaining: 34.9ms
# 40:	learn: 0.5045343	total: 141ms	remaining: 31ms
# 41:	learn: 0.5030318	total: 143ms	remaining: 27.3ms
# 42:	learn: 0.5016533	total: 145ms	remaining: 23.7ms
# 43:	learn: 0.5002426	total: 147ms	remaining: 20.1ms
# 44:	learn: 0.4992246	total: 149ms	remaining: 16.5ms
# 45:	learn: 0.4979655	total: 151ms	remaining: 13.1ms
# 46:	learn: 0.4970976	total: 153ms	remaining: 9.75ms
# 47:	learn: 0.4954625	total: 155ms	remaining: 6.45ms
# 48:	learn: 0.4943089	total: 157ms	remaining: 3.19ms
# 49:	learn: 0.4934317	total: 158ms	remaining: 0us
# 0:	learn: 0.6663622	total: 4.31ms	remaining: 211ms
# 1:	learn: 0.6445291	total: 6.64ms	remaining: 159ms
# 2:	learn: 0.6192800	total: 9ms	remaining: 141ms
# 3:	learn: 0.6019021	total: 11.3ms	remaining: 130ms
# 4:	learn: 0.5904980	total: 13.3ms	remaining: 120ms
# 5:	learn: 0.5796665	total: 15.4ms	remaining: 113ms
# 6:	learn: 0.5714054	total: 17.9ms	remaining: 110ms
# 7:	learn: 0.5625308	total: 20.1ms	remaining: 106ms
# 8:	learn: 0.5563548	total: 22.2ms	remaining: 101ms
# 9:	learn: 0.5511912	total: 24.2ms	remaining: 96.9ms
# 10:	learn: 0.5448257	total: 26.5ms	remaining: 93.9ms
# 11:	learn: 0.5396591	total: 28.7ms	remaining: 91ms
# 12:	learn: 0.5340609	total: 31.2ms	remaining: 88.8ms
# 13:	learn: 0.5296607	total: 38.9ms	remaining: 100ms
# 14:	learn: 0.5255293	total: 45.4ms	remaining: 106ms
# 15:	learn: 0.5213289	total: 52.5ms	remaining: 112ms
# 16:	learn: 0.5176754	total: 55ms	remaining: 107ms
# 17:	learn: 0.5144029	total: 56.8ms	remaining: 101ms
# 18:	learn: 0.5113437	total: 61.2ms	remaining: 99.9ms
# 19:	learn: 0.5092746	total: 64.9ms	remaining: 97.4ms
# 20:	learn: 0.5064341	total: 69ms	remaining: 95.3ms
# 21:	learn: 0.5041060	total: 74.2ms	remaining: 94.4ms
# 22:	learn: 0.5011844	total: 78ms	remaining: 91.5ms
# 23:	learn: 0.4997580	total: 82.6ms	remaining: 89.5ms
# 24:	learn: 0.4963521	total: 86.7ms	remaining: 86.7ms
# 25:	learn: 0.4935801	total: 93ms	remaining: 85.8ms
# 26:	learn: 0.4911360	total: 95.2ms	remaining: 81.1ms
# 27:	learn: 0.4899630	total: 104ms	remaining: 81.8ms
# 28:	learn: 0.4886838	total: 108ms	remaining: 78.3ms
# 29:	learn: 0.4869538	total: 113ms	remaining: 75.4ms
# 30:	learn: 0.4850964	total: 118ms	remaining: 72.6ms
# 31:	learn: 0.4832900	total: 124ms	remaining: 69.6ms
# 32:	learn: 0.4819200	total: 126ms	remaining: 65ms
# 33:	learn: 0.4804484	total: 128ms	remaining: 60.3ms
# 34:	learn: 0.4788946	total: 141ms	remaining: 60.4ms
# 35:	learn: 0.4777943	total: 143ms	remaining: 55.6ms
# 36:	learn: 0.4769286	total: 149ms	remaining: 52.3ms
# 37:	learn: 0.4758407	total: 153ms	remaining: 48.3ms
# 38:	learn: 0.4738465	total: 159ms	remaining: 44.9ms
# 39:	learn: 0.4730692	total: 163ms	remaining: 40.8ms
# 40:	learn: 0.4720351	total: 169ms	remaining: 37ms
# 41:	learn: 0.4712088	total: 171ms	remaining: 32.5ms
# 42:	learn: 0.4700733	total: 173ms	remaining: 28.1ms
# 43:	learn: 0.4684038	total: 175ms	remaining: 23.9ms
# 44:	learn: 0.4668666	total: 178ms	remaining: 19.8ms
# 45:	learn: 0.4655137	total: 180ms	remaining: 15.6ms
# 46:	learn: 0.4647299	total: 182ms	remaining: 11.6ms
# 47:	learn: 0.4640824	total: 184ms	remaining: 7.68ms
# 48:	learn: 0.4634905	total: 187ms	remaining: 3.81ms
# 49:	learn: 0.4627397	total: 189ms	remaining: 0us
# 0:	learn: 0.6688877	total: 2.41ms	remaining: 118ms
# 1:	learn: 0.6444758	total: 4.43ms	remaining: 106ms
# 2:	learn: 0.6260546	total: 6.01ms	remaining: 94.1ms
# 3:	learn: 0.6067774	total: 7.66ms	remaining: 88ms
# 4:	learn: 0.5940054	total: 9.33ms	remaining: 84ms
# 5:	learn: 0.5832708	total: 11.1ms	remaining: 81.2ms
# 6:	learn: 0.5727419	total: 13.1ms	remaining: 80.3ms
# 7:	learn: 0.5635808	total: 14.9ms	remaining: 78.4ms
# 8:	learn: 0.5572566	total: 16.7ms	remaining: 76.2ms
# 0:	learn: 0.6903745	total: 59.9ms	remaining: 2.94s
# 1:	learn: 0.6870488	total: 61.9ms	remaining: 1.49s
# 2:	learn: 0.6836393	total: 67.2ms	remaining: 1.05s
# 3:	learn: 0.6811952	total: 69.3ms	remaining: 796ms
# 4:	learn: 0.6784745	total: 79.1ms	remaining: 712ms
# 5:	learn: 0.6753218	total: 86.7ms	remaining: 636ms
# 6:	learn: 0.6721253	total: 88.7ms	remaining: 545ms
# 7:	learn: 0.6697828	total: 95.4ms	remaining: 501ms
# 8:	learn: 0.6668605	total: 103ms	remaining: 468ms
# 9:	learn: 0.6643634	total: 110ms	remaining: 442ms
# 10:	learn: 0.6621738	total: 113ms	remaining: 399ms
# 11:	learn: 0.6599089	total: 118ms	remaining: 374ms
# 12:	learn: 0.6576528	total: 125ms	remaining: 355ms
# 13:	learn: 0.6548308	total: 131ms	remaining: 338ms
# 14:	learn: 0.6525659	total: 139ms	remaining: 323ms
# 15:	learn: 0.6503761	total: 146ms	remaining: 310ms
# 16:	learn: 0.6478134	total: 153ms	remaining: 297ms
# 17:	learn: 0.6452629	total: 160ms	remaining: 284ms
# 18:	learn: 0.6431403	total: 162ms	remaining: 265ms
# 19:	learn: 0.6411076	total: 169ms	remaining: 253ms
# 20:	learn: 0.6391692	total: 174ms	remaining: 241ms
# 21:	learn: 0.6373542	total: 182ms	remaining: 231ms
# 22:	learn: 0.6354622	total: 189ms	remaining: 222ms
# 23:	learn: 0.6334261	total: 196ms	remaining: 213ms
# 24:	learn: 0.6311997	total: 203ms	remaining: 203ms
# 25:	learn: 0.6296821	total: 210ms	remaining: 194ms
# 26:	learn: 0.6277343	total: 216ms	remaining: 184ms
# 27:	learn: 0.6260152	total: 223ms	remaining: 175ms
# 28:	learn: 0.6243761	total: 225ms	remaining: 163ms
# 29:	learn: 0.6227720	total: 231ms	remaining: 154ms
# 30:	learn: 0.6209300	total: 238ms	remaining: 146ms
# 31:	learn: 0.6194647	total: 246ms	remaining: 138ms
# 32:	learn: 0.6175396	total: 251ms	remaining: 129ms
# 33:	learn: 0.6160339	total: 258ms	remaining: 121ms
# 34:	learn: 0.6145089	total: 263ms	remaining: 113ms
# 35:	learn: 0.6130921	total: 270ms	remaining: 105ms
# 36:	learn: 0.6111547	total: 277ms	remaining: 97.2ms
# 37:	learn: 0.6097521	total: 284ms	remaining: 89.6ms
# 38:	learn: 0.6079601	total: 290ms	remaining: 81.9ms
# 39:	learn: 0.6065194	total: 292ms	remaining: 73.1ms
# 40:	learn: 0.6048152	total: 302ms	remaining: 66.3ms
# 41:	learn: 0.6034832	total: 309ms	remaining: 58.9ms
# 42:	learn: 0.6022301	total: 316ms	remaining: 51.5ms
# 43:	learn: 0.6008652	total: 323ms	remaining: 44ms
# 44:	learn: 0.5996569	total: 330ms	remaining: 36.7ms
# 45:	learn: 0.5984759	total: 337ms	remaining: 29.3ms
# 46:	learn: 0.5973803	total: 344ms	remaining: 22ms
# 47:	learn: 0.5963002	total: 350ms	remaining: 14.6ms
# 48:	learn: 0.5951645	total: 357ms	remaining: 7.29ms
# 49:	learn: 0.5936820	total: 360ms	remaining: 0us
# 0:	learn: 0.6793591	total: 2.31ms	remaining: 113ms
# 1:	learn: 0.6668726	total: 4.05ms	remaining: 97.1ms
# 2:	learn: 0.6525718	total: 9.09ms	remaining: 142ms
# 3:	learn: 0.6432078	total: 13.3ms	remaining: 153ms
# 4:	learn: 0.6342599	total: 15.1ms	remaining: 136ms
# 5:	learn: 0.6258694	total: 17.1ms	remaining: 126ms
# 6:	learn: 0.6186684	total: 18.9ms	remaining: 116ms
# 7:	learn: 0.6095554	total: 20.7ms	remaining: 109ms
# 8:	learn: 0.6026638	total: 22.9ms	remaining: 104ms
# 9:	learn: 0.5943080	total: 31ms	remaining: 124ms
# 10:	learn: 0.5873631	total: 40.2ms	remaining: 142ms
# 11:	learn: 0.5822727	total: 49.4ms	remaining: 156ms
# 12:	learn: 0.5782534	total: 64.5ms	remaining: 184ms
# 13:	learn: 0.5726575	total: 75.5ms	remaining: 194ms
# 14:	learn: 0.5678150	total: 77.6ms	remaining: 181ms
# 15:	learn: 0.5639902	total: 86.3ms	remaining: 183ms
# 16:	learn: 0.5600881	total: 101ms	remaining: 196ms
# 17:	learn: 0.5559568	total: 105ms	remaining: 186ms
# 18:	learn: 0.5526368	total: 114ms	remaining: 185ms
# 19:	learn: 0.5493489	total: 117ms	remaining: 176ms
# 20:	learn: 0.5467531	total: 124ms	remaining: 171ms
# 21:	learn: 0.5432527	total: 126ms	remaining: 160ms
# 22:	learn: 0.5410703	total: 140ms	remaining: 164ms
# 23:	learn: 0.5387114	total: 152ms	remaining: 164ms
# 24:	learn: 0.5361348	total: 155ms	remaining: 155ms
# 25:	learn: 0.5333368	total: 165ms	remaining: 152ms
# 26:	learn: 0.5312725	total: 174ms	remaining: 149ms
# 27:	learn: 0.5293220	total: 176ms	remaining: 139ms
# 28:	learn: 0.5271364	total: 184ms	remaining: 133ms
# 29:	learn: 0.5248166	total: 188ms	remaining: 125ms
# 30:	learn: 0.5225412	total: 190ms	remaining: 117ms
# 31:	learn: 0.5200811	total: 193ms	remaining: 109ms
# 32:	learn: 0.5179210	total: 196ms	remaining: 101ms
# 33:	learn: 0.5159714	total: 198ms	remaining: 93ms
# 34:	learn: 0.5147354	total: 199ms	remaining: 85.2ms
# 35:	learn: 0.5128078	total: 200ms	remaining: 77.8ms
# 36:	learn: 0.5108362	total: 201ms	remaining: 70.8ms
# 37:	learn: 0.5089790	total: 203ms	remaining: 64ms
# 38:	learn: 0.5075281	total: 204ms	remaining: 57.6ms
# 39:	learn: 0.5062870	total: 206ms	remaining: 51.6ms
# 40:	learn: 0.5050864	total: 208ms	remaining: 45.7ms
# 41:	learn: 0.5033022	total: 211ms	remaining: 40.2ms
# 42:	learn: 0.5019157	total: 213ms	remaining: 34.7ms
# 43:	learn: 0.5009176	total: 215ms	remaining: 29.3ms
# 44:	learn: 0.4996524	total: 218ms	remaining: 24.2ms
# 45:	learn: 0.4987291	total: 220ms	remaining: 19.1ms
# 46:	learn: 0.4973777	total: 222ms	remaining: 14.2ms
# 47:	learn: 0.4965613	total: 224ms	remaining: 9.32ms
# 48:	learn: 0.4953736	total: 226ms	remaining: 4.61ms
# 49:	learn: 0.4946791	total: 228ms	remaining: 0us
# 0:	learn: 0.6667868	total: 5.96ms	remaining: 292ms
# 1:	learn: 0.6395683	total: 8.68ms	remaining: 208ms
# 2:	learn: 0.6213651	total: 11.2ms	remaining: 175ms
# 3:	learn: 0.6076521	total: 14.6ms	remaining: 168ms
# 4:	learn: 0.5909802	total: 19.6ms	remaining: 176ms
# 5:	learn: 0.5808654	total: 22.5ms	remaining: 165ms
# 6:	learn: 0.5721891	total: 25.5ms	remaining: 156ms
# 7:	learn: 0.5637356	total: 28.3ms	remaining: 149ms
# 8:	learn: 0.5559217	total: 30.9ms	remaining: 141ms
# 9:	learn: 0.5478409	total: 34.5ms	remaining: 138ms
# 10:	learn: 0.5427013	total: 36.3ms	remaining: 129ms
# 11:	learn: 0.5363885	total: 38.3ms	remaining: 121ms
# 12:	learn: 0.5308758	total: 40.3ms	remaining: 115ms
# 13:	learn: 0.5261772	total: 44.9ms	remaining: 115ms
# 14:	learn: 0.5215851	total: 46.7ms	remaining: 109ms
# 15:	learn: 0.5175462	total: 48.7ms	remaining: 103ms
# 16:	learn: 0.5137946	total: 52.1ms	remaining: 101ms
# 17:	learn: 0.5115134	total: 54.1ms	remaining: 96.2ms
# 18:	learn: 0.5080644	total: 57.3ms	remaining: 93.5ms
# 19:	learn: 0.5042690	total: 59.7ms	remaining: 89.5ms
# 20:	learn: 0.5015265	total: 63.1ms	remaining: 87.1ms
# 21:	learn: 0.4987587	total: 65.5ms	remaining: 83.3ms
# 22:	learn: 0.4962636	total: 70.9ms	remaining: 83.3ms
# 23:	learn: 0.4938772	total: 73ms	remaining: 79.1ms
# 24:	learn: 0.4921349	total: 74.8ms	remaining: 74.8ms
# 25:	learn: 0.4894584	total: 76.9ms	remaining: 71ms
# 26:	learn: 0.4871686	total: 79ms	remaining: 67.3ms
# 27:	learn: 0.4856901	total: 81.2ms	remaining: 63.8ms
# 28:	learn: 0.4838596	total: 83.7ms	remaining: 60.6ms
# 29:	learn: 0.4818100	total: 85.7ms	remaining: 57.1ms
# 30:	learn: 0.4798690	total: 87.6ms	remaining: 53.7ms
# 31:	learn: 0.4782407	total: 89.4ms	remaining: 50.3ms
# 32:	learn: 0.4767167	total: 91.4ms	remaining: 47.1ms
# 33:	learn: 0.4752140	total: 93.6ms	remaining: 44ms
# 34:	learn: 0.4741057	total: 95.5ms	remaining: 40.9ms
# 35:	learn: 0.4722335	total: 97.4ms	remaining: 37.9ms
# 36:	learn: 0.4714095	total: 99.6ms	remaining: 35ms
# 37:	learn: 0.4703566	total: 101ms	remaining: 32ms
# 38:	learn: 0.4695551	total: 103ms	remaining: 29.1ms
# 39:	learn: 0.4681726	total: 105ms	remaining: 26.3ms
# 40:	learn: 0.4671552	total: 109ms	remaining: 24ms
# 41:	learn: 0.4663029	total: 116ms	remaining: 22ms
# 42:	learn: 0.4652105	total: 124ms	remaining: 20.2ms
# 43:	learn: 0.4643948	total: 129ms	remaining: 17.6ms
# 44:	learn: 0.4636448	total: 131ms	remaining: 14.6ms
# 45:	learn: 0.4621948	total: 133ms	remaining: 11.6ms
# 46:	learn: 0.4609763	total: 136ms	remaining: 8.67ms
# 47:	learn: 0.4602148	total: 138ms	remaining: 5.74ms
# 48:	learn: 0.4583897	total: 140ms	remaining: 2.86ms
# 49:	learn: 0.4577954	total: 142ms	remaining: 0us
# 0:	learn: 0.6683703	total: 2.34ms	remaining: 115ms
# 1:	learn: 0.6449610	total: 4.07ms	remaining: 97.7ms
# 2:	learn: 0.6206286	total: 6ms	remaining: 94.1ms
# 3:	learn: 0.6051070	total: 14.9ms	remaining: 171ms
# 4:	learn: 0.5926515	total: 17.2ms	remaining: 155ms
# 5:	learn: 0.5818998	total: 19.2ms	remaining: 141ms
# 6:	learn: 0.5701193	total: 30.8ms	remaining: 189ms
# 7:	learn: 0.5605913	total: 36.9ms	remaining: 194ms
# 8:	learn: 0.5547565	total: 40.4ms	remaining: 184ms
# 0:	learn: 0.6904941	total: 59.9ms	remaining: 2.93s
# 1:	learn: 0.6876073	total: 62ms	remaining: 1.49s
# 2:	learn: 0.6842090	total: 70.4ms	remaining: 1.1s
# 3:	learn: 0.6816086	total: 76.5ms	remaining: 880ms
# 4:	learn: 0.6783571	total: 84ms	remaining: 756ms
# 5:	learn: 0.6756019	total: 91.4ms	remaining: 670ms
# 6:	learn: 0.6729700	total: 94.8ms	remaining: 583ms
# 7:	learn: 0.6698830	total: 101ms	remaining: 528ms
# 8:	learn: 0.6668682	total: 108ms	remaining: 491ms
# 9:	learn: 0.6638460	total: 116ms	remaining: 465ms
# 10:	learn: 0.6615678	total: 124ms	remaining: 441ms
# 11:	learn: 0.6592361	total: 126ms	remaining: 400ms
# 12:	learn: 0.6569218	total: 133ms	remaining: 380ms
# 13:	learn: 0.6548135	total: 141ms	remaining: 362ms
# 14:	learn: 0.6527009	total: 148ms	remaining: 344ms
# 15:	learn: 0.6501227	total: 150ms	remaining: 318ms
# 16:	learn: 0.6474683	total: 156ms	remaining: 304ms
# 17:	learn: 0.6454237	total: 164ms	remaining: 291ms
# 18:	learn: 0.6434692	total: 166ms	remaining: 270ms
# 19:	learn: 0.6409434	total: 173ms	remaining: 259ms
# 20:	learn: 0.6390117	total: 179ms	remaining: 247ms
# 21:	learn: 0.6365616	total: 185ms	remaining: 236ms
# 22:	learn: 0.6348605	total: 192ms	remaining: 225ms
# 23:	learn: 0.6326665	total: 199ms	remaining: 215ms
# 24:	learn: 0.6307812	total: 201ms	remaining: 201ms
# 25:	learn: 0.6291162	total: 211ms	remaining: 195ms
# 26:	learn: 0.6268257	total: 215ms	remaining: 183ms
# 27:	learn: 0.6250690	total: 225ms	remaining: 177ms
# 28:	learn: 0.6229406	total: 232ms	remaining: 168ms
# 29:	learn: 0.6213027	total: 235ms	remaining: 157ms
# 30:	learn: 0.6192648	total: 242ms	remaining: 148ms
# 31:	learn: 0.6177638	total: 249ms	remaining: 140ms
# 32:	learn: 0.6163102	total: 251ms	remaining: 129ms
# 33:	learn: 0.6148792	total: 259ms	remaining: 122ms
# 34:	learn: 0.6132979	total: 266ms	remaining: 114ms
# 35:	learn: 0.6118307	total: 272ms	remaining: 106ms
# 36:	learn: 0.6104404	total: 279ms	remaining: 98ms
# 37:	learn: 0.6091363	total: 281ms	remaining: 88.7ms
# 38:	learn: 0.6078256	total: 288ms	remaining: 81.2ms
# 39:	learn: 0.6059090	total: 294ms	remaining: 73.6ms
# 40:	learn: 0.6045565	total: 302ms	remaining: 66.3ms
# 41:	learn: 0.6031144	total: 310ms	remaining: 59ms
# 42:	learn: 0.6018860	total: 317ms	remaining: 51.6ms
# 43:	learn: 0.6007511	total: 325ms	remaining: 44.3ms
# 44:	learn: 0.5994730	total: 332ms	remaining: 36.9ms
# 45:	learn: 0.5983333	total: 339ms	remaining: 29.5ms
# 46:	learn: 0.5971263	total: 342ms	remaining: 21.8ms
# 47:	learn: 0.5959589	total: 349ms	remaining: 14.6ms
# 48:	learn: 0.5948363	total: 357ms	remaining: 7.28ms
# 49:	learn: 0.5937335	total: 359ms	remaining: 0us
# 0:	learn: 0.6801822	total: 6.59ms	remaining: 323ms
# 1:	learn: 0.6669730	total: 13.5ms	remaining: 323ms
# 2:	learn: 0.6519878	total: 15.5ms	remaining: 243ms
# 3:	learn: 0.6385775	total: 22.6ms	remaining: 260ms
# 4:	learn: 0.6287399	total: 29.6ms	remaining: 267ms
# 5:	learn: 0.6205712	total: 37.1ms	remaining: 272ms
# 6:	learn: 0.6133316	total: 39ms	remaining: 240ms
# 7:	learn: 0.6042841	total: 45.8ms	remaining: 241ms
# 8:	learn: 0.5983565	total: 53.5ms	remaining: 244ms
# 9:	learn: 0.5925530	total: 59.6ms	remaining: 239ms
# 10:	learn: 0.5850080	total: 61.8ms	remaining: 219ms
# 11:	learn: 0.5787838	total: 68.1ms	remaining: 216ms
# 12:	learn: 0.5742649	total: 74.8ms	remaining: 213ms
# 13:	learn: 0.5699704	total: 76.8ms	remaining: 197ms
# 14:	learn: 0.5662642	total: 78.9ms	remaining: 184ms
# 15:	learn: 0.5614711	total: 80.7ms	remaining: 171ms
# 16:	learn: 0.5573135	total: 82.4ms	remaining: 160ms
# 17:	learn: 0.5535417	total: 84.1ms	remaining: 150ms
# 18:	learn: 0.5501534	total: 86ms	remaining: 140ms
# 19:	learn: 0.5467260	total: 88ms	remaining: 132ms
# 20:	learn: 0.5434365	total: 89.9ms	remaining: 124ms
# 21:	learn: 0.5406815	total: 92ms	remaining: 117ms
# 22:	learn: 0.5382872	total: 93.8ms	remaining: 110ms
# 23:	learn: 0.5360194	total: 95.6ms	remaining: 104ms
# 24:	learn: 0.5331159	total: 97.5ms	remaining: 97.5ms
# 25:	learn: 0.5307312	total: 99.7ms	remaining: 92ms
# 26:	learn: 0.5274725	total: 102ms	remaining: 86.5ms
# 27:	learn: 0.5251345	total: 105ms	remaining: 82.8ms
# 28:	learn: 0.5230344	total: 116ms	remaining: 83.7ms
# 29:	learn: 0.5205139	total: 118ms	remaining: 78.8ms
# 30:	learn: 0.5185446	total: 120ms	remaining: 73.7ms
# 31:	learn: 0.5169262	total: 122ms	remaining: 68.7ms
# 32:	learn: 0.5155917	total: 124ms	remaining: 64.1ms
# 33:	learn: 0.5139183	total: 126ms	remaining: 59.5ms
# 34:	learn: 0.5121927	total: 129ms	remaining: 55.2ms
# 35:	learn: 0.5096895	total: 131ms	remaining: 50.9ms
# 36:	learn: 0.5085076	total: 132ms	remaining: 46.5ms
# 37:	learn: 0.5072719	total: 134ms	remaining: 42.4ms
# 38:	learn: 0.5058384	total: 136ms	remaining: 38.3ms
# 39:	learn: 0.5046433	total: 138ms	remaining: 34.4ms
# 40:	learn: 0.5030824	total: 139ms	remaining: 30.6ms
# 41:	learn: 0.5015336	total: 141ms	remaining: 26.9ms
# 42:	learn: 0.4996868	total: 144ms	remaining: 23.4ms
# 43:	learn: 0.4984390	total: 146ms	remaining: 19.8ms
# 44:	learn: 0.4974578	total: 148ms	remaining: 16.4ms
# 45:	learn: 0.4960652	total: 150ms	remaining: 13ms
# 46:	learn: 0.4950394	total: 151ms	remaining: 9.66ms
# 47:	learn: 0.4941654	total: 153ms	remaining: 6.38ms
# 48:	learn: 0.4926860	total: 155ms	remaining: 3.16ms
# 49:	learn: 0.4917539	total: 157ms	remaining: 0us
# 0:	learn: 0.6803842	total: 3.15ms	remaining: 154ms
# 1:	learn: 0.6672450	total: 9.85ms	remaining: 236ms
# 2:	learn: 0.6525933	total: 12.2ms	remaining: 191ms
# 3:	learn: 0.6396958	total: 14.5ms	remaining: 167ms
# 4:	learn: 0.6303402	total: 16.8ms	remaining: 151ms
# 5:	learn: 0.6214522	total: 33ms	remaining: 242ms
# 6:	learn: 0.6145736	total: 35.2ms	remaining: 216ms
# 7:	learn: 0.6081004	total: 44.3ms	remaining: 233ms
# 8:	learn: 0.5994697	total: 51.8ms	remaining: 236ms
# 9:	learn: 0.5934006	total: 60.8ms	remaining: 243ms
# 10:	learn: 0.5862745	total: 63ms	remaining: 223ms
# 11:	learn: 0.5812724	total: 74.5ms	remaining: 236ms
# 12:	learn: 0.5754969	total: 83.4ms	remaining: 237ms
# 13:	learn: 0.5701846	total: 91ms	remaining: 234ms
# 14:	learn: 0.5664113	total: 98.1ms	remaining: 229ms
# 15:	learn: 0.5625368	total: 100ms	remaining: 213ms
# 16:	learn: 0.5593521	total: 115ms	remaining: 224ms
# 17:	learn: 0.5550523	total: 117ms	remaining: 208ms
# 18:	learn: 0.5518924	total: 119ms	remaining: 195ms
# 19:	learn: 0.5480178	total: 121ms	remaining: 182ms
# 20:	learn: 0.5447864	total: 141ms	remaining: 195ms
# 21:	learn: 0.5422726	total: 147ms	remaining: 187ms
# 22:	learn: 0.5392736	total: 152ms	remaining: 178ms
# 23:	learn: 0.5367390	total: 154ms	remaining: 167ms
# 24:	learn: 0.5342612	total: 159ms	remaining: 159ms
# 25:	learn: 0.5323181	total: 161ms	remaining: 148ms
# 26:	learn: 0.5298366	total: 163ms	remaining: 139ms
# 27:	learn: 0.5274634	total: 164ms	remaining: 129ms
# 28:	learn: 0.5255046	total: 166ms	remaining: 120ms
# 29:	learn: 0.5231327	total: 168ms	remaining: 112ms
# 30:	learn: 0.5211787	total: 170ms	remaining: 104ms
# 31:	learn: 0.5192774	total: 172ms	remaining: 96.9ms
# 32:	learn: 0.5176921	total: 174ms	remaining: 89.6ms
# 33:	learn: 0.5156716	total: 176ms	remaining: 83ms
# 34:	learn: 0.5138340	total: 183ms	remaining: 78.6ms
# 35:	learn: 0.5119456	total: 193ms	remaining: 75ms
# 36:	learn: 0.5100691	total: 199ms	remaining: 69.9ms
# 37:	learn: 0.5085976	total: 201ms	remaining: 63.4ms
# 38:	learn: 0.5070994	total: 208ms	remaining: 58.8ms
# 39:	learn: 0.5057435	total: 212ms	remaining: 53.1ms
# 40:	learn: 0.5046924	total: 214ms	remaining: 47.1ms
# 41:	learn: 0.5033298	total: 217ms	remaining: 41.3ms
# 42:	learn: 0.5022472	total: 219ms	remaining: 35.6ms
# 43:	learn: 0.5012388	total: 221ms	remaining: 30.1ms
# 44:	learn: 0.5001848	total: 222ms	remaining: 24.7ms
# 45:	learn: 0.4986768	total: 224ms	remaining: 19.4ms
# 46:	learn: 0.4971842	total: 225ms	remaining: 14.4ms
# 47:	learn: 0.4959001	total: 227ms	remaining: 9.45ms
# 48:	learn: 0.4949901	total: 229ms	remaining: 4.67ms
# 49:	learn: 0.4936834	total: 230ms	remaining: 0us
# 0:	learn: 0.5906363	total: 2.2ms	remaining: 108ms
# 1:	learn: 0.5576844	total: 4.25ms	remaining: 102ms
# 2:	learn: 0.5295212	total: 22.3ms	remaining: 349ms
# 3:	learn: 0.5128691	total: 26.2ms	remaining: 301ms
# 4:	learn: 0.4994848	total: 30.1ms	remaining: 270ms
# 5:	learn: 0.4888394	total: 40.5ms	remaining: 297ms
# 6:	learn: 0.4803760	total: 42.6ms	remaining: 262ms
# 7:	learn: 0.4761437	total: 44.4ms	remaining: 233ms
# 8:	learn: 0.4692157	total: 48.8ms	remaining: 222ms
# 9:	learn: 0.5509560	total: 18.6ms	remaining: 74.5ms
# 10:	learn: 0.5463075	total: 20.4ms	remaining: 72.5ms
# 11:	learn: 0.5411393	total: 22.6ms	remaining: 71.6ms
# 12:	learn: 0.5358200	total: 25.8ms	remaining: 73.3ms
# 13:	learn: 0.5307152	total: 27.7ms	remaining: 71.3ms
# 14:	learn: 0.5261368	total: 29.8ms	remaining: 69.6ms
# 15:	learn: 0.5223091	total: 32ms	remaining: 67.9ms
# 16:	learn: 0.5192712	total: 33.9ms	remaining: 65.7ms
# 17:	learn: 0.5154781	total: 35.8ms	remaining: 63.6ms
# 18:	learn: 0.5124253	total: 37.7ms	remaining: 61.6ms
# 19:	learn: 0.5093377	total: 41.7ms	remaining: 62.5ms
# 20:	learn: 0.5069121	total: 43.5ms	remaining: 60ms
# 21:	learn: 0.5042127	total: 45.3ms	remaining: 57.6ms
# 22:	learn: 0.5023459	total: 48.9ms	remaining: 57.4ms
# 23:	learn: 0.5006750	total: 50.8ms	remaining: 55.1ms
# 24:	learn: 0.4989532	total: 52.9ms	remaining: 52.9ms
# 25:	learn: 0.4968511	total: 54.9ms	remaining: 50.7ms
# 26:	learn: 0.4957108	total: 57.1ms	remaining: 48.6ms
# 27:	learn: 0.4943498	total: 58.9ms	remaining: 46.3ms
# 28:	learn: 0.4924492	total: 61ms	remaining: 44.2ms
# 29:	learn: 0.4895071	total: 63ms	remaining: 42ms
# 30:	learn: 0.4877275	total: 65ms	remaining: 39.8ms
# 31:	learn: 0.4864116	total: 66.8ms	remaining: 37.6ms
# 32:	learn: 0.4851453	total: 68.7ms	remaining: 35.4ms
# 33:	learn: 0.4836547	total: 70.6ms	remaining: 33.2ms
# 34:	learn: 0.4814571	total: 72.8ms	remaining: 31.2ms
# 35:	learn: 0.4805001	total: 74.6ms	remaining: 29ms
# 36:	learn: 0.4795077	total: 76.4ms	remaining: 26.8ms
# 37:	learn: 0.4784715	total: 78.2ms	remaining: 24.7ms
# 38:	learn: 0.4767589	total: 80ms	remaining: 22.6ms
# 39:	learn: 0.4757075	total: 81.9ms	remaining: 20.5ms
# 40:	learn: 0.4745619	total: 83.6ms	remaining: 18.4ms
# 41:	learn: 0.4729755	total: 85.6ms	remaining: 16.3ms
# 42:	learn: 0.4723383	total: 87.7ms	remaining: 14.3ms
# 43:	learn: 0.4703600	total: 89.7ms	remaining: 12.2ms
# 44:	learn: 0.4695599	total: 91.8ms	remaining: 10.2ms
# 45:	learn: 0.4686794	total: 93.9ms	remaining: 8.17ms
# 46:	learn: 0.4680409	total: 96ms	remaining: 6.13ms
# 47:	learn: 0.4669858	total: 97.9ms	remaining: 4.08ms
# 48:	learn: 0.4662129	total: 99.7ms	remaining: 2.04ms
# 49:	learn: 0.4656755	total: 102ms	remaining: 0us
# 0:	learn: 0.5923566	total: 3.81ms	remaining: 187ms
# 1:	learn: 0.5419267	total: 6.76ms	remaining: 162ms
# 2:	learn: 0.5177978	total: 9.26ms	remaining: 145ms
# 3:	learn: 0.4982078	total: 11ms	remaining: 126ms
# 4:	learn: 0.4889798	total: 16.1ms	remaining: 145ms
# 5:	learn: 0.4810026	total: 21.2ms	remaining: 155ms
# 6:	learn: 0.4706403	total: 33.7ms	remaining: 207ms
# 7:	learn: 0.4642886	total: 39.7ms	remaining: 208ms
# 8:	learn: 0.4582834	total: 44.4ms	remaining: 202ms
# 9:	learn: 0.4541882	total: 47ms	remaining: 188ms
# 10:	learn: 0.4498236	total: 49.3ms	remaining: 175ms
# 11:	learn: 0.4466092	total: 51.4ms	remaining: 163ms
# 12:	learn: 0.4423771	total: 53.7ms	remaining: 153ms
# 13:	learn: 0.4382471	total: 55.6ms	remaining: 143ms
# 14:	learn: 0.4345388	total: 57.9ms	remaining: 135ms
# 15:	learn: 0.4326460	total: 59.9ms	remaining: 127ms
# 16:	learn: 0.4305785	total: 61.7ms	remaining: 120ms
# 17:	learn: 0.4292028	total: 63.9ms	remaining: 114ms
# 18:	learn: 0.4264086	total: 66ms	remaining: 108ms
# 19:	learn: 0.4249735	total: 68ms	remaining: 102ms
# 20:	learn: 0.4232753	total: 70.1ms	remaining: 96.8ms
# 21:	learn: 0.4214148	total: 72.5ms	remaining: 92.2ms
# 22:	learn: 0.4203286	total: 74.6ms	remaining: 87.6ms
# 23:	learn: 0.4186835	total: 76.4ms	remaining: 82.8ms
# 24:	learn: 0.4172722	total: 78.6ms	remaining: 78.6ms
# 25:	learn: 0.4156458	total: 80.7ms	remaining: 74.5ms
# 26:	learn: 0.4144223	total: 82.8ms	remaining: 70.5ms
# 27:	learn: 0.4126998	total: 85ms	remaining: 66.8ms
# 28:	learn: 0.4113924	total: 87ms	remaining: 63ms
# 29:	learn: 0.4105964	total: 89.7ms	remaining: 59.8ms
# 30:	learn: 0.4087241	total: 92.2ms	remaining: 56.5ms
# 31:	learn: 0.4073104	total: 94.6ms	remaining: 53.2ms
# 32:	learn: 0.4065670	total: 96.5ms	remaining: 49.7ms
# 33:	learn: 0.4052002	total: 98.4ms	remaining: 46.3ms
# 34:	learn: 0.4039003	total: 100ms	remaining: 42.9ms
# 35:	learn: 0.4009394	total: 102ms	remaining: 39.7ms
# 36:	learn: 0.3995907	total: 104ms	remaining: 36.5ms
# 37:	learn: 0.3988487	total: 105ms	remaining: 33.3ms
# 38:	learn: 0.3979791	total: 107ms	remaining: 30.2ms
# 39:	learn: 0.3964134	total: 110ms	remaining: 27.4ms
# 40:	learn: 0.3950017	total: 112ms	remaining: 24.6ms
# 41:	learn: 0.3939924	total: 117ms	remaining: 22.3ms
# 42:	learn: 0.3932628	total: 122ms	remaining: 19.8ms
# 43:	learn: 0.3926802	total: 124ms	remaining: 16.8ms
# 44:	learn: 0.3921302	total: 128ms	remaining: 14.2ms
# 45:	learn: 0.3913622	total: 130ms	remaining: 11.3ms
# 46:	learn: 0.3909019	total: 132ms	remaining: 8.42ms
# 47:	learn: 0.3904363	total: 134ms	remaining: 5.57ms
# 48:	learn: 0.3891960	total: 138ms	remaining: 2.82ms
# 49:	learn: 0.3888821	total: 140ms	remaining: 0us
# 0:	learn: 0.6903281	total: 2.96ms	remaining: 294ms
# 1:	learn: 0.6874752	total: 6.71ms	remaining: 329ms
# 2:	learn: 0.6840554	total: 8.83ms	remaining: 286ms
# 3:	learn: 0.6808526	total: 10.6ms	remaining: 253ms
# 4:	learn: 0.6784091	total: 15.9ms	remaining: 303ms
# 5:	learn: 0.6759988	total: 17.8ms	remaining: 280ms
# 6:	learn: 0.6727929	total: 23.2ms	remaining: 309ms
# 7:	learn: 0.6705376	total: 26.1ms	remaining: 300ms
# 8:	learn: 0.6676093	total: 28ms	remaining: 283ms
# 9:	learn: 0.6652232	total: 30.8ms	remaining: 277ms
# 10:	learn: 0.6623857	total: 32.9ms	remaining: 266ms
# 11:	learn: 0.6600796	total: 35.4ms	remaining: 259ms
# 12:	learn: 0.6573513	total: 40.6ms	remaining: 272ms
# 13:	learn: 0.6551961	total: 43.9ms	remaining: 270ms
# 14:	learn: 0.6531626	total: 45.8ms	remaining: 260ms
# 15:	learn: 0.6506733	total: 51.1ms	remaining: 268ms
# 16:	learn: 0.6485767	total: 52.8ms	remaining: 258ms
# 17:	learn: 0.6460681	total: 58.6ms	remaining: 267ms
# 18:	learn: 0.6433833	total: 62.2ms	remaining: 265ms
# 19:	learn: 0.6415081	total: 67.7ms	remaining: 271ms
# 20:	learn: 0.6391911	total: 69.4ms	remaining: 261ms
# 21:	learn: 0.6372921	total: 71.7ms	remaining: 254ms
# 22:	learn: 0.6349871	total: 74.8ms	remaining: 250ms
# 23:	learn: 0.6331583	total: 80.1ms	remaining: 254ms
# 24:	learn: 0.6309110	total: 82.1ms	remaining: 246ms
# 25:	learn: 0.6290385	total: 85.5ms	remaining: 243ms
# 26:	learn: 0.6273256	total: 87.1ms	remaining: 236ms
# 27:	learn: 0.6255558	total: 89ms	remaining: 229ms
# 28:	learn: 0.6238388	total: 90.7ms	remaining: 222ms
# 29:	learn: 0.6221716	total: 92.5ms	remaining: 216ms
# 30:	learn: 0.6206146	total: 94.3ms	remaining: 210ms
# 31:	learn: 0.6189782	total: 96.3ms	remaining: 205ms
# 32:	learn: 0.6171159	total: 98.1ms	remaining: 199ms
# 33:	learn: 0.6155618	total: 100ms	remaining: 194ms
# 34:	learn: 0.6140411	total: 104ms	remaining: 192ms
# 35:	learn: 0.6126106	total: 105ms	remaining: 187ms
# 36:	learn: 0.6113244	total: 107ms	remaining: 182ms
# 37:	learn: 0.6099310	total: 112ms	remaining: 183ms
# 38:	learn: 0.6081604	total: 116ms	remaining: 181ms
# 39:	learn: 0.6068484	total: 119ms	remaining: 179ms
# 40:	learn: 0.6055810	total: 121ms	remaining: 174ms
# 41:	learn: 0.6042053	total: 123ms	remaining: 170ms
# 42:	learn: 0.6028513	total: 125ms	remaining: 165ms
# 43:	learn: 0.6016579	total: 127ms	remaining: 161ms
# 44:	learn: 0.6003566	total: 128ms	remaining: 157ms
# 45:	learn: 0.5987763	total: 130ms	remaining: 153ms
# 46:	learn: 0.5975075	total: 133ms	remaining: 150ms
# 47:	learn: 0.5958134	total: 136ms	remaining: 147ms
# 48:	learn: 0.5946262	total: 137ms	remaining: 143ms
# 49:	learn: 0.5934530	total: 139ms	remaining: 139ms
# 50:	learn: 0.5920169	total: 141ms	remaining: 136ms
# 51:	learn: 0.5904534	total: 143ms	remaining: 132ms
# 52:	learn: 0.5890759	total: 145ms	remaining: 129ms
# 53:	learn: 0.5880527	total: 148ms	remaining: 126ms
# 54:	learn: 0.5867799	total: 150ms	remaining: 123ms
# 55:	learn: 0.5857461	total: 152ms	remaining: 120ms
# 56:	learn: 0.5844684	total: 154ms	remaining: 117ms
# 57:	learn: 0.5834654	total: 157ms	remaining: 113ms
# 58:	learn: 0.5825319	total: 159ms	remaining: 110ms
# 59:	learn: 0.5815764	total: 161ms	remaining: 107ms
# 60:	learn: 0.5806945	total: 164ms	remaining: 105ms
# 61:	learn: 0.5795653	total: 166ms	remaining: 102ms
# 62:	learn: 0.5784901	total: 168ms	remaining: 98.6ms
# 63:	learn: 0.5776442	total: 170ms	remaining: 95.4ms
# 64:	learn: 0.5767863	total: 171ms	remaining: 92.3ms
# 65:	learn: 0.5759934	total: 173ms	remaining: 89.3ms
# 66:	learn: 0.5748818	total: 176ms	remaining: 86.6ms
# 8:	learn: 0.5525095	total: 17.7ms	remaining: 80.6ms
# 9:	learn: 0.5472324	total: 19.4ms	remaining: 77.8ms
# 10:	learn: 0.5415363	total: 22ms	remaining: 77.9ms
# 11:	learn: 0.5362566	total: 25.6ms	remaining: 81.1ms
# 12:	learn: 0.5307131	total: 27.8ms	remaining: 79.2ms
# 13:	learn: 0.5259326	total: 29.6ms	remaining: 76.1ms
# 14:	learn: 0.5214018	total: 31.6ms	remaining: 73.8ms
# 15:	learn: 0.5176377	total: 33.8ms	remaining: 71.9ms
# 16:	learn: 0.5130761	total: 36.2ms	remaining: 70.2ms
# 17:	learn: 0.5098440	total: 38.1ms	remaining: 67.7ms
# 18:	learn: 0.5066874	total: 40.2ms	remaining: 65.5ms
# 19:	learn: 0.5030564	total: 42ms	remaining: 62.9ms
# 20:	learn: 0.5005155	total: 46.7ms	remaining: 64.4ms
# 21:	learn: 0.4980606	total: 48.6ms	remaining: 61.9ms
# 22:	learn: 0.4960757	total: 65.9ms	remaining: 77.3ms
# 23:	learn: 0.4931638	total: 74.5ms	remaining: 80.7ms
# 24:	learn: 0.4913416	total: 76.4ms	remaining: 76.4ms
# 25:	learn: 0.4887816	total: 78.5ms	remaining: 72.5ms
# 26:	learn: 0.4873442	total: 80.3ms	remaining: 68.4ms
# 27:	learn: 0.4844037	total: 85ms	remaining: 66.8ms
# 28:	learn: 0.4824159	total: 91.1ms	remaining: 66ms
# 29:	learn: 0.4796421	total: 93.4ms	remaining: 62.3ms
# 30:	learn: 0.4784848	total: 95.2ms	remaining: 58.4ms
# 31:	learn: 0.4770140	total: 97.4ms	remaining: 54.8ms
# 32:	learn: 0.4755292	total: 101ms	remaining: 52.2ms
# 33:	learn: 0.4736870	total: 105ms	remaining: 49.6ms
# 34:	learn: 0.4725751	total: 107ms	remaining: 45.9ms
# 35:	learn: 0.4714903	total: 109ms	remaining: 42.4ms
# 36:	learn: 0.4702080	total: 111ms	remaining: 39ms
# 37:	learn: 0.4686259	total: 115ms	remaining: 36.4ms
# 38:	learn: 0.4668662	total: 123ms	remaining: 34.8ms
# 39:	learn: 0.4654142	total: 130ms	remaining: 32.4ms
# 40:	learn: 0.4645074	total: 139ms	remaining: 30.4ms
# 41:	learn: 0.4633896	total: 141ms	remaining: 26.8ms
# 42:	learn: 0.4627048	total: 143ms	remaining: 23.2ms
# 43:	learn: 0.4619512	total: 144ms	remaining: 19.7ms
# 44:	learn: 0.4611496	total: 146ms	remaining: 16.3ms
# 45:	learn: 0.4607337	total: 148ms	remaining: 12.9ms
# 46:	learn: 0.4601842	total: 150ms	remaining: 9.61ms
# 47:	learn: 0.4585980	total: 153ms	remaining: 6.36ms
# 48:	learn: 0.4570621	total: 155ms	remaining: 3.16ms
# 49:	learn: 0.4561153	total: 157ms	remaining: 0us
# 0:	learn: 0.5971439	total: 3.43ms	remaining: 168ms
# 1:	learn: 0.5389895	total: 8.36ms	remaining: 201ms
# 2:	learn: 0.5135602	total: 10.3ms	remaining: 161ms
# 3:	learn: 0.4947828	total: 12.4ms	remaining: 142ms
# 4:	learn: 0.4851506	total: 14.4ms	remaining: 130ms
# 5:	learn: 0.4755304	total: 16.6ms	remaining: 121ms
# 6:	learn: 0.4660144	total: 18.7ms	remaining: 115ms
# 7:	learn: 0.4601109	total: 21.4ms	remaining: 112ms
# 8:	learn: 0.4575028	total: 24.4ms	remaining: 111ms
# 9:	learn: 0.4557699	total: 29.9ms	remaining: 120ms
# 10:	learn: 0.4528853	total: 32ms	remaining: 113ms
# 11:	learn: 0.4469870	total: 33.8ms	remaining: 107ms
# 12:	learn: 0.4450353	total: 37.9ms	remaining: 108ms
# 13:	learn: 0.4397465	total: 39.9ms	remaining: 103ms
# 14:	learn: 0.4344191	total: 41.8ms	remaining: 97.4ms
# 15:	learn: 0.4315209	total: 49.7ms	remaining: 106ms
# 16:	learn: 0.4292080	total: 51.8ms	remaining: 100ms
# 17:	learn: 0.4271737	total: 54.3ms	remaining: 96.5ms
# 18:	learn: 0.4253829	total: 56.5ms	remaining: 92.2ms
# 19:	learn: 0.4244192	total: 59ms	remaining: 88.5ms
# 20:	learn: 0.4228100	total: 61.3ms	remaining: 84.7ms
# 21:	learn: 0.4211187	total: 63.8ms	remaining: 81.2ms
# 22:	learn: 0.4194476	total: 65.6ms	remaining: 77ms
# 23:	learn: 0.4173506	total: 67.5ms	remaining: 73.1ms
# 24:	learn: 0.4158500	total: 69.2ms	remaining: 69.2ms
# 25:	learn: 0.4145764	total: 71.2ms	remaining: 65.7ms
# 26:	learn: 0.4138234	total: 76.4ms	remaining: 65.1ms
# 27:	learn: 0.4126832	total: 78.2ms	remaining: 61.4ms
# 28:	learn: 0.4119080	total: 80.1ms	remaining: 58ms
# 29:	learn: 0.4110514	total: 82ms	remaining: 54.7ms
# 30:	learn: 0.4096426	total: 84ms	remaining: 51.5ms
# 31:	learn: 0.4082774	total: 86.2ms	remaining: 48.5ms
# 32:	learn: 0.4073305	total: 88.5ms	remaining: 45.6ms
# 33:	learn: 0.4066046	total: 90.4ms	remaining: 42.6ms
# 34:	learn: 0.4057696	total: 92.6ms	remaining: 39.7ms
# 35:	learn: 0.4052974	total: 95.1ms	remaining: 37ms
# 36:	learn: 0.4041787	total: 97.1ms	remaining: 34.1ms
# 37:	learn: 0.4034513	total: 99.5ms	remaining: 31.4ms
# 38:	learn: 0.4030511	total: 102ms	remaining: 28.9ms
# 39:	learn: 0.4023452	total: 105ms	remaining: 26.1ms
# 40:	learn: 0.4016898	total: 107ms	remaining: 23.6ms
# 41:	learn: 0.4009850	total: 110ms	remaining: 20.9ms
# 42:	learn: 0.4003352	total: 113ms	remaining: 18.3ms
# 43:	learn: 0.3998850	total: 115ms	remaining: 15.7ms
# 44:	learn: 0.3986491	total: 119ms	remaining: 13.2ms
# 45:	learn: 0.3981593	total: 121ms	remaining: 10.5ms
# 46:	learn: 0.3973748	total: 123ms	remaining: 7.84ms
# 47:	learn: 0.3966704	total: 125ms	remaining: 5.21ms
# 48:	learn: 0.3961983	total: 127ms	remaining: 2.59ms
# 49:	learn: 0.3955224	total: 129ms	remaining: 0us
# 0:	learn: 0.6903745	total: 1.76ms	remaining: 174ms
# 1:	learn: 0.6870488	total: 5.59ms	remaining: 274ms
# 2:	learn: 0.6836393	total: 9.5ms	remaining: 307ms
# 3:	learn: 0.6811952	total: 13.4ms	remaining: 321ms
# 4:	learn: 0.6784745	total: 17.2ms	remaining: 327ms
# 5:	learn: 0.6753218	total: 19.1ms	remaining: 298ms
# 6:	learn: 0.6721253	total: 24.3ms	remaining: 322ms
# 7:	learn: 0.6697828	total: 27.9ms	remaining: 321ms
# 8:	learn: 0.6668605	total: 31.7ms	remaining: 321ms
# 9:	learn: 0.6643634	total: 35.2ms	remaining: 316ms
# 10:	learn: 0.6621738	total: 36.7ms	remaining: 297ms
# 11:	learn: 0.6599089	total: 42ms	remaining: 308ms
# 12:	learn: 0.6576528	total: 45.5ms	remaining: 305ms
# 13:	learn: 0.6548308	total: 49.2ms	remaining: 302ms
# 14:	learn: 0.6525659	total: 55ms	remaining: 312ms
# 15:	learn: 0.6503761	total: 57.7ms	remaining: 303ms
# 16:	learn: 0.6478134	total: 61.8ms	remaining: 302ms
# 17:	learn: 0.6452629	total: 67.9ms	remaining: 309ms
# 18:	learn: 0.6431403	total: 69.8ms	remaining: 298ms
# 19:	learn: 0.6411076	total: 74.9ms	remaining: 299ms
# 20:	learn: 0.6391692	total: 79.5ms	remaining: 299ms
# 21:	learn: 0.6373542	total: 85.6ms	remaining: 303ms
# 22:	learn: 0.6354622	total: 87.2ms	remaining: 292ms
# 23:	learn: 0.6334261	total: 93.8ms	remaining: 297ms
# 24:	learn: 0.6311997	total: 97.9ms	remaining: 294ms
# 25:	learn: 0.6296821	total: 99.5ms	remaining: 283ms
# 26:	learn: 0.6277343	total: 105ms	remaining: 285ms
# 27:	learn: 0.6260152	total: 113ms	remaining: 290ms
# 28:	learn: 0.6243761	total: 116ms	remaining: 283ms
# 29:	learn: 0.6227720	total: 117ms	remaining: 274ms
# 30:	learn: 0.6209300	total: 122ms	remaining: 271ms
# 31:	learn: 0.6194647	total: 126ms	remaining: 267ms
# 32:	learn: 0.6175396	total: 128ms	remaining: 259ms
# 33:	learn: 0.6160339	total: 133ms	remaining: 258ms
# 34:	learn: 0.6145089	total: 137ms	remaining: 255ms
# 35:	learn: 0.6130921	total: 141ms	remaining: 251ms
# 36:	learn: 0.6111547	total: 144ms	remaining: 246ms
# 37:	learn: 0.6097521	total: 146ms	remaining: 239ms
# 38:	learn: 0.6079601	total: 159ms	remaining: 249ms
# 39:	learn: 0.6065194	total: 167ms	remaining: 251ms
# 40:	learn: 0.6048152	total: 171ms	remaining: 247ms
# 41:	learn: 0.6034832	total: 179ms	remaining: 248ms
# 42:	learn: 0.6022301	total: 183ms	remaining: 243ms
# 43:	learn: 0.6008652	total: 185ms	remaining: 236ms
# 44:	learn: 0.5996569	total: 187ms	remaining: 229ms
# 45:	learn: 0.5984759	total: 189ms	remaining: 222ms
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2993, number of negative: 2918
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000750 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1953
# [LightGBM] [Info] Number of data points in the train set: 5911, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506344 -> initscore=0.025378
# [LightGBM] [Info] Start training from score 0.025378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 2984, number of negative: 2928
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000853 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1956
# [LightGBM] [Info] Number of data points in the train set: 5912, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504736 -> initscore=0.018945
# [LightGBM] [Info] Start training from score 0.018945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
metrics.sort(key=lambda x: x[1], reverse=True)

print("\nSorted model metrics (by accuracy):")
for metric in metrics:
    print(f"Model: {metric[0]}, Accuracy: {metric[1]:.3f}, Precision: {metric[2]:.3f}, Recall: {metric[3]:.3f}")
# Out:
# Sorted model metrics (by accuracy):
# Model: catboost, Accuracy: 0.797, Precision: 0.776, Recall: 0.830
# Model: lightgbm, Accuracy: 0.795, Precision: 0.779, Recall: 0.819
# Model: xgboost, Accuracy: 0.794, Precision: 0.768, Recall: 0.839
# Model: gradientboost, Accuracy: 0.789, Precision: 0.764, Recall: 0.832
# Model: adaboost, Accuracy: 0.766, Precision: 0.761, Recall: 0.771
# Model: logistic, Accuracy: 0.765, Precision: 0.752, Recall: 0.787
# Model: randomforest, Accuracy: 0.762, Precision: 0.779, Recall: 0.726
# Model: knn, Accuracy: 0.738, Precision: 0.752, Recall: 0.705

# %% [markdown]
# # 9. Apply ensemble method on the test set

# %%
from sklearn.ensemble import VotingClassifier

top_models = [name for name, _, _, _ in metrics[:5]]

estimators = [(name, best_estimators[name]) for name in top_models]

ensemble_model = VotingClassifier(estimators=estimators, voting='soft', n_jobs=-1)

ensemble_model.fit(X, y)

test_df = test_df.drop("Transported",axis=1)
test_predictions = ensemble_model.predict(test_df)
test_predictions = test_predictions.astype(bool)
# Out:
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 4378, number of negative: 4315
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001198 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1971
# [LightGBM] [Info] Number of data points in the train set: 8693, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503624 -> initscore=0.014495
# [LightGBM] [Info] Start training from score 0.014495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0:	learn: 0.6534607	total: 6.81ms	remaining: 1.01s
# 1:	learn: 0.6208866	total: 12.8ms	remaining: 946ms
# 2:	learn: 0.5982503	total: 16.2ms	remaining: 793ms
# 3:	learn: 0.5752141	total: 20.7ms	remaining: 754ms
# 4:	learn: 0.5598762	total: 26.5ms	remaining: 768ms
# 5:	learn: 0.5461717	total: 30.6ms	remaining: 735ms
# 6:	learn: 0.5327222	total: 34.1ms	remaining: 698ms
# 7:	learn: 0.5227910	total: 36.9ms	remaining: 655ms
# 8:	learn: 0.5154181	total: 40.4ms	remaining: 634ms
# 9:	learn: 0.5075849	total: 43.3ms	remaining: 606ms
# 10:	learn: 0.5003343	total: 46.1ms	remaining: 583ms
# 11:	learn: 0.4932974	total: 49.9ms	remaining: 573ms
# 12:	learn: 0.4878606	total: 52.6ms	remaining: 554ms
# 13:	learn: 0.4822339	total: 56.7ms	remaining: 551ms
# 14:	learn: 0.4779290	total: 59.6ms	remaining: 536ms
# 15:	learn: 0.4730304	total: 62.9ms	remaining: 527ms
# 16:	learn: 0.4698175	total: 66.1ms	remaining: 517ms
# 17:	learn: 0.4664145	total: 69.4ms	remaining: 509ms
# 18:	learn: 0.4627330	total: 72.4ms	remaining: 499ms
# 19:	learn: 0.4607263	total: 75.7ms	remaining: 492ms
# 20:	learn: 0.4584256	total: 78.3ms	remaining: 481ms
# 21:	learn: 0.4565209	total: 81.9ms	remaining: 476ms
# 22:	learn: 0.4540124	total: 84.6ms	remaining: 467ms
# 23:	learn: 0.4517791	total: 87.6ms	remaining: 460ms
# 24:	learn: 0.4505386	total: 90.9ms	remaining: 454ms
# 25:	learn: 0.4480753	total: 93.6ms	remaining: 447ms
# 26:	learn: 0.4460186	total: 97ms	remaining: 442ms
# 27:	learn: 0.4443554	total: 99.7ms	remaining: 435ms
# 28:	learn: 0.4433421	total: 103ms	remaining: 428ms
# 29:	learn: 0.4417192	total: 106ms	remaining: 424ms
# 30:	learn: 0.4406276	total: 109ms	remaining: 417ms
# 31:	learn: 0.4393544	total: 115ms	remaining: 423ms
# 32:	learn: 0.4380857	total: 120ms	remaining: 425ms
# 33:	learn: 0.4370130	total: 126ms	remaining: 429ms
# 34:	learn: 0.4363423	total: 132ms	remaining: 434ms
# 35:	learn: 0.4349483	total: 138ms	remaining: 438ms
# 36:	learn: 0.4339809	total: 145ms	remaining: 443ms
# 37:	learn: 0.4324515	total: 152ms	remaining: 447ms
# 38:	learn: 0.4315041	total: 155ms	remaining: 442ms
# 39:	learn: 0.4305829	total: 161ms	remaining: 443ms
# 40:	learn: 0.4296207	total: 166ms	remaining: 443ms
# 41:	learn: 0.4287402	total: 175ms	remaining: 449ms
# 42:	learn: 0.4282411	total: 181ms	remaining: 449ms
# 43:	learn: 0.4274074	total: 187ms	remaining: 450ms
# 44:	learn: 0.4264574	total: 193ms	remaining: 449ms
# 45:	learn: 0.4257138	total: 198ms	remaining: 449ms
# 46:	learn: 0.4245670	total: 202ms	remaining: 443ms
# 47:	learn: 0.4240714	total: 212ms	remaining: 450ms
# 48:	learn: 0.4222977	total: 218ms	remaining: 450ms
# 49:	learn: 0.4213420	total: 223ms	remaining: 447ms
# 50:	learn: 0.4205017	total: 228ms	remaining: 443ms
# 51:	learn: 0.4195325	total: 235ms	remaining: 443ms
# 52:	learn: 0.4185748	total: 242ms	remaining: 442ms
# 53:	learn: 0.4179672	total: 249ms	remaining: 443ms
# 54:	learn: 0.4173882	total: 255ms	remaining: 440ms
# 55:	learn: 0.4154176	total: 261ms	remaining: 438ms
# 56:	learn: 0.4147232	total: 268ms	remaining: 437ms
# 57:	learn: 0.4142170	total: 275ms	remaining: 436ms
# 58:	learn: 0.4132712	total: 282ms	remaining: 435ms
# 59:	learn: 0.4127122	total: 287ms	remaining: 431ms
# 60:	learn: 0.4122066	total: 292ms	remaining: 426ms
# 61:	learn: 0.4117011	total: 299ms	remaining: 424ms
# 62:	learn: 0.4110465	total: 302ms	remaining: 417ms
# 63:	learn: 0.4102405	total: 315ms	remaining: 423ms
# 64:	learn: 0.4095543	total: 320ms	remaining: 419ms
# 65:	learn: 0.4089902	total: 326ms	remaining: 415ms
# 66:	learn: 0.4087367	total: 333ms	remaining: 412ms
# 67:	learn: 0.4082077	total: 339ms	remaining: 409ms
# 68:	learn: 0.4078449	total: 347ms	remaining: 407ms
# 69:	learn: 0.4074448	total: 356ms	remaining: 406ms
# 70:	learn: 0.4068020	total: 365ms	remaining: 406ms
# 71:	learn: 0.4063062	total: 370ms	remaining: 401ms
# 72:	learn: 0.4059319	total: 378ms	remaining: 399ms
# 73:	learn: 0.4056133	total: 385ms	remaining: 395ms
# 74:	learn: 0.4051143	total: 391ms	remaining: 391ms
# 75:	learn: 0.4047814	total: 398ms	remaining: 387ms
# 76:	learn: 0.4042282	total: 405ms	remaining: 384ms
# 77:	learn: 0.4037302	total: 412ms	remaining: 380ms
# 78:	learn: 0.4033287	total: 418ms	remaining: 376ms
# 79:	learn: 0.4030506	total: 425ms	remaining: 372ms
# 80:	learn: 0.4021376	total: 433ms	remaining: 369ms
# 81:	learn: 0.4017081	total: 436ms	remaining: 362ms
# 82:	learn: 0.4013864	total: 445ms	remaining: 359ms
# 83:	learn: 0.4012151	total: 452ms	remaining: 355ms
# 84:	learn: 0.4010674	total: 459ms	remaining: 351ms
# 85:	learn: 0.4007490	total: 463ms	remaining: 345ms
# 86:	learn: 0.3995662	total: 471ms	remaining: 341ms
# 87:	learn: 0.3990898	total: 479ms	remaining: 337ms
# 88:	learn: 0.3986122	total: 484ms	remaining: 332ms

# %%
submission = pd.DataFrame([test_data['PassengerId'], test_predictions]).T
submission.columns = ['PassengerID', 'Transported']

# %%
submission.head()
# Out:
#   PassengerID Transported
# 0     0013_01        True
# 1     0018_01       False
# 2     0019_01        True
# 3     0021_01        True
# 4     0023_01        True

# %%
submission.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
