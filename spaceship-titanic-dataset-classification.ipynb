# %% [markdown]
# <a href="https://www.kaggle.com/code/averilkan/spaceship-titanic-dataset-classification?scriptVersionId=221786752" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 💡 About The Competition: Spaceship Titanic
#
# Task:
# The objective of this task is to predict whether a passenger was transported to an alternate dimension aboard the Spaceship Titanic. This binary classification problem requires the model to predict the 'Transported' status (True or False) for each passenger in the test dataset, based on a variety of features provided.
#
# Dataset:
# The dataset for this competition includes information about passengers aboard the fictional spaceship Titanic. Features include demographic data, cabin information, and details about their in-ship expenditures. The target variable is Transported.
#
# Exploration:
# Begin with exploratory data analysis (EDA) to understand the distribution and relationships of features. Utilize visualization techniques to identify patterns and anomalies that could influence the predictive model's performance.
#
# Evaluation:
# Submissions are evaluated on the accuracy of the predictions. A higher accuracy score indicates a more effective model at classifying passengers' transportation status.
#
# Submission Files:
# train.csv - The training dataset, including the target variable Transported.
# test.csv - The test dataset, where predictions are to be made.
# sample_submission.csv - A sample submission file in the correct format.
# Evaluation Metric:
# The competition uses accuracy as the metric for evaluating submissions. This metric assesses the proportion of correctly predicted outcomes to total predictions.

# %% [markdown]
# # 1. Importing libraries

# %% [markdown]
# ## 💡 About The Packages:
#
# - **NumPy** and **Pandas** for data manipulation and analysis.
# - **Matplotlib** and **Seaborn** for data visualization.
# - **Warnings** to manage warning messages.
# - **lazypredict** for quick model comparison.
# - **Scikit-learn**, **XGBoost**, **LightGBM**, **CatBoost**, and other machine learning libraries for model building and evaluation.

# %%
# !pip install lazypredict

import tensorflow as tf
import tensorflow_decision_forests as tfdf
import xgboost as xgb
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import category_encoders as ce

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score

from hyperopt import hp, fmin, tpe, Trials

from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.13-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.4.0)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.2.0)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Downloading lazypredict-0.2.13-py2.py3-none-any.whl (12 kB)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.13
# 2025-02-10 11:48:51.379228: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-10 11:48:51.379449: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-10 11:48:51.545492: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # 2. Reading the Datasets
#
# We start by reading the training and test datasets using the Pandas library. The training dataset contains the target variable `Transported`, which indicates whether a passenger was transported to another dimension. We convert this column to an integer type for compatibility with machine learning algorithms.
#
# We then concatenate the train and test datasets for combined preprocessing and feature engineering. This helps to ensure consistency in data processing and avoid data leakage.

# %%
train_data = pd.read_csv("/kaggle/input/spaceship-titanic/train.csv")
train_data['Transported'] = train_data['Transported'].astype(int)
train_data.head()

test_data = pd.read_csv("/kaggle/input/spaceship-titanic/test.csv")
test_data.head()

train_data['Source'] = 'train'
test_data['Source'] = 'test'

df = pd.concat([train_data, test_data], axis=0)

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis (EDA) involves summarizing and visualizing the main characteristics of the data. This step helps us understand the structure of the dataset, identify patterns, detect anomalies, and check assumptions.
#
# We create a summary function to give an overview of the dataset, including:
# - The number of unique values in each column.
# - The number of missing values in each column.
# - The data types of each column.
#
# This overview helps us identify any issues that need to be addressed during data preprocessing.

# %%
def summary(df):
    print(f"Dataset has {df.shape[1]} features and {df.shape[0]} examples.")
    summary = pd.DataFrame(index=df.columns)
    summary["Unique"] = df.nunique().values
    summary["Missing"] = df.isnull().sum().values
    summary["Duplicated"] = df.duplicated().sum()
    summary["Types"] = df.dtypes
    return summary

summary(df)
# Out:
# Dataset has 15 features and 12970 examples.
#               Unique  Missing  Duplicated    Types
# PassengerId    12970        0           0   object
# HomePlanet         3      288           0   object
# CryoSleep          2      310           0   object
# Cabin           9825      299           0   object
# Destination        3      274           0   object
# Age               80      270           0  float64
# VIP                2      296           0   object
# RoomService     1578      263           0  float64
# FoodCourt       1953      289           0  float64
# ShoppingMall    1367      306           0  float64
# Spa             1679      284           0  float64
# VRDeck          1642      268           0  float64
# Name           12629      294           0   object
# Transported        2     4277           0  float64
# Source             2        0           0   object

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ### 4.1 Extract Group Size from `PassengerId`
#
# A unique Id for each passenger takes the form `gggg_pp` where `gggg` indicates a group the passenger is travelling with and `pp` is their number within the group. People in a group are often family members, but not always. Extracting the group size can help us understand the potential impact of group travel on the likelihood of being transported.

# %%
group = df['PassengerId'].apply(lambda x: x.split('_')[0]).value_counts().to_dict()
df['Group_size'] = df['PassengerId'].apply(lambda x: group[x.split('_')[0]])
df.set_index('PassengerId', inplace=True)

# %% [markdown]
# ### 4.2 Handle Missing Values in `HomePlanet`
#
# The `HomePlanet` column indicates the planet the passenger is from. To fill missing values, we use a random selection based on the distribution of existing values in the column. This helps maintain the original distribution of `HomePlanet` in the dataset.

# %%
v = df['HomePlanet'].value_counts().index
p = df['HomePlanet'].value_counts(normalize=True).values
df.loc[df['HomePlanet'].isna(), 'HomePlanet'] = np.random.choice(v, df['HomePlanet'].isna().sum(), p=p)

# %% [markdown]
# ### 4.3 Handle Missing Values in CryoSleep
#
# The `CryoSleep` column indicates whether the passenger elected to be put into suspended animation for the duration of the voyage. Given that being in CryoSleep is a notable status that would likely be recorded, missing values are assumed to indicate passengers were not in CryoSleep. Thus, we fill missing values with 0 and convert this column to an integer type.

# %%
df['CryoSleep'] = df['CryoSleep'].fillna(0).astype(int)

# %% [markdown]
# ### 4.4 Extract Cabin Components and Handle Missing Values
#
# The `Cabin` column provides information about the passenger's cabin, including the deck, number, and side. We extract these components into separate columns and handle missing values by randomly assigning values based on the distribution of the existing data.

# %%
tmp = df['Cabin'].apply(lambda x: x.split('/') if isinstance(x, str) else ['-1', '-1', '-1']).to_list()
tmp = np.array(tmp)

df['Cabin_deck'] = tmp[:, 0]
df['Cabin_num'] = tmp[:, 1].astype(int)
df['Cabin_side'] = pd.Series(tmp[:, 2]).map({'S': 0, 'P': 1})

df.drop(columns='Cabin', inplace=True)

df.loc[df['Cabin_deck'] == '-1', 'Cabin_deck'] = np.random.choice(['F', 'G'], sum(df['Cabin_deck'] == '-1'), p=[0.5, 0.5])
df.loc[df['Cabin_side'].isna(), 'Cabin_side'] = np.random.choice([0, 1], sum(df['Cabin_side'].isna()), p=[0.5, 0.5])

# %% [markdown]
# ### 4.5 Handle Missing Values in `Destination`
#
# The `Destination` column indicates the destination of the passenger. We fill missing values by randomly assigning values based on the distribution of the existing data. This maintains the original distribution of `Destination` in the dataset.

# %%
v = df['Destination'].value_counts().index
p = df['Destination'].value_counts(normalize=True).values
df.loc[df['Destination'].isna(), 'Destination'] = np.random.choice(v, df['Destination'].isna().sum(), p=p)

# %% [markdown]
# ### 4.6 Handle Missing Values in `Age`
#
# The `Age` column indicates the age of the passenger. To fill missing values, we use a random sample from a normal distribution with the mean and standard deviation of the existing ages. This helps maintain the original distribution of `Age` in the dataset.

# %%
mean_age = df["Age"].mean()
std_age = df["Age"].std()
is_null = df["Age"].isnull().sum()
rand_sample = np.random.uniform(mean_age - std_age, mean_age + std_age, size = is_null)
df.loc[df['Age'].isna(), 'Age'] = rand_sample

# %% [markdown]
# ### 4.7 Handle Missing Values in `VIP`
#
# The `VIP` column indicates whether the passenger paid for special VIP service during the voyage. We fill missing values with `False` (0), assuming that most passengers did not opt for VIP service. We then convert this column to an integer type.

# %%
df['VIP'] = df['VIP'].fillna(0).astype(int)

# %% [markdown]
# ### 4.8 Handle Missing Values in Spending Columns
#
# The columns `RoomService`, `FoodCourt`, `ShoppingMall`, `Spa`, and `VRDeck` represent the amount of money spent by the passenger on various amenities. We fill missing values with the median value of each column. This helps maintain the original distribution of spending in the dataset.

# %%
cols = ['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']

for col in cols:
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# ### 4.9 Create Total Spending Feature
#
# We create a new feature `total_spending` by summing the values of the spending columns. This feature represents the total amount of money spent by the passenger on various amenities during the voyage. We then apply a logarithmic transformation to normalize the spending data, making it easier for the model to learn from.

# %%
df['total_spending'] = df['RoomService'] + df['FoodCourt'] + df['ShoppingMall'] + df['Spa'] + df['VRDeck']

for col in cols + ['total_spending']:
    df.loc[df[col]==0, col] = 0.367
    df[col] = np.log(df[col])

# %% [markdown]
# ### 4.10 Drop the Name column as it does not contain valuable information

# %%
df.drop(columns='Name', inplace=True)

# %% [markdown]
# # 5. One-Hot Encoding for Categorical Features
#
# One-hot encoding is a technique to convert categorical variables into numerical format. This step is crucial for machine learning algorithms, as they require numerical input.
#
# We apply one-hot encoding to the categorical features `HomePlanet`, `Destination`, and `Cabin_deck`. This creates new binary columns for each category, allowing the model to understand and use the categorical data effectively.

# %%
categorical_features = ['HomePlanet', 'Destination', 'Cabin_deck']
df = pd.concat([df, pd.get_dummies(df[categorical_features], dtype=int)], axis=1)
df.drop(columns=categorical_features, inplace=True)

# %% [markdown]
# # 6. Splitting Data back to Train and Test Sets
#
# After preprocessing and feature engineering, we split the combined dataset back into the original training and test sets. This ensures that we maintain the original structure of the data, with the training set used to train the model and the test set used to evaluate its performance.
#
# We also separate the target variable `Transported` from the training data, as this is what we aim to predict.

# %%
train_df = df[df['Source'] == 'train'].drop(columns=['Source'])
test_df = df[df['Source'] == 'test'].drop(columns=['Source'])

X = train_df.drop(columns=['Transported'])
y = train_df['Transported']

train_df.head()
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8693 entries, 0001_01 to 9280_02
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CryoSleep                  8693 non-null   int64
#  1   Age                        8693 non-null   float64
#  2   VIP                        8693 non-null   int64
#  3   RoomService                8693 non-null   float64
#  4   FoodCourt                  8693 non-null   float64
#  5   ShoppingMall               8693 non-null   float64
#  6   Spa                        8693 non-null   float64
#  7   VRDeck                     8693 non-null   float64
#  8   Transported                8693 non-null   float64
#  9   Group_size                 8693 non-null   int64
#  10  Cabin_num                  8693 non-null   int64
#  11  Cabin_side                 8693 non-null   float64
#  12  total_spending             8693 non-null   float64
#  13  HomePlanet_Earth           8693 non-null   int64
#  14  HomePlanet_Europa          8693 non-null   int64
#  15  HomePlanet_Mars            8693 non-null   int64
#  16  Destination_55 Cancri e    8693 non-null   int64
#  17  Destination_PSO J318.5-22  8693 non-null   int64
#  18  Destination_TRAPPIST-1e    8693 non-null   int64
#  19  Cabin_deck_A               8693 non-null   int64
#  20  Cabin_deck_B               8693 non-null   int64
#  21  Cabin_deck_C               8693 non-null   int64
#  22  Cabin_deck_D               8693 non-null   int64
#  23  Cabin_deck_E               8693 non-null   int64
#  24  Cabin_deck_F               8693 non-null   int64
#  25  Cabin_deck_G               8693 non-null   int64
#  26  Cabin_deck_T               8693 non-null   int64
# dtypes: float64(9), int64(18)
# memory usage: 1.9+ MB

# %% [markdown]
# # 7. Initial Model Comparison with LazyPredict
#
# We will use the LazyPredict library to quickly compare the performance of different machine learning models. LazyPredict provides an easy-to-use interface to fit multiple models and get a quick overview of their performance.

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

X = train_df.drop('Transported', axis=1)
y = train_df['Transported'].astype(int)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
#  97%|█████████▋| 28/29 [00:26<00:00,  1.47it/s]
# [LightGBM] [Info] Number of positive: 3731, number of negative: 3658
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003610 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1964
# [LightGBM] [Info] Number of data points in the train set: 7389, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504940 -> initscore=0.019760
# [LightGBM] [Info] Start training from score 0.019760
# 100%|██████████| 29/29 [00:26<00:00,  1.09it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.80               0.80     0.80      0.80
# XGBClassifier                      0.78               0.78     0.78      0.78
# RandomForestClassifier             0.78               0.78     0.78      0.78
# AdaBoostClassifier                 0.78               0.78     0.78      0.78
# SVC                                0.78               0.78     0.78      0.78
# NuSVC                              0.77               0.77     0.77      0.77
# ExtraTreesClassifier               0.77               0.77     0.77      0.77
# BaggingClassifier                  0.77               0.77     0.77      0.77
# LogisticRegression                 0.77               0.77     0.77      0.77
# RidgeClassifierCV                  0.77               0.77     0.77      0.77
# LinearSVC                          0.77               0.77     0.77      0.77
# RidgeClassifier                    0.77               0.77     0.77      0.77
# LinearDiscriminantAnalysis         0.77               0.77     0.77      0.77
# CalibratedClassifierCV             0.77               0.77     0.77      0.77
# SGDClassifier                      0.76               0.76     0.76      0.76
# GaussianNB                         0.74               0.74     0.74      0.74
# DecisionTreeClassifier             0.74               0.74     0.74      0.74
# KNeighborsClassifier               0.74               0.74     0.74      0.74
# NearestCentroid                    0.74               0.74     0.74      0.74
# BernoulliNB                        0.74               0.73     0.73      0.73
# QuadraticDiscriminantAnalysis      0.73               0.73     0.73      0.73
# ExtraTreeClassifier                0.73               0.73     0.73      0.73
# LabelSpreading                     0.71               0.71     0.71      0.71
# LabelPropagation                   0.71               0.71     0.71      0.71
# PassiveAggressiveClassifier        0.70               0.70     0.70      0.70
# Perceptron                         0.63               0.64     0.64      0.63
# DummyClassifier                    0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# LGBMClassifier                       0.28
# XGBClassifier                        0.31
# RandomForestClassifier               1.29
# AdaBoostClassifier                   0.46
# SVC                                  2.73
# NuSVC                                4.00
# ExtraTreesClassifier                 0.90
# BaggingClassifier                    0.39
# LogisticRegression                   0.18
# RidgeClassifierCV                    0.18
# LinearSVC                            1.06
# RidgeClassifier                      0.07
# LinearDiscriminantAnalysis           0.16
# CalibratedClassifierCV               4.27
# SGDClassifier                        0.18
# GaussianNB                           0.03
# DecisionTreeClassifier               0.10
# KNeighborsClassifier                 0.15
# NearestCentroid                      0.09
# BernoulliNB                          0.07
# QuadraticDiscriminantAnalysis        0.10
# ExtraTreeClassifier                  0.03
# LabelSpreading                       5.54
# LabelPropagation                     3.35
# PassiveAggressiveClassifier          0.09
# Perceptron                           0.23
# DummyClassifier                      0.02

# %% [markdown]
# # 8. Detailed Modeling with Pipelines and GridSearchCV
#
# For a more detailed evaluation and fine-tuning, we will use several classifiers with pipelines and GridSearchCV. We will use k-fold cross-validation to ensure a robust estimation of model performance.
#
# We will perform the following steps:
#
# 1. Set up the models and pipelines.
# 2. Define the hyperparameter grids for each model.
# 3. Use GridSearchCV with k-fold cross-validation to find the best parameters for each model.
# 4. Evaluate the performance of the best models on the test set.

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.metrics import accuracy_score

pipelines = {
    'adaboost': make_pipeline(StandardScaler(), AdaBoostClassifier(random_state=123)),
    'xgboost': make_pipeline(StandardScaler(), XGBClassifier(random_state=123)),
    'catboost': make_pipeline(StandardScaler(), CatBoostClassifier(random_state=123)),
    'gradientboost': make_pipeline(StandardScaler(), GradientBoostingClassifier(random_state=123)),
    'lightgbm': make_pipeline(StandardScaler(), LGBMClassifier(random_state=123)),
    'randomforest': make_pipeline(StandardScaler(), RandomForestClassifier(random_state=123)),
    'logistic': make_pipeline(StandardScaler(), LogisticRegression(random_state=123)),
    'knn': make_pipeline(StandardScaler(), KNeighborsClassifier())
}

grid = {
    'adaboost': {
        'adaboostclassifier__n_estimators': [50, 100, 150],
        'adaboostclassifier__learning_rate': [0.01, 0.05, 0.1]
    },
    'xgboost': {
        'xgbclassifier__n_estimators': [50, 100, 150],
        'xgbclassifier__learning_rate': [0.01, 0.05],
        'xgbclassifier__max_depth': [3, 4],
        'xgbclassifier__gamma': [0.1, 0.2],
        'xgbclassifier__subsample': [0.6, 0.8]
    },
    'catboost': {
        'catboostclassifier__learning_rate': [0.01, 0.05, 0.1, 0.5],
        'catboostclassifier__depth': [2, 3, 4], 
        'catboostclassifier__iterations': [50, 100, 150]
    },
    'gradientboost': {
        'gradientboostingclassifier__n_estimators': [50, 100, 150],
        'gradientboostingclassifier__learning_rate': [0.01, 0.05],
        'gradientboostingclassifier__max_depth': [3, 4],
        'gradientboostingclassifier__subsample': [0.6, 0.8]
    },
    'lightgbm': {
        'lgbmclassifier__n_estimators': [50, 100, 150],
        'lgbmclassifier__learning_rate': [0.01, 0.05],
        'lgbmclassifier__max_depth': [3, 4],
        'lgbmclassifier__subsample': [0.6, 0.8]
    },
    'randomforest': {
        'randomforestclassifier__n_estimators': [50, 100, 150],
        'randomforestclassifier__max_depth': [3, 4, 5],
        'randomforestclassifier__min_samples_split': [2, 3, 4]
    },
    'logistic': {
        'logisticregression__C': [0.01, 0.1, 1, 10]
    },
    'knn': {
        'kneighborsclassifier__n_neighbors': [3, 5, 7],
        'kneighborsclassifier__weights': ['uniform', 'distance'],
        'kneighborsclassifier__metric': ['euclidean', 'manhattan']
    }
}

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

best_estimators = {}
kf = KFold(n_splits=5, shuffle=True, random_state=42)

metrics = []

for name, pipeline in pipelines.items():
    grid_search = GridSearchCV(pipeline, grid[name], cv=kf, n_jobs=-1, verbose=0)
    grid_search.fit(X_train, y_train)
    best_estimators[name] = grid_search.best_estimator_
    yhat = grid_search.predict(X_test)
    accuracy = accuracy_score(y_test, yhat)
    precision = precision_score(y_test, yhat)
    recall = recall_score(y_test, yhat)
    metrics.append((name, accuracy, precision, recall))
    print(f'Metrics for {name}: accuracy- {accuracy:.3f}, precision- {precision:.3f}, recall- {recall:.3f}')
    print(f"Best parameters for {name}: {grid_search.best_params_}")
# Out:
# Metrics for adaboost: accuracy- 0.766, precision- 0.759, recall- 0.774
# Best parameters for adaboost: {'adaboostclassifier__learning_rate': 0.1, 'adaboostclassifier__n_estimators': 150}
# Metrics for xgboost: accuracy- 0.795, precision- 0.777, recall- 0.824
# Best parameters for xgboost: {'xgbclassifier__gamma': 0.2, 'xgbclassifier__learning_rate': 0.05, 'xgbclassifier__max_depth': 4, 'xgbclassifier__n_estimators': 150, 'xgbclassifier__subsample': 0.8}
# 0:	learn: 0.6903281	total: 54.6ms	remaining: 2.68s
# 1:	learn: 0.6874752	total: 56.9ms	remaining: 1.36s
# 2:	learn: 0.6841411	total: 58.7ms	remaining: 919ms
# 3:	learn: 0.6814745	total: 60.6ms	remaining: 696ms
# 4:	learn: 0.6788558	total: 62.5ms	remaining: 562ms
# 5:	learn: 0.6756894	total: 64.4ms	remaining: 472ms
# 6:	learn: 0.6730427	total: 66.1ms	remaining: 406ms
# 7:	learn: 0.6705384	total: 67.8ms	remaining: 356ms
# 8:	learn: 0.6675284	total: 69.7ms	remaining: 317ms
# 9:	learn: 0.6651449	total: 71.4ms	remaining: 285ms
# 10:	learn: 0.6627376	total: 73ms	remaining: 259ms
# 11:	learn: 0.6604897	total: 74.6ms	remaining: 236ms
# 12:	learn: 0.6577262	total: 76.5ms	remaining: 218ms
# 13:	learn: 0.6549479	total: 78.5ms	remaining: 202ms
# 14:	learn: 0.6529140	total: 80.4ms	remaining: 187ms
# 15:	learn: 0.6503958	total: 82.3ms	remaining: 175ms
# 16:	learn: 0.6479599	total: 84.2ms	remaining: 163ms
# 17:	learn: 0.6454244	total: 86.2ms	remaining: 153ms
# 18:	learn: 0.6434615	total: 88.1ms	remaining: 144ms
# 19:	learn: 0.6414041	total: 90ms	remaining: 135ms
# 20:	learn: 0.6394622	total: 92ms	remaining: 127ms
# 21:	learn: 0.6375234	total: 94ms	remaining: 120ms
# 22:	learn: 0.6356288	total: 95.8ms	remaining: 112ms
# 23:	learn: 0.6339472	total: 97.6ms	remaining: 106ms
# 24:	learn: 0.6316894	total: 99.6ms	remaining: 99.6ms
# 25:	learn: 0.6295159	total: 102ms	remaining: 93.8ms
# 26:	learn: 0.6279154	total: 103ms	remaining: 88ms
# 27:	learn: 0.6257311	total: 105ms	remaining: 82.7ms
# 28:	learn: 0.6236466	total: 107ms	remaining: 77.5ms
# 29:	learn: 0.6215611	total: 109ms	remaining: 72.7ms
# 30:	learn: 0.6200779	total: 111ms	remaining: 67.8ms
# 31:	learn: 0.6181468	total: 113ms	remaining: 63.3ms
# 32:	learn: 0.6165808	total: 114ms	remaining: 59ms
# 33:	learn: 0.6150674	total: 116ms	remaining: 54.8ms
# 34:	learn: 0.6135958	total: 119ms	remaining: 50.8ms
# 35:	learn: 0.6119703	total: 120ms	remaining: 46.8ms
# 36:	learn: 0.6104794	total: 122ms	remaining: 43ms
# 37:	learn: 0.6087706	total: 124ms	remaining: 39.3ms
# 38:	learn: 0.6075227	total: 126ms	remaining: 35.7ms
# 39:	learn: 0.6061377	total: 128ms	remaining: 32.1ms
# 40:	learn: 0.6048303	total: 130ms	remaining: 28.6ms
# 41:	learn: 0.6036179	total: 132ms	remaining: 25.2ms
# 42:	learn: 0.6023248	total: 134ms	remaining: 21.8ms
# 43:	learn: 0.6011141	total: 136ms	remaining: 18.6ms
# 44:	learn: 0.5999148	total: 138ms	remaining: 15.4ms
# 45:	learn: 0.5986938	total: 140ms	remaining: 12.2ms
# 46:	learn: 0.5974993	total: 142ms	remaining: 9.07ms
# 47:	learn: 0.5962439	total: 144ms	remaining: 6ms
# 48:	learn: 0.5947643	total: 146ms	remaining: 2.98ms
# 49:	learn: 0.5932316	total: 148ms	remaining: 0us
# 0:	learn: 0.6903745	total: 2.33ms	remaining: 114ms
# 1:	learn: 0.6869545	total: 4.38ms	remaining: 105ms
# 2:	learn: 0.6835967	total: 6.35ms	remaining: 99.5ms
# 3:	learn: 0.6811689	total: 8.03ms	remaining: 92.3ms
# 4:	learn: 0.6786098	total: 9.87ms	remaining: 88.8ms
# 5:	learn: 0.6759855	total: 11.6ms	remaining: 85ms
# 6:	learn: 0.6729117	total: 13.4ms	remaining: 82.5ms
# 7:	learn: 0.6697984	total: 15.3ms	remaining: 80.3ms
# 8:	learn: 0.6673338	total: 17.1ms	remaining: 77.9ms
# 9:	learn: 0.6650673	total: 18.9ms	remaining: 75.8ms
# 10:	learn: 0.6628553	total: 20.6ms	remaining: 73.2ms
# 11:	learn: 0.6600189	total: 22.4ms	remaining: 71ms
# 12:	learn: 0.6578153	total: 24.4ms	remaining: 69.3ms
# 13:	learn: 0.6556552	total: 26.3ms	remaining: 67.6ms
# 14:	learn: 0.6534294	total: 28.2ms	remaining: 65.8ms
# 15:	learn: 0.6507636	total: 30.1ms	remaining: 63.9ms
# 16:	learn: 0.6483313	total: 32.1ms	remaining: 62.3ms
# 17:	learn: 0.6458006	total: 34.1ms	remaining: 60.6ms
# 18:	learn: 0.6438369	total: 35.9ms	remaining: 58.6ms
# 19:	learn: 0.6414090	total: 37.8ms	remaining: 56.6ms
# 20:	learn: 0.6394253	total: 39.5ms	remaining: 54.6ms
# 21:	learn: 0.6370791	total: 41.4ms	remaining: 52.7ms
# 22:	learn: 0.6351949	total: 43.1ms	remaining: 50.6ms
# 23:	learn: 0.6333293	total: 44.9ms	remaining: 48.7ms
# 24:	learn: 0.6316348	total: 46.6ms	remaining: 46.6ms
# 25:	learn: 0.6294544	total: 48.4ms	remaining: 44.7ms
# 26:	learn: 0.6277105	total: 50.2ms	remaining: 42.8ms
# 27:	learn: 0.6256137	total: 52.1ms	remaining: 40.9ms
# 28:	learn: 0.6241030	total: 53.9ms	remaining: 39ms
# 29:	learn: 0.6225788	total: 55.6ms	remaining: 37.1ms
# 30:	learn: 0.6205570	total: 57.5ms	remaining: 35.2ms
# 31:	learn: 0.6190492	total: 59.3ms	remaining: 33.4ms
# 32:	learn: 0.6176060	total: 60.9ms	remaining: 31.4ms
# 33:	learn: 0.6157672	total: 62.8ms	remaining: 29.5ms
# 34:	learn: 0.6142456	total: 64.4ms	remaining: 27.6ms
# 35:	learn: 0.6127781	total: 66.1ms	remaining: 25.7ms
# 36:	learn: 0.6110486	total: 68ms	remaining: 23.9ms
# 37:	learn: 0.6096043	total: 69.8ms	remaining: 22.1ms
# 38:	learn: 0.6080590	total: 71.7ms	remaining: 20.2ms
# 39:	learn: 0.6066808	total: 73.6ms	remaining: 18.4ms
# 40:	learn: 0.6053071	total: 75.3ms	remaining: 16.5ms
# 41:	learn: 0.6039035	total: 77.3ms	remaining: 14.7ms
# 42:	learn: 0.6025705	total: 79.1ms	remaining: 12.9ms
# 43:	learn: 0.6013079	total: 81ms	remaining: 11ms
# 44:	learn: 0.6000027	total: 83ms	remaining: 9.23ms
# 45:	learn: 0.5988243	total: 84.7ms	remaining: 7.37ms
# 46:	learn: 0.5976300	total: 86.4ms	remaining: 5.52ms
# 47:	learn: 0.5964767	total: 88.3ms	remaining: 3.68ms
# 48:	learn: 0.5953317	total: 90.2ms	remaining: 1.84ms
# 49:	learn: 0.5941083	total: 92.1ms	remaining: 0us
# 0:	learn: 0.6904941	total: 2.32ms	remaining: 114ms
# 1:	learn: 0.6876073	total: 4.56ms	remaining: 109ms
# 2:	learn: 0.6842576	total: 6.25ms	remaining: 98ms
# 3:	learn: 0.6808186	total: 8.02ms	remaining: 92.2ms
# 4:	learn: 0.6784619	total: 9.77ms	remaining: 88ms
# 5:	learn: 0.6758537	total: 11.4ms	remaining: 83.9ms
# 6:	learn: 0.6736059	total: 13.1ms	remaining: 80.7ms
# 7:	learn: 0.6712569	total: 15ms	remaining: 78.8ms
# 8:	learn: 0.6682011	total: 16.9ms	remaining: 77.1ms
# 9:	learn: 0.6659608	total: 18.6ms	remaining: 74.3ms
# 10:	learn: 0.6629444	total: 20.1ms	remaining: 71.4ms
# 11:	learn: 0.6600981	total: 21.7ms	remaining: 68.9ms
# 12:	learn: 0.6577285	total: 23.6ms	remaining: 67.2ms
# 13:	learn: 0.6554922	total: 25.3ms	remaining: 65ms
# 14:	learn: 0.6528119	total: 27.2ms	remaining: 63.4ms
# 15:	learn: 0.6502051	total: 29ms	remaining: 61.5ms
# 16:	learn: 0.6475798	total: 30.6ms	remaining: 59.4ms
# 17:	learn: 0.6455076	total: 32.5ms	remaining: 57.7ms
# 18:	learn: 0.6435564	total: 34.3ms	remaining: 56ms
# 19:	learn: 0.6411813	total: 36.1ms	remaining: 54.2ms
# 20:	learn: 0.6386897	total: 37.8ms	remaining: 52.2ms
# 21:	learn: 0.6367211	total: 39.8ms	remaining: 50.6ms
# 22:	learn: 0.6349498	total: 41.6ms	remaining: 48.8ms
# 23:	learn: 0.6331281	total: 43.3ms	remaining: 46.9ms
# 24:	learn: 0.6315415	total: 45.3ms	remaining: 45.3ms
# 25:	learn: 0.6297918	total: 47ms	remaining: 43.4ms
# 26:	learn: 0.6279563	total: 48.7ms	remaining: 41.5ms
# 27:	learn: 0.6257949	total: 50.6ms	remaining: 39.8ms
# 28:	learn: 0.6243158	total: 52.3ms	remaining: 37.9ms
# 29:	learn: 0.6228005	total: 54.1ms	remaining: 36ms
# 30:	learn: 0.6207253	total: 55.7ms	remaining: 34.1ms
# 31:	learn: 0.6190547	total: 57.4ms	remaining: 32.3ms
# 32:	learn: 0.6174977	total: 59.2ms	remaining: 30.5ms
# 33:	learn: 0.6155140	total: 60.9ms	remaining: 28.7ms
# 34:	learn: 0.6139125	total: 62.7ms	remaining: 26.9ms
# 35:	learn: 0.6124444	total: 64.4ms	remaining: 25ms
# 36:	learn: 0.6110799	total: 66.1ms	remaining: 23.2ms
# 37:	learn: 0.6097376	total: 68ms	remaining: 21.5ms
# 38:	learn: 0.6082641	total: 69.8ms	remaining: 19.7ms
# 39:	learn: 0.6068511	total: 71.8ms	remaining: 18ms
# 40:	learn: 0.6055130	total: 73.7ms	remaining: 16.2ms
# 41:	learn: 0.6041707	total: 75.5ms	remaining: 14.4ms
# 42:	learn: 0.6023505	total: 77.5ms	remaining: 12.6ms
# 43:	learn: 0.6006714	total: 79.2ms	remaining: 10.8ms
# 44:	learn: 0.5990822	total: 81.1ms	remaining: 9.01ms
# 45:	learn: 0.5976147	total: 82.9ms	remaining: 7.21ms
# 46:	learn: 0.5963746	total: 84.7ms	remaining: 5.41ms
# 47:	learn: 0.5952148	total: 86.4ms	remaining: 3.6ms
# 48:	learn: 0.5940251	total: 88.1ms	remaining: 1.8ms
# 49:	learn: 0.5929233	total: 89.8ms	remaining: 0us
# 0:	learn: 0.6905940	total: 2.12ms	remaining: 104ms
# 1:	learn: 0.6876617	total: 4.02ms	remaining: 96.5ms
# 2:	learn: 0.6843786	total: 5.96ms	remaining: 93.4ms
# 3:	learn: 0.6811847	total: 8.04ms	remaining: 92.4ms
# 4:	learn: 0.6786753	total: 9.96ms	remaining: 89.7ms
# 5:	learn: 0.6757121	total: 11.7ms	remaining: 85.6ms
# 6:	learn: 0.6732248	total: 13.5ms	remaining: 82.9ms
# 7:	learn: 0.6710333	total: 15.2ms	remaining: 79.7ms
# 8:	learn: 0.6680786	total: 17.1ms	remaining: 78.1ms
# 9:	learn: 0.6655948	total: 19ms	remaining: 76.1ms
# 10:	learn: 0.6633129	total: 20.9ms	remaining: 74.1ms
# 11:	learn: 0.6612643	total: 22.8ms	remaining: 72.3ms
# 12:	learn: 0.6589873	total: 24.5ms	remaining: 69.7ms
# 13:	learn: 0.6563115	total: 26.4ms	remaining: 67.8ms
# 14:	learn: 0.6540597	total: 28.1ms	remaining: 65.6ms
# 15:	learn: 0.6519403	total: 29.8ms	remaining: 63.4ms
# 16:	learn: 0.6494144	total: 31.7ms	remaining: 61.5ms
# 17:	learn: 0.6474146	total: 33.5ms	remaining: 59.5ms
# 18:	learn: 0.6454084	total: 35.5ms	remaining: 57.9ms
# 19:	learn: 0.6435516	total: 37.3ms	remaining: 55.9ms
# 20:	learn: 0.6412731	total: 39.2ms	remaining: 54.1ms
# 21:	learn: 0.6389988	total: 41.1ms	remaining: 52.3ms
# 22:	learn: 0.6371592	total: 43ms	remaining: 50.4ms
# 23:	learn: 0.6353520	total: 44.6ms	remaining: 48.4ms
# 24:	learn: 0.6332544	total: 46.4ms	remaining: 46.4ms
# 25:	learn: 0.6315553	total: 48.3ms	remaining: 44.5ms
# 26:	learn: 0.6296204	total: 50.1ms	remaining: 42.7ms
# 27:	learn: 0.6275874	total: 51.8ms	remaining: 40.7ms
# 28:	learn: 0.6260227	total: 53.7ms	remaining: 38.9ms
# 29:	learn: 0.6244769	total: 55.5ms	remaining: 37ms
# 30:	learn: 0.6229522	total: 57.5ms	remaining: 35.2ms
# 31:	learn: 0.6214492	total: 59.1ms	remaining: 33.3ms
# 32:	learn: 0.6196310	total: 60.9ms	remaining: 31.4ms
# 33:	learn: 0.6177707	total: 63.2ms	remaining: 29.7ms
# 34:	learn: 0.6163863	total: 65.1ms	remaining: 27.9ms
# 35:	learn: 0.6150262	total: 67ms	remaining: 26ms
# 36:	learn: 0.6137077	total: 68.8ms	remaining: 24.2ms
# 37:	learn: 0.6124022	total: 70.8ms	remaining: 22.4ms
# 38:	learn: 0.6106631	total: 72.6ms	remaining: 20.5ms
# 39:	learn: 0.6094422	total: 74.5ms	remaining: 18.6ms
# 40:	learn: 0.6081473	total: 76.2ms	remaining: 16.7ms
# 41:	learn: 0.6068403	total: 77.9ms	remaining: 14.8ms
# 42:	learn: 0.6052401	total: 79.7ms	remaining: 13ms
# 43:	learn: 0.6039768	total: 81.6ms	remaining: 11.1ms
# 44:	learn: 0.6024948	total: 83.6ms	remaining: 9.29ms
# 45:	learn: 0.6013787	total: 85.6ms	remaining: 7.45ms
# 46:	learn: 0.6002234	total: 87.5ms	remaining: 5.58ms
# 47:	learn: 0.5987810	total: 89.5ms	remaining: 3.73ms
# 48:	learn: 0.5975891	total: 91.4ms	remaining: 1.86ms
# 49:	learn: 0.5964338	total: 93.2ms	remaining: 0us
# 0:	learn: 0.6905447	total: 1.93ms	remaining: 94.6ms
# 1:	learn: 0.6876640	total: 3.86ms	remaining: 92.6ms
# 2:	learn: 0.6842260	total: 5.59ms	remaining: 87.6ms
# 3:	learn: 0.6816111	total: 7.59ms	remaining: 87.3ms
# 4:	learn: 0.6783673	total: 9.68ms	remaining: 87.1ms
# 5:	learn: 0.6756883	total: 11.5ms	remaining: 84.4ms
# 6:	learn: 0.6731001	total: 13.3ms	remaining: 81.8ms
# 7:	learn: 0.6700279	total: 15.1ms	remaining: 79.5ms
# 8:	learn: 0.6670804	total: 17ms	remaining: 77.4ms
# 9:	learn: 0.6648126	total: 18.8ms	remaining: 75.4ms
# 10:	learn: 0.6625237	total: 20.5ms	remaining: 72.9ms
# 11:	learn: 0.6604032	total: 22.4ms	remaining: 70.9ms
# 12:	learn: 0.6575904	total: 24.2ms	remaining: 68.8ms
# 13:	learn: 0.6553547	total: 26ms	remaining: 66.9ms
# 14:	learn: 0.6530586	total: 27.7ms	remaining: 64.6ms
# 15:	learn: 0.6509132	total: 29.6ms	remaining: 62.8ms
# 16:	learn: 0.6487295	total: 31.4ms	remaining: 61ms
# 17:	learn: 0.6461158	total: 33.2ms	remaining: 59ms
# 18:	learn: 0.6440561	total: 35.1ms	remaining: 57.2ms
# 19:	learn: 0.6416849	total: 37ms	remaining: 55.5ms
# 20:	learn: 0.6397131	total: 38.9ms	remaining: 53.7ms
# 21:	learn: 0.6377392	total: 40.6ms	remaining: 51.6ms
# 22:	learn: 0.6354591	total: 42.4ms	remaining: 49.8ms
# 23:	learn: 0.6331726	total: 44.4ms	remaining: 48.1ms
# 24:	learn: 0.6313820	total: 46ms	remaining: 46ms
# 25:	learn: 0.6297505	total: 47.8ms	remaining: 44.1ms
# 26:	learn: 0.6276179	total: 49.7ms	remaining: 42.3ms
# 27:	learn: 0.6258758	total: 51.5ms	remaining: 40.5ms
# 28:	learn: 0.6236984	total: 53.5ms	remaining: 38.7ms
# 29:	learn: 0.6217549	total: 55.4ms	remaining: 36.9ms
# 30:	learn: 0.6201300	total: 57.3ms	remaining: 35.1ms
# 31:	learn: 0.6185757	total: 59.3ms	remaining: 33.4ms
# 32:	learn: 0.6169862	total: 61.1ms	remaining: 31.5ms
# 33:	learn: 0.6154095	total: 63ms	remaining: 29.6ms
# 34:	learn: 0.6139621	total: 64.9ms	remaining: 27.8ms
# 35:	learn: 0.6124800	total: 66.7ms	remaining: 25.9ms
# 36:	learn: 0.6110087	total: 68.5ms	remaining: 24.1ms
# 37:	learn: 0.6096910	total: 70.4ms	remaining: 22.2ms
# 38:	learn: 0.6082969	total: 72.1ms	remaining: 20.3ms
# 39:	learn: 0.6064568	total: 74.3ms	remaining: 18.6ms
# 40:	learn: 0.6047295	total: 76.1ms	remaining: 16.7ms
# 41:	learn: 0.6030349	total: 78.2ms	remaining: 14.9ms
# 42:	learn: 0.6013158	total: 80.3ms	remaining: 13.1ms
# 43:	learn: 0.6000717	total: 82ms	remaining: 11.2ms
# 44:	learn: 0.5986998	total: 84.1ms	remaining: 9.35ms
# 45:	learn: 0.5974793	total: 85.9ms	remaining: 7.47ms
# 46:	learn: 0.5962881	total: 87.8ms	remaining: 5.6ms
# 47:	learn: 0.5951372	total: 89.9ms	remaining: 3.75ms
# 48:	learn: 0.5939718	total: 91.9ms	remaining: 1.87ms
# 49:	learn: 0.5928084	total: 93.9ms	remaining: 0us
# 0:	learn: 0.6793591	total: 1.9ms	remaining: 93.2ms
# 1:	learn: 0.6668726	total: 4.27ms	remaining: 103ms
# 2:	learn: 0.6525367	total: 6.18ms	remaining: 96.8ms
# 3:	learn: 0.6431843	total: 8.03ms	remaining: 92.3ms
# 4:	learn: 0.6314324	total: 9.84ms	remaining: 88.6ms
# 5:	learn: 0.6231848	total: 11.8ms	remaining: 86.6ms
# 6:	learn: 0.6129555	total: 14ms	remaining: 85.7ms
# 7:	learn: 0.6043157	total: 15.8ms	remaining: 83.1ms
# 8:	learn: 0.5980876	total: 17.8ms	remaining: 81.1ms
# 9:	learn: 0.5923716	total: 19.7ms	remaining: 78.8ms
# 10:	learn: 0.5865507	total: 21.6ms	remaining: 76.6ms
# 11:	learn: 0.5819842	total: 23.7ms	remaining: 75ms
# 12:	learn: 0.5772419	total: 25.5ms	remaining: 72.6ms
# 13:	learn: 0.5731348	total: 27.2ms	remaining: 69.9ms
# 14:	learn: 0.5693053	total: 29.1ms	remaining: 67.8ms
# 15:	learn: 0.5659084	total: 30.9ms	remaining: 65.6ms
# 16:	learn: 0.5622938	total: 32.6ms	remaining: 63.4ms
# 17:	learn: 0.5581177	total: 34.6ms	remaining: 61.5ms
# 18:	learn: 0.5539874	total: 36.6ms	remaining: 59.7ms
# 19:	learn: 0.5507844	total: 38.5ms	remaining: 57.7ms
# 20:	learn: 0.5479686	total: 40.4ms	remaining: 55.8ms
# 21:	learn: 0.5452346	total: 42.4ms	remaining: 53.9ms
# 22:	learn: 0.5427660	total: 44.4ms	remaining: 52.1ms
# 23:	learn: 0.5400961	total: 46.4ms	remaining: 50.2ms
# 24:	learn: 0.5379183	total: 48.3ms	remaining: 48.3ms
# 25:	learn: 0.5350060	total: 50.3ms	remaining: 46.4ms
# 26:	learn: 0.5323176	total: 52.1ms	remaining: 44.4ms
# 27:	learn: 0.5298293	total: 53.8ms	remaining: 42.3ms
# 28:	learn: 0.5278833	total: 55.5ms	remaining: 40.2ms
# 29:	learn: 0.5262265	total: 57.2ms	remaining: 38.1ms
# 30:	learn: 0.5241796	total: 59.2ms	remaining: 36.3ms
# 31:	learn: 0.5225689	total: 61.2ms	remaining: 34.4ms
# 32:	learn: 0.5205191	total: 63.3ms	remaining: 32.6ms
# 33:	learn: 0.5191436	total: 65.1ms	remaining: 30.6ms
# 34:	learn: 0.5174579	total: 67.2ms	remaining: 28.8ms
# 35:	learn: 0.5152396	total: 69ms	remaining: 26.8ms
# 36:	learn: 0.5138589	total: 70.8ms	remaining: 24.9ms
# 37:	learn: 0.5128494	total: 72.7ms	remaining: 23ms
# 38:	learn: 0.5115723	total: 74.8ms	remaining: 21.1ms
# 39:	learn: 0.5097527	total: 76.8ms	remaining: 19.2ms
# 40:	learn: 0.5088878	total: 78.8ms	remaining: 17.3ms
# 41:	learn: 0.5080596	total: 81.2ms	remaining: 15.5ms
# 42:	learn: 0.5065834	total: 83.2ms	remaining: 13.5ms
# 43:	learn: 0.5052704	total: 85ms	remaining: 11.6ms
# 44:	learn: 0.5040900	total: 87.1ms	remaining: 9.67ms
# 45:	learn: 0.5023824	total: 89.2ms	remaining: 7.76ms
# 46:	learn: 0.5011905	total: 91.4ms	remaining: 5.83ms
# 47:	learn: 0.4997575	total: 93.5ms	remaining: 3.9ms
# 48:	learn: 0.4980776	total: 95.7ms	remaining: 1.95ms
# 49:	learn: 0.4967111	total: 97.6ms	remaining: 0us
# 0:	learn: 0.6795752	total: 2.2ms	remaining: 108ms
# 1:	learn: 0.6642531	total: 3.94ms	remaining: 94.5ms
# 2:	learn: 0.6528472	total: 5.8ms	remaining: 90.9ms
# 3:	learn: 0.6424655	total: 7.54ms	remaining: 86.7ms
# 4:	learn: 0.6309987	total: 9.35ms	remaining: 84.1ms
# 5:	learn: 0.6230391	total: 11.2ms	remaining: 82.2ms
# 6:	learn: 0.6129928	total: 13.3ms	remaining: 81.7ms
# 7:	learn: 0.6039405	total: 15.2ms	remaining: 80ms
# 8:	learn: 0.5973224	total: 17ms	remaining: 77.5ms
# 9:	learn: 0.5915170	total: 18.9ms	remaining: 75.7ms
# 10:	learn: 0.5846743	total: 20.9ms	remaining: 74.2ms
# 11:	learn: 0.5797262	total: 22.8ms	remaining: 72.3ms
# 12:	learn: 0.5751957	total: 24.7ms	remaining: 70.3ms
# 13:	learn: 0.5708542	total: 26.7ms	remaining: 68.5ms
# 14:	learn: 0.5670406	total: 28.6ms	remaining: 66.7ms
# 15:	learn: 0.5629913	total: 30.5ms	remaining: 64.9ms
# 16:	learn: 0.5597564	total: 32.3ms	remaining: 62.7ms
# 17:	learn: 0.5553567	total: 34.3ms	remaining: 61ms
# 18:	learn: 0.5515271	total: 36.2ms	remaining: 59.1ms
# 19:	learn: 0.5483152	total: 38.1ms	remaining: 57.1ms
# 20:	learn: 0.5456167	total: 40ms	remaining: 55.2ms
# 21:	learn: 0.5430427	total: 41.8ms	remaining: 53.2ms
# 22:	learn: 0.5401627	total: 43.6ms	remaining: 51.2ms
# 23:	learn: 0.5374805	total: 45.3ms	remaining: 49.1ms
# 24:	learn: 0.5345980	total: 47.5ms	remaining: 47.5ms
# 25:	learn: 0.5319299	total: 49.4ms	remaining: 45.6ms
# 26:	learn: 0.5295202	total: 51.4ms	remaining: 43.8ms
# 27:	learn: 0.5272386	total: 53.4ms	remaining: 42ms
# 28:	learn: 0.5251215	total: 55.6ms	remaining: 40.2ms
# 29:	learn: 0.5233646	total: 57.9ms	remaining: 38.6ms
# 30:	learn: 0.5216014	total: 60ms	remaining: 36.8ms
# 31:	learn: 0.5197840	total: 62.2ms	remaining: 35ms
# 32:	learn: 0.5187404	total: 64.3ms	remaining: 33.1ms
# 33:	learn: 0.5163592	total: 66.1ms	remaining: 31.1ms
# 34:	learn: 0.5142178	total: 68.1ms	remaining: 29.2ms
# 35:	learn: 0.5122068	total: 70.3ms	remaining: 27.3ms
# 36:	learn: 0.5105809	total: 72.3ms	remaining: 25.4ms
# 37:	learn: 0.5092802	total: 74.2ms	remaining: 23.4ms
# 38:	learn: 0.5075620	total: 76.2ms	remaining: 21.5ms
# 39:	learn: 0.5059842	total: 78.3ms	remaining: 19.6ms
# 40:	learn: 0.5047971	total: 80.2ms	remaining: 17.6ms
# 41:	learn: 0.5031617	total: 82.5ms	remaining: 15.7ms
# 42:	learn: 0.5022332	total: 84.4ms	remaining: 13.7ms
# 43:	learn: 0.5013090	total: 86.5ms	remaining: 11.8ms
# 44:	learn: 0.4998166	total: 88.5ms	remaining: 9.83ms
# 45:	learn: 0.4981386	total: 90.8ms	remaining: 7.9ms
# 46:	learn: 0.4970387	total: 93ms	remaining: 5.94ms
# 47:	learn: 0.4959583	total: 94.7ms	remaining: 3.94ms
# 48:	learn: 0.4947663	total: 96.6ms	remaining: 1.97ms
# 49:	learn: 0.4936216	total: 98.4ms	remaining: 0us
# 0:	learn: 0.6801822	total: 2.11ms	remaining: 104ms
# 1:	learn: 0.6669730	total: 3.96ms	remaining: 94.9ms
# 2:	learn: 0.6520779	total: 5.56ms	remaining: 87.1ms
# 3:	learn: 0.6386394	total: 7.59ms	remaining: 87.3ms
# 4:	learn: 0.6293640	total: 9.34ms	remaining: 84ms
# 5:	learn: 0.6209427	total: 11ms	remaining: 80.8ms
# 6:	learn: 0.6110020	total: 12.9ms	remaining: 79.2ms
# 7:	learn: 0.6033870	total: 14.9ms	remaining: 78.1ms
# 8:	learn: 0.5948640	total: 16.8ms	remaining: 76.4ms
# 9:	learn: 0.5888713	total: 18.6ms	remaining: 74.5ms
# 10:	learn: 0.5838919	total: 20.5ms	remaining: 72.8ms
# 11:	learn: 0.5778129	total: 22.4ms	remaining: 71ms
# 12:	learn: 0.5733532	total: 24.4ms	remaining: 69.4ms
# 13:	learn: 0.5680002	total: 26.4ms	remaining: 68ms
# 14:	learn: 0.5632458	total: 28.5ms	remaining: 66.5ms
# 15:	learn: 0.5597216	total: 30.3ms	remaining: 64.4ms
# 16:	learn: 0.5554442	total: 32.5ms	remaining: 63ms
# 17:	learn: 0.5522043	total: 34.4ms	remaining: 61.2ms
# 18:	learn: 0.5489713	total: 36.5ms	remaining: 59.5ms
# 19:	learn: 0.5455173	total: 38.4ms	remaining: 57.6ms
# 20:	learn: 0.5422382	total: 40.4ms	remaining: 55.8ms
# 21:	learn: 0.5393245	total: 42.2ms	remaining: 53.7ms
# 22:	learn: 0.5370235	total: 44ms	remaining: 51.7ms
# 23:	learn: 0.5344067	total: 46ms	remaining: 49.9ms
# 24:	learn: 0.5317039	total: 47.8ms	remaining: 47.8ms
# 25:	learn: 0.5292249	total: 49.7ms	remaining: 45.9ms
# 26:	learn: 0.5267943	total: 51.9ms	remaining: 44.2ms
# 27:	learn: 0.5243886	total: 53.6ms	remaining: 42.1ms
# 28:	learn: 0.5221502	total: 55.5ms	remaining: 40.2ms
# 29:	learn: 0.5201265	total: 57.4ms	remaining: 38.3ms
# 30:	learn: 0.5180215	total: 59.3ms	remaining: 36.3ms
# 31:	learn: 0.5157282	total: 61.3ms	remaining: 34.5ms
# 32:	learn: 0.5139855	total: 63.3ms	remaining: 32.6ms
# 33:	learn: 0.5119497	total: 65.1ms	remaining: 30.7ms
# 34:	learn: 0.5107470	total: 67.1ms	remaining: 28.8ms
# 35:	learn: 0.5092524	total: 68.9ms	remaining: 26.8ms
# 36:	learn: 0.5077724	total: 70.9ms	remaining: 24.9ms
# 37:	learn: 0.5058884	total: 73ms	remaining: 23.1ms
# 38:	learn: 0.5043380	total: 75ms	remaining: 21.2ms
# 39:	learn: 0.5030254	total: 77ms	remaining: 19.3ms
# 40:	learn: 0.5013443	total: 79ms	remaining: 17.3ms
# 41:	learn: 0.4998371	total: 81ms	remaining: 15.4ms
# 42:	learn: 0.4988710	total: 82.7ms	remaining: 13.5ms
# 43:	learn: 0.4977311	total: 84.5ms	remaining: 11.5ms
# 44:	learn: 0.4967855	total: 86.3ms	remaining: 9.59ms
# 45:	learn: 0.4949879	total: 88.6ms	remaining: 7.7ms
# 46:	learn: 0.4940631	total: 90.4ms	remaining: 5.77ms
# 47:	learn: 0.4928303	total: 92.6ms	remaining: 3.86ms
# 48:	learn: 0.4916822	total: 94.6ms	remaining: 1.93ms
# 49:	learn: 0.4908726	total: 96.6ms	remaining: 0us
# 0:	learn: 0.6806626	total: 2.02ms	remaining: 98.9ms
# 1:	learn: 0.6671181	total: 4.26ms	remaining: 102ms
# 2:	learn: 0.6557847	total: 6.01ms	remaining: 94.2ms
# 3:	learn: 0.6457978	total: 7.9ms	remaining: 90.8ms
# 4:	learn: 0.6345187	total: 9.56ms	remaining: 86ms
# 5:	learn: 0.6257878	total: 11.3ms	remaining: 82.6ms
# 6:	learn: 0.6178614	total: 12.9ms	remaining: 79.3ms
# 7:	learn: 0.6092238	total: 14.6ms	remaining: 76.8ms
# 8:	learn: 0.6033770	total: 16.4ms	remaining: 74.5ms
# 9:	learn: 0.5974038	total: 18.1ms	remaining: 72.5ms
# 10:	learn: 0.5902970	total: 20.2ms	remaining: 71.5ms
# 11:	learn: 0.5850842	total: 22.1ms	remaining: 70ms
# 12:	learn: 0.5804806	total: 24ms	remaining: 68.4ms
# 13:	learn: 0.5750643	total: 26.2ms	remaining: 67.4ms
# 14:	learn: 0.5714652	total: 28.2ms	remaining: 65.9ms
# 15:	learn: 0.5665513	total: 30.4ms	remaining: 64.5ms
# 16:	learn: 0.5621740	total: 32.3ms	remaining: 62.8ms
# 17:	learn: 0.5584853	total: 34.5ms	remaining: 61.3ms
# 18:	learn: 0.5549184	total: 36.4ms	remaining: 59.4ms
# 19:	learn: 0.5518321	total: 38.3ms	remaining: 57.4ms
# 20:	learn: 0.5488880	total: 40.2ms	remaining: 55.6ms
# 21:	learn: 0.5459787	total: 42.2ms	remaining: 53.7ms
# 22:	learn: 0.5439622	total: 44.2ms	remaining: 51.8ms
# 23:	learn: 0.5416830	total: 46.4ms	remaining: 50.2ms
# 24:	learn: 0.5392755	total: 48.4ms	remaining: 48.4ms
# 25:	learn: 0.5367241	total: 50.4ms	remaining: 46.5ms
# 26:	learn: 0.5346122	total: 52.2ms	remaining: 44.5ms
# 27:	learn: 0.5325348	total: 54.3ms	remaining: 42.7ms
# 28:	learn: 0.5303900	total: 56.3ms	remaining: 40.8ms
# 29:	learn: 0.5279195	total: 58.2ms	remaining: 38.8ms
# 30:	learn: 0.5258585	total: 60.2ms	remaining: 36.9ms
# 31:	learn: 0.5239938	total: 62.2ms	remaining: 35ms
# 32:	learn: 0.5220789	total: 64.1ms	remaining: 33ms
# 33:	learn: 0.5201889	total: 66.2ms	remaining: 31.1ms
# 34:	learn: 0.5183740	total: 68.1ms	remaining: 29.2ms
# 35:	learn: 0.5168348	total: 70ms	remaining: 27.2ms
# 36:	learn: 0.5149631	total: 71.9ms	remaining: 25.3ms
# 37:	learn: 0.5132476	total: 73.6ms	remaining: 23.3ms
# 38:	learn: 0.5117972	total: 75.6ms	remaining: 21.3ms
# 39:	learn: 0.5104787	total: 77.4ms	remaining: 19.4ms
# 40:	learn: 0.5089557	total: 79.4ms	remaining: 17.4ms
# 41:	learn: 0.5077053	total: 81.1ms	remaining: 15.5ms
# 42:	learn: 0.5063766	total: 83.3ms	remaining: 13.6ms
# 43:	learn: 0.5056137	total: 85.3ms	remaining: 11.6ms
# 44:	learn: 0.5043799	total: 87.4ms	remaining: 9.71ms
# 45:	learn: 0.5027967	total: 89.7ms	remaining: 7.8ms
# 46:	learn: 0.5017793	total: 91.8ms	remaining: 5.86ms
# 47:	learn: 0.5005492	total: 93.9ms	remaining: 3.91ms
# 48:	learn: 0.4994262	total: 95.8ms	remaining: 1.96ms
# 49:	learn: 0.4983930	total: 97.8ms	remaining: 0us
# 0:	learn: 0.6803842	total: 1.94ms	remaining: 94.9ms
# 1:	learn: 0.6672450	total: 3.82ms	remaining: 91.6ms
# 2:	learn: 0.6527377	total: 5.74ms	remaining: 90ms
# 3:	learn: 0.6400011	total: 7.67ms	remaining: 88.2ms
# 4:	learn: 0.6302236	total: 9.66ms	remaining: 87ms
# 5:	learn: 0.6199163	total: 11.5ms	remaining: 84.6ms
# 6:	learn: 0.6120139	total: 13.4ms	remaining: 82.4ms
# 7:	learn: 0.6053135	total: 15.2ms	remaining: 79.6ms
# 8:	learn: 0.5972179	total: 17.2ms	remaining: 78.2ms
# 9:	learn: 0.5917190	total: 19.3ms	remaining: 77.1ms
# 10:	learn: 0.5862560	total: 21ms	remaining: 74.4ms
# 11:	learn: 0.5802568	total: 22.9ms	remaining: 72.6ms
# 12:	learn: 0.5756221	total: 25ms	remaining: 71.2ms
# 13:	learn: 0.5712744	total: 27ms	remaining: 69.5ms
# 14:	learn: 0.5674970	total: 29.1ms	remaining: 68ms
# 15:	learn: 0.5627699	total: 31.2ms	remaining: 66.3ms
# 16:	learn: 0.5594114	total: 33.3ms	remaining: 64.6ms
# 17:	learn: 0.5563583	total: 35.2ms	remaining: 62.5ms
# 18:	learn: 0.5527180	total: 37.1ms	remaining: 60.5ms
# 19:	learn: 0.5500611	total: 39.2ms	remaining: 58.8ms
# 20:	learn: 0.5467506	total: 41.3ms	remaining: 57ms
# 21:	learn: 0.5441801	total: 43.1ms	remaining: 54.8ms
# 22:	learn: 0.5411064	total: 45.1ms	remaining: 52.9ms
# 23:	learn: 0.5386335	total: 47.1ms	remaining: 51ms
# 24:	learn: 0.5357248	total: 49.2ms	remaining: 49.2ms
# 25:	learn: 0.5334045	total: 51.3ms	remaining: 47.3ms
# 26:	learn: 0.5313060	total: 53.5ms	remaining: 45.6ms
# 27:	learn: 0.5291454	total: 56.5ms	remaining: 44.4ms
# 28:	learn: 0.5267120	total: 59.4ms	remaining: 43ms
# 29:	learn: 0.5243572	total: 61.4ms	remaining: 40.9ms
# 30:	learn: 0.5222333	total: 63.5ms	remaining: 38.9ms
# 31:	learn: 0.5205641	total: 65.5ms	remaining: 36.8ms
# 32:	learn: 0.5186277	total: 67.5ms	remaining: 34.8ms
# 33:	learn: 0.5168364	total: 69.5ms	remaining: 32.7ms
# 34:	learn: 0.5151536	total: 71.9ms	remaining: 30.8ms
# 35:	learn: 0.5135186	total: 73.8ms	remaining: 28.7ms
# 36:	learn: 0.5119607	total: 75.7ms	remaining: 26.6ms
# 37:	learn: 0.5103621	total: 77.7ms	remaining: 24.5ms
# 38:	learn: 0.5090739	total: 79.7ms	remaining: 22.5ms
# 39:	learn: 0.5072292	total: 81.7ms	remaining: 20.4ms
# 40:	learn: 0.5053008	total: 83.8ms	remaining: 18.4ms
# 41:	learn: 0.5041819	total: 85.5ms	remaining: 16.3ms
# 42:	learn: 0.5031655	total: 87.4ms	remaining: 14.2ms
# 43:	learn: 0.5020809	total: 89.1ms	remaining: 12.1ms
# 44:	learn: 0.5005655	total: 91.1ms	remaining: 10.1ms
# 45:	learn: 0.4993168	total: 93ms	remaining: 8.09ms
# 46:	learn: 0.4985019	total: 94.9ms	remaining: 6.06ms
# 47:	learn: 0.4971152	total: 96.8ms	remaining: 4.03ms
# 48:	learn: 0.4959855	total: 98.7ms	remaining: 2.02ms
# 49:	learn: 0.4953067	total: 101ms	remaining: 0us
# 0:	learn: 0.6663622	total: 2.04ms	remaining: 99.9ms
# 1:	learn: 0.6445291	total: 4.28ms	remaining: 103ms
# 2:	learn: 0.6199389	total: 6.25ms	remaining: 98ms
# 3:	learn: 0.6018785	total: 8.15ms	remaining: 93.8ms
# 4:	learn: 0.5872211	total: 10.2ms	remaining: 91.5ms
# 5:	learn: 0.5771269	total: 12.1ms	remaining: 88.7ms
# 6:	learn: 0.5671348	total: 14.1ms	remaining: 86.6ms
# 7:	learn: 0.5585570	total: 16.1ms	remaining: 84.5ms
# 8:	learn: 0.5517722	total: 17.9ms	remaining: 81.5ms
# 9:	learn: 0.5460588	total: 19.6ms	remaining: 78.4ms
# 10:	learn: 0.5398787	total: 21.5ms	remaining: 76.4ms
# 11:	learn: 0.5341210	total: 23.7ms	remaining: 74.9ms
# 12:	learn: 0.5288526	total: 25.6ms	remaining: 72.9ms
# 13:	learn: 0.5248774	total: 27.5ms	remaining: 70.7ms
# 14:	learn: 0.5213501	total: 29.5ms	remaining: 68.8ms
# 15:	learn: 0.5186157	total: 31.6ms	remaining: 67.1ms
# 16:	learn: 0.5150048	total: 33.5ms	remaining: 65.1ms
# 17:	learn: 0.5116778	total: 35.5ms	remaining: 63.1ms
# 18:	learn: 0.5088517	total: 37.4ms	remaining: 61ms
# 19:	learn: 0.5053092	total: 39.3ms	remaining: 59ms
# 20:	learn: 0.5023172	total: 41.4ms	remaining: 57.1ms
# 21:	learn: 0.5003381	total: 43.4ms	remaining: 55.2ms
# 22:	learn: 0.4982018	total: 45.3ms	remaining: 53.1ms
# 23:	learn: 0.4951246	total: 47.4ms	remaining: 51.4ms
# 24:	learn: 0.4939570	total: 49.6ms	remaining: 49.6ms
# 25:	learn: 0.4909094	total: 51.7ms	remaining: 47.7ms
# 26:	learn: 0.4881498	total: 53.5ms	remaining: 45.6ms
# 27:	learn: 0.4866287	total: 55.4ms	remaining: 43.5ms
# 28:	learn: 0.4855037	total: 57.6ms	remaining: 41.7ms
# 29:	learn: 0.4838146	total: 59.6ms	remaining: 39.7ms
# 30:	learn: 0.4817651	total: 61.8ms	remaining: 37.9ms
# 31:	learn: 0.4795094	total: 64ms	remaining: 36ms
# 32:	learn: 0.4784494	total: 66.1ms	remaining: 34ms
# 33:	learn: 0.4773684	total: 68.2ms	remaining: 32.1ms
# 34:	learn: 0.4764213	total: 70.1ms	remaining: 30.1ms
# 35:	learn: 0.4753976	total: 72.1ms	remaining: 28ms
# 36:	learn: 0.4741847	total: 74.1ms	remaining: 26ms
# 37:	learn: 0.4721439	total: 76.2ms	remaining: 24.1ms
# 38:	learn: 0.4709426	total: 78.4ms	remaining: 22.1ms
# 39:	learn: 0.4696947	total: 80.5ms	remaining: 20.1ms
# 40:	learn: 0.4673237	total: 82.7ms	remaining: 18.1ms
# 41:	learn: 0.4665303	total: 84.5ms	remaining: 16.1ms
# 42:	learn: 0.4653394	total: 86.5ms	remaining: 14.1ms
# 43:	learn: 0.4645229	total: 88.5ms	remaining: 12.1ms
# 44:	learn: 0.4634544	total: 90.7ms	remaining: 10.1ms
# 45:	learn: 0.4623474	total: 92.8ms	remaining: 8.07ms
# 46:	learn: 0.4617621	total: 94.8ms	remaining: 6.05ms
# 47:	learn: 0.4612259	total: 96.5ms	remaining: 4.02ms
# 48:	learn: 0.4608044	total: 98.7ms	remaining: 2.01ms
# 49:	learn: 0.4594919	total: 101ms	remaining: 0us
# 0:	learn: 0.6667868	total: 2.29ms	remaining: 112ms
# 1:	learn: 0.6388253	total: 4.53ms	remaining: 109ms
# 2:	learn: 0.6205307	total: 6.31ms	remaining: 98.8ms
# 3:	learn: 0.6058625	total: 8.07ms	remaining: 92.8ms
# 4:	learn: 0.5937682	total: 9.87ms	remaining: 88.8ms
# 5:	learn: 0.5825909	total: 11.7ms	remaining: 85.9ms
# 6:	learn: 0.5729638	total: 13.7ms	remaining: 84.2ms
# 7:	learn: 0.5649136	total: 15.5ms	remaining: 81.5ms
# 8:	learn: 0.5557175	total: 17.5ms	remaining: 79.8ms
# 9:	learn: 0.5496107	total: 19.4ms	remaining: 77.7ms
# 10:	learn: 0.5426560	total: 21.3ms	remaining: 75.6ms
# 11:	learn: 0.5368867	total: 23.1ms	remaining: 73.1ms
# 12:	learn: 0.5321070	total: 25ms	remaining: 71.1ms
# 13:	learn: 0.5271892	total: 26.9ms	remaining: 69.1ms
# 14:	learn: 0.5232665	total: 28.8ms	remaining: 67.3ms
# 15:	learn: 0.5190890	total: 30.9ms	remaining: 65.6ms
# 16:	learn: 0.5156503	total: 32.8ms	remaining: 63.6ms
# 17:	learn: 0.5121877	total: 34.7ms	remaining: 61.6ms
# 18:	learn: 0.5090033	total: 36.7ms	remaining: 59.9ms
# 19:	learn: 0.5057770	total: 38.5ms	remaining: 57.7ms
# 20:	learn: 0.5033716	total: 40.4ms	remaining: 55.7ms
# 21:	learn: 0.5005010	total: 42.4ms	remaining: 54ms
# 22:	learn: 0.4983232	total: 44.4ms	remaining: 52.1ms
# 23:	learn: 0.4947594	total: 46.5ms	remaining: 50.3ms
# 24:	learn: 0.4925107	total: 48.5ms	remaining: 48.5ms
# 25:	learn: 0.4905719	total: 50.4ms	remaining: 46.5ms
# 26:	learn: 0.4877510	total: 52.4ms	remaining: 44.7ms
# 27:	learn: 0.4848346	total: 54.7ms	remaining: 43ms
# 28:	learn: 0.4832283	total: 56.8ms	remaining: 41.1ms
# 29:	learn: 0.4811624	total: 59ms	remaining: 39.3ms
# 30:	learn: 0.4798391	total: 60.7ms	remaining: 37.2ms
# 31:	learn: 0.4786645	total: 62.6ms	remaining: 35.2ms
# 32:	learn: 0.4768914	total: 64.8ms	remaining: 33.4ms
# 33:	learn: 0.4749403	total: 67ms	remaining: 31.5ms
# 34:	learn: 0.4738170	total: 69ms	remaining: 29.6ms
# 35:	learn: 0.4729293	total: 70.9ms	remaining: 27.6ms
# 36:	learn: 0.4718017	total: 72.6ms	remaining: 25.5ms
# 37:	learn: 0.4698610	total: 74.4ms	remaining: 23.5ms
# 38:	learn: 0.4690059	total: 76.1ms	remaining: 21.5ms
# 39:	learn: 0.4672475	total: 78.3ms	remaining: 19.6ms
# 40:	learn: 0.4663824	total: 80ms	remaining: 17.6ms
# 41:	learn: 0.4645362	total: 82.2ms	remaining: 15.7ms
# 42:	learn: 0.4640117	total: 84ms	remaining: 13.7ms
# 43:	learn: 0.4629240	total: 86ms	remaining: 11.7ms
# 44:	learn: 0.4619379	total: 88.3ms	remaining: 9.81ms
# 45:	learn: 0.4610768	total: 90ms	remaining: 7.83ms
# 46:	learn: 0.4603090	total: 91.8ms	remaining: 5.86ms
# 47:	learn: 0.4592747	total: 93.5ms	remaining: 3.9ms
# 48:	learn: 0.4583033	total: 95.4ms	remaining: 1.95ms
# 49:	learn: 0.4569160	total: 97.7ms	remaining: 0us
# 0:	learn: 0.6679460	total: 2.06ms	remaining: 101ms
# 1:	learn: 0.6449716	total: 3.8ms	remaining: 91.2ms
# 2:	learn: 0.6200857	total: 5.43ms	remaining: 85.2ms
# 3:	learn: 0.6005830	total: 7.39ms	remaining: 85ms
# 4:	learn: 0.5881022	total: 9.17ms	remaining: 82.5ms
# 5:	learn: 0.5780987	total: 10.8ms	remaining: 79.6ms
# 6:	learn: 0.5669605	total: 12.9ms	remaining: 79ms
# 7:	learn: 0.5600091	total: 14.8ms	remaining: 77.7ms
# 8:	learn: 0.5517858	total: 16.7ms	remaining: 76ms
# 9:	learn: 0.5454415	total: 18.6ms	remaining: 74.2ms
# 10:	learn: 0.5402837	total: 20.4ms	remaining: 72.3ms
# 11:	learn: 0.5342239	total: 22.3ms	remaining: 70.6ms
# 12:	learn: 0.5299053	total: 24.2ms	remaining: 68.8ms
# 13:	learn: 0.5244778	total: 26ms	remaining: 66.9ms
# 14:	learn: 0.5203209	total: 28ms	remaining: 65.3ms
# 15:	learn: 0.5155781	total: 30ms	remaining: 63.8ms
# 16:	learn: 0.5127742	total: 32.1ms	remaining: 62.2ms
# 17:	learn: 0.5091179	total: 34.2ms	remaining: 60.8ms
# 18:	learn: 0.5061158	total: 36.1ms	remaining: 58.9ms
# 19:	learn: 0.5027337	total: 38.1ms	remaining: 57.2ms
# 20:	learn: 0.4991147	total: 40.3ms	remaining: 55.7ms
# 21:	learn: 0.4963348	total: 42.2ms	remaining: 53.7ms
# 22:	learn: 0.4942452	total: 44.1ms	remaining: 51.8ms
# 23:	learn: 0.4916972	total: 46.2ms	remaining: 50.1ms
# 24:	learn: 0.4904304	total: 48.4ms	remaining: 48.4ms
# 25:	learn: 0.4886853	total: 50.6ms	remaining: 46.7ms
# 26:	learn: 0.4870141	total: 52.3ms	remaining: 44.6ms
# 27:	learn: 0.4847861	total: 54.2ms	remaining: 42.6ms
# 28:	learn: 0.4830940	total: 56.1ms	remaining: 40.6ms
# 29:	learn: 0.4810238	total: 57.8ms	remaining: 38.5ms
# 30:	learn: 0.4790785	total: 59.3ms	remaining: 36.4ms
# 31:	learn: 0.4778905	total: 61.6ms	remaining: 34.6ms
# 32:	learn: 0.4765039	total: 63.4ms	remaining: 32.7ms
# 33:	learn: 0.4749829	total: 65.2ms	remaining: 30.7ms
# 34:	learn: 0.4741797	total: 67.2ms	remaining: 28.8ms
# 35:	learn: 0.4729554	total: 69.3ms	remaining: 27ms
# 36:	learn: 0.4712468	total: 71.5ms	remaining: 25.1ms
# 37:	learn: 0.4696630	total: 73.4ms	remaining: 23.2ms
# 38:	learn: 0.4681093	total: 75.4ms	remaining: 21.3ms
# 39:	learn: 0.4670512	total: 77.4ms	remaining: 19.4ms
# 40:	learn: 0.4661988	total: 79.5ms	remaining: 17.5ms
# 41:	learn: 0.4654061	total: 81.3ms	remaining: 15.5ms
# 42:	learn: 0.4634043	total: 83.2ms	remaining: 13.5ms
# 43:	learn: 0.4628821	total: 85ms	remaining: 11.6ms
# 44:	learn: 0.4620958	total: 87.2ms	remaining: 9.69ms
# 45:	learn: 0.4596990	total: 89.2ms	remaining: 7.76ms
# 46:	learn: 0.4585920	total: 91.1ms	remaining: 5.82ms
# 47:	learn: 0.4570942	total: 93.4ms	remaining: 3.89ms
# 48:	learn: 0.4563190	total: 95.3ms	remaining: 1.94ms
# 49:	learn: 0.4556034	total: 97.1ms	remaining: 0us
# 0:	learn: 0.6688877	total: 1.95ms	remaining: 95.5ms
# 1:	learn: 0.6445693	total: 3.79ms	remaining: 91.1ms
# 2:	learn: 0.6262098	total: 5.63ms	remaining: 88.2ms
# 3:	learn: 0.6118502	total: 7.48ms	remaining: 86ms
# 4:	learn: 0.5961059	total: 9.24ms	remaining: 83.2ms
# 5:	learn: 0.5850756	total: 11.1ms	remaining: 81.8ms
# 6:	learn: 0.5753239	total: 12.9ms	remaining: 79.3ms
# 7:	learn: 0.5657306	total: 14.8ms	remaining: 77.6ms
# 8:	learn: 0.5581443	total: 16.7ms	remaining: 76.1ms
# 9:	learn: 0.5517569	total: 18.7ms	remaining: 74.8ms
# 10:	learn: 0.5463962	total: 20.4ms	remaining: 72.3ms
# 11:	learn: 0.5409747	total: 22.2ms	remaining: 70.2ms
# 12:	learn: 0.5361801	total: 24.1ms	remaining: 68.5ms
# 13:	learn: 0.5306119	total: 26ms	remaining: 66.9ms
# 14:	learn: 0.5263653	total: 28.1ms	remaining: 65.7ms
# 15:	learn: 0.5222131	total: 30.2ms	remaining: 64.1ms
# 16:	learn: 0.5187156	total: 32.1ms	remaining: 62.3ms
# 17:	learn: 0.5152195	total: 33.8ms	remaining: 60.2ms
# 18:	learn: 0.5128025	total: 35.5ms	remaining: 58ms
# 19:	learn: 0.5090076	total: 37.6ms	remaining: 56.4ms
# 20:	learn: 0.5064363	total: 39.7ms	remaining: 54.8ms
# 21:	learn: 0.5036196	total: 41.8ms	remaining: 53.1ms
# 22:	learn: 0.5011155	total: 43.8ms	remaining: 51.4ms
# 23:	learn: 0.4994383	total: 45.8ms	remaining: 49.6ms
# 24:	learn: 0.4974425	total: 48.1ms	remaining: 48.1ms
# 25:	learn: 0.4953687	total: 49.7ms	remaining: 45.9ms
# 26:	learn: 0.4933924	total: 51.4ms	remaining: 43.7ms
# 27:	learn: 0.4917085	total: 53.3ms	remaining: 41.9ms
# 28:	learn: 0.4906219	total: 55.2ms	remaining: 40ms
# 29:	learn: 0.4896123	total: 57.1ms	remaining: 38ms
# 30:	learn: 0.4876651	total: 58.9ms	remaining: 36.1ms
# 31:	learn: 0.4862105	total: 60.9ms	remaining: 34.2ms
# 32:	learn: 0.4849791	total: 62.9ms	remaining: 32.4ms
# 33:	learn: 0.4842602	total: 65ms	remaining: 30.6ms
# 34:	learn: 0.4825717	total: 67.1ms	remaining: 28.7ms
# 35:	learn: 0.4812531	total: 68.8ms	remaining: 26.8ms
# 36:	learn: 0.4795735	total: 71ms	remaining: 24.9ms
# 37:	learn: 0.4783108	total: 72.9ms	remaining: 23ms
# 38:	learn: 0.4775893	total: 74.8ms	remaining: 21.1ms
# 39:	learn: 0.4763699	total: 77ms	remaining: 19.2ms
# 40:	learn: 0.4745885	total: 79ms	remaining: 17.4ms
# 41:	learn: 0.4736547	total: 80.9ms	remaining: 15.4ms
# 42:	learn: 0.4729685	total: 82.7ms	remaining: 13.5ms
# 43:	learn: 0.4723392	total: 84.8ms	remaining: 11.6ms
# 44:	learn: 0.4708991	total: 87.1ms	remaining: 9.68ms
# 45:	learn: 0.4694260	total: 89.5ms	remaining: 7.78ms
# 46:	learn: 0.4685814	total: 91.3ms	remaining: 5.83ms
# 47:	learn: 0.4674335	total: 93ms	remaining: 3.88ms
# 48:	learn: 0.4668086	total: 95.2ms	remaining: 1.94ms
# 49:	learn: 0.4660514	total: 97ms	remaining: 0us
# 0:	learn: 0.6683703	total: 1.83ms	remaining: 89.9ms
# 1:	learn: 0.6449610	total: 3.89ms	remaining: 93.4ms
# 2:	learn: 0.6206512	total: 5.73ms	remaining: 89.7ms
# 3:	learn: 0.6062646	total: 7.74ms	remaining: 89ms
# 4:	learn: 0.5904724	total: 9.66ms	remaining: 87ms
# 5:	learn: 0.5816151	total: 11.8ms	remaining: 86.7ms
# 6:	learn: 0.5737270	total: 13.5ms	remaining: 83.2ms
# 7:	learn: 0.5662678	total: 15.7ms	remaining: 82.2ms
# 8:	learn: 0.5587348	total: 17.5ms	remaining: 79.8ms
# 9:	learn: 0.5524557	total: 19.2ms	remaining: 76.8ms
# 10:	learn: 0.5463644	total: 21.2ms	remaining: 75.2ms
# 11:	learn: 0.5399336	total: 23.1ms	remaining: 73ms
# 12:	learn: 0.5348812	total: 25ms	remaining: 71.1ms
# 13:	learn: 0.5308539	total: 27ms	remaining: 69.5ms
# 14:	learn: 0.5270055	total: 29ms	remaining: 67.7ms
# 15:	learn: 0.5231379	total: 30.9ms	remaining: 65.6ms
# 16:	learn: 0.5196431	total: 33ms	remaining: 64ms
# 17:	learn: 0.5155844	total: 34.9ms	remaining: 62.1ms
# 18:	learn: 0.5121258	total: 37ms	remaining: 60.3ms
# 19:	learn: 0.5093416	total: 39ms	remaining: 58.4ms
# 20:	learn: 0.5065345	total: 40.7ms	remaining: 56.2ms
# 21:	learn: 0.5041601	total: 42.6ms	remaining: 54.2ms
# 22:	learn: 0.5014658	total: 44.5ms	remaining: 52.3ms
# 23:	learn: 0.4992802	total: 46.4ms	remaining: 50.3ms
# 24:	learn: 0.4971969	total: 48.7ms	remaining: 48.7ms
# 25:	learn: 0.4953693	total: 50.9ms	remaining: 47ms
# 26:	learn: 0.4923019	total: 53.1ms	remaining: 45.2ms
# 27:	learn: 0.4908287	total: 55.1ms	remaining: 43.3ms
# 28:	learn: 0.4889452	total: 57.2ms	remaining: 41.4ms
# 29:	learn: 0.4869332	total: 59.2ms	remaining: 39.5ms
# 30:	learn: 0.4855248	total: 61.2ms	remaining: 37.5ms
# 31:	learn: 0.4828052	total: 63.5ms	remaining: 35.7ms
# 32:	learn: 0.4819608	total: 65.7ms	remaining: 33.9ms
# 33:	learn: 0.4808246	total: 67.6ms	remaining: 31.8ms
# 34:	learn: 0.4795311	total: 69.7ms	remaining: 29.9ms
# 35:	learn: 0.4778918	total: 71.7ms	remaining: 27.9ms
# 36:	learn: 0.4763882	total: 73.8ms	remaining: 25.9ms
# 37:	learn: 0.4756473	total: 76ms	remaining: 24ms
# 38:	learn: 0.4745737	total: 78ms	remaining: 22ms
# 39:	learn: 0.4739930	total: 79.9ms	remaining: 20ms
# 40:	learn: 0.4733795	total: 81.8ms	remaining: 18ms
# 41:	learn: 0.4726293	total: 83.6ms	remaining: 15.9ms
# 42:	learn: 0.4711953	total: 85.5ms	remaining: 13.9ms
# 43:	learn: 0.4706705	total: 87.3ms	remaining: 11.9ms
# 44:	learn: 0.4701333	total: 89.2ms	remaining: 9.91ms
# 45:	learn: 0.4695271	total: 90.9ms	remaining: 7.91ms
# 46:	learn: 0.4676436	total: 93.2ms	remaining: 5.95ms
# 47:	learn: 0.4670655	total: 95.1ms	remaining: 3.96ms
# 48:	learn: 0.4659609	total: 97.1ms	remaining: 1.98ms
# 49:	learn: 0.4646950	total: 99.4ms	remaining: 0us
# 0:	learn: 0.5906363	total: 1.86ms	remaining: 91.2ms
# 1:	learn: 0.5576844	total: 3.91ms	remaining: 93.8ms
# 2:	learn: 0.5303614	total: 5.89ms	remaining: 92.3ms
# 3:	learn: 0.5137712	total: 7.91ms	remaining: 91ms
# 4:	learn: 0.5004010	total: 10ms	remaining: 90.1ms
# 5:	learn: 0.4845313	total: 11.9ms	remaining: 87.6ms
# 6:	learn: 0.4743721	total: 14.1ms	remaining: 86.6ms
# 7:	learn: 0.4695656	total: 15.9ms	remaining: 83.5ms
# 8:	learn: 0.4645362	total: 17.7ms	remaining: 80.8ms
# 9:	learn: 0.4613510	total: 19.7ms	remaining: 78.8ms
# 10:	learn: 0.4563251	total: 21.8ms	remaining: 77.2ms
# 11:	learn: 0.4515199	total: 23.9ms	remaining: 75.6ms
# 12:	learn: 0.4479321	total: 25.8ms	remaining: 73.3ms
# 13:	learn: 0.4425356	total: 28.1ms	remaining: 72.4ms
# 14:	learn: 0.4392764	total: 30ms	remaining: 69.9ms
# 15:	learn: 0.4363595	total: 31.7ms	remaining: 67.3ms
# 16:	learn: 0.4348142	total: 33.9ms	remaining: 65.9ms
# 17:	learn: 0.4311127	total: 35.7ms	remaining: 63.4ms
# 18:	learn: 0.4291184	total: 37.4ms	remaining: 61.1ms
# 19:	learn: 0.4277400	total: 39.4ms	remaining: 59.1ms
# 20:	learn: 0.4256450	total: 41.1ms	remaining: 56.8ms
# 21:	learn: 0.4240365	total: 43.3ms	remaining: 55.1ms
# 22:	learn: 0.4216935	total: 45.2ms	remaining: 53ms
# 23:	learn: 0.4196815	total: 47.4ms	remaining: 51.3ms
# 24:	learn: 0.4185326	total: 49.6ms	remaining: 49.6ms
# 25:	learn: 0.4172933	total: 51.7ms	remaining: 47.7ms
# 26:	learn: 0.4158959	total: 53.7ms	remaining: 45.8ms
# 27:	learn: 0.4141898	total: 56.4ms	remaining: 44.3ms
# 28:	learn: 0.4133420	total: 58.5ms	remaining: 42.4ms
# 29:	learn: 0.4128770	total: 60.7ms	remaining: 40.4ms
# 30:	learn: 0.4116510	total: 62.9ms	remaining: 38.5ms
# 31:	learn: 0.4108196	total: 65.1ms	remaining: 36.6ms
# 32:	learn: 0.4102992	total: 67.2ms	remaining: 34.6ms
# 33:	learn: 0.4089909	total: 69.1ms	remaining: 32.5ms
# 34:	learn: 0.4081550	total: 71.2ms	remaining: 30.5ms
# 35:	learn: 0.4073993	total: 72.9ms	remaining: 28.3ms
# 36:	learn: 0.4062613	total: 74.7ms	remaining: 26.3ms
# 37:	learn: 0.4055860	total: 76.9ms	remaining: 24.3ms
# 38:	learn: 0.4051578	total: 78.9ms	remaining: 22.2ms
# 39:	learn: 0.4046019	total: 80.7ms	remaining: 20.2ms
# 40:	learn: 0.4042502	total: 82.9ms	remaining: 18.2ms
# 41:	learn: 0.4034875	total: 85ms	remaining: 16.2ms
# 42:	learn: 0.4030648	total: 86.9ms	remaining: 14.2ms
# 43:	learn: 0.4023511	total: 88.9ms	remaining: 12.1ms
# 44:	learn: 0.4016502	total: 90.6ms	remaining: 10.1ms
# 45:	learn: 0.4007959	total: 92.8ms	remaining: 8.07ms
# 46:	learn: 0.4000034	total: 94.8ms	remaining: 6.05ms
# 47:	learn: 0.3979931	total: 96.5ms	remaining: 4.02ms
# 48:	learn: 0.3957959	total: 98.4ms	remaining: 2.01ms
# 49:	learn: 0.3952576	total: 101ms	remaining: 0us
# 0:	learn: 0.5923566	total: 1.98ms	remaining: 97ms
# 1:	learn: 0.5415166	total: 3.86ms	remaining: 92.6ms
# 2:	learn: 0.5183488	total: 5.85ms	remaining: 91.7ms
# 3:	learn: 0.5014290	total: 7.67ms	remaining: 88.2ms
# 4:	learn: 0.4879783	total: 9.34ms	remaining: 84ms
# 5:	learn: 0.4785849	total: 11.4ms	remaining: 83.7ms
# 6:	learn: 0.4668638	total: 13.5ms	remaining: 83.2ms
# 7:	learn: 0.4629378	total: 15.2ms	remaining: 80ms
# 8:	learn: 0.4595192	total: 17.5ms	remaining: 79.5ms
# 9:	learn: 0.4560800	total: 19.4ms	remaining: 77.8ms
# 10:	learn: 0.4531265	total: 21.4ms	remaining: 75.7ms
# 11:	learn: 0.4495543	total: 23.2ms	remaining: 73.6ms
# 12:	learn: 0.4464767	total: 25.3ms	remaining: 72.1ms
# 13:	learn: 0.4435363	total: 27.5ms	remaining: 70.7ms
# 14:	learn: 0.4409674	total: 29.3ms	remaining: 68.3ms
# 15:	learn: 0.4394174	total: 31.2ms	remaining: 66.4ms
# 16:	learn: 0.4352294	total: 33.1ms	remaining: 64.2ms
# 17:	learn: 0.4320239	total: 35ms	remaining: 62.2ms
# 18:	learn: 0.4297436	total: 37.2ms	remaining: 60.7ms
# 19:	learn: 0.4276842	total: 39.2ms	remaining: 58.8ms
# 20:	learn: 0.4263550	total: 41.3ms	remaining: 57.1ms
# 21:	learn: 0.4248943	total: 43.6ms	remaining: 55.5ms
# 22:	learn: 0.4235105	total: 45.5ms	remaining: 53.4ms
# 23:	learn: 0.4221659	total: 47.4ms	remaining: 51.4ms
# 24:	learn: 0.4201183	total: 49.3ms	remaining: 49.3ms
# 25:	learn: 0.4188996	total: 51.3ms	remaining: 47.4ms
# 26:	learn: 0.4168309	total: 53.5ms	remaining: 45.6ms
# 27:	learn: 0.4147795	total: 55.4ms	remaining: 43.5ms
# 28:	learn: 0.4129983	total: 57.4ms	remaining: 41.6ms
# 29:	learn: 0.4120221	total: 59.6ms	remaining: 39.7ms
# 30:	learn: 0.4106401	total: 61.6ms	remaining: 37.8ms
# 31:	learn: 0.4073558	total: 63.6ms	remaining: 35.8ms
# 32:	learn: 0.4052451	total: 65.3ms	remaining: 33.7ms
# 33:	learn: 0.4038950	total: 67.2ms	remaining: 31.6ms
# 34:	learn: 0.4028125	total: 69.1ms	remaining: 29.6ms
# 35:	learn: 0.4020659	total: 71ms	remaining: 27.6ms
# 36:	learn: 0.4009568	total: 72.7ms	remaining: 25.5ms
# 37:	learn: 0.4000661	total: 75ms	remaining: 23.7ms
# 38:	learn: 0.3990391	total: 77.1ms	remaining: 21.7ms
# 39:	learn: 0.3981919	total: 79ms	remaining: 19.8ms
# 40:	learn: 0.3976694	total: 80.7ms	remaining: 17.7ms
# 41:	learn: 0.3969874	total: 82.5ms	remaining: 15.7ms
# 42:	learn: 0.3960745	total: 84.2ms	remaining: 13.7ms
# 43:	learn: 0.3953685	total: 86.2ms	remaining: 11.8ms
# 44:	learn: 0.3945325	total: 88.2ms	remaining: 9.8ms
# 45:	learn: 0.3939224	total: 89.9ms	remaining: 7.82ms
# 46:	learn: 0.3934495	total: 92.1ms	remaining: 5.88ms
# 47:	learn: 0.3924189	total: 93.9ms	remaining: 3.91ms
# 48:	learn: 0.3909530	total: 95.8ms	remaining: 1.95ms
# 49:	learn: 0.3904654	total: 97.7ms	remaining: 0us
# 0:	learn: 0.5971439	total: 1.97ms	remaining: 96.8ms
# 1:	learn: 0.5393232	total: 4.43ms	remaining: 106ms
# 2:	learn: 0.5138270	total: 6.37ms	remaining: 99.9ms
# 3:	learn: 0.4950564	total: 8.3ms	remaining: 95.5ms
# 4:	learn: 0.4856774	total: 10.3ms	remaining: 92.8ms
# 5:	learn: 0.4752633	total: 12.5ms	remaining: 91.8ms
# 6:	learn: 0.4703857	total: 14.2ms	remaining: 87.2ms
# 7:	learn: 0.4651265	total: 16.1ms	remaining: 84.7ms
# 8:	learn: 0.4609710	total: 18.1ms	remaining: 82.7ms
# 9:	learn: 0.4541407	total: 20.3ms	remaining: 81.3ms
# 10:	learn: 0.4507113	total: 22.3ms	remaining: 79ms
# 11:	learn: 0.4462833	total: 24.6ms	remaining: 77.8ms
# 12:	learn: 0.4420736	total: 26.3ms	remaining: 74.9ms
# 13:	learn: 0.4405753	total: 28.5ms	remaining: 73.4ms
# 14:	learn: 0.4381965	total: 30.6ms	remaining: 71.5ms
# 15:	learn: 0.4367844	total: 32.5ms	remaining: 69.1ms
# 16:	learn: 0.4350234	total: 34.3ms	remaining: 66.5ms
# 17:	learn: 0.4324562	total: 36.4ms	remaining: 64.8ms
# 18:	learn: 0.4305512	total: 38.4ms	remaining: 62.6ms
# 19:	learn: 0.4264251	total: 40.1ms	remaining: 60.2ms
# 20:	learn: 0.4249350	total: 42.1ms	remaining: 58.1ms
# 21:	learn: 0.4220234	total: 44.1ms	remaining: 56.1ms
# 22:	learn: 0.4199324	total: 46.4ms	remaining: 54.4ms
# 23:	learn: 0.4186993	total: 47.9ms	remaining: 51.9ms
# 24:	learn: 0.4176918	total: 50.1ms	remaining: 50.1ms
# 25:	learn: 0.4164788	total: 51.9ms	remaining: 47.9ms
# 26:	learn: 0.4150534	total: 53.7ms	remaining: 45.7ms
# 27:	learn: 0.4141650	total: 55.9ms	remaining: 43.9ms
# 28:	learn: 0.4124292	total: 58ms	remaining: 42ms
# 29:	learn: 0.4113436	total: 59.6ms	remaining: 39.8ms
# 30:	learn: 0.4083040	total: 61.5ms	remaining: 37.7ms
# 31:	learn: 0.4076819	total: 63.2ms	remaining: 35.5ms
# 32:	learn: 0.4069871	total: 65.3ms	remaining: 33.6ms
# 33:	learn: 0.4059652	total: 67.3ms	remaining: 31.7ms
# 34:	learn: 0.4050508	total: 69.3ms	remaining: 29.7ms
# 35:	learn: 0.4044399	total: 71.5ms	remaining: 27.8ms
# 36:	learn: 0.4037448	total: 73.8ms	remaining: 25.9ms
# 37:	learn: 0.4033270	total: 75.9ms	remaining: 24ms
# 38:	learn: 0.4028459	total: 78.1ms	remaining: 22ms
# 39:	learn: 0.4022365	total: 79.8ms	remaining: 19.9ms
# 40:	learn: 0.4010423	total: 81.8ms	remaining: 18ms
# 41:	learn: 0.4002236	total: 83.8ms	remaining: 16ms
# 42:	learn: 0.3993503	total: 85.8ms	remaining: 14ms
# 43:	learn: 0.3986911	total: 87.9ms	remaining: 12ms
# 44:	learn: 0.3976876	total: 90ms	remaining: 10ms
# 45:	learn: 0.3972131	total: 92.1ms	remaining: 8.01ms
# 46:	learn: 0.3966836	total: 94.3ms	remaining: 6.02ms
# 47:	learn: 0.3960446	total: 96ms	remaining: 4ms
# 48:	learn: 0.3955087	total: 97.8ms	remaining: 2ms
# 49:	learn: 0.3949627	total: 99.9ms	remaining: 0us
# 0:	learn: 0.6004753	total: 1.98ms	remaining: 96.9ms
# 1:	learn: 0.5527448	total: 3.77ms	remaining: 90.5ms
# 2:	learn: 0.5257089	total: 5.82ms	remaining: 91.2ms
# 3:	learn: 0.5066569	total: 7.53ms	remaining: 86.6ms
# 4:	learn: 0.4975645	total: 9.28ms	remaining: 83.5ms
# 5:	learn: 0.4894840	total: 11.4ms	remaining: 83.3ms
# 6:	learn: 0.4816507	total: 13.4ms	remaining: 82.2ms
# 7:	learn: 0.4755803	total: 15.6ms	remaining: 81.9ms
# 8:	learn: 0.4676324	total: 17.7ms	remaining: 80.8ms
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 3731, number of negative: 3658
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001555 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1964
# [LightGBM] [Info] Number of data points in the train set: 7389, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504940 -> initscore=0.019760
# [LightGBM] [Info] Start training from score 0.019760
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Metrics for lightgbm: accuracy- 0.791, precision- 0.775, recall- 0.818
# Best parameters for lightgbm: {'lgbmclassifier__learning_rate': 0.05, 'lgbmclassifier__max_depth': 4, 'lgbmclassifier__n_estimators': 150, 'lgbmclassifier__subsample': 0.6}
# Metrics for randomforest: accuracy- 0.765, precision- 0.779, recall- 0.736
# Best parameters for randomforest: {'randomforestclassifier__max_depth': 5, 'randomforestclassifier__min_samples_split': 3, 'randomforestclassifier__n_estimators': 100}
# Metrics for logistic: accuracy- 0.767, precision- 0.753, recall- 0.790
# Best parameters for logistic: {'logisticregression__C': 0.1}
# Metrics for knn: accuracy- 0.744, precision- 0.760, recall- 0.708
# Best parameters for knn: {'kneighborsclassifier__metric': 'manhattan', 'kneighborsclassifier__n_neighbors': 7, 'kneighborsclassifier__weights': 'uniform'}

# %%
metrics.sort(key=lambda x: x[1], reverse=True)

print("\nSorted model metrics (by accuracy):")
for metric in metrics:
    print(f"Model: {metric[0]}, Accuracy: {metric[1]:.3f}, Precision: {metric[2]:.3f}, Recall: {metric[3]:.3f}")
# Out:
# Sorted model metrics (by accuracy):
# Model: catboost, Accuracy: 0.802, Precision: 0.783, Recall: 0.832
# Model: xgboost, Accuracy: 0.795, Precision: 0.777, Recall: 0.824
# Model: gradientboost, Accuracy: 0.793, Precision: 0.776, Recall: 0.819
# Model: lightgbm, Accuracy: 0.791, Precision: 0.775, Recall: 0.818
# Model: logistic, Accuracy: 0.767, Precision: 0.753, Recall: 0.790
# Model: adaboost, Accuracy: 0.766, Precision: 0.759, Recall: 0.774
# Model: randomforest, Accuracy: 0.765, Precision: 0.779, Recall: 0.736
# Model: knn, Accuracy: 0.744, Precision: 0.760, Recall: 0.708

# %% [markdown]
# # 9. Apply ensemble method on the test set

# %%
from sklearn.ensemble import VotingClassifier

top_models = [name for name, _, _, _ in metrics[:5]]

estimators = [(name, best_estimators[name]) for name in top_models]

ensemble_model = VotingClassifier(estimators=estimators, voting='soft', n_jobs=-1)

ensemble_model.fit(X, y)

test_df = test_df.drop("Transported",axis=1)
test_predictions = ensemble_model.predict(test_df)
test_predictions = test_predictions.astype(bool)
# Out:
# 0:	learn: 0.6537704	total: 3.71ms	remaining: 554ms
# 1:	learn: 0.6211044	total: 7.45ms	remaining: 551ms
# 2:	learn: 0.5952589	total: 10.8ms	remaining: 531ms
# 3:	learn: 0.5755511	total: 14ms	remaining: 511ms
# 4:	learn: 0.5594800	total: 17.4ms	remaining: 503ms
# 5:	learn: 0.5480146	total: 20.9ms	remaining: 503ms
# 6:	learn: 0.5357977	total: 24.6ms	remaining: 502ms
# 7:	learn: 0.5241577	total: 27.8ms	remaining: 493ms
# 8:	learn: 0.5161962	total: 30.8ms	remaining: 482ms
# 9:	learn: 0.5059874	total: 33.6ms	remaining: 470ms
# 10:	learn: 0.4968812	total: 37.2ms	remaining: 470ms
# 11:	learn: 0.4914310	total: 40.6ms	remaining: 467ms
# 12:	learn: 0.4865781	total: 44.3ms	remaining: 466ms
# 13:	learn: 0.4810976	total: 47.9ms	remaining: 465ms
# 14:	learn: 0.4771136	total: 51.2ms	remaining: 461ms
# 15:	learn: 0.4731935	total: 54.9ms	remaining: 460ms
# 16:	learn: 0.4700605	total: 58.5ms	remaining: 458ms
# 17:	learn: 0.4658440	total: 62.2ms	remaining: 456ms
# 18:	learn: 0.4605219	total: 65.6ms	remaining: 453ms
# 19:	learn: 0.4582298	total: 69ms	remaining: 449ms
# 20:	learn: 0.4557967	total: 72.6ms	remaining: 446ms
# 21:	learn: 0.4542378	total: 76.3ms	remaining: 444ms
# 22:	learn: 0.4520733	total: 79.8ms	remaining: 441ms
# 23:	learn: 0.4500065	total: 83.1ms	remaining: 437ms
# 24:	learn: 0.4476802	total: 86.8ms	remaining: 434ms
# 25:	learn: 0.4463994	total: 90.4ms	remaining: 431ms
# 26:	learn: 0.4447012	total: 93.8ms	remaining: 427ms
# 27:	learn: 0.4426978	total: 97.3ms	remaining: 424ms
# 28:	learn: 0.4414347	total: 101ms	remaining: 420ms
# 29:	learn: 0.4396767	total: 104ms	remaining: 417ms
# 30:	learn: 0.4385454	total: 108ms	remaining: 413ms
# 31:	learn: 0.4368347	total: 111ms	remaining: 410ms
# 32:	learn: 0.4359295	total: 115ms	remaining: 407ms
# 33:	learn: 0.4353143	total: 118ms	remaining: 403ms
# 34:	learn: 0.4346174	total: 122ms	remaining: 400ms
# 35:	learn: 0.4333706	total: 125ms	remaining: 396ms
# 36:	learn: 0.4320373	total: 129ms	remaining: 393ms
# 37:	learn: 0.4308390	total: 133ms	remaining: 391ms
# 38:	learn: 0.4300247	total: 136ms	remaining: 387ms
# 39:	learn: 0.4283110	total: 140ms	remaining: 384ms
# 40:	learn: 0.4267873	total: 143ms	remaining: 379ms
# 41:	learn: 0.4258913	total: 146ms	remaining: 376ms
# 42:	learn: 0.4251337	total: 150ms	remaining: 373ms
# 43:	learn: 0.4245693	total: 153ms	remaining: 369ms
# 44:	learn: 0.4234691	total: 157ms	remaining: 366ms
# 45:	learn: 0.4228556	total: 160ms	remaining: 362ms
# 46:	learn: 0.4218684	total: 164ms	remaining: 359ms
# 47:	learn: 0.4214131	total: 167ms	remaining: 356ms
# 48:	learn: 0.4208216	total: 171ms	remaining: 352ms
# 49:	learn: 0.4203446	total: 174ms	remaining: 349ms
# 50:	learn: 0.4196063	total: 178ms	remaining: 345ms
# 51:	learn: 0.4187426	total: 181ms	remaining: 341ms
# 52:	learn: 0.4182529	total: 184ms	remaining: 338ms
# 53:	learn: 0.4177584	total: 188ms	remaining: 334ms
# 54:	learn: 0.4174194	total: 191ms	remaining: 331ms
# 55:	learn: 0.4167607	total: 195ms	remaining: 327ms
# 56:	learn: 0.4162340	total: 199ms	remaining: 325ms
# 57:	learn: 0.4155228	total: 204ms	remaining: 323ms
# 58:	learn: 0.4150133	total: 207ms	remaining: 319ms
# 59:	learn: 0.4145107	total: 210ms	remaining: 316ms
# 60:	learn: 0.4139902	total: 214ms	remaining: 312ms
# 61:	learn: 0.4136756	total: 217ms	remaining: 309ms
# 62:	learn: 0.4132564	total: 221ms	remaining: 305ms
# 63:	learn: 0.4125335	total: 224ms	remaining: 301ms
# 64:	learn: 0.4120914	total: 228ms	remaining: 298ms
# 65:	learn: 0.4115819	total: 232ms	remaining: 295ms
# 66:	learn: 0.4094458	total: 235ms	remaining: 292ms
# 67:	learn: 0.4088839	total: 239ms	remaining: 288ms
# 68:	learn: 0.4081155	total: 242ms	remaining: 284ms
# 69:	learn: 0.4078091	total: 246ms	remaining: 281ms
# 70:	learn: 0.4073737	total: 249ms	remaining: 277ms
# 71:	learn: 0.4069653	total: 253ms	remaining: 274ms
# 72:	learn: 0.4057859	total: 256ms	remaining: 270ms
# 73:	learn: 0.4054462	total: 260ms	remaining: 267ms
# 74:	learn: 0.4051516	total: 263ms	remaining: 263ms
# 75:	learn: 0.4049093	total: 267ms	remaining: 260ms
# 76:	learn: 0.4045632	total: 270ms	remaining: 256ms
# 77:	learn: 0.4041584	total: 273ms	remaining: 252ms
# 78:	learn: 0.4039310	total: 277ms	remaining: 249ms
# 79:	learn: 0.4035156	total: 280ms	remaining: 245ms
# 80:	learn: 0.4030226	total: 284ms	remaining: 242ms
# 81:	learn: 0.4024085	total: 287ms	remaining: 238ms
# 82:	learn: 0.4020740	total: 291ms	remaining: 235ms
# 83:	learn: 0.4018575	total: 294ms	remaining: 231ms
# 84:	learn: 0.4006556	total: 298ms	remaining: 228ms
# 85:	learn: 0.4004417	total: 302ms	remaining: 224ms
# 86:	learn: 0.3996083	total: 305ms	remaining: 221ms
# 87:	learn: 0.3994042	total: 309ms	remaining: 218ms
# 88:	learn: 0.3988081	total: 312ms	remaining: 214ms
# 89:	learn: 0.3985050	total: 316ms	remaining: 210ms
# 90:	learn: 0.3974828	total: 319ms	remaining: 207ms
# 91:	learn: 0.3971219	total: 323ms	remaining: 203ms
# 92:	learn: 0.3966729	total: 326ms	remaining: 200ms
# 93:	learn: 0.3963062	total: 329ms	remaining: 196ms
# 94:	learn: 0.3960207	total: 333ms	remaining: 193ms
# 95:	learn: 0.3955785	total: 337ms	remaining: 189ms
# 96:	learn: 0.3950875	total: 340ms	remaining: 186ms
# 97:	learn: 0.3948019	total: 343ms	remaining: 182ms
# 98:	learn: 0.3945288	total: 347ms	remaining: 179ms
# 99:	learn: 0.3941839	total: 351ms	remaining: 175ms
# 100:	learn: 0.3939991	total: 354ms	remaining: 172ms
# 101:	learn: 0.3936890	total: 358ms	remaining: 168ms
# 102:	learn: 0.3933565	total: 361ms	remaining: 165ms
# 103:	learn: 0.3925022	total: 365ms	remaining: 161ms
# 104:	learn: 0.3921029	total: 368ms	remaining: 158ms
# 105:	learn: 0.3918530	total: 372ms	remaining: 154ms
# 106:	learn: 0.3915619	total: 375ms	remaining: 151ms
# 107:	learn: 0.3911503	total: 379ms	remaining: 147ms
# 108:	learn: 0.3905026	total: 383ms	remaining: 144ms
# 109:	learn: 0.3900476	total: 386ms	remaining: 140ms
# 110:	learn: 0.3893380	total: 390ms	remaining: 137ms
# 111:	learn: 0.3889845	total: 393ms	remaining: 133ms
# 112:	learn: 0.3886544	total: 398ms	remaining: 130ms
# 113:	learn: 0.3884062	total: 401ms	remaining: 127ms
# 114:	learn: 0.3872757	total: 405ms	remaining: 123ms
# 115:	learn: 0.3865993	total: 408ms	remaining: 120ms
# 116:	learn: 0.3862384	total: 412ms	remaining: 116ms
# 117:	learn: 0.3859056	total: 415ms	remaining: 113ms
# 118:	learn: 0.3854677	total: 419ms	remaining: 109ms
# 119:	learn: 0.3850050	total: 422ms	remaining: 106ms
# 120:	learn: 0.3846936	total: 426ms	remaining: 102ms
# 121:	learn: 0.3843943	total: 429ms	remaining: 98.5ms
# 122:	learn: 0.3840755	total: 433ms	remaining: 95ms
# 123:	learn: 0.3836757	total: 436ms	remaining: 91.4ms
# 124:	learn: 0.3833894	total: 440ms	remaining: 87.9ms
# 125:	learn: 0.3830248	total: 443ms	remaining: 84.4ms
# 126:	learn: 0.3826950	total: 447ms	remaining: 80.9ms
# 127:	learn: 0.3823595	total: 450ms	remaining: 77.4ms
# 128:	learn: 0.3820095	total: 454ms	remaining: 73.9ms
# 129:	learn: 0.3816380	total: 457ms	remaining: 70.4ms
# 130:	learn: 0.3813775	total: 461ms	remaining: 66.9ms
# 131:	learn: 0.3811211	total: 464ms	remaining: 63.3ms
# 132:	learn: 0.3807777	total: 467ms	remaining: 59.7ms
# 133:	learn: 0.3804031	total: 470ms	remaining: 56.2ms
# 134:	learn: 0.3801653	total: 474ms	remaining: 52.7ms
# 135:	learn: 0.3797301	total: 477ms	remaining: 49.1ms
# 136:	learn: 0.3793559	total: 481ms	remaining: 45.6ms
# 137:	learn: 0.3790805	total: 485ms	remaining: 42.2ms
# 138:	learn: 0.3788574	total: 489ms	remaining: 38.7ms
# 139:	learn: 0.3785866	total: 492ms	remaining: 35.1ms
# 140:	learn: 0.3783443	total: 495ms	remaining: 31.6ms
# 141:	learn: 0.3780638	total: 499ms	remaining: 28.1ms
# 142:	learn: 0.3777166	total: 502ms	remaining: 24.6ms
# 143:	learn: 0.3774798	total: 506ms	remaining: 21.1ms
# 144:	learn: 0.3771838	total: 509ms	remaining: 17.6ms
# 145:	learn: 0.3769862	total: 513ms	remaining: 14.1ms
# 146:	learn: 0.3768371	total: 516ms	remaining: 10.5ms
# 147:	learn: 0.3762049	total: 520ms	remaining: 7.02ms
# 148:	learn: 0.3759676	total: 523ms	remaining: 3.51ms
# 149:	learn: 0.3757126	total: 527ms	remaining: 0us
# [LightGBM] [Info] Number of positive: 4378, number of negative: 4315
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001621 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1973
# [LightGBM] [Info] Number of data points in the train set: 8693, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503624 -> initscore=0.014495
# [LightGBM] [Info] Start training from score 0.014495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
submission = pd.DataFrame([test_data['PassengerId'], test_predictions]).T
submission.columns = ['PassengerID', 'Transported']

# %%
submission.head()
# Out:
#   PassengerID Transported
# 0     0013_01        True
# 1     0018_01       False
# 2     0019_01        True
# 3     0021_01        True
# 4     0023_01        True

# %%
submission.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
